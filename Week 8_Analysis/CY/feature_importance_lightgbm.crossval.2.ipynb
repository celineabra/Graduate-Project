# %%
#this version uses groups of features instead of all features
import pandas as pd
import os

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', None)
pd.set_option('display.expand_frame_repr', False)

# %%
import numpy as np
from sklearn.model_selection import KFold
from sklearn.impute import KNNImputer
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from lightgbm import LGBMRegressor
import re

# %%
folder_loc = 'F:/class/BANA 698/week 8'

file_list = [f for f in os.listdir(folder_loc) if os.path.isfile(os.path.join(folder_loc, f))]
#for file in file_list: print(file)

# %%
file = 'Group1DatasetRaw.onehotted.csv'
df = pd.read_csv(os.path.join(folder_loc, file))

# %%
#for col in sorted(df.columns): print(col)

# %%
target = 'Life expectancy at birth, total (years)'

cols_to_exclude = [
    #target and directly related
    'Life expectancy at birth, total (years)',
    'Life expectancy at birth, female (years)',
    'Life expectancy at birth, male (years)',
    'CountryShortName',
    'Year',
    #perfect correlate determined by correlation_to_all_lister.ipynb
    'Rural population (% of total population)' #'Urban population (% of total population)'
]

# %%
#function to remove special chars and spaces from feature names bc lightgbm can't handle them
def clean_col_name(col_name):
    col_name = col_name.replace('-', ' to ')
    col_name = col_name.replace('=', 'equals')
    col_name = col_name.replace('/', ' divided by ')
    col_name = col_name.replace('%', 'percent')
    col_name = col_name.replace('$', 'dollars')
    col_name = col_name.replace('&', 'and')
    col_name = col_name.replace(' ', '_')
    col_name = re.sub(r'[^\w\s]', '', col_name)
    col_name = col_name.strip()
    return col_name

# %%
target = clean_col_name(target)
cols_to_exclude = [clean_col_name(col) for col in cols_to_exclude]
df.columns = df.columns.map(clean_col_name)

# %%
#print(target)
#for col in cols_to_exclude: print(col)
#for col in sorted(df.columns): print(col)

# %%
#default hyperparameters (don't edit)
lgbm_defaults = {
    'boosting_type': 'gbdt',
    'class_weight': None,
    'colsample_bytree': 1.0,
    'importance_type': 'split',
    'learning_rate': 0.1,
    'max_depth': -1,
    'min_child_samples': 20,
    'min_child_weight': 0.001,
    'min_split_gain': 0.0,
    'n_estimators': 100,
    'n_jobs': None,
    'num_leaves': 31,
    'objective': None,
    'random_state': None,
    'reg_alpha': 0.0,
    'reg_lambda': 0.0,
    'subsample': 1.0,
    'subsample_for_bin': 200000,
    'subsample_freq': 0
 }
#from:
#model = LGBMRegressor()
#model.get_params()

# %%
#in production hyperparameters
lgbm_params = {
    'boosting_type': 'gbdt',
    'class_weight': None,
    'colsample_bytree': 1.0,
    'importance_type': 'split',
    'learning_rate': 0.1,
    'max_depth': -1,
    'min_child_samples': 20,
    'min_child_weight': 0.001,
    'min_split_gain': 0.0,
    'n_estimators': 100,
    'n_jobs': -1,
    'num_leaves': 31,
    'objective': None,
    'random_state': 1,
    'reg_alpha': 0.0,
    'reg_lambda': 0.0,
    'subsample': 1.0,
    'subsample_for_bin': 200000,
    'subsample_freq': 0,
    'verbose': 0
}

# %%
def lgbm_features(cols_to_exclude = cols_to_exclude, target = target, df = df, kfold_random_state = 1, n_neighbors = 5):
    X = df.drop(columns = cols_to_exclude)
    y = df[target]

    cv = KFold(n_splits=5, shuffle=True, random_state = kfold_random_state)

    mae_scores = []
    mse_scores = []
    r2_scores = []
    r2_train_scores = []
    feature_importance_list = []

    for train_idx, val_idx in cv.split(X):
        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]
        
        imputer = KNNImputer(n_neighbors = n_neighbors)
        X_train_imputed = imputer.fit_transform(X_train)
        X_val_imputed = imputer.transform(X_val)        
        X_train_imputed = pd.DataFrame(X_train_imputed, columns=X_train.columns)
        X_val_imputed = pd.DataFrame(X_val_imputed, columns=X_val.columns)
        
        model = LGBMRegressor(**lgbm_params)
        model.fit(X_train_imputed, y_train)
        y_train_pred = model.predict(X_train_imputed)
        y_pred = model.predict(X_val_imputed)
        
        mae = mean_absolute_error(y_val, y_pred)
        mse = mean_squared_error(y_val, y_pred)
        r2_train = r2_score(y_train, y_train_pred)
        r2 = r2_score(y_val, y_pred)        
        mae_scores.append(mae)
        mse_scores.append(mse)
        r2_train_scores.append(r2_train)
        r2_scores.append(r2)
        
        feature_importance_list.append(model.feature_importances_)


    avg_mae = np.mean(mae_scores)
    avg_mse = np.mean(mse_scores)
    avg_r2_train = np.mean(r2_train_scores)
    avg_r2 = np.mean(r2_scores)

    print(f'Average MAE: {avg_mae:.4f}')
    print(f'Average MSE: {avg_mse:.4f}')
    print(f'Average Training R²: {avg_r2_train:.4f}')
    print(f'Average Validation R²: {avg_r2:.4f}')

    avg_feature_importance = np.mean(feature_importance_list, axis=0)
    feature_importance_df = pd.DataFrame({
        'Feature': X.columns,
        'Importance': avg_feature_importance
    })
    feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False).reset_index(drop=True)
    feature_importance_df['Rank'] = feature_importance_df.index + 1
    feature_importance_df = feature_importance_df[['Feature', 'Importance', 'Rank']]

    print('\nSorted Feature Importance:')
    print(feature_importance_df.to_string(index=False))

# %%
#first run, with all features
lgbm_features()
# Out:
# Average MAE: 0.2799
# Average MSE: 0.1968
# Average Training R²: 0.9997
# Average Validation R²: 0.9972
#
# Sorted Feature Importance:
#                                                                                                               Feature  Importance  Rank
#                                                                    Mortality_rate_adult_female_per_1000_female_adults       202.8     1
#                                                                                      Death_rate_crude_per_1000_people       196.4     2
#                                                                        Mortality_rate_adult_male_per_1000_male_adults       153.6     3
#                                                                   Mortality_rate_under_to_5_male_per_1000_live_births        34.0     4
#                                                          Population_ages_15_to_19_female_percent_of_female_population        31.6     5
#                                                                               Import_unit_value_index_2015_equals_100        27.2     6
#                                                                   Final_consumption_expenditure_annual_percent_growth        27.2     7
#                                                        Probability_of_dying_among_children_ages_5_to_9_years_per_1000        25.8     8
#                                                                    Livestock_production_index_2014_to_2016_equals_100        25.6     9
#                                                                               Export_unit_value_index_2015_equals_100        24.8    10
#                                                                          Mortality_rate_neonatal_per_1000_live_births        24.0    11
#                                                                  Refugee_population_by_country_or_territory_of_origin        23.6    12
#                                                Insurance_and_financial_services_percent_of_commercial_service_exports        22.4    13
#                                                                                  GDP_per_capita_growth_annual_percent        22.0    14
#                                                                           Incidence_of_tuberculosis_per_100000_people        21.4    15
#                                                                          Claims_on_central_government_etc_percent_GDP        21.2    16
#                                                                                 Inflation_GDP_deflator_annual_percent        21.0    17
#                                                                                             GDP_growth_annual_percent        20.8    18
#                                                                                Pillar_3__to__Data_Products__to__Score        20.8    19
#                                                               Official_exchange_rate_LCU_per_USdollars_period_average        20.0    20
#                                                                 Mortality_rate_under_to_5_female_per_1000_live_births        20.0    21
#                                                                         Crop_production_index_2014_to_2016_equals_100        19.8    22
#                                                                         Food_production_index_2014_to_2016_equals_100        19.2    23
#                                                        GOAL_17_Partnerships_to_achieve_the_Goal_5_year_moving_average        19.0    24
#                                                                                       Arable_land_hectares_per_person        18.6    25
#                                                               Current_health_expenditure_per_capita_current_USdollars        17.8    26
#                                                              Transport_services_percent_of_commercial_service_exports        17.8    27
#                                  Domestic_general_government_health_expenditure_percent_of_current_health_expenditure        17.4    28
#                                                              Population_ages_15_to_19_male_percent_of_male_population        17.2    29
#                                    Prevalence_of_stunting_height_for_age_modeled_estimate_percent_of_children_under_5        17.2    30
#                                                                 Travel_services_percent_of_commercial_service_imports        17.2    31
#                                                      Domestic_private_health_expenditure_per_capita_current_USdollars        17.0    32
#                                                                                Urban_population_growth_annual_percent        17.0    33
#                                                              Tuberculosis_treatment_success_rate_percent_of_new_cases        16.6    34
#                                                   GOAL_16_Peace_and_Justice_Strong_Institutions_5_year_moving_average        16.6    35
#                                                                          Exports_of_goods_and_services_percent_of_GDP        16.2    36
#                                                                                      Forest_area_percent_of_land_area        16.2    37
#                                                General_government_final_consumption_expenditure_annual_percent_growth        16.2    38
#                                                                  Population_ages_15_to_64_percent_of_total_population        16.0    39
#                                                                 Travel_services_percent_of_commercial_service_exports        16.0    40
#                                                                                      Birth_rate_crude_per_1000_people        15.8    41
#                     Labor_force_participation_rate_male_percent_of_male_population_ages_15_to_64_modeled_ILO_estimate        15.6    42
#                                                                           Fuel_imports_percent_of_merchandise_imports        15.6    43
#                                                                      Domestic_credit_to_private_sector_percent_of_GDP        15.4    44
#                                                                            Commercial_bank_branches_per_100000_adults        15.4    45
#                                                         Domestic_general_government_health_expenditure_percent_of_GDP        15.2    46
#                                                            Communications_computer_etc_percent_of_service_exports_BoP        15.0    47
#                                                                      GOAL_10_Reduced_Inequality_5_year_moving_average        15.0    48
#                                                                        Mortality_rate_under_to_5_per_1000_live_births        15.0    49
#                                                                                   Compulsory_education_duration_years        14.8    50
#                                                              Transport_services_percent_of_commercial_service_imports        14.6    51
#                                                       Renewable_internal_freshwater_resources_per_capita_cubic_meters        14.6    52
#                                                                                     Pillar_1__to__Data_Use__to__Score        14.4    53
#                                                                                                         Net_migration        14.4    54
#                                                                                            Broad_money_percent_of_GDP        14.2    55
#                                                                     Mortality_rate_infant_female_per_1000_live_births        14.0    56
#                                                         Adolescent_fertility_rate_births_per_1000_women_ages_15_to_19        14.0    57
#                                       Agriculture_forestry_and_fishing_value_added_per_worker_constant_2015_USdollars        13.8    58
#                                                                               Permanent_cropland_percent_of_land_area        13.8    59
#                                          Carbon_dioxide_CO2_emissions_total_excluding_LULUCF_percent_change_from_1990        13.6    60
#                                                                                Total_fisheries_production_metric_tons        13.4    61
#                                                     Proportion_of_seats_held_by_women_in_national_parliaments_percent        13.4    62
#                                                                                GDP_per_capita_constant_2015_USdollars        13.4    63
#                                                                                Agricultural_land_percent_of_land_area        13.4    64
#                                                                 Adjusted_savings_education_expenditure_percent_of_GNI        13.2    65
#                                                                 External_balance_on_goods_and_services_percent_of_GDP        13.2    66
#                                                                  Refugee_population_by_country_or_territory_of_asylum        13.2    67
#                                                                 Adjusted_savings_carbon_dioxide_damage_percent_of_GNI        13.2    68
#                                                   Employment_to_population_ratio_15_male_percent_modeled_ILO_estimate        13.0    69
#                                                    PM25_air_pollution_mean_annual_exposure_micrograms_per_cubic_meter        12.8    70
#                                                     International_tourism_receipts_for_travel_items_current_USdollars        12.8    71
#                                                                          Urban_population_percent_of_total_population        12.8    72
#                                                                        School_enrollment_primary_female_percent_gross        12.8    73
#                                                                          School_enrollment_primary_male_percent_gross        12.8    74
#                                                                                Rural_population_growth_annual_percent        12.8    75
#                                                                          Total_natural_resources_rents_percent_of_GDP        12.6    76
#                                                   Probability_of_dying_among_adolescents_ages_15_to_19_years_per_1000        12.4    77
#                                                                       Labor_force_female_percent_of_total_labor_force        12.2    78
#                                                              Population_ages_10_to_14_male_percent_of_male_population        12.2    79
#                                              Total_greenhouse_gas_emissions_excluding_LULUCF_percent_change_from_1990        12.0    80
#                                             People_using_at_least_basic_drinking_water_services_percent_of_population        12.0    81
#                                                    Carbon_intensity_of_GDP_kg_CO2e_per_constant_2021_USdollars_of_GDP        11.6    82
#                                                                           Fuel_exports_percent_of_merchandise_exports        11.6    83
#                                   Labor_force_participation_rate_for_ages_15_to_24_total_percent_modeled_ILO_estimate        11.6    84
#                                                 Prevalence_of_overweight_modeled_estimate_percent_of_children_under_5        11.4    85
#                                     People_using_at_least_basic_sanitation_services_rural_percent_of_rural_population        11.4    86
#                                Unemployment_youth_male_percent_of_male_labor_force_ages_15_to_24_modeled_ILO_estimate        11.2    87
#                                             Domestic_private_health_expenditure_percent_of_current_health_expenditure        11.2    88
#                                                 Methane_CH4_emissions_total_excluding_LULUCF_percent_change_from_1990        11.0    89
#                                   Ratio_of_female_to_male_labor_force_participation_rate_percent_modeled_ILO_estimate        10.8    90
#                                                      Maternal_mortality_ratio_modeled_estimate_per_100000_live_births        10.8    91
#                                                           Population_ages_0_to_14_female_percent_of_female_population        10.6    92
#                                                                Ores_and_metals_imports_percent_of_merchandise_imports        10.6    93
#                                      Computer_communications_and_other_services_percent_of_commercial_service_exports        10.6    94
#                                                                                      Arable_land_percent_of_land_area        10.4    95
#                                      Computer_communications_and_other_services_percent_of_commercial_service_imports        10.4    96
#                                      Domestic_private_health_expenditure_per_capita_PPP_current_international_dollars        10.4    97
#                          Carbon_dioxide_CO2_net_fluxes_from_LULUCF__to__Total_excluding_non_to_tropical_fires_Mt_CO2e        10.4    98
#                                                  GOAL_12_Responsible_Consumption_and_Production_5_year_moving_average        10.4    99
#                                                    Unemployment_male_percent_of_male_labor_force_modeled_ILO_estimate        10.4   100
#     Share_of_youth_not_in_education_employment_or_training_male_percent_of_male_youth_population_modeled_ILO_estimate        10.2   101
#         Share_of_youth_not_in_education_employment_or_training_total_percent_of_youth_population_modeled_ILO_estimate        10.2   102
#                                                                            Mortality_rate_infant_per_1000_live_births        10.2   103
#                                                Insurance_and_financial_services_percent_of_commercial_service_imports        10.2   104
#                                    Labor_force_participation_rate_for_ages_15_to_24_male_percent_modeled_ILO_estimate        10.0   105
#                              Unemployment_youth_total_percent_of_total_labor_force_ages_15_to_24_modeled_ILO_estimate        10.0   106
#                                                Unemployment_female_percent_of_female_labor_force_modeled_ILO_estimate        10.0   107
#                                                                               Lifetime_risk_of_maternal_death_percent         9.8   108
#                                                               People_practicing_open_defecation_percent_of_population         9.8   109
#                                            Energy_intensity_level_of_primary_energy_MJ_divided_by_dollars2017_PPP_GDP         9.8   110
#                                           Nitrous_oxide_N2O_emissions_total_excluding_LULUCF_percent_change_from_1990         9.8   111
#                                                 Employment_to_population_ratio_15_female_percent_modeled_ILO_estimate         9.8   112
#                                                    Carbon_dioxide_CO2_net_fluxes_from_LULUCF__to__Forest_Land_Mt_CO2e         9.8   113
#                                                             Immunization_DPT_percent_of_children_ages_12_to_23_months         9.6   114
#                                       Employment_to_population_ratio_ages_15_to_24_total_percent_modeled_ILO_estimate         9.6   115
#                                                 Out_to_of_to_pocket_expenditure_percent_of_current_health_expenditure         9.6   116
#                                                         Probability_of_dying_among_youth_ages_20_to_24_years_per_1000         9.4   117
#                                                                    Tuberculosis_case_detection_rate_percent_all_forms         9.4   118
#                                                                               School_enrollment_primary_percent_gross         9.4   119
#                                                                   Inflation_GDP_deflator_linked_series_annual_percent         9.2   120
#                   Water_productivity_total_constant_2015_USdollars_GDP_per_cubic_meter_of_total_freshwater_withdrawal         9.2   121
#                                                          Population_ages_10_to_14_female_percent_of_female_population         8.8   122
# Share_of_youth_not_in_education_employment_or_training_female_percent_of_female_youth_population_modeled_ILO_estimate         8.8   123
#                                                                              Capture_fisheries_production_metric_tons         8.8   124
#                                                                                          Mineral_rents_percent_of_GDP         8.8   125
#                                          Out_to_of_to_pocket_expenditure_per_capita_PPP_current_international_dollars         8.6   126
#                           Labor_force_participation_rate_male_percent_of_male_population_ages_15_modeled_ILO_estimate         8.6   127
#                                                 People_using_at_least_basic_sanitation_services_percent_of_population         8.6   128
#                            Unemployment_youth_female_percent_of_female_labor_force_ages_15_to_24_modeled_ILO_estimate         8.6   129
#                                                                      Automated_teller_machines_ATMs_per_100000_adults         8.6   130
#                                                                     Prevalence_of_anemia_among_pregnant_women_percent         8.6   131
#                                           Prevalence_of_anemia_among_children_percent_of_children_ages_6_to_59_months         8.4   132
#                                                                             Current_health_expenditure_percent_of_GDP         8.4   133
#                   Labor_force_participation_rate_total_percent_of_total_population_ages_15_to_64_modeled_ILO_estimate         8.4   134
#                                                                      Adjusted_savings_energy_depletion_percent_of_GNI         8.4   135
#                                                                       Mortality_rate_infant_male_per_1000_live_births         8.2   136
#                                                            Communications_computer_etc_percent_of_service_imports_BoP         8.2   137
#                                                                              International_tourism_number_of_arrivals         8.2   138
#                                     People_using_at_least_basic_sanitation_services_urban_percent_of_urban_population         8.2   139
#                                                                                    Aquaculture_production_metric_tons         8.0   140
#                                                                                           Forest_rents_percent_of_GDP         8.0   141
#                                                      GOAL_11_Sustainable_Cities_and_Communities_5_year_moving_average         7.8   142
#                                                  Unemployment_total_percent_of_total_labor_force_modeled_ILO_estimate         7.8   143
#                                               Current_health_expenditure_per_capita_PPP_current_international_dollars         7.6   144
#                                                                  Carbon_intensity_of_GDP_kg_CO2e_per_2021_PPP_dollars         7.4   145
#                           Domestic_general_government_health_expenditure_per_capita_PPP_current_international_dollars         7.4   146
#                                                    Renewable_internal_freshwater_resources_total_billion_cubic_meters         7.4   147
#         Total_alcohol_consumption_per_capita_female_liters_of_pure_alcohol_projected_estimates_female_15_years_of_age         7.2   148
#                                       Prevalence_of_anemia_among_non_to_pregnant_women_percent_of_women_ages_15_to_49         7.2   149
#                                                                      Population_density_people_per_sq_km_of_land_area         7.0   150
#                                      Employment_to_population_ratio_ages_15_to_24_female_percent_modeled_ILO_estimate         7.0   151
#                                                  Carbon_dioxide_CO2_net_fluxes_from_LULUCF__to__Deforestation_Mt_CO2e         7.0   152
#                         Labor_force_participation_rate_total_percent_of_total_population_ages_15_modeled_ILO_estimate         7.0   153
#                                                Renewable_energy_consumption_percent_of_total_final_energy_consumption         7.0   154
#                                                          Out_to_of_to_pocket_expenditure_per_capita_current_USdollars         7.0   155
#                                                                      GNI_per_capita_PPP_current_international_dollars         6.8   156
#                                   Fluorinated_greenhouse_gases_F_to_gases_emissions_from_Industrial_Processes_Mt_CO2e         6.8   157
#                                                  Employment_to_population_ratio_15_total_percent_modeled_ILO_estimate         6.6   158
#                                                                    Methane_CH4_emissions_from_Building_Energy_Mt_CO2e         6.6   159
#                                        Vulnerable_employment_female_percent_of_female_employment_modeled_ILO_estimate         6.6   160
#                                           Domestic_general_government_health_expenditure_per_capita_current_USdollars         6.4   161
#                                                                           Access_to_electricity_percent_of_population         6.4   162
#                       Labor_force_participation_rate_female_percent_of_female_population_ages_15_modeled_ILO_estimate         6.4   163
#                                   Total_greenhouse_gas_emissions_per_capita_excluding_LULUCF_t_CO2e_divided_by_capita         6.4   164
#                                             Self_to_employed_female_percent_of_female_employment_modeled_ILO_estimate         6.4   165
#                                               Self_to_employed_total_percent_of_total_employment_modeled_ILO_estimate         6.4   166
#                       Total_alcohol_consumption_per_capita_liters_of_pure_alcohol_projected_estimates_15_years_of_age         6.4   167
#                                                 International_tourism_expenditures_for_travel_items_current_USdollars         6.2   168
#                                                   Probability_of_dying_among_adolescents_ages_10_to_14_years_per_1000         6.2   169
#                                 People_using_at_least_basic_drinking_water_services_urban_percent_of_urban_population         6.2   170
#                                                           Lifetime_risk_of_maternal_death_1_in_rate_varies_by_country         6.0   171
#                                                                  Prevalence_of_undernourishment_percent_of_population         6.0   172
#                                        Employment_to_population_ratio_ages_15_to_24_male_percent_modeled_ILO_estimate         6.0   173
#                                                                                                      Urban_population         6.0   174
#                                                           Fertilizer_consumption_kilograms_per_hectare_of_arable_land         5.8   175
#                                                              Nitrous_oxide_N2O_emissions_from_Building_Energy_Mt_CO2e         5.8   176
#                                  Labor_force_participation_rate_for_ages_15_to_24_female_percent_modeled_ILO_estimate         5.6   177
#                                                                 Women_Business_and_the_Law_Index_Score_scale_1_to_100         5.6   178
#                                                         Immunization_measles_percent_of_children_ages_12_to_23_months         5.6   179
#                                                 Self_to_employed_male_percent_of_male_employment_modeled_ILO_estimate         5.6   180
#                                                                            GOAL_15_Life_on_Land_5_year_moving_average         5.4   181
#                                                                                                       Land_area_sq_km         5.4   182
#                                            Vulnerable_employment_male_percent_of_male_employment_modeled_ILO_estimate         5.4   183
#             Total_alcohol_consumption_per_capita_male_liters_of_pure_alcohol_projected_estimates_male_15_years_of_age         5.2   184
#                                                                                               Number_of_infant_deaths         5.2   185
#                                                         Nitrous_oxide_N2O_emissions_from_Industrial_Processes_Mt_CO2e         5.2   186
#                                                                     GDP_per_person_employed_constant_2021_PPP_dollars         5.2   187
#                                                                  Monetary_Sector_credit_to_private_sector_percent_GDP         5.0   188
#                                                               Population_ages_0_to_14_male_percent_of_male_population         5.0   189
#                                                                                         Cereal_production_metric_tons         4.8   190
#                                                                              Methane_CH4_emissions_from_Waste_Mt_CO2e         4.8   191
#                                                             Carbon_dioxide_CO2_emissions_from_Building_Energy_Mt_CO2e         4.8   192
#                                                                                      Natural_gas_rents_percent_of_GDP         4.8   193
#                                                                   Population_ages_0_to_14_percent_of_total_population         4.8   194
#                                                                                              Oil_rents_percent_of_GDP         4.8   195
#                                                                                             Number_of_neonatal_deaths         4.8   196
#                                                                                              Primary_education_pupils         4.6   197
#                                                           Agriculture_forestry_and_fishing_value_added_percent_of_GDP         4.6   198
#                                                                                                     Forest_area_sq_km         4.4   199
#                                                    Exports_of_goods_services_and_primary_income_BoP_current_USdollars         4.4   200
#                                                              Methane_CH4_emissions_from_Power_Industry_Energy_Mt_CO2e         4.2   201
#                                                                                    Region_Latin_America_and_Caribbean         4.2   202
#                                   Prevalence_of_anemia_among_women_of_reproductive_age_percent_of_women_ages_15_to_49         4.2   203
#                                                   Carbon_dioxide_CO2_emissions_from_Fugitive_Emissions_Energy_Mt_CO2e         4.2   204
#                                                          Methane_CH4_emissions_from_Fugitive_Emissions_Energy_Mt_CO2e         4.2   205
#                                                                   Methane_CH4_emissions_from_Transport_Energy_Mt_CO2e         4.0   206
#                                                    Nitrous_oxide_N2O_emissions_from_Fugitive_Emissions_Energy_Mt_CO2e         4.0   207
#                                                                                  Number_of_deaths_ages_15_to_19_years         4.0   208
#                                  Access_to_clean_fuels_and_technologies_for_cooking_rural_percent_of_rural_population         4.0   209
#                                                        Nitrous_oxide_N2O_emissions_from_Power_Industry_Energy_Mt_CO2e         4.0   210
#                 Labor_force_participation_rate_female_percent_of_female_population_ages_15_to_64_modeled_ILO_estimate         4.0   211
#                                                       Carbon_dioxide_CO2_emissions_from_Power_Industry_Energy_Mt_CO2e         3.8   212
#                                                                                                      Rural_population         3.8   213
#                                                                                 Land_under_cereal_production_hectares         3.8   214
#                                  Access_to_clean_fuels_and_technologies_for_cooking_urban_percent_of_urban_population         3.8   215
#                                                                               GOAL_1_No_Poverty_5_year_moving_average         3.6   216
#                                                               Access_to_electricity_rural_percent_of_rural_population         3.6   217
#                                                                                  Number_of_deaths_ages_20_to_24_years         3.6   218
#                                                                      GDP_per_capita_PPP_current_international_dollars         3.6   219
#                                                 Nitrous_oxide_N2O_emissions_from_Industrial_Combustion_Energy_Mt_CO2e         3.4   220
#                                              Access_to_clean_fuels_and_technologies_for_cooking_percent_of_population         3.4   221
#                                                       Methane_CH4_emissions_from_Industrial_Combustion_Energy_Mt_CO2e         3.4   222
#                                                             Adjusted_net_national_income_per_capita_current_USdollars         3.4   223
#                                                                                             Number_of_maternal_deaths         3.4   224
#                                                                        Methane_CH4_emissions_from_Agriculture_Mt_CO2e         3.2   225
#                                                                         GNI_per_capita_Atlas_method_current_USdollars         3.2   226
#                                                 Health_divided_by_Demographic_survey_Availability_score_over_10_years         3.2   227
#                                                             Domestic_credit_to_private_sector_by_banks_percent_of_GDP         3.2   228
#                                     Carbon_dioxide_CO2_emissions_excluding_LULUCF_per_capita_t_CO2e_divided_by_capita         3.2   229
#                                                               Access_to_electricity_urban_percent_of_urban_population         3.0   230
#                                                                                    Number_of_deaths_ages_5_to_9_years         3.0   231
#                                                               Total_greenhouse_gas_emissions_including_LULUCF_Mt_CO2e         3.0   232
#                                                Carbon_dioxide_CO2_emissions_from_Industrial_Combustion_Energy_Mt_CO2e         2.6   233
#                                                                  Nitrous_oxide_N2O_emissions_from_Agriculture_Mt_CO2e         2.6   234
#                                                                 Final_consumption_expenditure_constant_2015_USdollars         2.6   235
#                                      Wage_and_salaried_workers_total_percent_of_total_employment_modeled_ILO_estimate         2.4   236
#                                        Wage_and_salaried_workers_male_percent_of_male_employment_modeled_ILO_estimate         2.4   237
#                                                                          GOAL_13_Climate_Action_5_year_moving_average         2.4   238
#                                                               Total_greenhouse_gas_emissions_excluding_LULUCF_Mt_CO2e         2.4   239
#                                                                        Nitrous_oxide_N2O_emissions_from_Waste_Mt_CO2e         2.4   240
#                                                            Carbon_dioxide_CO2_emissions_from_Transport_Energy_Mt_CO2e         2.4   241
#                                                                                        Population_ages_0_to_14_female         2.2   242
#                                          Vulnerable_employment_total_percent_of_total_employment_modeled_ILO_estimate         2.2   243
#                                                             Nitrous_oxide_N2O_emissions_from_Transport_Energy_Mt_CO2e         2.2   244
#                                                                  Methane_CH4_emissions_total_excluding_LULUCF_Mt_CO2e         2.2   245
#                                    Wage_and_salaried_workers_female_percent_of_female_employment_modeled_ILO_estimate         2.0   246
#                                                                                             Coal_rents_percent_of_GDP         2.0   247
#                                                        Carbon_dioxide_CO2_emissions_from_Industrial_Processes_Mt_CO2e         2.0   248
#                                              General_government_final_consumption_expenditure_constant_2015_USdollars         1.8   249
#                                                                                   Preprimary_education_duration_years         1.8   250
#                                                                                        Number_of_under_to_five_deaths         1.8   251
#                                                                        Adjusted_net_national_income_current_USdollars         1.8   252
#                                                       Household_Survey_on_income_etc_Availability_score_over_10_years         1.8   253
#                                                                                           GDP_constant_2015_USdollars         1.6   254
#                                                                                  Number_of_deaths_ages_10_to_14_years         1.6   255
#                                                                                 GDP_PPP_current_international_dollars         1.4   256
#                                                                                 GNI_PPP_current_international_dollars         1.4   257
#                                                                                                     Labor_force_total         1.4   258
#                                                                GDP_per_capita_PPP_constant_2021_international_dollars         1.4   259
#                                                                                      GDP_per_capita_current_USdollars         1.2   260
#                                                                                                 GNI_current_USdollars         1.2   261
#                                                                                                    Surface_area_sq_km         1.2   262
#                                                           Carbon_dioxide_CO2_emissions_total_excluding_LULUCF_Mt_CO2e         1.2   263
#                                                                                        Region_Europe_and_Central_Asia         1.0   264
#                                                                                                 GDP_current_USdollars         1.0   265
#                                                                                    GNI_Atlas_method_current_USdollars         1.0   266
#                                                                                          Population_ages_0_to_14_male         1.0   267
#                                                            Nitrous_oxide_N2O_emissions_total_excluding_LULUCF_Mt_CO2e         1.0   268
#                                                                                         Population_ages_0_to_14_total         0.8   269
#                                                                   Labor_Force_Survey_Availability_score_over_10_years         0.8   270
#                                                                           GDP_PPP_constant_2021_international_dollars         0.8   271
#                                                                                               Income_Group_Low_income         0.4   272
#                                                                                      Income_Group_Lower_middle_income         0.4   273
#                                                                                          Region_East_Asia_and_Pacific         0.2   274
#                                                                                      Income_Group_Upper_middle_income         0.2   275
#                                                                                   Region_Middle_East_and_North_Africa         0.0   276
#                                                                                                  Region_North_America         0.0   277
#                                                                                                     Region_South_Asia         0.0   278
#                                                                                          Region_Sub_to_Saharan_Africa         0.0   279
#                                                                                              Income_Group_High_income         0.0   280

# %%
#run only 1 subgroup of features at a time
file = 'Field Mapping List.csv'
df2 = pd.read_csv(os.path.join(folder_loc, file))
print(df2['Indicator Category'].unique())
# Out:
# ['Environmental' 'Health' 'Socioeconomic']

# %%
df2['Field Name'] = df2['Field Name'].apply(clean_col_name)

# %%
feats_all = df.columns.tolist()
cols_to_exclude_except_enviro = list(set(df2[df2['Indicator Category'] != 'Environmental']['Field Name'].tolist() + cols_to_exclude))
cols_to_exclude_except_health = list(set(df2[df2['Indicator Category'] != 'Health']['Field Name'].tolist() + cols_to_exclude))
cols_to_exclude_except_socio = list(set(df2[df2['Indicator Category'] != 'Socioeconomic']['Field Name'].tolist() + cols_to_exclude))
print(f"{len(feats_all)} total features")
print(f"{len(feats_all) - len(cols_to_exclude_except_enviro)} environmental features")
print(f"{len(feats_all) - len(cols_to_exclude_except_health)} health features")
print(f"{len(feats_all) - len(cols_to_exclude_except_socio)} socioeconomic features")

print(cols_to_exclude_except_enviro)
print(cols_to_exclude_except_health)
print(cols_to_exclude_except_socio)
# Out:
# 286 total features
# 80 environmental features
# 73 health features
# 127 socioeconomic features
# ['Number_of_deaths_ages_20_to_24_years', 'Wage_and_salaried_workers_total_percent_of_total_employment_modeled_ILO_estimate', 'Employment_to_population_ratio_15_female_percent_modeled_ILO_estimate', 'Final_consumption_expenditure_annual_percent_growth', 'Population_ages_15_to_19_female_percent_of_female_population', 'Region_South_Asia', 'Out_to_of_to_pocket_expenditure_per_capita_PPP_current_international_dollars', 'Communications_computer_etc_percent_of_service_exports_BoP', 'Vulnerable_employment_male_percent_of_male_employment_modeled_ILO_estimate', 'Probability_of_dying_among_adolescents_ages_10_to_14_years_per_1000', 'Total_alcohol_consumption_per_capita_male_liters_of_pure_alcohol_projected_estimates_male_15_years_of_age', 'Mortality_rate_infant_per_1000_live_births', 'International_tourism_receipts_for_travel_items_current_USdollars', 'Domestic_private_health_expenditure_per_capita_PPP_current_international_dollars', 'Mortality_rate_under_to_5_male_per_1000_live_births', 'GDP_per_person_employed_constant_2021_PPP_dollars', 'General_government_final_consumption_expenditure_annual_percent_growth', 'Domestic_credit_to_private_sector_by_banks_percent_of_GDP', 'Monetary_Sector_credit_to_private_sector_percent_GDP', 'Current_health_expenditure_per_capita_current_USdollars', 'Insurance_and_financial_services_percent_of_commercial_service_exports', 'Current_health_expenditure_per_capita_PPP_current_international_dollars', 'CountryShortName', 'Computer_communications_and_other_services_percent_of_commercial_service_exports', 'Wage_and_salaried_workers_female_percent_of_female_employment_modeled_ILO_estimate', 'Lifetime_risk_of_maternal_death_percent', 'Population_ages_0_to_14_percent_of_total_population', 'GDP_per_capita_PPP_current_international_dollars', 'Region_East_Asia_and_Pacific', 'Labor_force_participation_rate_total_percent_of_total_population_ages_15_modeled_ILO_estimate', 'Number_of_deaths_ages_10_to_14_years', 'Region_Latin_America_and_Caribbean', 'Maternal_mortality_ratio_modeled_estimate_per_100000_live_births', 'Out_to_of_to_pocket_expenditure_per_capita_current_USdollars', 'Population_ages_0_to_14_total', 'Adjusted_savings_carbon_dioxide_damage_percent_of_GNI', 'Total_alcohol_consumption_per_capita_female_liters_of_pure_alcohol_projected_estimates_female_15_years_of_age', 'Computer_communications_and_other_services_percent_of_commercial_service_imports', 'Adjusted_savings_energy_depletion_percent_of_GNI', 'Out_to_of_to_pocket_expenditure_percent_of_current_health_expenditure', 'Labor_force_participation_rate_for_ages_15_to_24_total_percent_modeled_ILO_estimate', 'Region_Europe_and_Central_Asia', 'People_using_at_least_basic_sanitation_services_percent_of_population', 'Health_divided_by_Demographic_survey_Availability_score_over_10_years', 'GDP_growth_annual_percent', 'Domestic_private_health_expenditure_per_capita_current_USdollars', 'External_balance_on_goods_and_services_percent_of_GDP', 'Unemployment_youth_male_percent_of_male_labor_force_ages_15_to_24_modeled_ILO_estimate', 'GOAL_15_Life_on_Land_5_year_moving_average', 'Domestic_credit_to_private_sector_percent_of_GDP', 'Unemployment_male_percent_of_male_labor_force_modeled_ILO_estimate', 'Mortality_rate_neonatal_per_1000_live_births', 'Income_Group_High_income', 'Labor_force_participation_rate_male_percent_of_male_population_ages_15_modeled_ILO_estimate', 'Preprimary_education_duration_years', 'Life_expectancy_at_birth_total_years', 'Adjusted_net_national_income_current_USdollars', 'Ratio_of_female_to_male_labor_force_participation_rate_percent_modeled_ILO_estimate', 'Current_health_expenditure_percent_of_GDP', 'Number_of_under_to_five_deaths', 'Tuberculosis_treatment_success_rate_percent_of_new_cases', 'People_using_at_least_basic_sanitation_services_urban_percent_of_urban_population', 'GDP_per_capita_current_USdollars', 'Claims_on_central_government_etc_percent_GDP', 'Mortality_rate_adult_female_per_1000_female_adults', 'Fuel_imports_percent_of_merchandise_ ...
# ['Wage_and_salaried_workers_total_percent_of_total_employment_modeled_ILO_estimate', 'Employment_to_population_ratio_15_female_percent_modeled_ILO_estimate', 'Final_consumption_expenditure_annual_percent_growth', 'Region_South_Asia', 'Land_area_sq_km', 'Land_under_cereal_production_hectares', 'Communications_computer_etc_percent_of_service_exports_BoP', 'Carbon_dioxide_CO2_net_fluxes_from_LULUCF__to__Forest_Land_Mt_CO2e', 'Vulnerable_employment_male_percent_of_male_employment_modeled_ILO_estimate', 'Urban_population_percent_of_total_population', 'Energy_intensity_level_of_primary_energy_MJ_divided_by_dollars2017_PPP_GDP', 'Rural_population_growth_annual_percent', 'International_tourism_receipts_for_travel_items_current_USdollars', 'Nitrous_oxide_N2O_emissions_from_Industrial_Processes_Mt_CO2e', 'Urban_population', 'GDP_per_person_employed_constant_2021_PPP_dollars', 'Total_greenhouse_gas_emissions_excluding_LULUCF_Mt_CO2e', 'General_government_final_consumption_expenditure_annual_percent_growth', 'Methane_CH4_emissions_from_Building_Energy_Mt_CO2e', 'Domestic_credit_to_private_sector_by_banks_percent_of_GDP', 'Monetary_Sector_credit_to_private_sector_percent_GDP', 'Insurance_and_financial_services_percent_of_commercial_service_exports', 'Computer_communications_and_other_services_percent_of_commercial_service_exports', 'CountryShortName', 'Wage_and_salaried_workers_female_percent_of_female_employment_modeled_ILO_estimate', 'GDP_per_capita_PPP_current_international_dollars', 'Region_East_Asia_and_Pacific', 'Labor_force_participation_rate_total_percent_of_total_population_ages_15_modeled_ILO_estimate', 'Nitrous_oxide_N2O_emissions_total_excluding_LULUCF_percent_change_from_1990', 'Forest_area_percent_of_land_area', 'Capture_fisheries_production_metric_tons', 'Region_Latin_America_and_Caribbean', 'Livestock_production_index_2014_to_2016_equals_100', 'Computer_communications_and_other_services_percent_of_commercial_service_imports', 'Adjusted_savings_energy_depletion_percent_of_GNI', 'Labor_force_participation_rate_for_ages_15_to_24_total_percent_modeled_ILO_estimate', 'Methane_CH4_emissions_from_Power_Industry_Energy_Mt_CO2e', 'Carbon_dioxide_CO2_emissions_from_Industrial_Processes_Mt_CO2e', 'Region_Europe_and_Central_Asia', 'Access_to_clean_fuels_and_technologies_for_cooking_percent_of_population', 'GDP_growth_annual_percent', 'Methane_CH4_emissions_from_Waste_Mt_CO2e', 'Access_to_electricity_percent_of_population', 'External_balance_on_goods_and_services_percent_of_GDP', 'Unemployment_youth_male_percent_of_male_labor_force_ages_15_to_24_modeled_ILO_estimate', 'Carbon_dioxide_CO2_emissions_total_excluding_LULUCF_percent_change_from_1990', 'GOAL_15_Life_on_Land_5_year_moving_average', 'Domestic_credit_to_private_sector_percent_of_GDP', 'Unemployment_male_percent_of_male_labor_force_modeled_ILO_estimate', 'Income_Group_High_income', 'Nitrous_oxide_N2O_emissions_from_Fugitive_Emissions_Energy_Mt_CO2e', 'Labor_force_participation_rate_male_percent_of_male_population_ages_15_modeled_ILO_estimate', 'Preprimary_education_duration_years', 'Life_expectancy_at_birth_total_years', 'Fluorinated_greenhouse_gases_F_to_gases_emissions_from_Industrial_Processes_Mt_CO2e', 'Aquaculture_production_metric_tons', 'Adjusted_net_national_income_current_USdollars', 'Ratio_of_female_to_male_labor_force_participation_rate_percent_modeled_ILO_estimate', 'Carbon_dioxide_CO2_net_fluxes_from_LULUCF__to__Deforestation_Mt_CO2e', 'GDP_per_capita_current_USdollars', 'Claims_on_central_government_etc_percent_GDP', 'Carbon_dioxide_CO2_emissions_total_excluding_LULUCF_Mt_CO2e', 'Fuel_imports_percent_of_merchandise_imports', 'Nitrous_oxide_N2O_emissions_from_Agriculture_Mt_CO2e', 'Export_unit_value_index_2015_equals_100', 'Nitrous_oxide_N2O_emissions_from_Building_Energy_Mt_CO2e', 'Travel_services_percent_of_commercial_service_exports', 'Access_to_electricity_urban_percent_of_urban_population', 'Official_exchange_rate_LCU_per_USdollars_period_average', 'Methane_CH4_ ...
# ['Number_of_deaths_ages_20_to_24_years', 'Population_ages_15_to_19_female_percent_of_female_population', 'Land_area_sq_km', 'Out_to_of_to_pocket_expenditure_per_capita_PPP_current_international_dollars', 'Land_under_cereal_production_hectares', 'Carbon_dioxide_CO2_net_fluxes_from_LULUCF__to__Forest_Land_Mt_CO2e', 'Probability_of_dying_among_adolescents_ages_10_to_14_years_per_1000', 'Total_alcohol_consumption_per_capita_male_liters_of_pure_alcohol_projected_estimates_male_15_years_of_age', 'Urban_population_percent_of_total_population', 'Energy_intensity_level_of_primary_energy_MJ_divided_by_dollars2017_PPP_GDP', 'Rural_population_growth_annual_percent', 'Mortality_rate_infant_per_1000_live_births', 'Nitrous_oxide_N2O_emissions_from_Industrial_Processes_Mt_CO2e', 'Domestic_private_health_expenditure_per_capita_PPP_current_international_dollars', 'Mortality_rate_under_to_5_male_per_1000_live_births', 'Urban_population', 'Total_greenhouse_gas_emissions_excluding_LULUCF_Mt_CO2e', 'Methane_CH4_emissions_from_Building_Energy_Mt_CO2e', 'Current_health_expenditure_per_capita_current_USdollars', 'Current_health_expenditure_per_capita_PPP_current_international_dollars', 'CountryShortName', 'Lifetime_risk_of_maternal_death_percent', 'Population_ages_0_to_14_percent_of_total_population', 'Number_of_deaths_ages_10_to_14_years', 'Nitrous_oxide_N2O_emissions_total_excluding_LULUCF_percent_change_from_1990', 'Forest_area_percent_of_land_area', 'Capture_fisheries_production_metric_tons', 'Maternal_mortality_ratio_modeled_estimate_per_100000_live_births', 'Out_to_of_to_pocket_expenditure_per_capita_current_USdollars', 'Population_ages_0_to_14_total', 'Livestock_production_index_2014_to_2016_equals_100', 'Total_alcohol_consumption_per_capita_female_liters_of_pure_alcohol_projected_estimates_female_15_years_of_age', 'Out_to_of_to_pocket_expenditure_percent_of_current_health_expenditure', 'Methane_CH4_emissions_from_Power_Industry_Energy_Mt_CO2e', 'Carbon_dioxide_CO2_emissions_from_Industrial_Processes_Mt_CO2e', 'People_using_at_least_basic_sanitation_services_percent_of_population', 'Access_to_clean_fuels_and_technologies_for_cooking_percent_of_population', 'Health_divided_by_Demographic_survey_Availability_score_over_10_years', 'Methane_CH4_emissions_from_Waste_Mt_CO2e', 'Domestic_private_health_expenditure_per_capita_current_USdollars', 'Access_to_electricity_percent_of_population', 'Carbon_dioxide_CO2_emissions_total_excluding_LULUCF_percent_change_from_1990', 'Mortality_rate_neonatal_per_1000_live_births', 'Nitrous_oxide_N2O_emissions_from_Fugitive_Emissions_Energy_Mt_CO2e', 'Life_expectancy_at_birth_total_years', 'Fluorinated_greenhouse_gases_F_to_gases_emissions_from_Industrial_Processes_Mt_CO2e', 'Aquaculture_production_metric_tons', 'Current_health_expenditure_percent_of_GDP', 'Carbon_dioxide_CO2_net_fluxes_from_LULUCF__to__Deforestation_Mt_CO2e', 'Number_of_under_to_five_deaths', 'Tuberculosis_treatment_success_rate_percent_of_new_cases', 'People_using_at_least_basic_sanitation_services_urban_percent_of_urban_population', 'Carbon_dioxide_CO2_emissions_total_excluding_LULUCF_Mt_CO2e', 'Mortality_rate_adult_female_per_1000_female_adults', 'Nitrous_oxide_N2O_emissions_from_Agriculture_Mt_CO2e', 'Nitrous_oxide_N2O_emissions_from_Building_Energy_Mt_CO2e', 'Access_to_electricity_urban_percent_of_urban_population', 'Methane_CH4_emissions_from_Agriculture_Mt_CO2e', 'Prevalence_of_anemia_among_pregnant_women_percent', 'Total_fisheries_production_metric_tons', 'Prevalence_of_overweight_modeled_estimate_percent_of_children_under_5', 'Methane_CH4_emissions_from_Transport_Energy_Mt_CO2e', 'Death_rate_crude_per_1000_people', 'Renewable_energy_consumption_percent_of_total_final_energy_consumption', 'Nitrous_oxide_N2O_emissions_from_Transport_Energy_Mt_CO2e', 'People_practicing_open_defecation_percent_of_population', 'Life_expectancy_at_birth_female_years', 'Incidence_of_tuberculosis_per_100000_people', 'Domestic_private_health_expenditure_percent_of_c ...

# %% [markdown]
# ## Environmental Features

# %%
#just the environmental features
lgbm_features(cols_to_exclude_except_enviro)
# Out:
# Average MAE: 0.6578
# Average MSE: 1.1022
# Average Training R²: 0.9977
# Average Validation R²: 0.9840
#
# Sorted Feature Importance:
#                                                                                             Feature  Importance  Rank
#                                                  Livestock_production_index_2014_to_2016_equals_100       102.6     1
#                                                         Access_to_electricity_percent_of_population        78.8     2
#                                                       Crop_production_index_2014_to_2016_equals_100        78.0     3
#                                             Access_to_electricity_urban_percent_of_urban_population        77.2     4
#                                                                     Arable_land_hectares_per_person        76.6     5
#                          Energy_intensity_level_of_primary_energy_MJ_divided_by_dollars2017_PPP_GDP        74.8     6
#                                                       Food_production_index_2014_to_2016_equals_100        74.8     7
# Water_productivity_total_constant_2015_USdollars_GDP_per_cubic_meter_of_total_freshwater_withdrawal        74.8     8
#                                                              Urban_population_growth_annual_percent        72.2     9
#                                  PM25_air_pollution_mean_annual_exposure_micrograms_per_cubic_meter        67.8    10
#                                                              Rural_population_growth_annual_percent        67.2    11
#                                                                  Aquaculture_production_metric_tons        67.0    12
#                        Carbon_dioxide_CO2_emissions_total_excluding_LULUCF_percent_change_from_1990        65.6    13
#                                  Carbon_intensity_of_GDP_kg_CO2e_per_constant_2021_USdollars_of_GDP        65.6    14
#                                                              Agricultural_land_percent_of_land_area        65.6    15
#                                                        Urban_population_percent_of_total_population        62.8    16
#                                                             Permanent_cropland_percent_of_land_area        61.8    17
#                            Total_greenhouse_gas_emissions_excluding_LULUCF_percent_change_from_1990        57.2    18
#                                         Fertilizer_consumption_kilograms_per_hectare_of_arable_land        53.6    19
#                                  Carbon_dioxide_CO2_net_fluxes_from_LULUCF__to__Forest_Land_Mt_CO2e        51.2    20
#                                                    Population_density_people_per_sq_km_of_land_area        48.2    21
#                         Nitrous_oxide_N2O_emissions_total_excluding_LULUCF_percent_change_from_1990        47.0    22
#                                                                    Arable_land_percent_of_land_area        45.6    23
#                                                        Total_natural_resources_rents_percent_of_GDP        45.0    24
#                                     Renewable_internal_freshwater_resources_per_capita_cubic_meters        42.4    25
#                                                                        Mineral_rents_percent_of_GDP        40.4    26
#                                                              Total_fisheries_production_metric_tons        40.2    27
#                              Renewable_energy_consumption_percent_of_total_final_energy_consumption        39.6    28
#                                                        GOAL_13_Climate_Action_5_year_moving_average        39.6    29
#                Access_to_clean_fuels_and_technologies_for_cooking_urban_percent_of_urban_population        38.8    30
#                               Methane_CH4_emissions_total_excluding_LULUCF_percent_change_from_1990        38.6    31
#                   Carbon_dioxide_CO2_emissions_excluding_LULUCF_per_capita_t_CO2e_divided_by_capita        36.8    32
#                                                            Capture_fisheries_production_metric_tons        36.2    33
#                                  Nitrous_oxide_N2O_emissions_from_Fugitive_Emissions_Energy_Mt_CO2e        36.0    34
#                                                  Methane_CH4_emissions_from_Building_Energy_Mt_CO2e        35.0    35
#                 Fluorinated_greenhouse_gases_F_to_gases_emissions_from_Industrial_Processes_Mt_CO2e        34.0    36
#                                        Methane_CH4_emissions_from_Fugitive_Emissions_Energy_Mt_CO2e        33.8    37
#                            Access_to_clean_fuels_and_technologies_for_cooking_percent_of_population        33.8    38
#                                             Access_to_electricity_rural_percent_of_rural_population        33.6    39
#                                                                           Coal_rents_percent_of_GDP        33.0    40
#        Carbon_dioxide_CO2_net_fluxes_from_LULUCF__to__Total_excluding_non_to_tropical_fires_Mt_CO2e        32.6    41
#                                                Carbon_intensity_of_GDP_kg_CO2e_per_2021_PPP_dollars        32.6    42
#                                                                         Forest_rents_percent_of_GDP        32.0    43
#                                Carbon_dioxide_CO2_net_fluxes_from_LULUCF__to__Deforestation_Mt_CO2e        30.8    44
#                                      Nitrous_oxide_N2O_emissions_from_Power_Industry_Energy_Mt_CO2e        29.4    45
#                                             Total_greenhouse_gas_emissions_including_LULUCF_Mt_CO2e        29.4    46
#                                                                    Forest_area_percent_of_land_area        28.8    47
#                                                                            Oil_rents_percent_of_GDP        28.2    48
#                 Total_greenhouse_gas_emissions_per_capita_excluding_LULUCF_t_CO2e_divided_by_capita        28.0    49
#                                            Methane_CH4_emissions_from_Power_Industry_Energy_Mt_CO2e        27.0    50
#                                       Nitrous_oxide_N2O_emissions_from_Industrial_Processes_Mt_CO2e        26.6    51
#                                            Nitrous_oxide_N2O_emissions_from_Building_Energy_Mt_CO2e        25.4    52
#                                           Nitrous_oxide_N2O_emissions_from_Transport_Energy_Mt_CO2e        24.0    53
#                                                                                    Urban_population        23.6    54
#                                                      Nitrous_oxide_N2O_emissions_from_Waste_Mt_CO2e        23.4    55
#                                                                                     Land_area_sq_km        22.8    56
#                                                                                   Forest_area_sq_km        22.0    57
#                                      Carbon_dioxide_CO2_emissions_from_Industrial_Processes_Mt_CO2e        21.8    58
#                                                            Methane_CH4_emissions_from_Waste_Mt_CO2e        21.6    59
#                                     Carbon_dioxide_CO2_emissions_from_Power_Industry_Energy_Mt_CO2e        21.6    60
#                                                                       Cereal_production_metric_tons        21.2    61
#                                           Carbon_dioxide_CO2_emissions_from_Building_Energy_Mt_CO2e        20.4    62
#                                  Renewable_internal_freshwater_resources_total_billion_cubic_meters        20.0    63
#                                     Methane_CH4_emissions_from_Industrial_Combustion_Energy_Mt_CO2e        19.8    64
#                                                                    Natural_gas_rents_percent_of_GDP        19.4    65
#                                                               Land_under_cereal_production_hectares        17.6    66
#                Access_to_clean_fuels_and_technologies_for_cooking_rural_percent_of_rural_population        17.6    67
#                                                 Methane_CH4_emissions_from_Transport_Energy_Mt_CO2e        17.4    68
#                                                                                    Rural_population        16.2    69
#                              Carbon_dioxide_CO2_emissions_from_Industrial_Combustion_Energy_Mt_CO2e        15.0    70
#                               Nitrous_oxide_N2O_emissions_from_Industrial_Combustion_Energy_Mt_CO2e        15.0    71
#                                 Carbon_dioxide_CO2_emissions_from_Fugitive_Emissions_Energy_Mt_CO2e        13.6    72
#                                          Nitrous_oxide_N2O_emissions_total_excluding_LULUCF_Mt_CO2e        13.4    73
#                                                      Methane_CH4_emissions_from_Agriculture_Mt_CO2e        13.4    74
#                                                Methane_CH4_emissions_total_excluding_LULUCF_Mt_CO2e        13.2    75
#                                          Carbon_dioxide_CO2_emissions_from_Transport_Energy_Mt_CO2e        12.6    76
#                                         Carbon_dioxide_CO2_emissions_total_excluding_LULUCF_Mt_CO2e         9.8    77
#                                                Nitrous_oxide_N2O_emissions_from_Agriculture_Mt_CO2e         9.0    78
#                                             Total_greenhouse_gas_emissions_excluding_LULUCF_Mt_CO2e         8.0    79
#                                                                                  Surface_area_sq_km         3.0    80

# %%
#also exclude high correlation environmental features from correlation_to_all_within_group_lister.ipynb
addl_cols_to_exclude = [
    'Total greenhouse gas emissions including LULUCF (Mt CO2e)',
    'Carbon dioxide (CO2) emissions (total) excluding LULUCF (Mt CO2e)',
    'Cereal production (metric tons)',
    'Fluorinated greenhouse gases (F-gases) emissions from Industrial Processes (Mt CO2e)',
    'Methane (CH4) emissions (total) excluding LULUCF (Mt CO2e)',
    'Carbon dioxide (CO2) emissions from Industrial Combustion (Energy) (Mt CO2e)',
    'Carbon dioxide (CO2) emissions from Power Industry (Energy) (Mt CO2e)',
    'Nitrous oxide (N2O) emissions (total) excluding LULUCF (Mt CO2e)',
    'Carbon dioxide (CO2) emissions from Building (Energy) (Mt CO2e)',
    'Carbon dioxide (CO2) emissions from Fugitive Emissions (Energy) (Mt CO2e)',
    'Land under cereal production (hectares)',
    'Methane (CH4) emissions from Waste (Mt CO2e)',
    'Methane (CH4) emissions from Industrial Combustion (Energy) (Mt CO2e)',
    'Methane (CH4) emissions from Agriculture (Mt CO2e)',
    'Carbon dioxide (CO2) emissions from Industrial Processes (Mt CO2e)',
    'Nitrous oxide (N2O) emissions from Industrial Combustion (Energy) (Mt CO2e)',
    'Nitrous oxide (N2O) emissions from Agriculture (Mt CO2e)',
    'Aquaculture production (metric tons)',
    'Total fisheries production (metric tons)',
    'Nitrous oxide (N2O) emissions from Power Industry (Energy) (Mt CO2e)',
    'Forest area (sq. km)',
    'Nitrous oxide (N2O) emissions from Waste (Mt CO2e)',
    'Nitrous oxide (N2O) emissions from Building (Energy) (Mt CO2e)',
    'Access to clean fuels and technologies for cooking (% of population)',
    'Methane (CH4) emissions from Power Industry (Energy) (Mt CO2e)',
    'Methane (CH4) emissions from Fugitive Emissions (Energy) (Mt CO2e)',
    'Carbon dioxide (CO2) emissions from Transport (Energy) (Mt CO2e)',
    'Methane (CH4) emissions from Transport (Energy) (Mt CO2e)',
    'Land area (sq. km)',
    'Carbon dioxide (CO2) emissions excluding LULUCF per capita (t CO2e/capita)',
    'Nitrous oxide (N2O) emissions from Industrial Processes (Mt CO2e)',
    'Methane (CH4) emissions from Building (Energy) (Mt CO2e)',
    'Access to electricity (% of population)',
    'Rural population (% of total population)',
    'Total greenhouse gas emissions excluding LULUCF (Mt CO2e)',
    'Access to electricity, rural (% of rural population)'  
]
addl_cols_to_exclude = [clean_col_name(col) for col in addl_cols_to_exclude]
new_cols_to_exclude_except_enviro = list(set(cols_to_exclude_except_enviro + addl_cols_to_exclude))
lgbm_features(new_cols_to_exclude_except_enviro)
# Out:
# Average MAE: 0.6805
# Average MSE: 1.1771
# Average Training R²: 0.9973
# Average Validation R²: 0.9831
#
# Sorted Feature Importance:
#                                                                                             Feature  Importance  Rank
#                                             Access_to_electricity_urban_percent_of_urban_population       135.4     1
#                                                  Livestock_production_index_2014_to_2016_equals_100       118.8     2
# Water_productivity_total_constant_2015_USdollars_GDP_per_cubic_meter_of_total_freshwater_withdrawal       115.0     3
#                                                                     Arable_land_hectares_per_person        96.8     4
#                                  PM25_air_pollution_mean_annual_exposure_micrograms_per_cubic_meter        89.4     5
#                                                       Crop_production_index_2014_to_2016_equals_100        89.2     6
#                                                       Food_production_index_2014_to_2016_equals_100        87.0     7
#                                                              Urban_population_growth_annual_percent        85.4     8
#                                                             Permanent_cropland_percent_of_land_area        82.8     9
#                          Energy_intensity_level_of_primary_energy_MJ_divided_by_dollars2017_PPP_GDP        81.8    10
#                                         Fertilizer_consumption_kilograms_per_hectare_of_arable_land        81.6    11
#                                                              Rural_population_growth_annual_percent        79.6    12
#                                                        Urban_population_percent_of_total_population        76.0    13
#                                  Carbon_intensity_of_GDP_kg_CO2e_per_constant_2021_USdollars_of_GDP        72.0    14
#                                                            Capture_fisheries_production_metric_tons        71.4    15
#                            Total_greenhouse_gas_emissions_excluding_LULUCF_percent_change_from_1990        71.2    16
#                        Carbon_dioxide_CO2_emissions_total_excluding_LULUCF_percent_change_from_1990        70.2    17
#                                           Nitrous_oxide_N2O_emissions_from_Transport_Energy_Mt_CO2e        68.4    18
#                                     Renewable_internal_freshwater_resources_per_capita_cubic_meters        66.8    19
#                                                              Agricultural_land_percent_of_land_area        66.0    20
#                                                                    Arable_land_percent_of_land_area        65.4    21
#                                                    Population_density_people_per_sq_km_of_land_area        65.2    22
#                         Nitrous_oxide_N2O_emissions_total_excluding_LULUCF_percent_change_from_1990        62.0    23
#                               Methane_CH4_emissions_total_excluding_LULUCF_percent_change_from_1990        61.8    24
#                              Renewable_energy_consumption_percent_of_total_final_energy_consumption        60.4    25
#                                                                                    Urban_population        59.6    26
#                                  Nitrous_oxide_N2O_emissions_from_Fugitive_Emissions_Energy_Mt_CO2e        58.4    27
#                 Total_greenhouse_gas_emissions_per_capita_excluding_LULUCF_t_CO2e_divided_by_capita        57.8    28
#                                                                    Forest_area_percent_of_land_area        57.6    29
#                                  Carbon_dioxide_CO2_net_fluxes_from_LULUCF__to__Forest_Land_Mt_CO2e        57.4    30
#                                                        Total_natural_resources_rents_percent_of_GDP        54.4    31
#                Access_to_clean_fuels_and_technologies_for_cooking_urban_percent_of_urban_population        53.8    32
#                                                                         Forest_rents_percent_of_GDP        53.0    33
#                                                        GOAL_13_Climate_Action_5_year_moving_average        52.2    34
#                Access_to_clean_fuels_and_technologies_for_cooking_rural_percent_of_rural_population        51.8    35
#                                                Carbon_intensity_of_GDP_kg_CO2e_per_2021_PPP_dollars        51.6    36
#        Carbon_dioxide_CO2_net_fluxes_from_LULUCF__to__Total_excluding_non_to_tropical_fires_Mt_CO2e        48.6    37
#                                Carbon_dioxide_CO2_net_fluxes_from_LULUCF__to__Deforestation_Mt_CO2e        46.8    38
#                                                                           Coal_rents_percent_of_GDP        46.0    39
#                                                                        Mineral_rents_percent_of_GDP        45.8    40
#                                                                            Oil_rents_percent_of_GDP        41.4    41
#                                                                                    Rural_population        40.4    42
#                                  Renewable_internal_freshwater_resources_total_billion_cubic_meters        36.4    43
#                                                                                  Surface_area_sq_km        34.6    44
#                                                                    Natural_gas_rents_percent_of_GDP        32.8    45

# %% [markdown]
# ## Health Features

# %%
#just the health features
lgbm_features(cols_to_exclude_except_health)
# Out:
# Average MAE: 0.3041
# Average MSE: 0.2230
# Average Training R²: 0.9994
# Average Validation R²: 0.9968
#
# Sorted Feature Importance:
#                                                                                                       Feature  Importance  Rank
#                                                                              Death_rate_crude_per_1000_people       252.8     1
#                                                            Mortality_rate_adult_female_per_1000_female_adults       250.2     2
#                                                                Mortality_rate_adult_male_per_1000_male_adults       217.4     3
#                                                                   Incidence_of_tuberculosis_per_100000_people        99.4     4
#                            Prevalence_of_stunting_height_for_age_modeled_estimate_percent_of_children_under_5        70.2     5
#                                                          Population_ages_15_to_64_percent_of_total_population        67.6     6
#                                                 Adolescent_fertility_rate_births_per_1000_women_ages_15_to_19        62.8     7
#                                                  Population_ages_15_to_19_female_percent_of_female_population        54.8     8
#                                                           Mortality_rate_under_to_5_male_per_1000_live_births        49.8     9
#                                              Domestic_private_health_expenditure_per_capita_current_USdollars        49.4    10
#                                                                              Birth_rate_crude_per_1000_people        48.6    11
#                                                                     Current_health_expenditure_percent_of_GDP        45.4    12
#                                                 Domestic_general_government_health_expenditure_percent_of_GDP        44.8    13
#                             People_using_at_least_basic_sanitation_services_urban_percent_of_urban_population        44.8    14
#                                   Prevalence_of_anemia_among_children_percent_of_children_ages_6_to_59_months        44.2    15
#                                                             Prevalence_of_anemia_among_pregnant_women_percent        43.2    16
#                                                            Tuberculosis_case_detection_rate_percent_all_forms        43.0    17
#                                                      Population_ages_15_to_19_male_percent_of_male_population        42.8    18
#                             People_using_at_least_basic_sanitation_services_rural_percent_of_rural_population        41.6    19
#                                     People_using_at_least_basic_drinking_water_services_percent_of_population        41.2    20
#                                                       Current_health_expenditure_per_capita_current_USdollars        41.2    21
# Total_alcohol_consumption_per_capita_female_liters_of_pure_alcohol_projected_estimates_female_15_years_of_age        41.0    22
#                                                  Out_to_of_to_pocket_expenditure_per_capita_current_USdollars        40.0    23
#                                                 Probability_of_dying_among_youth_ages_20_to_24_years_per_1000        39.6    24
#                                         Prevalence_of_overweight_modeled_estimate_percent_of_children_under_5        39.4    25
#                          Domestic_general_government_health_expenditure_percent_of_current_health_expenditure        38.6    26
#                                                Probability_of_dying_among_children_ages_5_to_9_years_per_1000        38.2    27
#                                              Maternal_mortality_ratio_modeled_estimate_per_100000_live_births        38.0    28
#               Total_alcohol_consumption_per_capita_liters_of_pure_alcohol_projected_estimates_15_years_of_age        37.6    29
#                                  Out_to_of_to_pocket_expenditure_per_capita_PPP_current_international_dollars        36.4    30
#                                         Out_to_of_to_pocket_expenditure_percent_of_current_health_expenditure        35.8    31
#                                                                  Mortality_rate_neonatal_per_1000_live_births        35.2    32
#                                         People_using_at_least_basic_sanitation_services_percent_of_population        35.0    33
#                               Prevalence_of_anemia_among_non_to_pregnant_women_percent_of_women_ages_15_to_49        33.4    34
#                                                       People_practicing_open_defecation_percent_of_population        31.8    35
#                                                   Population_ages_0_to_14_female_percent_of_female_population        31.4    36
#                                                     Immunization_DPT_percent_of_children_ages_12_to_23_months        30.8    37
#                                                      Population_ages_10_to_14_male_percent_of_male_population        30.6    38
#                         People_using_at_least_basic_drinking_water_services_urban_percent_of_urban_population        30.4    39
#                                           Probability_of_dying_among_adolescents_ages_15_to_19_years_per_1000        29.4    40
#                                           Probability_of_dying_among_adolescents_ages_10_to_14_years_per_1000        29.0    41
#                                                      Tuberculosis_treatment_success_rate_percent_of_new_cases        28.8    42
#                                                  Population_ages_10_to_14_female_percent_of_female_population        28.2    43
#                                                   Lifetime_risk_of_maternal_death_1_in_rate_varies_by_country        27.2    44
#                                                 Immunization_measles_percent_of_children_ages_12_to_23_months        26.8    45
#                                                          Prevalence_of_undernourishment_percent_of_population        26.4    46
#                              Domestic_private_health_expenditure_per_capita_PPP_current_international_dollars        25.4    47
#                                                                            Number_of_deaths_ages_5_to_9_years        24.8    48
#                                                                                     Number_of_maternal_deaths        24.6    49
#                                                         Mortality_rate_under_to_5_female_per_1000_live_births        24.6    50
#                                       Current_health_expenditure_per_capita_PPP_current_international_dollars        24.2    51
#                                   Domestic_general_government_health_expenditure_per_capita_current_USdollars        22.8    52
#                                                                Mortality_rate_under_to_5_per_1000_live_births        22.6    53
#                                                           Population_ages_0_to_14_percent_of_total_population        22.0    54
#                                                                          Number_of_deaths_ages_15_to_19_years        21.2    55
#                                                             Mortality_rate_infant_female_per_1000_live_births        21.2    56
#     Total_alcohol_consumption_per_capita_male_liters_of_pure_alcohol_projected_estimates_male_15_years_of_age        20.4    57
#                                                                       Lifetime_risk_of_maternal_death_percent        20.4    58
#                                                       Population_ages_0_to_14_male_percent_of_male_population        20.2    59
#                                                                                Population_ages_0_to_14_female        20.0    60
#                                                                          Number_of_deaths_ages_20_to_24_years        19.8    61
#                                     Domestic_private_health_expenditure_percent_of_current_health_expenditure        19.6    62
#                                                                    Mortality_rate_infant_per_1000_live_births        19.0    63
#                                                               Mortality_rate_infant_male_per_1000_live_births        18.4    64
#                           Prevalence_of_anemia_among_women_of_reproductive_age_percent_of_women_ages_15_to_49        17.8    65
#                   Domestic_general_government_health_expenditure_per_capita_PPP_current_international_dollars        16.6    66
#                                                                                     Number_of_neonatal_deaths        16.4    67
#                                                                          Number_of_deaths_ages_10_to_14_years        15.4    68
#                                                                                       Number_of_infant_deaths        14.4    69
#                                                                                  Population_ages_0_to_14_male        10.0    70
#                                                                                Number_of_under_to_five_deaths         9.6    71
#                                         Health_divided_by_Demographic_survey_Availability_score_over_10_years         9.6    72
#                                                                                 Population_ages_0_to_14_total         4.8    73

# %%
#also exclude high correlation health features from correlation_to_all_within_group_lister.ipynb
addl_cols_to_exclude = [
    'Life expectancy at birth, female (years)',
    'Number of deaths ages 15-19 years',
    'Mortality rate, infant (per 1,000 live births)',
    'Life expectancy at birth, total (years)',
    'Number of deaths ages 10-14 years',
    'Mortality rate, infant, female (per 1,000 live births)',
    'Number of deaths ages 20-24 years',
    'Prevalence of anemia among children (% of children ages 6-59 months)',
    'Mortality rate, infant, male (per 1,000 live births)',
    'Population ages 0-14 (% of total population)',
    'Mortality rate, under-5 (per 1,000 live births)',
    'Birth rate, crude (per 1,000 people)',
    'Population ages 0-14, female (% of female population)',
    'Mortality rate, neonatal (per 1,000 live births)',
    'Mortality rate, under-5, female (per 1,000 live births)',
    'Life expectancy at birth, male (years)',
    'Number of deaths ages 5-9 years',
    'Current health expenditure per capita (current US$)',
    'Out-of-pocket expenditure per capita (current US$)',
    'Population ages 0-14, male (% of male population)',
    'Population ages 10-14, female (% of female population)',
    'Population ages 0-14, female',
    'Population ages 10-14, male (% of male population)',
    'Prevalence of anemia among non-pregnant women (% of women ages 15-49)',
    'Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)',
    'People using at least basic sanitation services, rural (% of rural population)',
    'Number of infant deaths',
    'Current health expenditure per capita, PPP (current international $)',
    'Mortality rate, under-5, male (per 1,000 live births)',
    'Maternal mortality ratio (modeled estimate, per 100,000 live births)',
    'Out-of-pocket expenditure (% of current health expenditure)',
    'Population ages 15-19, female (% of female population)',
    'Probability of dying among adolescents ages 15-19 years (per 1,000)',
    'Probability of dying among adolescents ages 10-14 years (per 1,000)',
    'Prevalence of anemia among pregnant women (%)',
    'Domestic general government health expenditure per capita (current US$)',
    'Domestic private health expenditure per capita (current US$)',
    'Lifetime risk of maternal death (%)',
    'Immunization, DPT (% of children ages 12-23 months)',
    'People using at least basic drinking water services, urban (% of urban population)',
    'Population ages 0-14, male',
    'Mortality rate, adult, female (per 1,000 female adults)',
    'Number of maternal deaths',
    'People using at least basic sanitation services, urban (% of urban population)',
    'Number of neonatal deaths',
    'Total alcohol consumption per capita, female (liters of pure alcohol, projected estimates, female 15+ years of age)'  
]
addl_cols_to_exclude = [clean_col_name(col) for col in addl_cols_to_exclude]
new_cols_to_exclude_except_health = list(set(cols_to_exclude_except_health + addl_cols_to_exclude))
lgbm_features(new_cols_to_exclude_except_health)
# Out:
# Average MAE: 0.3599
# Average MSE: 0.3071
# Average Training R²: 0.9992
# Average Validation R²: 0.9956
#
# Sorted Feature Importance:
#                                                                                                   Feature  Importance  Rank
#                                                            Mortality_rate_adult_male_per_1000_male_adults       334.2     1
#                                                                          Death_rate_crude_per_1000_people       301.4     2
#                                            Probability_of_dying_among_children_ages_5_to_9_years_per_1000       142.8     3
#                                                      Population_ages_15_to_64_percent_of_total_population       133.2     4
#                                                               Incidence_of_tuberculosis_per_100000_people       120.2     5
#                                                  Population_ages_15_to_19_male_percent_of_male_population       118.0     6
#                       Prevalence_of_anemia_among_women_of_reproductive_age_percent_of_women_ages_15_to_49       117.4     7
#                                               Lifetime_risk_of_maternal_death_1_in_rate_varies_by_country       109.6     8
# Total_alcohol_consumption_per_capita_male_liters_of_pure_alcohol_projected_estimates_male_15_years_of_age       107.8     9
#                                                                            Number_of_under_to_five_deaths       107.8    10
#                                     People_using_at_least_basic_sanitation_services_percent_of_population       100.0    11
#                                                                             Population_ages_0_to_14_total       100.0    12
#                                     Prevalence_of_overweight_modeled_estimate_percent_of_children_under_5        95.6    13
#                                             Adolescent_fertility_rate_births_per_1000_women_ages_15_to_19        94.8    14
#                                 People_using_at_least_basic_drinking_water_services_percent_of_population        83.4    15
#                                             Probability_of_dying_among_youth_ages_20_to_24_years_per_1000        81.8    16
#                                                        Tuberculosis_case_detection_rate_percent_all_forms        75.2    17
#                        Prevalence_of_stunting_height_for_age_modeled_estimate_percent_of_children_under_5        72.8    18
#                              Out_to_of_to_pocket_expenditure_per_capita_PPP_current_international_dollars        72.6    19
#               Domestic_general_government_health_expenditure_per_capita_PPP_current_international_dollars        70.2    20
#                          Domestic_private_health_expenditure_per_capita_PPP_current_international_dollars        68.0    21
#                                                                 Current_health_expenditure_percent_of_GDP        65.2    22
#                                             Domestic_general_government_health_expenditure_percent_of_GDP        64.8    23
#                      Domestic_general_government_health_expenditure_percent_of_current_health_expenditure        64.0    24
#                                                      Prevalence_of_undernourishment_percent_of_population        62.2    25
#                                                   People_practicing_open_defecation_percent_of_population        59.4    26
#                                             Immunization_measles_percent_of_children_ages_12_to_23_months        54.4    27
#                                 Domestic_private_health_expenditure_percent_of_current_health_expenditure        52.6    28
#                                                  Tuberculosis_treatment_success_rate_percent_of_new_cases        51.0    29
#                                     Health_divided_by_Demographic_survey_Availability_score_over_10_years        19.6    30

# %% [markdown]
# ## Socioeconomic Features

# %%
#just the socioeconomic features
lgbm_features(cols_to_exclude_except_socio)
# Out:
# Average MAE: 0.6966
# Average MSE: 1.1699
# Average Training R²: 0.9981
# Average Validation R²: 0.9832
#
# Sorted Feature Importance:
#                                                                                                               Feature  Importance  Rank
#                                                                                     Pillar_1__to__Data_Use__to__Score        62.8     1
#                                                               Official_exchange_rate_LCU_per_USdollars_period_average        62.6     2
#                                                                               Import_unit_value_index_2015_equals_100        62.4     3
#                                                                  Refugee_population_by_country_or_territory_of_origin        59.0     4
#                                                                      Adjusted_savings_energy_depletion_percent_of_GNI        58.4     5
#                                                                       Labor_force_female_percent_of_total_labor_force        56.8     6
#                                                Insurance_and_financial_services_percent_of_commercial_service_imports        55.8     7
#                                                                 Adjusted_savings_carbon_dioxide_damage_percent_of_GNI        50.4     8
#                                                                            Commercial_bank_branches_per_100000_adults        49.6     9
#                                                                 Adjusted_savings_education_expenditure_percent_of_GNI        48.6    10
#                                                              Transport_services_percent_of_commercial_service_exports        48.2    11
#                                                     Proportion_of_seats_held_by_women_in_national_parliaments_percent        48.0    12
#                                                              Transport_services_percent_of_commercial_service_imports        47.2    13
#                                                                 Travel_services_percent_of_commercial_service_imports        43.6    14
#                                                                                                         Net_migration        43.2    15
#                                                                                            Broad_money_percent_of_GDP        42.6    16
#                                                                  Refugee_population_by_country_or_territory_of_asylum        40.4    17
#                                                     International_tourism_receipts_for_travel_items_current_USdollars        39.8    18
#                                                                                              Primary_education_pupils        39.8    19
#                                                                                   Compulsory_education_duration_years        39.4    20
#                                                                      Domestic_credit_to_private_sector_percent_of_GDP        38.8    21
#                                                                          Claims_on_central_government_etc_percent_GDP        36.8    22
#                                                                 Travel_services_percent_of_commercial_service_exports        36.8    23
#                                                                                  GDP_per_capita_growth_annual_percent        36.4    24
#                                                                   Final_consumption_expenditure_annual_percent_growth        35.6    25
#                                                                  Monetary_Sector_credit_to_private_sector_percent_GDP        35.4    26
#                                                Insurance_and_financial_services_percent_of_commercial_service_exports        35.0    27
#                                                                           Fuel_exports_percent_of_merchandise_exports        35.0    28
#                                                                                Pillar_3__to__Data_Products__to__Score        34.2    29
#                                                                               Export_unit_value_index_2015_equals_100        34.2    30
#                                                        GOAL_17_Partnerships_to_achieve_the_Goal_5_year_moving_average        34.0    31
#                                                                         GNI_per_capita_Atlas_method_current_USdollars        33.6    32
#                                                                 External_balance_on_goods_and_services_percent_of_GDP        33.6    33
# Share_of_youth_not_in_education_employment_or_training_female_percent_of_female_youth_population_modeled_ILO_estimate        33.4    34
#                                                                        School_enrollment_primary_female_percent_gross        32.4    35
#                                                                          Exports_of_goods_and_services_percent_of_GDP        31.6    36
#                                                                           Fuel_imports_percent_of_merchandise_imports        31.4    37
#                                                                          School_enrollment_primary_male_percent_gross        30.8    38
#                                                                                          Region_Sub_to_Saharan_Africa        30.6    39
#                                                                                             GDP_growth_annual_percent        30.4    40
#                                                                              International_tourism_number_of_arrivals        29.4    41
#                                       Agriculture_forestry_and_fishing_value_added_per_worker_constant_2015_USdollars        29.4    42
#                                                                Ores_and_metals_imports_percent_of_merchandise_imports        28.2    43
#                                                                                GDP_per_capita_constant_2015_USdollars        28.0    44
#                     Labor_force_participation_rate_male_percent_of_male_population_ages_15_to_64_modeled_ILO_estimate        27.0    45
#                                                                 Women_Business_and_the_Law_Index_Score_scale_1_to_100        25.8    46
#         Share_of_youth_not_in_education_employment_or_training_total_percent_of_youth_population_modeled_ILO_estimate        25.4    47
#     Share_of_youth_not_in_education_employment_or_training_male_percent_of_male_youth_population_modeled_ILO_estimate        25.0    48
#                                      Computer_communications_and_other_services_percent_of_commercial_service_exports        25.0    49
#                                                                     GDP_per_person_employed_constant_2021_PPP_dollars        24.8    50
#                                                           Agriculture_forestry_and_fishing_value_added_percent_of_GDP        24.6    51
#                                    Labor_force_participation_rate_for_ages_15_to_24_male_percent_modeled_ILO_estimate        24.2    52
#                                                                                 Inflation_GDP_deflator_annual_percent        24.0    53
#                                   Ratio_of_female_to_male_labor_force_participation_rate_percent_modeled_ILO_estimate        23.6    54
#                                                   GOAL_16_Peace_and_Justice_Strong_Institutions_5_year_moving_average        23.2    55
#                                                            Communications_computer_etc_percent_of_service_exports_BoP        23.2    56
#                                Unemployment_youth_male_percent_of_male_labor_force_ages_15_to_24_modeled_ILO_estimate        23.0    57
#                                                  Employment_to_population_ratio_15_total_percent_modeled_ILO_estimate        23.0    58
#                                                General_government_final_consumption_expenditure_annual_percent_growth        23.0    59
#                           Labor_force_participation_rate_male_percent_of_male_population_ages_15_modeled_ILO_estimate        22.8    60
#                                                             Adjusted_net_national_income_per_capita_current_USdollars        21.8    61
#                                                                                                     Labor_force_total        21.6    62
#                                                  GOAL_12_Responsible_Consumption_and_Production_5_year_moving_average        21.0    63
#                                                Unemployment_female_percent_of_female_labor_force_modeled_ILO_estimate        20.4    64
#                                             Self_to_employed_female_percent_of_female_employment_modeled_ILO_estimate        20.2    65
#                 Labor_force_participation_rate_female_percent_of_female_population_ages_15_to_64_modeled_ILO_estimate        20.0    66
#                                                 International_tourism_expenditures_for_travel_items_current_USdollars        19.6    67
#                                                 Self_to_employed_male_percent_of_male_employment_modeled_ILO_estimate        19.4    68
#                       Labor_force_participation_rate_female_percent_of_female_population_ages_15_modeled_ILO_estimate        19.4    69
#                                            Vulnerable_employment_male_percent_of_male_employment_modeled_ILO_estimate        18.8    70
#                                                                      Automated_teller_machines_ATMs_per_100000_adults        18.8    71
#                                                            Communications_computer_etc_percent_of_service_imports_BoP        18.6    72
#                                                                      GOAL_10_Reduced_Inequality_5_year_moving_average        18.6    73
#                                                    Unemployment_male_percent_of_male_labor_force_modeled_ILO_estimate        18.2    74
#                                      Computer_communications_and_other_services_percent_of_commercial_service_imports        18.2    75
#                                              General_government_final_consumption_expenditure_constant_2015_USdollars        18.0    76
#                            Unemployment_youth_female_percent_of_female_labor_force_ages_15_to_24_modeled_ILO_estimate        17.8    77
#                                   Labor_force_participation_rate_for_ages_15_to_24_total_percent_modeled_ILO_estimate        17.8    78
#                                                                                   Preprimary_education_duration_years        17.8    79
#                                                                GDP_per_capita_PPP_constant_2021_international_dollars        17.8    80
#                                                             Domestic_credit_to_private_sector_by_banks_percent_of_GDP        17.4    81
#                                  Labor_force_participation_rate_for_ages_15_to_24_female_percent_modeled_ILO_estimate        16.8    82
#                                                    Exports_of_goods_services_and_primary_income_BoP_current_USdollars        16.8    83
#                                                      GOAL_11_Sustainable_Cities_and_Communities_5_year_moving_average        16.6    84
#                                                   Employment_to_population_ratio_15_male_percent_modeled_ILO_estimate        16.2    85
#                                                                               School_enrollment_primary_percent_gross        16.0    86
#                                                                            GOAL_15_Life_on_Land_5_year_moving_average        15.4    87
#                              Unemployment_youth_total_percent_of_total_labor_force_ages_15_to_24_modeled_ILO_estimate        15.2    88
#                                      Employment_to_population_ratio_ages_15_to_24_female_percent_modeled_ILO_estimate        15.2    89
#                                                                   Inflation_GDP_deflator_linked_series_annual_percent        15.0    90
#                                        Employment_to_population_ratio_ages_15_to_24_male_percent_modeled_ILO_estimate        14.8    91
#                                                                      GNI_per_capita_PPP_current_international_dollars        14.6    92
#                                                                               GOAL_1_No_Poverty_5_year_moving_average        14.6    93
#                                                  Unemployment_total_percent_of_total_labor_force_modeled_ILO_estimate        14.2    94
#                         Labor_force_participation_rate_total_percent_of_total_population_ages_15_modeled_ILO_estimate        13.8    95
#                                       Employment_to_population_ratio_ages_15_to_24_total_percent_modeled_ILO_estimate        13.2    96
#                                                 Employment_to_population_ratio_15_female_percent_modeled_ILO_estimate        13.2    97
#                                               Self_to_employed_total_percent_of_total_employment_modeled_ILO_estimate        12.6    98
#                                          Vulnerable_employment_total_percent_of_total_employment_modeled_ILO_estimate        11.6    99
#                   Labor_force_participation_rate_total_percent_of_total_population_ages_15_to_64_modeled_ILO_estimate        11.2   100
#                                        Vulnerable_employment_female_percent_of_female_employment_modeled_ILO_estimate        10.8   101
#                                                                           GDP_PPP_constant_2021_international_dollars        10.6   102
#                                    Wage_and_salaried_workers_female_percent_of_female_employment_modeled_ILO_estimate        10.6   103
#                                                                 Final_consumption_expenditure_constant_2015_USdollars        10.4   104
#                                                                      GDP_per_capita_PPP_current_international_dollars        10.4   105
#                                                                                      GDP_per_capita_current_USdollars         9.0   106
#                                      Wage_and_salaried_workers_total_percent_of_total_employment_modeled_ILO_estimate         8.8   107
#                                                                                 GDP_PPP_current_international_dollars         8.6   108
#                                                                                 GNI_PPP_current_international_dollars         8.0   109
#                                        Wage_and_salaried_workers_male_percent_of_male_employment_modeled_ILO_estimate         7.4   110
#                                                                                           GDP_constant_2015_USdollars         6.8   111
#                                                                                          Region_East_Asia_and_Pacific         5.6   112
#                                                                        Adjusted_net_national_income_current_USdollars         4.8   113
#                                                                                                 GNI_current_USdollars         4.0   114
#                                                                                                 GDP_current_USdollars         4.0   115
#                                                       Household_Survey_on_income_etc_Availability_score_over_10_years         3.8   116
#                                                                   Labor_Force_Survey_Availability_score_over_10_years         3.6   117
#                                                                                    GNI_Atlas_method_current_USdollars         3.2   118
#                                                                                                     Region_South_Asia         3.0   119
#                                                                                        Region_Europe_and_Central_Asia         1.6   120
#                                                                                    Region_Latin_America_and_Caribbean         1.6   121
#                                                                                   Region_Middle_East_and_North_Africa         1.4   122
#                                                                                      Income_Group_Lower_middle_income         1.4   123
#                                                                                      Income_Group_Upper_middle_income         0.8   124
#                                                                                               Income_Group_Low_income         0.4   125
#                                                                                                  Region_North_America         0.0   126
#                                                                                              Income_Group_High_income         0.0   127

# %%
#also exclude high correlation socioeconomic features from correlation_to_all_within_group_lister.ipynb
addl_cols_to_exclude = [
    'General government final consumption expenditure (constant 2015 US$)',
    'Self-employed, female (% of female employment) (modeled ILO estimate)',
    'Self-employed, male (% of male employment) (modeled ILO estimate)',
    'Adjusted net national income (current US$)',
    'Final consumption expenditure (constant 2015 US$)',
    'Self-employed, total (% of total employment) (modeled ILO estimate)',
    'GDP, PPP (constant 2021 international $)',
    'GDP per capita, PPP (constant 2021 international $)',
    'GNI, PPP (current international $)',
    'Vulnerable employment, female (% of female employment) (modeled ILO estimate)',
    'Adjusted net national income per capita (current US$)',
    'GDP, PPP (current international $)',
    'Vulnerable employment, male (% of male employment) (modeled ILO estimate)',
    'Exports of goods, services and primary income (BoP, current US$)',
    'GDP per capita (constant 2015 US$)',
    'Unemployment, male (% of male labor force) (modeled ILO estimate)',
    'Unemployment, female (% of female labor force) (modeled ILO estimate)',
    'Vulnerable employment, total (% of total employment) (modeled ILO estimate)',
    'GDP (constant 2015 US$)',
    'GNI, Atlas method (current US$)',
    'Employment to population ratio, 15+, female (%) (modeled ILO estimate)',
    'Unemployment, total (% of total labor force) (modeled ILO estimate)',
    'Domestic credit to private sector (% of GDP)',
    'GNI per capita, PPP (current international $)',
    'GDP per capita, PPP (current international $)',
    'Employment to population ratio, ages 15-24, male (%) (modeled ILO estimate)',
    'Employment to population ratio, ages 15-24, female (%) (modeled ILO estimate)',
    'Wage and salaried workers, female (% of female employment) (modeled ILO estimate)',
    'School enrollment, primary, female (% gross)',
    'Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate)',
    'Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate)',
    'School enrollment, primary, male (% gross)',
    'Share of youth not in education, employment or training, female (% of female youth population) (modeled ILO estimate)',
    'Communications, computer, etc. (% of service exports, BoP)',
    'Communications, computer, etc. (% of service imports, BoP)',
    'Labor force participation rate for ages 15-24, female (%) (modeled ILO estimate)',
    'Primary education, pupils',
    'Monetary Sector credit to private sector (% GDP)',
    'Labor force, female (% of total labor force)',
    'Labor force participation rate, female (% of female population ages 15-64) (modeled ILO estimate)',
    'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)',
    'Labor force participation rate for ages 15-24, male (%) (modeled ILO estimate)',
    'Inflation, GDP deflator (annual %)',
    'GNI per capita, Atlas method (current US$)',
    'GNI (current US$)',
    'GDP growth (annual %)',
    'Employment to population ratio, ages 15-24, total (%) (modeled ILO estimate)',
    'Employment to population ratio, 15+, total (%) (modeled ILO estimate)',
    'Employment to population ratio, 15+, male (%) (modeled ILO estimate)',
    'Wage and salaried workers, male (% of male employment) (modeled ILO estimate)'  
]
addl_cols_to_exclude = [clean_col_name(col) for col in addl_cols_to_exclude]
new_cols_to_exclude_except_socio = list(set(cols_to_exclude_except_socio + addl_cols_to_exclude))
lgbm_features(new_cols_to_exclude_except_socio)
# Out:
# Average MAE: 0.7531
# Average MSE: 1.3487
# Average Training R²: 0.9978
# Average Validation R²: 0.9806
#
# Sorted Feature Importance:
#                                                                                                           Feature  Importance  Rank
#                                  Wage_and_salaried_workers_total_percent_of_total_employment_modeled_ILO_estimate        83.4     1
#                                                           Official_exchange_rate_LCU_per_USdollars_period_average        77.6     2
#                                                                                  GDP_per_capita_current_USdollars        76.4     3
#                                                              Refugee_population_by_country_or_territory_of_origin        76.4     4
#                                                         Domestic_credit_to_private_sector_by_banks_percent_of_GDP        76.0     5
#                                                                  Adjusted_savings_energy_depletion_percent_of_GNI        72.8     6
#                                                             Adjusted_savings_education_expenditure_percent_of_GNI        70.2     7
#                                                                           Import_unit_value_index_2015_equals_100        70.0     8
#                                                             Adjusted_savings_carbon_dioxide_damage_percent_of_GNI        69.8     9
#                                                                        Commercial_bank_branches_per_100000_adults        66.4    10
#                                                 Proportion_of_seats_held_by_women_in_national_parliaments_percent        62.4    11
#                                            Insurance_and_financial_services_percent_of_commercial_service_imports        61.4    12
#                                                          Transport_services_percent_of_commercial_service_exports        61.4    13
#                          Unemployment_youth_total_percent_of_total_labor_force_ages_15_to_24_modeled_ILO_estimate        58.6    14
#                                                                                        Broad_money_percent_of_GDP        56.4    15
#                                                          Transport_services_percent_of_commercial_service_imports        55.4    16
#                               Ratio_of_female_to_male_labor_force_participation_rate_percent_modeled_ILO_estimate        54.8    17
#                                   Agriculture_forestry_and_fishing_value_added_per_worker_constant_2015_USdollars        54.6    18
#                                                                                 Pillar_1__to__Data_Use__to__Score        54.4    19
#                                                                                                     Net_migration        51.8    20
#                                                                      Claims_on_central_government_etc_percent_GDP        51.0    21
#                                                 International_tourism_receipts_for_travel_items_current_USdollars        50.8    22
#                                                                                                 Labor_force_total        50.6    23
#                                                             Travel_services_percent_of_commercial_service_imports        49.8    24
#                                                              Refugee_population_by_country_or_territory_of_asylum        48.4    25
#     Share_of_youth_not_in_education_employment_or_training_total_percent_of_youth_population_modeled_ILO_estimate        47.2    26
#                                                                              GDP_per_capita_growth_annual_percent        46.4    27
#                                                                 GDP_per_person_employed_constant_2021_PPP_dollars        46.2    28
#                                                                           School_enrollment_primary_percent_gross        46.2    29
#                                                                            Pillar_3__to__Data_Products__to__Score        45.8    30
#                                            Insurance_and_financial_services_percent_of_commercial_service_exports        45.6    31
#                                                             Travel_services_percent_of_commercial_service_exports        45.4    32
#                     Labor_force_participation_rate_total_percent_of_total_population_ages_15_modeled_ILO_estimate        45.4    33
#                                                                           Export_unit_value_index_2015_equals_100        45.2    34
#                                                                          International_tourism_number_of_arrivals        45.0    35
#                 Labor_force_participation_rate_male_percent_of_male_population_ages_15_to_64_modeled_ILO_estimate        44.6    36
#                                                                      Exports_of_goods_and_services_percent_of_GDP        42.0    37
#                                                               Final_consumption_expenditure_annual_percent_growth        41.8    38
#                                                               Inflation_GDP_deflator_linked_series_annual_percent        41.6    39
#                       Labor_force_participation_rate_male_percent_of_male_population_ages_15_modeled_ILO_estimate        41.0    40
#                                                                       Fuel_exports_percent_of_merchandise_exports        41.0    41
#                                                             External_balance_on_goods_and_services_percent_of_GDP        39.8    42
#                                             International_tourism_expenditures_for_travel_items_current_USdollars        37.8    43
#                                  Computer_communications_and_other_services_percent_of_commercial_service_exports        37.2    44
# Share_of_youth_not_in_education_employment_or_training_male_percent_of_male_youth_population_modeled_ILO_estimate        36.2    45
#                                                                       Fuel_imports_percent_of_merchandise_imports        36.2    46
#                                                                               Compulsory_education_duration_years        33.6    47
#                                                                                             GDP_current_USdollars        32.6    48
#                               Labor_force_participation_rate_for_ages_15_to_24_total_percent_modeled_ILO_estimate        32.4    49
#                                  Computer_communications_and_other_services_percent_of_commercial_service_imports        32.0    50
#                                                    GOAL_17_Partnerships_to_achieve_the_Goal_5_year_moving_average        32.0    51
#                                                       Agriculture_forestry_and_fishing_value_added_percent_of_GDP        31.2    52
#                                                                                      Region_Sub_to_Saharan_Africa        31.2    53
#                                                            Ores_and_metals_imports_percent_of_merchandise_imports        30.6    54
#                                                                               Preprimary_education_duration_years        29.2    55
#                                                             Women_Business_and_the_Law_Index_Score_scale_1_to_100        29.0    56
#                                               GOAL_16_Peace_and_Justice_Strong_Institutions_5_year_moving_average        27.2    57
#               Labor_force_participation_rate_total_percent_of_total_population_ages_15_to_64_modeled_ILO_estimate        25.8    58
#                                                                  Automated_teller_machines_ATMs_per_100000_adults        25.6    59
#                                            General_government_final_consumption_expenditure_annual_percent_growth        23.6    60
#                                              GOAL_12_Responsible_Consumption_and_Production_5_year_moving_average        22.4    61
#                                                  GOAL_11_Sustainable_Cities_and_Communities_5_year_moving_average        21.0    62
#                                                                           GOAL_1_No_Poverty_5_year_moving_average        19.8    63
#                                                                  GOAL_10_Reduced_Inequality_5_year_moving_average        19.6    64
#                                                                        GOAL_15_Life_on_Land_5_year_moving_average        14.0    65
#                                                   Household_Survey_on_income_etc_Availability_score_over_10_years         6.4    66
#                                                                                      Region_East_Asia_and_Pacific         5.6    67
#                                                               Labor_Force_Survey_Availability_score_over_10_years         5.0    68
#                                                                                                 Region_South_Asia         4.2    69
#                                                                                Region_Latin_America_and_Caribbean         2.2    70
#                                                                                  Income_Group_Lower_middle_income         2.2    71
#                                                                                    Region_Europe_and_Central_Asia         2.0    72
#                                                                                  Income_Group_Upper_middle_income         0.8    73
#                                                                               Region_Middle_East_and_North_Africa         0.4    74
#                                                                                              Region_North_America         0.0    75
#                                                                                          Income_Group_High_income         0.0    76
#                                                                                           Income_Group_Low_income         0.0    77
