# %%
import pandas as pd
import os 

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', None)
pd.set_option('display.expand_frame_repr', False)

# %%
import numpy as np
from sklearn.model_selection import KFold
from sklearn.impute import KNNImputer
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.ensemble import BaggingRegressor
from sklearn.tree import DecisionTreeRegressor
import re

# %%
folder_loc = 'F:/class/BANA 698/week 8'


file_list = [f for f in os.listdir(folder_loc) if os.path.isfile(os.path.join(folder_loc, f))]
for file in file_list:
    print(file)

# %%
file = 'Group1DatasetRaw.onehotted.csv'
df = pd.read_csv(os.path.join(folder_loc, file))

# %%
#for col in sorted(df.columns): print(col)

# %%
target = 'Life expectancy at birth, total (years)'

cols_to_exclude = [
    'Life expectancy at birth, female (years)',
    'Life expectancy at birth, male (years)',
    'Life expectancy at birth, total (years)',
    'CountryShortName',
    'Year',
    'Death rate, crude (per 1,000 people)',
    'Lifetime risk of maternal death (%)',
    'Lifetime risk of maternal death (1 in: rate varies by country)',
    'Maternal mortality ratio (modeled estimate, per 100,000 live births)',
    'Mortality rate, adult, female (per 1,000 female adults)',
    'Mortality rate, adult, male (per 1,000 male adults)',
    'Mortality rate, infant (per 1,000 live births)',
    'Mortality rate, infant, female (per 1,000 live births)',
    'Mortality rate, infant, male (per 1,000 live births)',
    'Mortality rate, neonatal (per 1,000 live births)',
    'Mortality rate, under-5 (per 1,000 live births)',
    'Mortality rate, under-5, female (per 1,000 live births)',
    'Mortality rate, under-5, male (per 1,000 live births)',
    'Number of deaths ages 10-14 years',
    'Number of deaths ages 15-19 years',
    'Number of deaths ages 20-24 years',
    'Number of deaths ages 5-9 years',
    'Number of infant deaths',
    'Number of maternal deaths',
    'Number of neonatal deaths',
    'Number of under-five deaths',
    'Probability of dying among adolescents ages 10-14 years (per 1,000)',
    'Probability of dying among adolescents ages 15-19 years (per 1,000)',
    'Probability of dying among children ages 5-9 years (per 1,000)',
    'Probability of dying among youth ages 20-24 years (per 1,000)'
]

# %%
bag_params = {
    'bootstrap': True,
    'bootstrap_features': False,
    'estimator': DecisionTreeRegressor(),
    'max_features': 1.0,
    'max_samples': 1.0,
    'n_estimators': 10,
    'n_jobs': -1,
    'oob_score': False,
    'random_state': 1,
    'verbose': 0,
    'warm_start': False
 }
#got default parameters from running:
#model = BaggingRegressor()
#model.get_params()

# %%
def bagging_features(cols_to_exclude = cols_to_exclude, target = target, df = df, kfold_random_state = 1, n_neighbors = 5):
    X = df.drop(columns = cols_to_exclude)
    y = df[target]

    imputer = KNNImputer(n_neighbors = n_neighbors)
    model = BaggingRegressor(**bag_params)

    cv = KFold(n_splits=5, shuffle=True, random_state = kfold_random_state)

    mae_scores = []
    mse_scores = []
    r2_scores = []
    feature_importance_list = []

    for train_idx, val_idx in cv.split(X):
        #train_idx will be a NumPy array containing the integer indices of the rows in the original DataFrame X (and y) that should be used as the training set for the current fold.
        #val_idx will be a NumPy array containing the integer indices of the rows in X (and y) that should be used as the validation (or test) set for the current fold.

        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]
        
        X_train_imputed = imputer.fit_transform(X_train)
        X_val_imputed = imputer.transform(X_val)
        
        X_train_imputed = pd.DataFrame(X_train_imputed, columns=X_train.columns)
        X_val_imputed = pd.DataFrame(X_val_imputed, columns=X_val.columns)
        
        model.fit(X_train_imputed, y_train)
        y_pred = model.predict(X_val_imputed)

        mae = mean_absolute_error(y_val, y_pred)
        mse = mean_squared_error(y_val, y_pred)
        r2 = r2_score(y_val, y_pred)        
        mae_scores.append(mae)
        mse_scores.append(mse)
        r2_scores.append(r2)
        
        feature_importance_fold = np.mean([tree.feature_importances_ for tree in model.estimators_], axis=0)
        feature_importance_list.append(feature_importance_fold)


    avg_mae = np.mean(mae_scores)
    avg_mse = np.mean(mse_scores)
    avg_r2 = np.mean(r2_scores)

    print(f'Average MAE: {avg_mae:.4f}')
    print(f'Average MSE: {avg_mse:.4f}')
    print(f'Average R²: {avg_r2:.4f}')

    avg_feature_importance = np.mean(feature_importance_list, axis=0)
    feature_importance_df = pd.DataFrame({
        'Feature': X.columns,
        'Importance': avg_feature_importance
    })
    feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False).reset_index(drop=True)
    feature_importance_df['Rank'] = feature_importance_df.index + 1
    feature_importance_df = feature_importance_df[['Feature', 'Importance', 'Rank']]

    print('\nSorted Feature Importance:')
    print(feature_importance_df.to_string(index=False))

# %%
bagging_features()
# Out:
# Average MAE: 0.6619
# Average MSE: 1.1397
# Average R²: 0.9836
#
# Sorted Feature Importance:
#                                                                                                               Feature   Importance  Rank
#                                                                               Access to electricity (% of population) 5.354115e-01     1
#                                                     People using at least basic sanitation services (% of population) 9.459721e-02     2
#                                                  Current health expenditure per capita, PPP (current international $) 9.095075e-02     3
#                                                                                             Region_Sub-Saharan Africa 5.485148e-02     4
#                                                                   Current health expenditure per capita (current US$) 4.219162e-02     5
#                                                                        Incidence of tuberculosis (per 100,000 people) 1.692916e-02     6
#                                                                                  Birth rate, crude (per 1,000 people) 1.517784e-02     7
#                                        People using at least basic sanitation services, urban (% of urban population) 1.458866e-02     8
#                                      Prevalence of stunting, height for age (modeled estimate, % of children under 5) 1.384203e-02     9
#                                    People using at least basic drinking water services, urban (% of urban population) 5.835677e-03    10
#                                               Domestic general government health expenditure per capita (current US$) 4.711687e-03    11
#                                                                                    Rural population growth (annual %) 4.528961e-03    12
#                                                  Prevalence of anemia among children (% of children ages 6-59 months) 4.366707e-03    13
#                                                                                           Pillar 1 - Data Use - Score 3.936095e-03    14
#                                                                  Access to electricity, urban (% of urban population) 3.380330e-03    15
#                                                                    Out-of-pocket expenditure per capita (current US$) 2.593435e-03    16
#                                                                      Monetary Sector credit to private sector (% GDP) 2.468253e-03    17
#                                          Carbon dioxide (CO2) emissions (total) excluding LULUCF (% change from 1990) 2.284498e-03    18
#                                                                          Labor force, female (% of total labor force) 2.173610e-03    19
#                                                                                   Permanent cropland (% of land area) 2.154992e-03    20
#                                                         Adolescent fertility rate (births per 1,000 women ages 15-19) 2.054210e-03    21
#                                                  Total greenhouse gas emissions excluding LULUCF (% change from 1990) 1.944573e-03    22
#                                                                                     Arable land (hectares per person) 1.940250e-03    23
#                                                                         Prevalence of anemia among pregnant women (%) 1.897700e-03    24
#                                                          Domestic private health expenditure per capita (current US$) 1.835290e-03    25
#                                                                            Capture fisheries production (metric tons) 1.680641e-03    26
#                                                                   Immunization, DPT (% of children ages 12-23 months) 1.633006e-03    27
#                                                                   Population density (people per sq. km of land area) 1.632366e-03    28
#                                        People using at least basic sanitation services, rural (% of rural population) 1.558276e-03    29
#                                                 Prevalence of anemia among non-pregnant women (% of women ages 15-49) 1.519559e-03    30
#                                                                 Domestic credit to private sector by banks (% of GDP) 1.389967e-03    31
#                                                                  Refugee population by country or territory of origin 1.352994e-03    32
#                      Water productivity, total (constant 2015 US$ GDP per cubic meter of total freshwater withdrawal) 1.263788e-03    33
#                                                                     Population ages 0-14, male (% of male population) 1.163342e-03    34
#                                                                                                Broad money (% of GDP) 1.077788e-03    35
#                                                                  Refugee population by country or territory of asylum 1.001231e-03    36
#                                                                   People practicing open defecation (% of population) 9.696111e-04    37
#                                                                  Transport services (% of commercial service exports) 9.482073e-04    38
#                                                                                                  Forest area (sq. km) 9.247846e-04    39
#                                                                         Commercial bank branches (per 100,000 adults) 9.190964e-04    40
#                                                         Fertilizer consumption (kilograms per hectare of arable land) 8.860961e-04    41
#                                                                     Travel services (% of commercial service imports) 8.719934e-04    42
#                                                                                Compulsory education, duration (years) 8.101491e-04    43
#                                                                  Official exchange rate (LCU per US$, period average) 8.027763e-04    44
#                                                         Proportion of seats held by women in national parliaments (%) 7.623412e-04    45
#                                           Nitrous oxide (N2O) emissions (total) excluding LULUCF (% change from 1990) 7.543400e-04    46
#                                                 Carbon dioxide (CO2) net fluxes from LULUCF - Deforestation (Mt CO2e) 7.425915e-04    47
#                                                                              Rural population (% of total population) 7.366864e-04    48
#                                                                              Total fisheries production (metric tons) 7.177500e-04    49
#                                                                Population ages 15-19, female (% of female population) 7.118378e-04    50
#                                                                              Urban population (% of total population) 6.622176e-04    51
#                                          Prevalence of anemia among women of reproductive age (% of women ages 15-49) 6.331050e-04    52
#                                                 People using at least basic drinking water services (% of population) 6.065390e-04    53
#                                                                     Travel services (% of commercial service exports) 5.787905e-04    54
#                                                 Renewable internal freshwater resources, total (billion cubic meters) 5.718966e-04    55
#                                                                    Adjusted savings: carbon dioxide damage (% of GNI) 5.696693e-04    56
#                                                                       Tuberculosis case detection rate (%, all forms) 5.601455e-04    57
#                                                                               Food production index (2014-2016 = 100) 5.550215e-04    58
#                                                                                                         Net migration 5.478901e-04    59
#                                              Nitrous oxide (N2O) emissions from Fugitive Emissions (Energy) (Mt CO2e) 5.373478e-04    60
#                                                                            GOAL 1: No Poverty (5 year moving average) 5.320285e-04    61
#                                      Domestic general government health expenditure (% of current health expenditure) 5.249428e-04    62
#                                                                                  Import unit value index (2015 = 100) 5.005860e-04    63
#                                         Domestic private health expenditure per capita, PPP (current international $) 5.001620e-04    64
#                                                        International tourism, receipts for travel items (current US$) 4.983792e-04    65
#                                                                          Livestock production index (2014-2016 = 100) 4.982523e-04    66
#                                                 Methane (CH4) emissions (total) excluding LULUCF (% change from 1990) 4.913788e-04    67
#                                                                    Adjusted savings: education expenditure (% of GNI) 4.868600e-04    68
#                                                                    Population ages 15-19, male (% of male population) 4.702035e-04    69
#                                                    Methane (CH4) emissions from Fugitive Emissions (Energy) (Mt CO2e) 4.682073e-04    70
#                     Labor force participation rate, female (% of female population ages 15-64) (modeled ILO estimate) 4.425652e-04    71
#                                                                                    Urban population growth (annual %) 4.414421e-04    72
#                                                                            Claims on central government, etc. (% GDP) 4.413794e-04    73
#                                                                Population ages 10-14, female (% of female population) 4.394008e-04    74
#                                                                 Population ages 0-14, female (% of female population) 4.383780e-04    75
#                                        Agriculture, forestry, and fishing, value added per worker (constant 2015 US$) 4.357545e-04    76
#                                  Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate) 4.287845e-04    77
#                                                                          Population ages 0-14 (% of total population) 4.271486e-04    78
#                                                                                                      Urban population 4.200553e-04    79
#                                                                                              Mineral rents (% of GDP) 4.152472e-04    80
#                                                                              Total natural resources rents (% of GDP) 4.060821e-04    81
#                                                                                          Forest area (% of land area) 3.968136e-04    82
#                                                                         Population ages 15-64 (% of total population) 3.952103e-04    83
#                                                                 Automated teller machines (ATMs) (per 100,000 adults) 3.921076e-04    84
#                                                           Energy intensity level of primary energy (MJ/$2017 PPP GDP) 3.906635e-04    85
#                                      Labor force participation rate for ages 15-24, female (%) (modeled ILO estimate) 3.802323e-04    86
#                                                     Renewable internal freshwater resources per capita (cubic meters) 3.785375e-04    87
#                                                                  Women Business and the Law Index Score (scale 1-100) 3.762069e-04    88
#                                                                                      Pillar 3 - Data Products - Score 3.751458e-04    89
#                                                                                    Agricultural land (% of land area) 3.672831e-04    90
#                                                           Out-of-pocket expenditure (% of current health expenditure) 3.520921e-04    91
#                                                                               Crop production index (2014-2016 = 100) 3.520473e-04    92
#                                                                                 Current health expenditure (% of GDP) 3.511886e-04    93
#                                                                    Population ages 10-14, male (% of male population) 3.434119e-04    94
#                                                                     External balance on goods and services (% of GDP) 3.428259e-04    95
#                                                    Insurance and financial services (% of commercial service exports) 3.335863e-04    96
#                                                       Nitrous oxide (N2O) emissions from Transport (Energy) (Mt CO2e) 3.327271e-04    97
#                                                                                                  Oil rents (% of GDP) 3.286513e-04    98
#                                                              Methane (CH4) emissions from Building (Energy) (Mt CO2e) 3.259321e-04    99
#                              Domestic general government health expenditure per capita, PPP (current international $) 3.245178e-04   100
#                                                   GOAL 11: Sustainable Cities and Communities (5 year moving average) 3.241942e-04   101
#                                                               Immunization, measles (% of children ages 12-23 months) 3.155294e-04   102
#                                                 Domestic private health expenditure (% of current health expenditure) 3.148784e-04   103
#                                                    Renewable energy consumption (% of total final energy consumption) 3.038083e-04   104
#     Share of youth not in education, employment or training, male (% of male youth population) (modeled ILO estimate) 2.984367e-04   105
#                                                PM2.5 air pollution, mean annual exposure (micrograms per cubic meter) 2.970422e-04   106
#                                                                                  Aquaculture production (metric tons) 2.948958e-04   107
#                                                        Carbon intensity of GDP (kg CO2e per constant 2021 US$ of GDP) 2.853854e-04   108
#                                     Access to clean fuels and technologies for cooking, urban (% of urban population) 2.825247e-04   109
#                            Carbon dioxide (CO2) net fluxes from LULUCF - Total excluding non-tropical fires (Mt CO2e) 2.819227e-04   110
#                                                                                      GDP per capita growth (annual %) 2.812727e-04   111
# Share of youth not in education, employment or training, female (% of female youth population) (modeled ILO estimate) 2.786597e-04   112
#                                                   Carbon dioxide (CO2) net fluxes from LULUCF - Forest Land (Mt CO2e) 2.728186e-04   113
#                                         Wage and salaried workers, male (% of male employment) (modeled ILO estimate) 2.725428e-04   114
#                                                                    Nitrous oxide (N2O) emissions from Waste (Mt CO2e) 2.717155e-04   115
#                                                                      Prevalence of undernourishment (% of population) 2.687630e-04   116
#                                                                      Carbon intensity of GDP (kg CO2e per 2021 PPP $) 2.638205e-04   117
#                                                                       Final consumption expenditure (annual % growth) 2.612258e-04   118
#                                            Total greenhouse gas emissions per capita excluding LULUCF (t CO2e/capita) 2.548816e-04   119
#                                           Vulnerable employment, total (% of total employment) (modeled ILO estimate) 2.512352e-04   120
#                                                                                    GDP per capita (constant 2015 US$) 2.506756e-04   121
#                                                       Carbon dioxide (CO2) emissions from Building (Energy) (Mt CO2e) 2.506720e-04   122
#                                                        Methane (CH4) emissions from Power Industry (Energy) (Mt CO2e) 2.497779e-04   123
#         Share of youth not in education, employment or training, total (% of youth population) (modeled ILO estimate) 2.482540e-04   124
#                                                                    Methane (CH4) emissions from Agriculture (Mt CO2e) 2.477911e-04   125
#                                Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate) 2.468291e-04   126
#                                                             Methane (CH4) emissions from Transport (Energy) (Mt CO2e) 2.463025e-04   127
#                                         Computer, communications and other services (% of commercial service exports) 2.434612e-04   128
#                                                 Self-employed, female (% of female employment) (modeled ILO estimate) 2.425398e-04   129
#                                                   Out-of-pocket expenditure per capita, PPP (current international $) 2.397318e-04   130
#                                                                 Labor Force Survey (Availability score over 10 years) 2.380871e-04   131
#                                       Wage and salaried workers, total (% of total employment) (modeled ILO estimate) 2.372726e-04   132
#                                                    Prevalence of overweight (modeled estimate, % of children under 5) 2.358499e-04   133
#                                                                                                    Land area (sq. km) 2.339321e-04   134
#                                     Wage and salaried workers, female (% of female employment) (modeled ILO estimate) 2.327635e-04   135
#                       Labor force participation rate, total (% of total population ages 15-64) (modeled ILO estimate) 2.315658e-04   136
#                                                                                  Export unit value index (2015 = 100) 2.278746e-04   137
#                                                     GOAL 17: Partnerships to achieve the Goal (5 year moving average) 2.254924e-04   138
#                                                                  Transport services (% of commercial service imports) 2.225457e-04   139
#                                                                                               Forest rents (% of GDP) 2.224596e-04   140
#                                                                              Exports of goods and services (% of GDP) 2.160856e-04   141
#                                                    Insurance and financial services (% of commercial service imports) 2.143476e-04   142
#                                                            Methane (CH4) emissions (total) excluding LULUCF (Mt CO2e) 2.108158e-04   143
#                                    Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate) 2.081980e-04   144
#                                                      Carbon dioxide (CO2) emissions from Transport (Energy) (Mt CO2e) 2.078750e-04   145
#                                                 Unemployment, female (% of female labor force) (modeled ILO estimate) 2.073797e-04   146
#                                                                          Methane (CH4) emissions from Waste (Mt CO2e) 2.070017e-04   147
#                                                                                       Cereal production (metric tons) 2.064870e-04   148
#                                                                                          Arable land (% of land area) 2.037836e-04   149
#                                                                          Domestic credit to private sector (% of GDP) 2.009337e-04   150
#                                                             Domestic general government health expenditure (% of GDP) 1.993046e-04   151
#                                                     Nitrous oxide (N2O) emissions from Industrial Processes (Mt CO2e) 1.957351e-04   152
#                                                            Communications, computer, etc. (% of service exports, BoP) 1.949582e-04   153
#                                                                  Tuberculosis treatment success rate (% of new cases) 1.947017e-04   154
#                                                                               Fuel imports (% of merchandise imports) 1.942921e-04   155
#                                                                         Adjusted savings: energy depletion (% of GNI) 1.933861e-04   156
#                                                     Unemployment, male (% of male labor force) (modeled ILO estimate) 1.933472e-04   157
#                                           Employment to population ratio, ages 15-24, male (%) (modeled ILO estimate) 1.931735e-04   158
#                                                                 Adjusted net national income per capita (current US$) 1.901410e-04   159
#                                                                                                      Rural population 1.898045e-04   160
#                                                                            GNI per capita, Atlas method (current US$) 1.879269e-04   161
#                                                                                                 GDP growth (annual %) 1.872999e-04   162
#                       Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate) 1.867880e-04   163
#                                                            Agriculture, forestry, and fishing, value added (% of GDP) 1.860871e-04   164
#                                                                               Fuel exports (% of merchandise exports) 1.859730e-04   165
#                                     Ratio of female to male labor force participation rate (%) (modeled ILO estimate) 1.807697e-04   166
#                                               GOAL 12: Responsible Consumption and Production (5 year moving average) 1.786370e-04   167
#                                                            Communications, computer, etc. (% of service imports, BoP) 1.774697e-04   168
#                                                                                    GNI, PPP (current international $) 1.748328e-04   169
#                                                                         GOAL 15: Life on Land (5 year moving average) 1.711030e-04   170
#                                                 Carbon dioxide (CO2) emissions from Power Industry (Energy) (Mt CO2e) 1.707303e-04   171
#                                                  Access to clean fuels and technologies for cooking (% of population) 1.688256e-04   172
#                                                                                                 Coal rents (% of GDP) 1.665986e-04   173
#                                                  Nitrous oxide (N2O) emissions from Power Industry (Energy) (Mt CO2e) 1.665965e-04   174
#                         Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate) 1.640548e-04   175
#   Total alcohol consumption per capita, female (liters of pure alcohol, projected estimates, female 15+ years of age) 1.633749e-04   176
#                                                                             International tourism, number of arrivals 1.608421e-04   177
#                                            Carbon dioxide (CO2) emissions excluding LULUCF per capita (t CO2e/capita) 1.575453e-04   178
#                                                 Employment to population ratio, 15+, total (%) (modeled ILO estimate) 1.559851e-04   179
#                                                 Methane (CH4) emissions from Industrial Combustion (Energy) (Mt CO2e) 1.558593e-04   180
#                                             Vulnerable employment, male (% of male employment) (modeled ILO estimate) 1.542471e-04   181
#                                                                         GDP per capita, PPP (current international $) 1.509339e-04   182
#                                                Employment to population ratio, 15+, female (%) (modeled ILO estimate) 1.486626e-04   183
#                                     Access to clean fuels and technologies for cooking, rural (% of rural population) 1.483115e-04   184
#                                                                          School enrollment, primary, female (% gross) 1.410277e-04   185
#                                                        Nitrous oxide (N2O) emissions from Building (Energy) (Mt CO2e) 1.381075e-04   186
#                                         Employment to population ratio, ages 15-24, female (%) (modeled ILO estimate) 1.371755e-04   187
#       Total alcohol consumption per capita, male (liters of pure alcohol, projected estimates, male 15+ years of age) 1.357428e-04   188
#                                                                     Final consumption expenditure (constant 2015 US$) 1.353738e-04   189
#                                                                                          GDP per capita (current US$) 1.343979e-04   190
#                         Labor force participation rate, male (% of male population ages 15-64) (modeled ILO estimate) 1.327182e-04   191
#                                             Carbon dioxide (CO2) emissions from Fugitive Emissions (Energy) (Mt CO2e) 1.323376e-04   192
#                                        Labor force participation rate for ages 15-24, male (%) (modeled ILO estimate) 1.272980e-04   193
#                                                                                    Inflation, GDP deflator (annual %) 1.268147e-04   194
#                                                                                                    Labor force, total 1.250571e-04   195
#                                                     Carbon dioxide (CO2) emissions (total) excluding LULUCF (Mt CO2e) 1.224617e-04   196
#                                                   Unemployment, total (% of total labor force) (modeled ILO estimate) 1.222314e-04   197
#                                                   Self-employed, total (% of total employment) (modeled ILO estimate) 1.198316e-04   198
#                                                                                          Population ages 0-14, female 1.195474e-04   199
#                                         Vulnerable employment, female (% of female employment) (modeled ILO estimate) 1.179816e-04   200
#                                                                   GDP per capita, PPP (constant 2021 international $) 1.177131e-04   201
#                                                    Carbon dioxide (CO2) emissions from Industrial Processes (Mt CO2e) 1.163928e-04   202
#                  Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) 1.150004e-04   203
#                                                      Nitrous oxide (N2O) emissions (total) excluding LULUCF (Mt CO2e) 1.125749e-04   204
#                                                                                Preprimary education, duration (years) 1.125009e-04   205
#                                                                  Access to electricity, rural (% of rural population) 1.120859e-04   206
#                                                                       GOAL 13: Climate Action (5 year moving average) 1.081584e-04   207
#                                                                         GNI per capita, PPP (current international $) 1.050282e-04   208
#                                                                         GDP per person employed (constant 2021 PPP $) 1.024669e-04   209
#                                                                     Inflation, GDP deflator: linked series (annual %) 1.005935e-04   210
#                                                                                  School enrollment, primary (% gross) 9.821711e-05   211
#                                                                   GOAL 10: Reduced Inequality (5 year moving average) 9.466034e-05   212
#                                                  General government final consumption expenditure (constant 2015 US$) 9.416290e-05   213
#                                                                                          Natural gas rents (% of GDP) 9.412310e-05   214
#                                  Fluorinated greenhouse gases (F-gases) emissions from Industrial Processes (Mt CO2e) 9.353904e-05   215
#                                                                    Ores and metals imports (% of merchandise imports) 9.325249e-05   216
#                                          Employment to population ratio, ages 15-24, total (%) (modeled ILO estimate) 9.250447e-05   217
#                                                                            School enrollment, primary, male (% gross) 9.217842e-05   218
#                                       Labor force participation rate for ages 15-24, total (%) (modeled ILO estimate) 9.134123e-05   219
#                                                                                       GNI, Atlas method (current US$) 8.764876e-05   220
#                           Labor force participation rate, male (% of male population ages 15+) (modeled ILO estimate) 8.729609e-05   221
#                                         Computer, communications and other services (% of commercial service imports) 8.725065e-05   222
#                                                                                                 Surface area (sq. km) 8.551966e-05   223
#                                                    General government final consumption expenditure (annual % growth) 8.547282e-05   224
#                                                                               Land under cereal production (hectares) 8.316883e-05   225
#                                                GOAL 16: Peace and Justice Strong Institutions (5 year moving average) 8.259764e-05   226
#                                                    Household Survey on income, etc (Availability score over 10 years) 8.043753e-05   227
#                                                     Self-employed, male (% of male employment) (modeled ILO estimate) 7.733860e-05   228
#                                                  Employment to population ratio, 15+, male (%) (modeled ILO estimate) 7.537178e-05   229
#                                                                              GDP, PPP (constant 2021 international $) 7.316216e-05   230
#                                                    International tourism, expenditures for travel items (current US$) 6.952801e-05   231
#                                                      Exports of goods, services and primary income (BoP, current US$) 6.347385e-05   232
#                                                                                             Primary education, pupils 5.769380e-05   233
#                                                              Nitrous oxide (N2O) emissions from Agriculture (Mt CO2e) 5.630522e-05   234
#                                                             Total greenhouse gas emissions excluding LULUCF (Mt CO2e) 5.602575e-05   235
#                                                             Total greenhouse gas emissions including LULUCF (Mt CO2e) 5.011061e-05   236
#                                                          Health/Demographic survey (Availability score over 10 years) 4.802492e-05   237
#                                                                                                     GDP (current US$) 4.421412e-05   238
#                                                                            Adjusted net national income (current US$) 3.594865e-05   239
#                                                                                               GDP (constant 2015 US$) 3.515577e-05   240
#                                           Nitrous oxide (N2O) emissions from Industrial Combustion (Energy) (Mt CO2e) 3.209812e-05   241
#                                          Carbon dioxide (CO2) emissions from Industrial Combustion (Energy) (Mt CO2e) 3.048711e-05   242
#                                                                                            Population ages 0-14, male 2.865660e-05   243
#                                                                                    GDP, PPP (current international $) 2.805484e-05   244
#                                                                                           Population ages 0-14, total 2.485784e-05   245
#                                                                                                     GNI (current US$) 2.119697e-05   246
#                                                                                      Income Group_Lower middle income 1.496918e-05   247
#                                                                                            Region_East Asia & Pacific 5.881485e-06   248
#                                                                                          Region_Europe & Central Asia 3.481249e-06   249
#                                                                                      Income Group_Upper middle income 2.615602e-06   250
#                                                                                      Region_Latin America & Caribbean 1.670849e-06   251
#                                                                                              Income Group_High income 1.367228e-06   252
#                                                                                               Income Group_Low income 5.472207e-07   253
#                                                                                     Region_Middle East & North Africa 1.834230e-07   254
#                                                                                                     Region_South Asia 1.181402e-07   255
#                                                                                                  Region_North America 1.257489e-08   256
