# %%
import pandas as pd
import os

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', None)
pd.set_option('display.expand_frame_repr', False)

# %%
import numpy as np
from sklearn.model_selection import KFold
from sklearn.impute import KNNImputer
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.ensemble import BaggingRegressor
from sklearn.tree import DecisionTreeRegressor
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
import re

# %%
folder_loc = 'F:/class/BANA 698/week 8'


file_list = [f for f in os.listdir(folder_loc) if os.path.isfile(os.path.join(folder_loc, f))]
for file in file_list:
    print(file)
# Out:
# #week 8 - y.lnk
# basic_stats_Group1DatasetCleaned.knn.standarddeviation.csv
# basic_stats_Group1DatasetRaw.onehotted.csv
# basic_stats_Group1Dataset_LCU_removed(except_exchange_rate).income.groups.regions.onehotted.csv
# correlations.all.csv
# correlations.all.to.life_expectancy_total.csv
# Group1DatasetCleaned.knn.standarddeviation.csv
# Group1DatasetRaw.csv
# Group1DatasetRaw.onehotted.csv
# Group1Dataset_LCU_removed(except_exchange_rate).income.groups.regions.csv
# Group1Dataset_LCU_removed(except_exchange_rate).income.groups.regions.onehotted.20percent.nans.dropped.csv
# Group1Dataset_LCU_removed(except_exchange_rate).income.groups.regions.onehotted.csv
# ImputationAndStandardize.ipynb
# README.md

# %%
file = 'Group1DatasetRaw.onehotted.csv'
df = pd.read_csv(os.path.join(folder_loc, file))

# %%
#for col in sorted(df.columns): print(col)

# %%
target = 'Life expectancy at birth, total (years)'

cols_to_exclude = [
    'Life expectancy at birth, total (years)',
    'Life expectancy at birth, female (years)',
    'Life expectancy at birth, male (years)',
    'CountryShortName',
    'Year'
]

# %%
bag_params = {
    'bootstrap': True,
    'bootstrap_features': False,
    'estimator': DecisionTreeRegressor(),
    'max_features': 1.0,
    'max_samples': 1.0,
    'n_estimators': 10,
    'n_jobs': -1,
    'oob_score': False,
    'random_state': 1,
    'verbose': 0,
    'warm_start': False
 }
#got default parameters from running:
#model = BaggingRegressor()
#model.get_params()

# %%
def bagging_features(cols_to_exclude = cols_to_exclude, target = target, df = df, kfold_random_state = 1, n_neighbors = 5):
    X = df.drop(columns = cols_to_exclude)
    y = df[target]

    imputer = KNNImputer(n_neighbors = n_neighbors)
    model = BaggingRegressor(**bag_params)

    cv = KFold(n_splits=5, shuffle=True, random_state = kfold_random_state)

    mae_scores = []
    mse_scores = []
    r2_scores = []
    feature_importance_list = []

    for train_idx, val_idx in cv.split(X):
        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]
        
        X_train_imputed = imputer.fit_transform(X_train)
        X_val_imputed = imputer.transform(X_val)
        
        X_train_imputed = pd.DataFrame(X_train_imputed, columns=X_train.columns)
        X_val_imputed = pd.DataFrame(X_val_imputed, columns=X_val.columns)
        
        model.fit(X_train_imputed, y_train)
        y_pred = model.predict(X_val_imputed)

        mae = mean_absolute_error(y_val, y_pred)
        mse = mean_squared_error(y_val, y_pred)
        r2 = r2_score(y_val, y_pred)        
        mae_scores.append(mae)
        mse_scores.append(mse)
        r2_scores.append(r2)
        
        feature_importance_fold = np.mean([tree.feature_importances_ for tree in model.estimators_], axis=0)
        feature_importance_list.append(feature_importance_fold)


    avg_mae = np.mean(mae_scores)
    avg_mse = np.mean(mse_scores)
    avg_r2 = np.mean(r2_scores)

    print(f'Average MAE: {avg_mae:.4f}')
    print(f'Average MSE: {avg_mse:.4f}')
    print(f'Average R²: {avg_r2:.4f}')

    avg_feature_importance = np.mean(feature_importance_list, axis=0)
    feature_importance_df = pd.DataFrame({
        'Feature': X.columns,
        'Importance': avg_feature_importance
    })
    feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False).reset_index(drop=True)
    feature_importance_df['Rank'] = feature_importance_df.index + 1
    feature_importance_df = feature_importance_df[['Feature', 'Importance', 'Rank']]

    print('\nSorted Average Feature Importance:')
    print(feature_importance_df.to_string(index=False))

# %%
#first run, with all features
bagging_features()
# Out:
# Average MAE: 0.3837
# Average MSE: 0.3676
# Average R²: 0.9947
#
# Sorted Average Feature Importance:
#                                                                                                               Feature   Importance  Rank
#                                                               Mortality rate, adult, female (per 1,000 female adults) 6.499488e-01     1
#                                                                 Mortality rate, under-5, male (per 1,000 live births) 1.415335e-01     2
#                                                                                  Death rate, crude (per 1,000 people) 7.212093e-02     3
#                                                                       Mortality rate, under-5 (per 1,000 live births) 5.605925e-02     4
#                                                               Mortality rate, under-5, female (per 1,000 live births) 4.233866e-02     5
#                                                          Domestic private health expenditure per capita (current US$) 1.025947e-02     6
#                                                                   Mortality rate, adult, male (per 1,000 male adults) 5.551662e-03     7
#                                                                                    GDP per capita (constant 2015 US$) 1.558475e-03     8
#                                                                   Current health expenditure per capita (current US$) 1.034316e-03     9
#                                                                      Mortality rate, neonatal (per 1,000 live births) 7.279410e-04    10
#                                                        Probability of dying among children ages 5-9 years (per 1,000) 6.987285e-04    11
#                                                                                     Arable land (hectares per person) 6.927956e-04    12
#                                                                  Mortality rate, infant, male (per 1,000 live births) 6.923599e-04    13
#                                                                Mortality rate, infant, female (per 1,000 live births) 3.923918e-04    14
#                                                                                      Region_Latin America & Caribbean 3.889917e-04    15
#                                        Agriculture, forestry, and fishing, value added per worker (constant 2015 US$) 3.665512e-04    16
#                                                  Employment to population ratio, 15+, male (%) (modeled ILO estimate) 3.341988e-04    17
#                                                                        Mortality rate, infant (per 1,000 live births) 3.330716e-04    18
#                                                                        Incidence of tuberculosis (per 100,000 people) 3.230794e-04    19
#                              Domestic general government health expenditure per capita, PPP (current international $) 3.085023e-04    20
#                                                 People using at least basic drinking water services (% of population) 2.854790e-04    21
#                                                           Out-of-pocket expenditure (% of current health expenditure) 2.278924e-04    22
#                                                                              Total fisheries production (metric tons) 2.181057e-04    23
#                                                                Population ages 15-19, female (% of female population) 1.965786e-04    24
#                                                                         Commercial bank branches (per 100,000 adults) 1.894565e-04    25
#                                                PM2.5 air pollution, mean annual exposure (micrograms per cubic meter) 1.862492e-04    26
#                                                                  Refugee population by country or territory of origin 1.774400e-04    27
#                                                   Probability of dying among adolescents ages 15-19 years (per 1,000) 1.759332e-04    28
#                                                              Methane (CH4) emissions from Building (Energy) (Mt CO2e) 1.713341e-04    29
#                                                                 Adjusted net national income per capita (current US$) 1.701603e-04    30
#                                                                          Domestic credit to private sector (% of GDP) 1.673848e-04    31
#                                                                                                         Net migration 1.641140e-04    32
#                                                                         Prevalence of anemia among pregnant women (%) 1.550116e-04    33
#                                                        Carbon intensity of GDP (kg CO2e per constant 2021 US$ of GDP) 1.489212e-04    34
#                                                    Prevalence of overweight (modeled estimate, % of children under 5) 1.461539e-04    35
# Share of youth not in education, employment or training, female (% of female youth population) (modeled ILO estimate) 1.412619e-04    36
#                                          Carbon dioxide (CO2) emissions (total) excluding LULUCF (% change from 1990) 1.406596e-04    37
#                                                         Fertilizer consumption (kilograms per hectare of arable land) 1.362351e-04    38
#                                                 Renewable internal freshwater resources, total (billion cubic meters) 1.275080e-04    39
#                                                                     External balance on goods and services (% of GDP) 1.265617e-04    40
#                                                                                    Rural population growth (annual %) 1.240493e-04    41
#                                               Domestic general government health expenditure per capita (current US$) 1.236131e-04    42
#                                                                              Urban population (% of total population) 1.147551e-04    43
#                                                                                  Birth rate, crude (per 1,000 people) 1.115026e-04    44
#         Share of youth not in education, employment or training, total (% of youth population) (modeled ILO estimate) 1.083135e-04    45
#                                          Prevalence of anemia among women of reproductive age (% of women ages 15-49) 1.069805e-04    46
#                                                                             International tourism, number of arrivals 1.066041e-04    47
#                                                  Current health expenditure per capita, PPP (current international $) 1.060369e-04    48
#                                                                                    Agricultural land (% of land area) 1.046159e-04    49
#                                                                              Exports of goods and services (% of GDP) 1.040582e-04    50
#                                                                                                 Surface area (sq. km) 1.040129e-04    51
#                                                         Probability of dying among youth ages 20-24 years (per 1,000) 1.036286e-04    52
#                                                                         Population ages 15-64 (% of total population) 1.020397e-04    53
#                                                                                          Arable land (% of land area) 1.015033e-04    54
#                                     Ratio of female to male labor force participation rate (%) (modeled ILO estimate) 1.006979e-04    55
#                                                             Domestic general government health expenditure (% of GDP) 1.002011e-04    56
#                                      Prevalence of stunting, height for age (modeled estimate, % of children under 5) 9.968512e-05    57
#                                                                   Immunization, DPT (% of children ages 12-23 months) 9.902804e-05    58
#                                                                    Adjusted savings: carbon dioxide damage (% of GNI) 9.477102e-05    59
#                                                                 Automated teller machines (ATMs) (per 100,000 adults) 9.379497e-05    60
#                                                   Probability of dying among adolescents ages 10-14 years (per 1,000) 9.340986e-05    61
#                                              Nitrous oxide (N2O) emissions from Fugitive Emissions (Energy) (Mt CO2e) 9.339085e-05    62
#                                                                          Labor force, female (% of total labor force) 9.052369e-05    63
#                                                                    Out-of-pocket expenditure per capita (current US$) 9.046256e-05    64
#                                                  Total greenhouse gas emissions excluding LULUCF (% change from 1990) 9.010460e-05    65
#                                                                               Food production index (2014-2016 = 100) 8.969179e-05    66
#                         Labor force participation rate, male (% of male population ages 15-64) (modeled ILO estimate) 8.850891e-05    67
#                                                     Renewable internal freshwater resources per capita (cubic meters) 8.684110e-05    68
#                                                                Population ages 10-14, female (% of female population) 8.632979e-05    69
#                                                                  Transport services (% of commercial service exports) 8.534502e-05    70
#                                    Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate) 8.495633e-05    71
#                                                                   Population density (people per sq. km of land area) 8.479428e-05    72
#                                                  Prevalence of anemia among children (% of children ages 6-59 months) 8.392686e-05    73
#                                                                     Travel services (% of commercial service imports) 8.149376e-05    74
#                                                         Adolescent fertility rate (births per 1,000 women ages 15-19) 8.060434e-05    75
#                                                            Agriculture, forestry, and fishing, value added (% of GDP) 8.026852e-05    76
#                                                      Carbon dioxide (CO2) emissions from Transport (Energy) (Mt CO2e) 7.719868e-05    77
#                                                                  Transport services (% of commercial service imports) 7.681191e-05    78
#                                                                                             Number of neonatal deaths 7.676262e-05    79
#                                        People using at least basic sanitation services, rural (% of rural population) 7.647811e-05    80
#                                                                    Population ages 10-14, male (% of male population) 7.629681e-05    81
#                                                                                   Lifetime risk of maternal death (%) 7.365993e-05    82
#                                                                                      Pillar 3 - Data Products - Score 7.362794e-05    83
#                                                     People using at least basic sanitation services (% of population) 7.336589e-05    84
#                                                                                                Broad money (% of GDP) 7.293580e-05    85
#                                                                                             Number of maternal deaths 7.244055e-05    86
#                                                                                   Permanent cropland (% of land area) 7.094179e-05    87
#                                                                                          Forest area (% of land area) 7.042106e-05    88
#                                                     GOAL 17: Partnerships to achieve the Goal (5 year moving average) 6.974311e-05    89
#                       Labor force participation rate, total (% of total population ages 15-64) (modeled ILO estimate) 6.866500e-05    90
#                                                                     Travel services (% of commercial service exports) 6.829087e-05    91
#                                                 Methane (CH4) emissions (total) excluding LULUCF (% change from 1990) 6.748261e-05    92
#                                                GOAL 16: Peace and Justice Strong Institutions (5 year moving average) 6.729008e-05    93
#                                                                                  Aquaculture production (metric tons) 6.680522e-05    94
#                                                                       Tuberculosis case detection rate (%, all forms) 6.653067e-05    95
#                                                     Unemployment, male (% of male labor force) (modeled ILO estimate) 6.568026e-05    96
#                                                                                    Urban population growth (annual %) 6.518314e-05    97
#                                                        Nitrous oxide (N2O) emissions from Building (Energy) (Mt CO2e) 6.471798e-05    98
#                                                    Renewable energy consumption (% of total final energy consumption) 6.456961e-05    99
#                                                                                                    Land area (sq. km) 6.436744e-05   100
#                                                         Proportion of seats held by women in national parliaments (%) 6.421978e-05   101
#                                                  Maternal mortality ratio (modeled estimate, per 100,000 live births) 6.414264e-05   102
#                      Water productivity, total (constant 2015 US$ GDP per cubic meter of total freshwater withdrawal) 6.372898e-05   103
#                                                                          School enrollment, primary, female (% gross) 6.301360e-05   104
#                                                                               Land under cereal production (hectares) 6.288765e-05   105
#                                                Employment to population ratio, 15+, female (%) (modeled ILO estimate) 6.225064e-05   106
#                                                                              Rural population (% of total population) 5.987541e-05   107
#                                                                                  Import unit value index (2015 = 100) 5.780471e-05   108
#                                                           Energy intensity level of primary energy (MJ/$2017 PPP GDP) 5.700830e-05   109
#                                                                            GNI per capita, Atlas method (current US$) 5.685315e-05   110
#                                                                                                  Forest area (sq. km) 5.648472e-05   111
#                                                                                    Inflation, GDP deflator (annual %) 5.600946e-05   112
#                                                                         GNI per capita, PPP (current international $) 5.591372e-05   113
#                                                                                  Export unit value index (2015 = 100) 5.577833e-05   114
#                                                             Methane (CH4) emissions from Transport (Energy) (Mt CO2e) 5.569611e-05   115
#                                                    Insurance and financial services (% of commercial service imports) 5.546972e-05   116
#                                      Domestic general government health expenditure (% of current health expenditure) 5.543963e-05   117
#                                                                    Adjusted savings: education expenditure (% of GNI) 5.536857e-05   118
#                                                                      Prevalence of undernourishment (% of population) 5.479758e-05   119
#                                                                                               Forest rents (% of GDP) 5.271954e-05   120
#                                                                    Ores and metals imports (% of merchandise imports) 5.242613e-05   121
#                                                                          Livestock production index (2014-2016 = 100) 5.206122e-05   122
#                                         Employment to population ratio, ages 15-24, female (%) (modeled ILO estimate) 5.179179e-05   123
#                                         Domestic private health expenditure per capita, PPP (current international $) 5.091882e-05   124
#                                    People using at least basic drinking water services, urban (% of urban population) 5.088819e-05   125
#                                                                      Carbon intensity of GDP (kg CO2e per 2021 PPP $) 5.065961e-05   126
#                                                            Communications, computer, etc. (% of service exports, BoP) 5.033765e-05   127
#                                                   Out-of-pocket expenditure per capita, PPP (current international $) 5.016464e-05   128
#                                                                  Women Business and the Law Index Score (scale 1-100) 4.980278e-05   129
#                                                                    Population ages 15-19, male (% of male population) 4.968211e-05   130
#                                                                   People practicing open defecation (% of population) 4.954243e-05   131
#                                                                              Total natural resources rents (% of GDP) 4.920881e-05   132
#                                          Employment to population ratio, ages 15-24, total (%) (modeled ILO estimate) 4.917010e-05   133
#                                                                            Claims on central government, etc. (% GDP) 4.893720e-05   134
#                                                                                      GDP per capita growth (annual %) 4.879071e-05   135
#                                                        International tourism, receipts for travel items (current US$) 4.844675e-05   136
#                                                                     Inflation, GDP deflator: linked series (annual %) 4.837006e-05   137
#                                                 Prevalence of anemia among non-pregnant women (% of women ages 15-49) 4.797349e-05   138
#                                  Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate) 4.788958e-05   139
#                                                                         GDP per capita, PPP (current international $) 4.771097e-05   140
#                                                                  Official exchange rate (LCU per US$, period average) 4.770377e-05   141
#                                                                                           Pillar 1 - Data Use - Score 4.736435e-05   142
#                         Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate) 4.697630e-05   143
#                                                    Insurance and financial services (% of commercial service exports) 4.676967e-05   144
#                                                                            Capture fisheries production (metric tons) 4.674291e-05   145
#                                                                                          GDP per capita (current US$) 4.656184e-05   146
#                                                 Domestic private health expenditure (% of current health expenditure) 4.585843e-05   147
#                                                   Unemployment, total (% of total labor force) (modeled ILO estimate) 4.564078e-05   148
#                                                    General government final consumption expenditure (annual % growth) 4.560370e-05   149
#                                                                            School enrollment, primary, male (% gross) 4.431000e-05   150
#                                                               Immunization, measles (% of children ages 12-23 months) 4.403876e-05   151
#                                           Nitrous oxide (N2O) emissions (total) excluding LULUCF (% change from 1990) 4.355462e-05   152
#                       Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate) 4.181650e-05   153
#                                                      Exports of goods, services and primary income (BoP, current US$) 4.064147e-05   154
#                  Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) 4.054671e-05   155
#                                                                  Tuberculosis treatment success rate (% of new cases) 4.005836e-05   156
#                                                  Nitrous oxide (N2O) emissions from Power Industry (Energy) (Mt CO2e) 3.951286e-05   157
#                                                 Unemployment, female (% of female labor force) (modeled ILO estimate) 3.934964e-05   158
#                                         Computer, communications and other services (% of commercial service exports) 3.925928e-05   159
#                                                 Carbon dioxide (CO2) emissions from Power Industry (Energy) (Mt CO2e) 3.879287e-05   160
#                                        People using at least basic sanitation services, urban (% of urban population) 3.862667e-05   161
#                                                                                  School enrollment, primary (% gross) 3.830789e-05   162
#       Total alcohol consumption per capita, male (liters of pure alcohol, projected estimates, male 15+ years of age) 3.791136e-05   163
#                                           Vulnerable employment, total (% of total employment) (modeled ILO estimate) 3.771301e-05   164
#                                                                 Population ages 0-14, female (% of female population) 3.768707e-05   165
#                                             Carbon dioxide (CO2) emissions from Fugitive Emissions (Energy) (Mt CO2e) 3.736289e-05   166
#                                                                                              Mineral rents (% of GDP) 3.725524e-05   167
#                                                                                 Current health expenditure (% of GDP) 3.657017e-05   168
#                                                                          Population ages 0-14 (% of total population) 3.649142e-05   169
#                                                                                Compulsory education, duration (years) 3.635729e-05   170
#                                                                                       Number of deaths ages 5-9 years 3.578195e-05   171
#                                                                                           Number of under-five deaths 3.570677e-05   172
#                           Labor force participation rate, male (% of male population ages 15+) (modeled ILO estimate) 3.564174e-05   173
#                                               GOAL 12: Responsible Consumption and Production (5 year moving average) 3.544235e-05   174
#                            Carbon dioxide (CO2) net fluxes from LULUCF - Total excluding non-tropical fires (Mt CO2e) 3.522885e-05   175
#                                                                                       Cereal production (metric tons) 3.502099e-05   176
#                                            Total greenhouse gas emissions per capita excluding LULUCF (t CO2e/capita) 3.498229e-05   177
#                                                                  Refugee population by country or territory of asylum 3.461502e-05   178
#                                       Labor force participation rate for ages 15-24, total (%) (modeled ILO estimate) 3.424651e-05   179
#                                Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate) 3.397430e-05   180
#                                                  Access to clean fuels and technologies for cooking (% of population) 3.378112e-05   181
#                                                                                               Number of infant deaths 3.369352e-05   182
#                                                    International tourism, expenditures for travel items (current US$) 3.364531e-05   183
#                                  Fluorinated greenhouse gases (F-gases) emissions from Industrial Processes (Mt CO2e) 3.334559e-05   184
#                                                                       Final consumption expenditure (annual % growth) 3.330690e-05   185
#                                                    Carbon dioxide (CO2) emissions from Industrial Processes (Mt CO2e) 3.271297e-05   186
#                                                                  Access to electricity, rural (% of rural population) 3.267693e-05   187
#     Share of youth not in education, employment or training, male (% of male youth population) (modeled ILO estimate) 3.263844e-05   188
#                                                        Lifetime risk of maternal death (1 in: rate varies by country) 3.243533e-05   189
#                                      Labor force participation rate for ages 15-24, female (%) (modeled ILO estimate) 3.215167e-05   190
#                                                                                          Natural gas rents (% of GDP) 3.213156e-05   191
#                                        Labor force participation rate for ages 15-24, male (%) (modeled ILO estimate) 3.207755e-05   192
#                                                                 Domestic credit to private sector by banks (% of GDP) 3.158664e-05   193
#                                                                                                      Rural population 3.158133e-05   194
#                                                            Communications, computer, etc. (% of service imports, BoP) 3.141619e-05   195
#                                                    Methane (CH4) emissions from Fugitive Emissions (Energy) (Mt CO2e) 3.131695e-05   196
#                                                                              GDP, PPP (constant 2021 international $) 3.092985e-05   197
#                                                                     Population ages 0-14, male (% of male population) 3.082480e-05   198
#                                                 Employment to population ratio, 15+, total (%) (modeled ILO estimate) 3.045128e-05   199
#                                                   Carbon dioxide (CO2) net fluxes from LULUCF - Forest Land (Mt CO2e) 2.969736e-05   200
#                                                                               Fuel imports (% of merchandise imports) 2.927622e-05   201
#                                                                               Access to electricity (% of population) 2.913769e-05   202
#                                                                    Methane (CH4) emissions from Agriculture (Mt CO2e) 2.894287e-05   203
#   Total alcohol consumption per capita, female (liters of pure alcohol, projected estimates, female 15+ years of age) 2.892594e-05   204
#                                                   GOAL 11: Sustainable Cities and Communities (5 year moving average) 2.888003e-05   205
#                                                     Nitrous oxide (N2O) emissions from Industrial Processes (Mt CO2e) 2.877637e-05   206
#                                     Wage and salaried workers, female (% of female employment) (modeled ILO estimate) 2.856596e-05   207
#                                                                    Nitrous oxide (N2O) emissions from Waste (Mt CO2e) 2.820776e-05   208
#                     Labor force participation rate, female (% of female population ages 15-64) (modeled ILO estimate) 2.784550e-05   209
#                                                                               Fuel exports (% of merchandise exports) 2.746797e-05   210
#                                                                               Crop production index (2014-2016 = 100) 2.682705e-05   211
#                                                                                Preprimary education, duration (years) 2.651607e-05   212
#                                                        Methane (CH4) emissions from Power Industry (Energy) (Mt CO2e) 2.587458e-05   213
#                                         Vulnerable employment, female (% of female employment) (modeled ILO estimate) 2.559973e-05   214
#                                                                  Access to electricity, urban (% of urban population) 2.544310e-05   215
#                                                                                             Primary education, pupils 2.516761e-05   216
#                                                                      Monetary Sector credit to private sector (% GDP) 2.477876e-05   217
#                                         Computer, communications and other services (% of commercial service imports) 2.439440e-05   218
#                                                                                                 GDP growth (annual %) 2.388586e-05   219
#                                                                                                  Oil rents (% of GDP) 2.341813e-05   220
#                                                                         GDP per person employed (constant 2021 PPP $) 2.288513e-05   221
#                                                 Self-employed, female (% of female employment) (modeled ILO estimate) 2.261083e-05   222
#                                                                         GOAL 15: Life on Land (5 year moving average) 2.256539e-05   223
#                                            Carbon dioxide (CO2) emissions excluding LULUCF per capita (t CO2e/capita) 2.209148e-05   224
#                                         Wage and salaried workers, male (% of male employment) (modeled ILO estimate) 2.182181e-05   225
#                                           Employment to population ratio, ages 15-24, male (%) (modeled ILO estimate) 2.176133e-05   226
#                                                             Total greenhouse gas emissions including LULUCF (Mt CO2e) 2.125356e-05   227
#                                                     Self-employed, male (% of male employment) (modeled ILO estimate) 2.122823e-05   228
#                                                                   GDP per capita, PPP (constant 2021 international $) 2.105293e-05   229
#                                                                                               GDP (constant 2015 US$) 2.067074e-05   230
#                                                                                     Number of deaths ages 15-19 years 1.984377e-05   231
#                                                   Self-employed, total (% of total employment) (modeled ILO estimate) 1.975570e-05   232
#                                     Access to clean fuels and technologies for cooking, urban (% of urban population) 1.950156e-05   233
#                                                       Nitrous oxide (N2O) emissions from Transport (Energy) (Mt CO2e) 1.920339e-05   234
#                                             Vulnerable employment, male (% of male employment) (modeled ILO estimate) 1.863397e-05   235
#                                                                         Adjusted savings: energy depletion (% of GNI) 1.847566e-05   236
#                                       Wage and salaried workers, total (% of total employment) (modeled ILO estimate) 1.839869e-05   237
#                                                                                                 Coal rents (% of GDP) 1.830310e-05   238
#                                                              Nitrous oxide (N2O) emissions from Agriculture (Mt CO2e) 1.798667e-05   239
#                                                                   GOAL 10: Reduced Inequality (5 year moving average) 1.716683e-05   240
#                                                                            GOAL 1: No Poverty (5 year moving average) 1.715436e-05   241
#                                                 Carbon dioxide (CO2) net fluxes from LULUCF - Deforestation (Mt CO2e) 1.674908e-05   242
#                                                                            Adjusted net national income (current US$) 1.664562e-05   243
#                                                                                    GDP, PPP (current international $) 1.606839e-05   244
#                                                      Nitrous oxide (N2O) emissions (total) excluding LULUCF (Mt CO2e) 1.584850e-05   245
#                                                                                                     GDP (current US$) 1.523137e-05   246
#                                                       Carbon dioxide (CO2) emissions from Building (Energy) (Mt CO2e) 1.511752e-05   247
#                                                             Total greenhouse gas emissions excluding LULUCF (Mt CO2e) 1.457495e-05   248
#                                                                                     Number of deaths ages 10-14 years 1.420888e-05   249
#                                                  General government final consumption expenditure (constant 2015 US$) 1.393652e-05   250
#                                          Carbon dioxide (CO2) emissions from Industrial Combustion (Energy) (Mt CO2e) 1.362107e-05   251
#                                                                                     Number of deaths ages 20-24 years 1.355463e-05   252
#                                                                                          Population ages 0-14, female 1.332821e-05   253
#                                                                                            Population ages 0-14, male 1.316899e-05   254
#                                                     Carbon dioxide (CO2) emissions (total) excluding LULUCF (Mt CO2e) 1.234721e-05   255
#                                                            Methane (CH4) emissions (total) excluding LULUCF (Mt CO2e) 1.083552e-05   256
#                                           Nitrous oxide (N2O) emissions from Industrial Combustion (Energy) (Mt CO2e) 1.064834e-05   257
#                                                                                                    Labor force, total 1.054782e-05   258
#                                                 Methane (CH4) emissions from Industrial Combustion (Energy) (Mt CO2e) 1.034700e-05   259
#                                                                                    GNI, PPP (current international $) 9.818746e-06   260
#                                                          Health/Demographic survey (Availability score over 10 years) 8.741705e-06   261
#                                                                          Methane (CH4) emissions from Waste (Mt CO2e) 8.320859e-06   262
#                                     Access to clean fuels and technologies for cooking, rural (% of rural population) 7.959168e-06   263
#                                                                                                      Urban population 7.264484e-06   264
#                                                                                       GNI, Atlas method (current US$) 6.624935e-06   265
#                                                                     Final consumption expenditure (constant 2015 US$) 6.509150e-06   266
#                                                                                                     GNI (current US$) 6.454263e-06   267
#                                                    Household Survey on income, etc (Availability score over 10 years) 6.123367e-06   268
#                                                                 Labor Force Survey (Availability score over 10 years) 4.882009e-06   269
#                                                                                           Population ages 0-14, total 4.695901e-06   270
#                                                                                      Income Group_Lower middle income 3.921708e-06   271
#                                                                       GOAL 13: Climate Action (5 year moving average) 3.695512e-06   272
#                                                                                     Region_Middle East & North Africa 7.317381e-07   273
#                                                                                      Income Group_Upper middle income 6.118944e-07   274
#                                                                                               Income Group_Low income 4.409546e-07   275
#                                                                                              Income Group_High income 1.451973e-07   276
#                                                                                                     Region_South Asia 1.287281e-07   277
#                                                                                            Region_East Asia & Pacific 6.493036e-08   278
#                                                                                             Region_Sub-Saharan Africa 5.996811e-08   279
#                                                                                          Region_Europe & Central Asia 5.191612e-08   280
#                                                                                                  Region_North America 1.355650e-08   281

# %%
mortality_cols_to_exclude = [
    'Death rate, crude (per 1,000 people)',
    'Lifetime risk of maternal death (%)',
    'Lifetime risk of maternal death (1 in: rate varies by country)',
    'Maternal mortality ratio (modeled estimate, per 100,000 live births)',
    'Number of maternal deaths',
    'Number of deaths ages 5-9 years',
    'Number of under-five deaths',
    'Number of infant deaths',
    'Number of deaths ages 10-14 years',
    'Number of neonatal deaths',
    'Number of deaths ages 15-19 years',
    'Number of deaths ages 20-24 years',
    'Mortality rate, adult, female (per 1,000 female adults)',
    'Mortality rate, infant, male (per 1,000 live births)',
    'Mortality rate, infant (per 1,000 live births)',
    'Mortality rate, adult, male (per 1,000 male adults)',
    'Mortality rate, infant, female (per 1,000 live births)',
    'Mortality rate, under-5, male (per 1,000 live births)',
    'Mortality rate, under-5 (per 1,000 live births)',
    'Mortality rate, under-5, female (per 1,000 live births)',
    'Mortality rate, neonatal (per 1,000 live births)',
    'Probability of dying among youth ages 20-24 years (per 1,000)',
    'Probability of dying among adolescents ages 15-19 years (per 1,000)',
    'Probability of dying among children ages 5-9 years (per 1,000)',
    'Probability of dying among adolescents ages 10-14 years (per 1,000)'   
]

# %%
#second run, but dropping redundant features
addl_cols_to_exclude = [
    #features in column "Feature_1" from correlation_to_all_lister.ipynb
    'Total greenhouse gas emissions including LULUCF (Mt CO2e)',
    'GDP, PPP (constant 2021 international $)',
    'General government final consumption expenditure (constant 2015 US$)',
    'GNI, PPP (current international $)',
    'Carbon dioxide (CO2) emissions (total) excluding LULUCF (Mt CO2e)',
    'GDP, PPP (current international $)',
    'Cereal production (metric tons)',
    'Methane (CH4) emissions (total) excluding LULUCF (Mt CO2e)',
    'Life expectancy at birth, female (years)',
    'Adjusted net national income (current US$)',
    'Fluorinated greenhouse gases (F-gases) emissions from Industrial Processes (Mt CO2e)',
    'Primary education, pupils',
    'Final consumption expenditure (constant 2015 US$)',
    'Adjusted net national income per capita (current US$)',
    'Number of deaths ages 15-19 years',
    'Self-employed, female (% of female employment) (modeled ILO estimate)',
    'Nitrous oxide (N2O) emissions (total) excluding LULUCF (Mt CO2e)',
    'Self-employed, male (% of male employment) (modeled ILO estimate)',
    'Mortality rate, infant (per 1,000 live births)',
    'GDP (constant 2015 US$)',
    'Life expectancy at birth, total (years)',
    'Carbon dioxide (CO2) emissions from Power Industry (Energy) (Mt CO2e)',
    'Carbon dioxide (CO2) emissions from Industrial Combustion (Energy) (Mt CO2e)',
    'Land under cereal production (hectares)',
    'GDP per capita, PPP (constant 2021 international $)',
    'Methane (CH4) emissions from Industrial Combustion (Energy) (Mt CO2e)',
    'Self-employed, total (% of total employment) (modeled ILO estimate)',
    'Carbon dioxide (CO2) emissions from Fugitive Emissions (Energy) (Mt CO2e)',
    'Carbon dioxide (CO2) emissions from Building (Energy) (Mt CO2e)',
    'Number of deaths ages 10-14 years',
    'Methane (CH4) emissions from Agriculture (Mt CO2e)',
    'Number of deaths ages 20-24 years',
    'GNI, Atlas method (current US$)',
    'Prevalence of anemia among children (% of children ages 6-59 months)',
    'Nitrous oxide (N2O) emissions from Industrial Combustion (Energy) (Mt CO2e)',
    'Rural population',
    'Nitrous oxide (N2O) emissions from Agriculture (Mt CO2e)',
    'GNI per capita, Atlas method (current US$)',
    'Methane (CH4) emissions from Waste (Mt CO2e)',
    'Mortality rate, infant, female (per 1,000 live births)',
    'Mortality rate, infant, male (per 1,000 live births)',
    'Vulnerable employment, female (% of female employment) (modeled ILO estimate)',
    'Nitrous oxide (N2O) emissions from Power Industry (Energy) (Mt CO2e)',
    'GNI (current US$)',
    'GDP per capita (current US$)',
    'GDP per capita (constant 2015 US$)',
    'Population ages 0-14 (% of total population)',
    'Vulnerable employment, male (% of male employment) (modeled ILO estimate)',
    'Carbon dioxide (CO2) emissions from Industrial Processes (Mt CO2e)',
    'Birth rate, crude (per 1,000 people)',
    'Mortality rate, under-5 (per 1,000 live births)',
    'Access to electricity (% of population)',
    'Life expectancy at birth, male (years)',
    'Mortality rate, neonatal (per 1,000 live births)',
    'Nitrous oxide (N2O) emissions from Building (Energy) (Mt CO2e)',
    'Number of deaths ages 5-9 years',
    'Nitrous oxide (N2O) emissions from Waste (Mt CO2e)',
    'Exports of goods, services and primary income (BoP, current US$)',
    'Access to electricity, rural (% of rural population)',
    'Aquaculture production (metric tons)',
    'Vulnerable employment, total (% of total employment) (modeled ILO estimate)',
    'Current health expenditure per capita (current US$)',
    'Population ages 0-14, female (% of female population)',
    'Total fisheries production (metric tons)',
    'Mortality rate, under-5, female (per 1,000 live births)',
    'GDP (current US$)',
    'Unemployment, male (% of male labor force) (modeled ILO estimate)',
    'Unemployment, female (% of female labor force) (modeled ILO estimate)',
    'Out-of-pocket expenditure per capita (current US$)',
    'People using at least basic sanitation services, rural (% of rural population)',
    'Number of infant deaths',
    'Population ages 0-14, male',
    'Population ages 0-14, male (% of male population)',
    'School enrollment, primary, female (% gross)',
    'Population ages 10-14, female (% of female population)',
    'Population ages 10-14, male (% of male population)',
    'Mortality rate, under-5, male (per 1,000 live births)',
    'Population ages 0-14, female',
    'Access to clean fuels and technologies for cooking (% of population)',
    'Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)',
    'GDP per capita, PPP (current international $)',
    'Employment to population ratio, ages 15-24, female (%) (modeled ILO estimate)',
    'Domestic credit to private sector (% of GDP)',
    'Employment to population ratio, ages 15-24, male (%) (modeled ILO estimate)',
    'Methane (CH4) emissions from Power Industry (Energy) (Mt CO2e)',
    'Unemployment, total (% of total labor force) (modeled ILO estimate)',
    'Current health expenditure per capita, PPP (current international $)',
    'Forest area (sq. km)',
    'GNI per capita, PPP (current international $)',
    'Employment to population ratio, 15+, female (%) (modeled ILO estimate)',
    'Carbon dioxide (CO2) emissions from Transport (Energy) (Mt CO2e)',
    'Wage and salaried workers, female (% of female employment) (modeled ILO estimate)',
    'Prevalence of anemia among non-pregnant women (% of women ages 15-49)',
    'Maternal mortality ratio (modeled estimate, per 100,000 live births)',
    'Methane (CH4) emissions from Building (Energy) (Mt CO2e)',
    'Methane (CH4) emissions from Fugitive Emissions (Energy) (Mt CO2e)',
    'Prevalence of anemia among pregnant women (%)',
    'Urban population',
    'School enrollment, primary, male (% gross)',
    'Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate)',
    'Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate)',
    'Probability of dying among adolescents ages 10-14 years (per 1,000)',
    'Rural population (% of total population)',
    'Total greenhouse gas emissions excluding LULUCF (Mt CO2e)',
    'Total alcohol consumption per capita, female (liters of pure alcohol, projected estimates, female 15+ years of age)',
    'Share of youth not in education, employment or training, female (% of female youth population) (modeled ILO estimate)',
    'Probability of dying among adolescents ages 15-19 years (per 1,000)',
    'Methane (CH4) emissions from Transport (Energy) (Mt CO2e)',
    'Population ages 15-19, female (% of female population)',
    'People using at least basic sanitation services, urban (% of urban population)',
    'Carbon dioxide (CO2) emissions excluding LULUCF per capita (t CO2e/capita)',
    'Communications, computer, etc. (% of service exports, BoP)',
    'Communications, computer, etc. (% of service imports, BoP)',
    'Domestic general government health expenditure per capita (current US$)',
    'Domestic private health expenditure per capita (current US$)',
    'Employment to population ratio, 15+, male (%) (modeled ILO estimate)',
    'Employment to population ratio, 15+, total (%) (modeled ILO estimate)',
    'Employment to population ratio, ages 15-24, total (%) (modeled ILO estimate)',
    'GDP growth (annual %)',
    'Immunization, DPT (% of children ages 12-23 months)',
    'Inflation, GDP deflator (annual %)',
    'Labor force participation rate for ages 15-24, female (%) (modeled ILO estimate)',
    'Labor force participation rate for ages 15-24, male (%) (modeled ILO estimate)',
    'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)',
    'Labor force participation rate, female (% of female population ages 15-64) (modeled ILO estimate)',
    'Labor force, female (% of total labor force)',
    'Land area (sq. km)',
    'Lifetime risk of maternal death (%)',
    'Monetary Sector credit to private sector (% GDP)',
    'Mortality rate, adult, female (per 1,000 female adults)',
    'Nitrous oxide (N2O) emissions from Industrial Processes (Mt CO2e)',
    'Number of maternal deaths',
    'Number of neonatal deaths',
    'Out-of-pocket expenditure (% of current health expenditure)',
    'People using at least basic drinking water services, urban (% of urban population)',
    'Wage and salaried workers, male (% of male employment) (modeled ILO estimate)'
]
new_cols_to_exclude = cols_to_exclude + mortality_cols_to_exclude + addl_cols_to_exclude
new_cols_to_exclude = list(set(new_cols_to_exclude))
bagging_features(new_cols_to_exclude)
# Out:
# Average MAE: 0.6989
# Average MSE: 1.3180
# Average R²: 0.9811
#
# Sorted Average Feature Importance:
#                                                                                                           Feature   Importance  Rank
#                                                 People using at least basic sanitation services (% of population) 6.273059e-01     1
#                          Domestic general government health expenditure per capita, PPP (current international $) 1.196438e-01     2
#                                                                                         Region_Sub-Saharan Africa 5.415043e-02     3
#                                                              Access to electricity, urban (% of urban population) 2.438145e-02     4
#                                  Prevalence of stunting, height for age (modeled estimate, % of children under 5) 1.934422e-02     5
#                                                             Domestic credit to private sector by banks (% of GDP) 1.615428e-02     6
#                                                                    Incidence of tuberculosis (per 100,000 people) 1.211995e-02     7
#                                                                                       Pillar 1 - Data Use - Score 6.157572e-03     8
#                                                     Adolescent fertility rate (births per 1,000 women ages 15-19) 5.987734e-03     9
#                                                                                Rural population growth (annual %) 5.818748e-03    10
#                                      Prevalence of anemia among women of reproductive age (% of women ages 15-49) 5.086543e-03    11
#                                               Out-of-pocket expenditure per capita, PPP (current international $) 5.020669e-03    12
#                                                                        Capture fisheries production (metric tons) 4.992446e-03    13
#                                                                                 Arable land (hectares per person) 3.786542e-03    14
#                                                                     GDP per person employed (constant 2021 PPP $) 3.660572e-03    15
#                                                     Fertilizer consumption (kilograms per hectare of arable land) 2.552952e-03    16
#                                              Total greenhouse gas emissions excluding LULUCF (% change from 1990) 2.530684e-03    17
#                                      Carbon dioxide (CO2) emissions (total) excluding LULUCF (% change from 1990) 2.490122e-03    18
#                                                                     Commercial bank branches (per 100,000 adults) 2.380183e-03    19
#                                                                           Food production index (2014-2016 = 100) 2.323584e-03    20
#                                                                               Permanent cropland (% of land area) 2.066404e-03    21
#                                                                 Travel services (% of commercial service imports) 1.963085e-03    22
#                  Water productivity, total (constant 2015 US$ GDP per cubic meter of total freshwater withdrawal) 1.766549e-03    23
#                                                                     Population ages 15-64 (% of total population) 1.760989e-03    24
#                                                                          Urban population (% of total population) 1.717721e-03    25
#                                                           Immunization, measles (% of children ages 12-23 months) 1.676553e-03    26
#                                                               Population density (people per sq. km of land area) 1.573173e-03    27
#                                                              Refugee population by country or territory of origin 1.441291e-03    28
#                                     Domestic private health expenditure per capita, PPP (current international $) 1.400546e-03    29
#                                                               People practicing open defecation (% of population) 1.277915e-03    30
#                                             People using at least basic drinking water services (% of population) 1.228402e-03    31
#                                                                Adjusted savings: carbon dioxide damage (% of GNI) 1.200991e-03    32
#                                                              Official exchange rate (LCU per US$, period average) 1.199219e-03    33
#                                                Insurance and financial services (% of commercial service exports) 1.146339e-03    34
#                                                                      Livestock production index (2014-2016 = 100) 1.120686e-03    35
#                                                                                            Broad money (% of GDP) 1.120647e-03    36
#                                                Insurance and financial services (% of commercial service imports) 1.085086e-03    37
#                                                                           Crop production index (2014-2016 = 100) 1.050740e-03    38
#                                 Access to clean fuels and technologies for cooking, urban (% of urban population) 1.026244e-03    39
#                                                                                                     Net migration 9.890958e-04    40
#                                   Wage and salaried workers, total (% of total employment) (modeled ILO estimate) 9.604127e-04    41
#                                                Renewable energy consumption (% of total final energy consumption) 9.479123e-04    42
#                                                                Population ages 15-19, male (% of male population) 9.193625e-04    43
#                                                   Nitrous oxide (N2O) emissions from Transport (Energy) (Mt CO2e) 9.190619e-04    44
#                                                                          Total natural resources rents (% of GDP) 9.100899e-04    45
#                                                     Proportion of seats held by women in national parliaments (%) 9.098375e-04    46
#                                       Nitrous oxide (N2O) emissions (total) excluding LULUCF (% change from 1990) 8.983658e-04    47
#                                             Renewable internal freshwater resources, total (billion cubic meters) 8.769229e-04    48
#                              Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate) 8.696561e-04    49
#                                                                 Travel services (% of commercial service exports) 8.576776e-04    50
#                                                         Domestic general government health expenditure (% of GDP) 8.484170e-04    51
#                                 Ratio of female to male labor force participation rate (%) (modeled ILO estimate) 8.451747e-04    52
#                                                       Energy intensity level of primary energy (MJ/$2017 PPP GDP) 8.003729e-04    53
#                                                              Women Business and the Law Index Score (scale 1-100) 7.914449e-04    54
#                                                    International tourism, receipts for travel items (current US$) 7.840690e-04    55
#                                                                        GOAL 1: No Poverty (5 year moving average) 7.694881e-04    56
#                                                              Refugee population by country or territory of asylum 7.208085e-04    57
#                                                                  Prevalence of undernourishment (% of population) 7.102511e-04    58
#   Total alcohol consumption per capita, male (liters of pure alcohol, projected estimates, male 15+ years of age) 7.005780e-04    59
#                                                                            Compulsory education, duration (years) 6.793112e-04    60
#                                          Nitrous oxide (N2O) emissions from Fugitive Emissions (Energy) (Mt CO2e) 6.734176e-04    61
#                                                                   Tuberculosis case detection rate (%, all forms) 6.706655e-04    62
#                   Labor force participation rate, total (% of total population ages 15-64) (modeled ILO estimate) 6.691654e-04    63
#                                                                                Agricultural land (% of land area) 6.614198e-04    64
#                                                                        Claims on central government, etc. (% GDP) 6.560592e-04    65
#                                                        Agriculture, forestry, and fishing, value added (% of GDP) 6.501804e-04    66
#                                                Prevalence of overweight (modeled estimate, % of children under 5) 6.376709e-04    67
#                                                                Adjusted savings: education expenditure (% of GNI) 6.272241e-04    68
#                                                              Tuberculosis treatment success rate (% of new cases) 6.238084e-04    69
#                                               GOAL 11: Sustainable Cities and Communities (5 year moving average) 6.008876e-04    70
#                                                                                  Pillar 3 - Data Products - Score 6.003199e-04    71
#                                                             Automated teller machines (ATMs) (per 100,000 adults) 5.918095e-04    72
#                                                                  Carbon intensity of GDP (kg CO2e per 2021 PPP $) 5.838615e-04    73
#                                                                             Current health expenditure (% of GDP) 5.724432e-04    74
#                                                                                             Coal rents (% of GDP) 5.557958e-04    75
#                                                                                      Forest area (% of land area) 5.507145e-04    76
#                                                              Transport services (% of commercial service exports) 5.251092e-04    77
#                                     Computer, communications and other services (% of commercial service exports) 5.172059e-04    78
#                                        Total greenhouse gas emissions per capita excluding LULUCF (t CO2e/capita) 5.127627e-04    79
#                                 Access to clean fuels and technologies for cooking, rural (% of rural population) 5.059167e-04    80
#                                                                              Import unit value index (2015 = 100) 5.025989e-04    81
#                                                              Transport services (% of commercial service imports) 4.966833e-04    82
#                                             Methane (CH4) emissions (total) excluding LULUCF (% change from 1990) 4.951629e-04    83
#                                                 Renewable internal freshwater resources per capita (cubic meters) 4.906302e-04    84
#                                                                          Exports of goods and services (% of GDP) 4.886037e-04    85
#                                            PM2.5 air pollution, mean annual exposure (micrograms per cubic meter) 4.868675e-04    86
#                                                International tourism, expenditures for travel items (current US$) 4.705079e-04    87
#                                                                                       Population ages 0-14, total 4.685655e-04    88
#                                                                                Urban population growth (annual %) 4.579536e-04    89
#                     Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate) 4.522446e-04    90
#                                                 GOAL 17: Partnerships to achieve the Goal (5 year moving average) 4.498703e-04    91
#                                                                Ores and metals imports (% of merchandise imports) 4.449601e-04    92
#                                   Labor force participation rate for ages 15-24, total (%) (modeled ILO estimate) 4.413984e-04    93
#                                    Agriculture, forestry, and fishing, value added per worker (constant 2015 US$) 4.399842e-04    94
#                                                                                  GDP per capita growth (annual %) 4.307748e-04    95
#                                                                              School enrollment, primary (% gross) 4.262771e-04    96
#                        Carbon dioxide (CO2) net fluxes from LULUCF - Total excluding non-tropical fires (Mt CO2e) 4.082906e-04    97
#                                                                                              Oil rents (% of GDP) 4.050769e-04    98
#                                                                                      Arable land (% of land area) 3.975835e-04    99
#                                                    Carbon intensity of GDP (kg CO2e per constant 2021 US$ of GDP) 3.807047e-04   100
#                                                                                                Labor force, total 3.763575e-04   101
#                                  Domestic general government health expenditure (% of current health expenditure) 3.762508e-04   102
#                                                                     Adjusted savings: energy depletion (% of GNI) 3.733739e-04   103
#                                                                                           Forest rents (% of GDP) 3.704912e-04   104
#     Share of youth not in education, employment or training, total (% of youth population) (modeled ILO estimate) 3.697981e-04   105
#                                                                           Fuel exports (% of merchandise exports) 3.653974e-04   106
#                                                                                      Natural gas rents (% of GDP) 3.631411e-04   107
#                                               Carbon dioxide (CO2) net fluxes from LULUCF - Forest Land (Mt CO2e) 3.520855e-04   108
#                                             Carbon dioxide (CO2) net fluxes from LULUCF - Deforestation (Mt CO2e) 3.358678e-04   109
#                                                                                          Mineral rents (% of GDP) 3.344196e-04   110
#                                                                                             Surface area (sq. km) 3.212452e-04   111
#                                     Computer, communications and other services (% of commercial service imports) 3.162587e-04   112
#                                                                              Export unit value index (2015 = 100) 3.106552e-04   113
#                                                                   Final consumption expenditure (annual % growth) 3.040195e-04   114
#                                                                           Fuel imports (% of merchandise imports) 2.888563e-04   115
#                                             Domestic private health expenditure (% of current health expenditure) 2.876778e-04   116
#                                                                 External balance on goods and services (% of GDP) 2.858413e-04   117
#                     Labor force participation rate, male (% of male population ages 15-64) (modeled ILO estimate) 2.806193e-04   118
#                                                                 Inflation, GDP deflator: linked series (annual %) 2.734837e-04   119
#                                                                   GOAL 13: Climate Action (5 year moving average) 2.640764e-04   120
# Share of youth not in education, employment or training, male (% of male youth population) (modeled ILO estimate) 2.382467e-04   121
#                                                                         International tourism, number of arrivals 2.325165e-04   122
#                                                                            Preprimary education, duration (years) 2.316382e-04   123
#                                            GOAL 16: Peace and Justice Strong Institutions (5 year moving average) 2.301225e-04   124
#                       Labor force participation rate, male (% of male population ages 15+) (modeled ILO estimate) 2.234033e-04   125
#                                           GOAL 12: Responsible Consumption and Production (5 year moving average) 1.389607e-04   126
#                                                General government final consumption expenditure (annual % growth) 1.347229e-04   127
#                                                             Labor Force Survey (Availability score over 10 years) 1.333762e-04   128
#                                                               GOAL 10: Reduced Inequality (5 year moving average) 9.620374e-05   129
#                                                      Health/Demographic survey (Availability score over 10 years) 8.399560e-05   130
#                                                                     GOAL 15: Life on Land (5 year moving average) 7.994896e-05   131
#                                                                                        Region_East Asia & Pacific 7.688436e-05   132
#                                                Household Survey on income, etc (Availability score over 10 years) 7.304760e-05   133
#                                                                                  Income Group_Upper middle income 1.278900e-05   134
#                                                                                  Income Group_Lower middle income 6.865232e-06   135
#                                                                                 Region_Middle East & North Africa 5.743946e-06   136
#                                                                                                 Region_South Asia 5.648063e-06   137
#                                                                                          Income Group_High income 1.827530e-06   138
#                                                                                  Region_Latin America & Caribbean 1.801234e-06   139
#                                                                                           Income Group_Low income 1.124510e-06   140
#                                                                                      Region_Europe & Central Asia 7.446832e-07   141
#                                                                                              Region_North America 1.943748e-09   142

# %%
#third run, but dropping different redundant features
addl_cols_to_exclude = [
    #features in column "Feature_2" from correlation_to_all_lister.ipynb
    'Total greenhouse gas emissions excluding LULUCF (Mt CO2e)',
    'Nitrous oxide (N2O) emissions from Waste (Mt CO2e)',
    'Urban population',
    'Labor force, total',
    'Nitrous oxide (N2O) emissions from Transport (Energy) (Mt CO2e)',
    'Methane (CH4) emissions from Power Industry (Energy) (Mt CO2e)',
    'Carbon dioxide (CO2) emissions from Power Industry (Energy) (Mt CO2e)',
    'Carbon dioxide (CO2) emissions from Building (Energy) (Mt CO2e)',
    'GDP (current US$)',
    'GNI (current US$)',
    'Mortality rate, under-5, male (per 1,000 live births)',
    'Nitrous oxide (N2O) emissions from Power Industry (Energy) (Mt CO2e)',
    'GNI, Atlas method (current US$)',
    'Nitrous oxide (N2O) emissions from Agriculture (Mt CO2e)',
    'Nitrous oxide (N2O) emissions (total) excluding LULUCF (Mt CO2e)',
    'Wage and salaried workers, total (% of total employment) (modeled ILO estimate)',
    'Carbon dioxide (CO2) emissions from Transport (Energy) (Mt CO2e)',
    'Nitrous oxide (N2O) emissions from Building (Energy) (Mt CO2e)',
    'Nitrous oxide (N2O) emissions from Industrial Combustion (Energy) (Mt CO2e)',
    'Mortality rate, under-5 (per 1,000 live births)',
    'Carbon dioxide (CO2) emissions (total) excluding LULUCF (Mt CO2e)',
    'Wage and salaried workers, male (% of male employment) (modeled ILO estimate)',
    'Wage and salaried workers, female (% of female employment) (modeled ILO estimate)',
    'Methane (CH4) emissions from Waste (Mt CO2e)',
    'GDP (constant 2015 US$)',
    'Domestic general government health expenditure per capita, PPP (current international $)',
    'Mortality rate, under-5, female (per 1,000 live births)',
    'Population ages 0-14, total',
    'Probability of dying among children ages 5-9 years (per 1,000)',
    'Number of under-five deaths',
    'Number of neonatal deaths',
    'Population ages 0-14, male',
    'Vulnerable employment, total (% of total employment) (modeled ILO estimate)',
    'Carbon dioxide (CO2) emissions from Industrial Processes (Mt CO2e)',
    'Mortality rate, infant, male (per 1,000 live births)',
    'Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate)',
    'GDP per capita (current US$)',
    'Cereal production (metric tons)',
    'Current health expenditure per capita (current US$)',
    'Methane (CH4) emissions from Fugitive Emissions (Energy) (Mt CO2e)',
    'Domestic general government health expenditure per capita (current US$)',
    'Methane (CH4) emissions (total) excluding LULUCF (Mt CO2e)',
    'Mortality rate, neonatal (per 1,000 live births)',
    'Methane (CH4) emissions from Industrial Combustion (Energy) (Mt CO2e)',
    'GDP per person employed (constant 2021 PPP $)',
    'Number of deaths ages 20-24 years',
    'Population ages 10-14, female (% of female population)',
    'Vulnerable employment, male (% of male employment) (modeled ILO estimate)',
    'Carbon dioxide (CO2) emissions from Industrial Combustion (Energy) (Mt CO2e)',
    'Current health expenditure per capita, PPP (current international $)',
    'Total greenhouse gas emissions including LULUCF (Mt CO2e)',
    'Fluorinated greenhouse gases (F-gases) emissions from Industrial Processes (Mt CO2e)',
    'Population ages 10-14, male (% of male population)',
    'GDP, PPP (current international $)',
    'Population ages 0-14, female',
    'People using at least basic sanitation services (% of population)',
    'Number of infant deaths',
    'Mortality rate, adult, male (per 1,000 male adults)',
    'Number of deaths ages 5-9 years',
    'Prevalence of anemia among women of reproductive age (% of women ages 15-49)',
    'Population ages 0-14, male (% of male population)',
    'Probability of dying among adolescents ages 10-14 years (per 1,000)',
    'Vulnerable employment, female (% of female employment) (modeled ILO estimate)',
    'Mortality rate, infant, female (per 1,000 live births)',
    'Mortality rate, infant (per 1,000 live births)',
    'Mortality rate, adult, female (per 1,000 female adults)',
    'GDP, PPP (constant 2021 international $)',
    'GNI per capita, Atlas method (current US$)',
    'Labor force participation rate for ages 15-24, total (%) (modeled ILO estimate)',
    'GNI, PPP (current international $)',
    'Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate)',
    'Population ages 15-19, male (% of male population)',
    'People using at least basic sanitation services, urban (% of urban population)',
    'Population ages 0-14, female (% of female population)',
    'Adjusted net national income (current US$)',
    'Carbon dioxide (CO2) emissions from Fugitive Emissions (Energy) (Mt CO2e)',
    'Domestic credit to private sector by banks (% of GDP)',
    'GDP per capita, PPP (current international $)',
    'Prevalence of anemia among pregnant women (%)',
    'Unemployment, total (% of total labor force) (modeled ILO estimate)',
    'GDP per capita (constant 2015 US$)',
    'People using at least basic drinking water services (% of population)',
    'School enrollment, primary (% gross)',
    'Self-employed, total (% of total employment) (modeled ILO estimate)',
    'Surface area (sq. km)',
    'Total alcohol consumption per capita, male (liters of pure alcohol, projected estimates, male 15+ years of age)',
    'Employment to population ratio, ages 15-24, total (%) (modeled ILO estimate)',
    'Population ages 15-19, female (% of female population)',
    'Labor force participation rate, female (% of female population ages 15-64) (modeled ILO estimate)',
    'Land under cereal production (hectares)',
    'Methane (CH4) emissions from Transport (Energy) (Mt CO2e)',
    'Nitrous oxide (N2O) emissions from Industrial Processes (Mt CO2e)',
    'Life expectancy at birth, total (years)',
    'Out-of-pocket expenditure per capita, PPP (current international $)',
    'Total alcohol consumption per capita, female (liters of pure alcohol, projected estimates, female 15+ years of age)',
    'Life expectancy at birth, male (years)',
    'Total fisheries production (metric tons)',
    'Domestic private health expenditure per capita, PPP (current international $)',
    'Domestic private health expenditure (% of current health expenditure)',
    'Total greenhouse gas emissions per capita excluding LULUCF (t CO2e/capita)',
    'Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate)',
    'Land area (sq. km)',
    'Maternal mortality ratio (modeled estimate, per 100,000 live births)',
    'Methane (CH4) emissions from Agriculture (Mt CO2e)',
    'Computer, communications and other services (% of commercial service imports)',
    'Urban population (% of total population)',
    'Computer, communications and other services (% of commercial service exports)',
    'Monetary Sector credit to private sector (% GDP)',
    'Access to electricity, urban (% of urban population)',
    'Access to electricity (% of population)',
    'Share of youth not in education, employment or training, total (% of youth population) (modeled ILO estimate)',
    'School enrollment, primary, male (% gross)',
    'Self-employed, male (% of male employment) (modeled ILO estimate)',
    'GDP per capita growth (annual %)',
    'Inflation, GDP deflator: linked series (annual %)',
    'Population ages 0-14 (% of total population)',
    'GNI per capita, PPP (current international $)',
    'Labor force participation rate for ages 15-24, female (%) (modeled ILO estimate)',
    'Labor force participation rate for ages 15-24, male (%) (modeled ILO estimate)',
    'Number of deaths ages 15-19 years',
    'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)',
    'GDP per capita, PPP (constant 2021 international $)',
    'Access to clean fuels and technologies for cooking, urban (% of urban population)',
    'Immunization, measles (% of children ages 12-23 months)',
    'Prevalence of anemia among non-pregnant women (% of women ages 15-49)',
    'Labor force participation rate, male (% of male population ages 15+) (modeled ILO estimate)',
    'Final consumption expenditure (constant 2015 US$)',
    'Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate)',
    'Probability of dying among youth ages 20-24 years (per 1,000)',
    'Ratio of female to male labor force participation rate (%) (modeled ILO estimate)',
    'Rural population',
    'Labor force participation rate, total (% of total population ages 15-64) (modeled ILO estimate)',
    'Access to clean fuels and technologies for cooking, rural (% of rural population)'
]
new_cols_to_exclude = cols_to_exclude + mortality_cols_to_exclude + addl_cols_to_exclude
new_cols_to_exclude = list(set(new_cols_to_exclude))
bagging_features(new_cols_to_exclude)
# Out:
# Average MAE: 0.6931
# Average MSE: 1.1971
# Average R²: 0.9828
#
# Sorted Average Feature Importance:
#                                                                                                               Feature   Importance  Rank
#                                                                  Access to electricity, rural (% of rural population) 2.319018e-01     1
#                                                                                  Birth rate, crude (per 1,000 people) 1.829953e-01     2
#                                                                                             Region_Sub-Saharan Africa 1.549752e-01     3
#                                                  Prevalence of anemia among children (% of children ages 6-59 months) 1.262994e-01     4
#                                                          Domestic private health expenditure per capita (current US$) 8.571319e-02     5
#                                                                 Adjusted net national income per capita (current US$) 3.102744e-02     6
#                                                                        Incidence of tuberculosis (per 100,000 people) 2.713831e-02     7
#                                      Prevalence of stunting, height for age (modeled estimate, % of children under 5) 1.931616e-02     8
#                                                                    Out-of-pocket expenditure per capita (current US$) 1.715035e-02     9
#                                                         Adolescent fertility rate (births per 1,000 women ages 15-19) 1.047627e-02    10
#                                                                                    Rural population growth (annual %) 4.590097e-03    11
#                                    People using at least basic drinking water services, urban (% of urban population) 4.406070e-03    12
#                                                                                           Pillar 1 - Data Use - Score 3.925279e-03    13
#                                                                            Capture fisheries production (metric tons) 3.588788e-03    14
#                                                                   People practicing open defecation (% of population) 3.304831e-03    15
#                                        People using at least basic sanitation services, rural (% of rural population) 3.125296e-03    16
#                                                                   Immunization, DPT (% of children ages 12-23 months) 2.842748e-03    17
#                                              Nitrous oxide (N2O) emissions from Fugitive Emissions (Energy) (Mt CO2e) 2.491904e-03    18
#                                                                                      Region_Latin America & Caribbean 2.323060e-03    19
#                                                  Total greenhouse gas emissions excluding LULUCF (% change from 1990) 2.212745e-03    20
#                                                                                     Arable land (hectares per person) 2.211949e-03    21
#                                                                                   Permanent cropland (% of land area) 2.145103e-03    22
#                                                         Fertilizer consumption (kilograms per hectare of arable land) 2.041482e-03    23
#                                                                              Rural population (% of total population) 1.979201e-03    24
#                                                            Agriculture, forestry, and fishing, value added (% of GDP) 1.972901e-03    25
#                                                                          Labor force, female (% of total labor force) 1.813724e-03    26
#                                                                                 Current health expenditure (% of GDP) 1.796139e-03    27
#                                                                                                Broad money (% of GDP) 1.762253e-03    28
#                                                                   Population density (people per sq. km of land area) 1.596825e-03    29
#                                                 Unemployment, female (% of female labor force) (modeled ILO estimate) 1.595607e-03    30
#                                          Carbon dioxide (CO2) emissions (total) excluding LULUCF (% change from 1990) 1.582939e-03    31
#                                                                          Domestic credit to private sector (% of GDP) 1.410344e-03    32
#                                                         Proportion of seats held by women in national parliaments (%) 1.369840e-03    33
#                                                           Out-of-pocket expenditure (% of current health expenditure) 1.342049e-03    34
#                                                                  Refugee population by country or territory of origin 1.268356e-03    35
#                                                                         Commercial bank branches (per 100,000 adults) 1.254256e-03    36
#                                                                                                  Forest area (sq. km) 1.195882e-03    37
#                                                                         Population ages 15-64 (% of total population) 1.186030e-03    38
#                                                                  Refugee population by country or territory of asylum 1.173774e-03    39
#                      Water productivity, total (constant 2015 US$ GDP per cubic meter of total freshwater withdrawal) 1.158290e-03    40
#                                                             Domestic general government health expenditure (% of GDP) 1.052299e-03    41
#                                                                              Total natural resources rents (% of GDP) 1.048929e-03    42
#                                        Agriculture, forestry, and fishing, value added per worker (constant 2015 US$) 1.041725e-03    43
#                                                                     Travel services (% of commercial service imports) 1.027673e-03    44
#                                                 Methane (CH4) emissions (total) excluding LULUCF (% change from 1990) 1.018234e-03    45
#                                                                     Travel services (% of commercial service exports) 9.431085e-04    46
#                                                           Energy intensity level of primary energy (MJ/$2017 PPP GDP) 9.121441e-04    47
#                                                                                Compulsory education, duration (years) 8.977817e-04    48
# Share of youth not in education, employment or training, female (% of female youth population) (modeled ILO estimate) 8.929688e-04    49
#                                                                               Food production index (2014-2016 = 100) 8.818348e-04    50
#                                                                  Transport services (% of commercial service exports) 8.816782e-04    51
#                                                 Self-employed, female (% of female employment) (modeled ILO estimate) 8.606440e-04    52
#                                                                       Tuberculosis case detection rate (%, all forms) 8.315169e-04    53
#                                                              Methane (CH4) emissions from Building (Energy) (Mt CO2e) 7.914952e-04    54
#                                                    Renewable energy consumption (% of total final energy consumption) 7.737359e-04    55
#                                                                                    Agricultural land (% of land area) 7.650810e-04    56
#                                           Nitrous oxide (N2O) emissions (total) excluding LULUCF (% change from 1990) 7.648162e-04    57
#                                                 Employment to population ratio, 15+, total (%) (modeled ILO estimate) 7.455493e-04    58
#                                                                                                         Net migration 7.243063e-04    59
#                                                                    Adjusted savings: carbon dioxide damage (% of GNI) 7.216919e-04    60
#                                                        International tourism, receipts for travel items (current US$) 7.195859e-04    61
#                                                                 Automated teller machines (ATMs) (per 100,000 adults) 7.167298e-04    62
#                                                   GOAL 11: Sustainable Cities and Communities (5 year moving average) 7.167186e-04    63
#                                                                          Livestock production index (2014-2016 = 100) 7.161307e-04    64
#                                                                                          Forest area (% of land area) 7.040154e-04    65
#                                      Domestic general government health expenditure (% of current health expenditure) 6.953306e-04    66
#                                                    Insurance and financial services (% of commercial service imports) 6.602484e-04    67
#                                                 Renewable internal freshwater resources, total (billion cubic meters) 6.433827e-04    68
#                                                                  Official exchange rate (LCU per US$, period average) 6.375966e-04    69
#                                                        Carbon intensity of GDP (kg CO2e per constant 2021 US$ of GDP) 6.235490e-04    70
#                                                Employment to population ratio, 15+, female (%) (modeled ILO estimate) 6.199189e-04    71
#                                                                                                 Coal rents (% of GDP) 6.067932e-04    72
#                                                                      Carbon intensity of GDP (kg CO2e per 2021 PPP $) 5.908668e-04    73
#                                                     Renewable internal freshwater resources per capita (cubic meters) 5.904354e-04    74
#                                                                    Ores and metals imports (% of merchandise imports) 5.885371e-04    75
#                                                                  Women Business and the Law Index Score (scale 1-100) 5.792141e-04    76
#                                                                                  Aquaculture production (metric tons) 5.687512e-04    77
#                                                    Insurance and financial services (% of commercial service exports) 5.610575e-04    78
#                                                     Unemployment, male (% of male labor force) (modeled ILO estimate) 5.603281e-04    79
#                                                                                          Arable land (% of land area) 5.537352e-04    80
#                                                      Exports of goods, services and primary income (BoP, current US$) 5.507355e-04    81
#                                                                    Adjusted savings: education expenditure (% of GNI) 5.502834e-04    82
#                                                                            GOAL 1: No Poverty (5 year moving average) 5.275720e-04    83
#                         Labor force participation rate, male (% of male population ages 15-64) (modeled ILO estimate) 4.869873e-04    84
#                                                                                  Import unit value index (2015 = 100) 4.798074e-04    85
#                                                   Carbon dioxide (CO2) net fluxes from LULUCF - Forest Land (Mt CO2e) 4.730861e-04    86
#                                                                                  Export unit value index (2015 = 100) 4.364744e-04    87
#                                                                               Crop production index (2014-2016 = 100) 4.314839e-04    88
#                                                    Prevalence of overweight (modeled estimate, % of children under 5) 4.238200e-04    89
#                                         Employment to population ratio, ages 15-24, female (%) (modeled ILO estimate) 4.198656e-04    90
#                                                                            Claims on central government, etc. (% GDP) 4.192763e-04    91
#                                                 Carbon dioxide (CO2) net fluxes from LULUCF - Deforestation (Mt CO2e) 4.177790e-04    92
#                                                    Household Survey on income, etc (Availability score over 10 years) 4.139290e-04    93
#                                                                                      Pillar 3 - Data Products - Score 4.102875e-04    94
#                                                                                               Forest rents (% of GDP) 4.073883e-04    95
#                                           Employment to population ratio, ages 15-24, male (%) (modeled ILO estimate) 4.061761e-04    96
#                                                                                    Urban population growth (annual %) 4.024380e-04    97
#                                                                      Prevalence of undernourishment (% of population) 3.960571e-04    98
#                                                     GOAL 17: Partnerships to achieve the Goal (5 year moving average) 3.949780e-04    99
#                                                  Access to clean fuels and technologies for cooking (% of population) 3.799257e-04   100
#                                                PM2.5 air pollution, mean annual exposure (micrograms per cubic meter) 3.742613e-04   101
#                                                                     External balance on goods and services (% of GDP) 3.694702e-04   102
#                  Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) 3.678539e-04   103
#                                                                                    Inflation, GDP deflator (annual %) 3.578456e-04   104
#                                                  General government final consumption expenditure (constant 2015 US$) 3.547815e-04   105
#                            Carbon dioxide (CO2) net fluxes from LULUCF - Total excluding non-tropical fires (Mt CO2e) 3.489515e-04   106
#                                                                                                 GDP growth (annual %) 3.477547e-04   107
#                                                                                             Primary education, pupils 3.475704e-04   108
#                                                                  Tuberculosis treatment success rate (% of new cases) 3.463847e-04   109
#                                                                       Final consumption expenditure (annual % growth) 3.460920e-04   110
#                                                                  Transport services (% of commercial service imports) 3.437112e-04   111
#                                                                              Exports of goods and services (% of GDP) 3.230210e-04   112
#     Share of youth not in education, employment or training, male (% of male youth population) (modeled ILO estimate) 3.122110e-04   113
#                                                    International tourism, expenditures for travel items (current US$) 3.119379e-04   114
#                                                                                              Mineral rents (% of GDP) 3.094839e-04   115
#                                                                         Adjusted savings: energy depletion (% of GNI) 2.816172e-04   116
#                                                                                                  Oil rents (% of GDP) 2.816107e-04   117
#                                                                          School enrollment, primary, female (% gross) 2.815674e-04   118
#                                                            Communications, computer, etc. (% of service exports, BoP) 2.771782e-04   119
#                                                  Employment to population ratio, 15+, male (%) (modeled ILO estimate) 2.758579e-04   120
#                                                            Communications, computer, etc. (% of service imports, BoP) 2.629452e-04   121
#                                                                             International tourism, number of arrivals 2.602775e-04   122
#                                                                               Fuel exports (% of merchandise exports) 2.481929e-04   123
#                                                                               Fuel imports (% of merchandise imports) 2.391699e-04   124
#                                                                                          Natural gas rents (% of GDP) 2.252209e-04   125
#                                            Carbon dioxide (CO2) emissions excluding LULUCF per capita (t CO2e/capita) 2.207715e-04   126
#                                               GOAL 12: Responsible Consumption and Production (5 year moving average) 2.173784e-04   127
#                                                GOAL 16: Peace and Justice Strong Institutions (5 year moving average) 1.580544e-04   128
#                                                                   GOAL 10: Reduced Inequality (5 year moving average) 1.498640e-04   129
#                                                                                Preprimary education, duration (years) 1.464137e-04   130
#                                                    General government final consumption expenditure (annual % growth) 1.421429e-04   131
#                                                                 Labor Force Survey (Availability score over 10 years) 1.355965e-04   132
#                                                          Health/Demographic survey (Availability score over 10 years) 7.549852e-05   133
#                                                                                            Region_East Asia & Pacific 7.052835e-05   134
#                                                                         GOAL 15: Life on Land (5 year moving average) 6.287468e-05   135
#                                                                                      Income Group_Upper middle income 4.655249e-05   136
#                                                                       GOAL 13: Climate Action (5 year moving average) 3.312725e-05   137
#                                                                                      Income Group_Lower middle income 1.019049e-05   138
#                                                                                               Income Group_Low income 6.341071e-06   139
#                                                                                              Income Group_High income 3.723623e-06   140
#                                                                                          Region_Europe & Central Asia 3.063463e-06   141
#                                                                                                     Region_South Asia 2.336351e-06   142
#                                                                                     Region_Middle East & North Africa 7.795709e-07   143
#                                                                                                  Region_North America 6.001679e-08   144
