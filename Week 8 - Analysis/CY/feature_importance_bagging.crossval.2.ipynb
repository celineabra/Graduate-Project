# %%
#this version uses groups of features instead of all features
import pandas as pd
import os

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', None)
pd.set_option('display.expand_frame_repr', False)

# %%
import numpy as np
from sklearn.model_selection import KFold
from sklearn.impute import KNNImputer
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.ensemble import BaggingRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
folder_loc = 'F:/class/BANA 698/week 8'


file_list = [f for f in os.listdir(folder_loc) if os.path.isfile(os.path.join(folder_loc, f))]
#for file in file_list: print(file)

# %%
file = 'Group1DatasetRaw.onehotted.csv'
df = pd.read_csv(os.path.join(folder_loc, file))

# %%
#for col in sorted(df.columns): print(col)

# %%
target = 'Life expectancy at birth, total (years)'

cols_to_exclude = [
    #target and directly related
    'Life expectancy at birth, total (years)',
    'Life expectancy at birth, female (years)',
    'Life expectancy at birth, male (years)',
    'CountryShortName',
    'Year',
    #perfect correlate determined by correlation_to_all_lister.ipynb
    'Rural population (% of total population)' #'Urban population (% of total population)'
]

# %%
#default hyperparameters (don't edit)
dtr_params = {
    'ccp_alpha': 0.0,
    'criterion': 'squared_error',
    'max_depth': None,
    'max_features': None,
    'max_leaf_nodes': None,
    'min_impurity_decrease': 0.0,
    'min_samples_leaf': 1,
    'min_samples_split': 2,
    'min_weight_fraction_leaf': 0.0,
    'random_state': None,
    'splitter': 'best'
 }
#from:
#model = DecisionTreeRegressor()
#model.get_params()

bag_params = {
    'base_estimator': 'deprecated',
    'bootstrap': True,
    'bootstrap_features': False,
    'estimator': None,
    'max_features': 1.0,
    'max_samples': 1.0,
    'n_estimators': 10,
    'n_jobs': None,
    'oob_score': False,
    'random_state': None,
    'verbose': 0,
    'warm_start': False
}
#from:
#model = BaggingRegressor()
#model.get_params()

# %%
#EDITED hyperparameters
dtr_params = {
    'ccp_alpha': 0.0,
    'criterion': 'squared_error',
    'max_depth': None,
    'max_features': None,
    'max_leaf_nodes': None,
    'min_impurity_decrease': 0.0,
    'min_samples_leaf': 1,
    'min_samples_split': 2,
    'min_weight_fraction_leaf': 0.0,
    'random_state': 1,
    'splitter': 'best'
 }

bag_params = {
    'bootstrap': True,
    'bootstrap_features': False,
    'estimator': DecisionTreeRegressor(**dtr_params),
    'max_features': 1.0,
    'max_samples': 1.0,
    'n_estimators': 10,
    'n_jobs': -1,
    'oob_score': False,
    'random_state': 1,
    'verbose': 0,
    'warm_start': False
 }

# %%
def bagging_features(cols_to_exclude = cols_to_exclude, target = target, df = df, kfold_random_state = 1, n_neighbors = 5):
    X = df.drop(columns = cols_to_exclude)
    y = df[target]

    cv = KFold(n_splits=5, shuffle=True, random_state = kfold_random_state)

    mae_scores = []
    mse_scores = []
    r2_scores = []
    r2_train_scores = []
    feature_importance_list = []

    for train_idx, val_idx in cv.split(X):
        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]
        
        imputer = KNNImputer(n_neighbors = n_neighbors)
        X_train_imputed = imputer.fit_transform(X_train)
        X_val_imputed = imputer.transform(X_val)        
        X_train_imputed = pd.DataFrame(X_train_imputed, columns=X_train.columns)
        X_val_imputed = pd.DataFrame(X_val_imputed, columns=X_val.columns)
        
        model = BaggingRegressor(**bag_params)
        model.fit(X_train_imputed, y_train)
        y_train_pred = model.predict(X_train_imputed)
        y_pred = model.predict(X_val_imputed)

        mae = mean_absolute_error(y_val, y_pred)
        mse = mean_squared_error(y_val, y_pred)
        r2_train = r2_score(y_train, y_train_pred)
        r2 = r2_score(y_val, y_pred)        
        mae_scores.append(mae)
        mse_scores.append(mse)
        r2_train_scores.append(r2_train)
        r2_scores.append(r2)
        
        feature_importance_fold = np.mean([tree.feature_importances_ for tree in model.estimators_], axis=0)
        feature_importance_list.append(feature_importance_fold)


    avg_mae = np.mean(mae_scores)
    avg_mse = np.mean(mse_scores)
    avg_r2_train = np.mean(r2_train_scores)
    avg_r2 = np.mean(r2_scores)

    print(f'Average MAE: {avg_mae:.4f}')
    print(f'Average MSE: {avg_mse:.4f}')
    print(f'Average Training R²: {avg_r2_train:.4f}')
    print(f'Average Validation R²: {avg_r2:.4f}')

    avg_feature_importance = np.mean(feature_importance_list, axis=0)
    feature_importance_df = pd.DataFrame({
        'Feature': X.columns,
        'Importance': avg_feature_importance
    })
    feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False).reset_index(drop=True)
    feature_importance_df['Rank'] = feature_importance_df.index + 1
    feature_importance_df = feature_importance_df[['Feature', 'Importance', 'Rank']]

    print('\nSorted Feature Importance:')
    print(feature_importance_df.to_string(index=False))

# %%
#first run, with all features
bagging_features()
# Out:
# Average MAE: 0.3816
# Average MSE: 0.3643
# Average Training R²: 0.9989
# Average Validation R²: 0.9948
#
# Sorted Feature Importance:
#                                                                                                               Feature   Importance  Rank
#                                                               Mortality rate, adult, female (per 1,000 female adults) 6.503155e-01     1
#                                                                 Mortality rate, under-5, male (per 1,000 live births) 1.414440e-01     2
#                                                                                  Death rate, crude (per 1,000 people) 7.230752e-02     3
#                                                                       Mortality rate, under-5 (per 1,000 live births) 5.595189e-02     4
#                                                               Mortality rate, under-5, female (per 1,000 live births) 4.235377e-02     5
#                                                          Domestic private health expenditure per capita (current US$) 1.026332e-02     6
#                                                                   Mortality rate, adult, male (per 1,000 male adults) 5.035733e-03     7
#                                                                                    GDP per capita (constant 2015 US$) 1.557877e-03     8
#                                                                   Current health expenditure per capita (current US$) 1.034311e-03     9
#                                                                  Mortality rate, infant, male (per 1,000 live births) 7.153087e-04    10
#                                                                      Mortality rate, neonatal (per 1,000 live births) 7.047000e-04    11
#                                                                                     Arable land (hectares per person) 7.045558e-04    12
#                                                        Probability of dying among children ages 5-9 years (per 1,000) 6.909666e-04    13
#                                                                Mortality rate, infant, female (per 1,000 live births) 4.411437e-04    14
#                                                                                      Region_Latin America & Caribbean 3.880417e-04    15
#                                        Agriculture, forestry, and fishing, value added per worker (constant 2015 US$) 3.784789e-04    16
#                                                  Employment to population ratio, 15+, male (%) (modeled ILO estimate) 3.409757e-04    17
#                                                                        Incidence of tuberculosis (per 100,000 people) 3.237364e-04    18
#                              Domestic general government health expenditure per capita, PPP (current international $) 3.101866e-04    19
#                                                                        Mortality rate, infant (per 1,000 live births) 3.078212e-04    20
#                                                 People using at least basic drinking water services (% of population) 2.957008e-04    21
#                                                           Out-of-pocket expenditure (% of current health expenditure) 2.299481e-04    22
#                                                PM2.5 air pollution, mean annual exposure (micrograms per cubic meter) 1.854082e-04    23
#                                                                  Refugee population by country or territory of origin 1.765393e-04    24
#                                                   Probability of dying among adolescents ages 15-19 years (per 1,000) 1.735273e-04    25
#                                                                Population ages 15-19, female (% of female population) 1.713852e-04    26
#                                                              Methane (CH4) emissions from Building (Energy) (Mt CO2e) 1.710888e-04    27
#                                                                 Adjusted net national income per capita (current US$) 1.692136e-04    28
#                                                                                                         Net migration 1.651735e-04    29
#                                                                          Domestic credit to private sector (% of GDP) 1.584534e-04    30
#                                                                 Population ages 0-14, female (% of female population) 1.506772e-04    31
#                                                    Prevalence of overweight (modeled estimate, % of children under 5) 1.447468e-04    32
# Share of youth not in education, employment or training, female (% of female youth population) (modeled ILO estimate) 1.446738e-04    33
#                                                        Carbon intensity of GDP (kg CO2e per constant 2021 US$ of GDP) 1.430660e-04    34
#                                          Carbon dioxide (CO2) emissions (total) excluding LULUCF (% change from 1990) 1.312264e-04    35
#                                                         Fertilizer consumption (kilograms per hectare of arable land) 1.307867e-04    36
#                                                                     External balance on goods and services (% of GDP) 1.285149e-04    37
#                                                                              Urban population (% of total population) 1.271167e-04    38
#                                                                         Prevalence of anemia among pregnant women (%) 1.243667e-04    39
#                                                                                  Birth rate, crude (per 1,000 people) 1.194473e-04    40
#                                                                                    Rural population growth (annual %) 1.180778e-04    41
#                                                                         Commercial bank branches (per 100,000 adults) 1.171676e-04    42
#                                                                Population ages 10-14, female (% of female population) 1.113121e-04    43
#                                               Domestic general government health expenditure per capita (current US$) 1.091825e-04    44
#                                                                              Exports of goods and services (% of GDP) 1.083137e-04    45
#                                                         Probability of dying among youth ages 20-24 years (per 1,000) 1.065417e-04    46
#                                                                    Population ages 15-19, male (% of male population) 1.059594e-04    47
#                                          Prevalence of anemia among women of reproductive age (% of women ages 15-49) 1.059498e-04    48
#                                                                             International tourism, number of arrivals 1.055280e-04    49
#                                                                              Total fisheries production (metric tons) 1.053271e-04    50
#         Share of youth not in education, employment or training, total (% of youth population) (modeled ILO estimate) 1.038201e-04    51
#                                                                                    Agricultural land (% of land area) 1.024726e-04    52
#                                                  Current health expenditure per capita, PPP (current international $) 1.023369e-04    53
#                                                                                           Number of under-five deaths 1.021559e-04    54
#                                      Prevalence of stunting, height for age (modeled estimate, % of children under 5) 1.017290e-04    55
#                                                                         Population ages 15-64 (% of total population) 1.010972e-04    56
#                                                                   Immunization, DPT (% of children ages 12-23 months) 9.983881e-05    57
#                                                   Probability of dying among adolescents ages 10-14 years (per 1,000) 9.771840e-05    58
#                                    Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate) 9.733937e-05    59
#                                                             Domestic general government health expenditure (% of GDP) 9.541132e-05    60
#                                                                          Labor force, female (% of total labor force) 9.519172e-05    61
#                                                                    Adjusted savings: carbon dioxide damage (% of GNI) 9.268419e-05    62
#                                     Ratio of female to male labor force participation rate (%) (modeled ILO estimate) 9.167764e-05    63
#                                                                                          Arable land (% of land area) 9.137215e-05    64
#                                                                    Out-of-pocket expenditure per capita (current US$) 9.100424e-05    65
#                         Labor force participation rate, male (% of male population ages 15-64) (modeled ILO estimate) 9.058522e-05    66
#                                                     Renewable internal freshwater resources per capita (cubic meters) 9.029676e-05    67
#                                              Nitrous oxide (N2O) emissions from Fugitive Emissions (Energy) (Mt CO2e) 8.972401e-05    68
#                                                                               Food production index (2014-2016 = 100) 8.835819e-05    69
#                                                  Total greenhouse gas emissions excluding LULUCF (% change from 1990) 8.801412e-05    70
#                                                                 Automated teller machines (ATMs) (per 100,000 adults) 8.764228e-05    71
#                                                    Renewable energy consumption (% of total final energy consumption) 8.500233e-05    72
#                                                                  Transport services (% of commercial service exports) 8.340626e-05    73
#                                                  Prevalence of anemia among children (% of children ages 6-59 months) 8.292363e-05    74
#                                                                   Population density (people per sq. km of land area) 8.292054e-05    75
#                                                                    Population ages 10-14, male (% of male population) 8.164430e-05    76
#                                        People using at least basic sanitation services, rural (% of rural population) 8.162049e-05    77
#                                                                  Access to electricity, urban (% of urban population) 8.150085e-05    78
#                                                     Nitrous oxide (N2O) emissions from Industrial Processes (Mt CO2e) 8.104225e-05    79
#                                                                                  Aquaculture production (metric tons) 7.982618e-05    80
#                                                            Agriculture, forestry, and fishing, value added (% of GDP) 7.963400e-05    81
#                                                 Renewable internal freshwater resources, total (billion cubic meters) 7.886531e-05    82
#                                                                                                Broad money (% of GDP) 7.809310e-05    83
#                                                                     Travel services (% of commercial service imports) 7.615917e-05    84
#                                                 Self-employed, female (% of female employment) (modeled ILO estimate) 7.596482e-05    85
#                                                     People using at least basic sanitation services (% of population) 7.554764e-05    86
#                                                         Adolescent fertility rate (births per 1,000 women ages 15-19) 7.389818e-05    87
#                                                                  Transport services (% of commercial service imports) 7.292920e-05    88
#                                                Employment to population ratio, 15+, female (%) (modeled ILO estimate) 7.279572e-05    89
#                                                 Prevalence of anemia among non-pregnant women (% of women ages 15-49) 7.247335e-05    90
#                                                                                      Pillar 3 - Data Products - Score 7.213533e-05    91
#                                                                                   Lifetime risk of maternal death (%) 7.126798e-05    92
#                                                                                    Urban population growth (annual %) 7.025318e-05    93
#                                                                                  Export unit value index (2015 = 100) 6.984418e-05    94
#                                                                                    Inflation, GDP deflator (annual %) 6.946935e-05    95
#                                                         Proportion of seats held by women in national parliaments (%) 6.936193e-05    96
#                       Labor force participation rate, total (% of total population ages 15-64) (modeled ILO estimate) 6.847476e-05    97
#                                                                   GDP per capita, PPP (constant 2021 international $) 6.790052e-05    98
#                                                                                                    Land area (sq. km) 6.746772e-05    99
#                                                        Nitrous oxide (N2O) emissions from Building (Energy) (Mt CO2e) 6.630752e-05   100
#                                                                                  Import unit value index (2015 = 100) 6.527423e-05   101
#                                                                                             Number of maternal deaths 6.473022e-05   102
#                                                                         GNI per capita, PPP (current international $) 6.469680e-05   103
#                                                                                   Permanent cropland (% of land area) 6.330603e-05   104
#                                                                     Travel services (% of commercial service exports) 6.285963e-05   105
#                                                                               Land under cereal production (hectares) 6.203385e-05   106
#                                                                            Claims on central government, etc. (% GDP) 6.189856e-05   107
#                                                                                          Forest area (% of land area) 6.152059e-05   108
#                                                  Maternal mortality ratio (modeled estimate, per 100,000 live births) 6.119022e-05   109
#                      Water productivity, total (constant 2015 US$ GDP per cubic meter of total freshwater withdrawal) 6.055327e-05   110
#                                      Domestic general government health expenditure (% of current health expenditure) 6.007979e-05   111
#                                                               Immunization, measles (% of children ages 12-23 months) 5.981825e-05   112
#                                                                                      GDP per capita growth (annual %) 5.980007e-05   113
#                                                 Unemployment, female (% of female labor force) (modeled ILO estimate) 5.914033e-05   114
#                                                 Methane (CH4) emissions (total) excluding LULUCF (% change from 1990) 5.892194e-05   115
#                                                                                                  Forest area (sq. km) 5.807967e-05   116
#                                                                          School enrollment, primary, female (% gross) 5.785358e-05   117
#                                                GOAL 16: Peace and Justice Strong Institutions (5 year moving average) 5.779417e-05   118
#                                                                      Prevalence of undernourishment (% of population) 5.726547e-05   119
#                                                           Energy intensity level of primary energy (MJ/$2017 PPP GDP) 5.705515e-05   120
#                                                             Methane (CH4) emissions from Transport (Energy) (Mt CO2e) 5.686385e-05   121
#                                                     GOAL 17: Partnerships to achieve the Goal (5 year moving average) 5.644231e-05   122
#                                                    Insurance and financial services (% of commercial service imports) 5.517392e-05   123
#                                                                  Official exchange rate (LCU per US$, period average) 5.510439e-05   124
#                                         Vulnerable employment, female (% of female employment) (modeled ILO estimate) 5.446756e-05   125
#                                                                            Adjusted net national income (current US$) 5.446029e-05   126
#                                         Domestic private health expenditure per capita, PPP (current international $) 5.445570e-05   127
#                                                        International tourism, receipts for travel items (current US$) 5.409910e-05   128
#                                                    Carbon dioxide (CO2) emissions from Industrial Processes (Mt CO2e) 5.264743e-05   129
#                                                                                          GDP per capita (current US$) 5.261594e-05   130
#                                                                  Women Business and the Law Index Score (scale 1-100) 5.247095e-05   131
#                                                                            GNI per capita, Atlas method (current US$) 5.117191e-05   132
#                                                                              Total natural resources rents (% of GDP) 5.046748e-05   133
#                                                                          Livestock production index (2014-2016 = 100) 5.032448e-05   134
#                                                                                            Population ages 0-14, male 5.005963e-05   135
#                                                                    Ores and metals imports (% of merchandise imports) 4.967927e-05   136
#                                                 Domestic private health expenditure (% of current health expenditure) 4.902249e-05   137
#                                                    Insurance and financial services (% of commercial service exports) 4.771140e-05   138
#                                                   Out-of-pocket expenditure per capita, PPP (current international $) 4.654585e-05   139
#                                                                            Capture fisheries production (metric tons) 4.649506e-05   140
#                                  Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate) 4.620974e-05   141
#                                                    General government final consumption expenditure (annual % growth) 4.619545e-05   142
#                                                                       Tuberculosis case detection rate (%, all forms) 4.552646e-05   143
#                                                                                           Pillar 1 - Data Use - Score 4.518057e-05   144
#                                                                   People practicing open defecation (% of population) 4.508346e-05   145
#                                       Labor force participation rate for ages 15-24, total (%) (modeled ILO estimate) 4.464176e-05   146
#                                    People using at least basic drinking water services, urban (% of urban population) 4.459461e-05   147
#                                           Nitrous oxide (N2O) emissions (total) excluding LULUCF (% change from 1990) 4.456068e-05   148
#                                                   Unemployment, total (% of total labor force) (modeled ILO estimate) 4.432460e-05   149
#                                                        Lifetime risk of maternal death (1 in: rate varies by country) 4.427529e-05   150
#                                                                    Adjusted savings: education expenditure (% of GNI) 4.424478e-05   151
#                                                                  Tuberculosis treatment success rate (% of new cases) 4.413172e-05   152
#                                                                       Final consumption expenditure (annual % growth) 4.397555e-05   153
#                                                     Unemployment, male (% of male labor force) (modeled ILO estimate) 4.376378e-05   154
#                                                                                               Forest rents (% of GDP) 4.347785e-05   155
#                                         Employment to population ratio, ages 15-24, female (%) (modeled ILO estimate) 4.337134e-05   156
#                       Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate) 4.278559e-05   157
#                                  Fluorinated greenhouse gases (F-gases) emissions from Industrial Processes (Mt CO2e) 4.237819e-05   158
#                                         Computer, communications and other services (% of commercial service exports) 4.237371e-05   159
#                                                                                  School enrollment, primary (% gross) 4.196883e-05   160
#                                                                      Carbon intensity of GDP (kg CO2e per 2021 PPP $) 4.193813e-05   161
#   Total alcohol consumption per capita, female (liters of pure alcohol, projected estimates, female 15+ years of age) 4.157316e-05   162
#                                                                                                 Surface area (sq. km) 4.078810e-05   163
#                                                 Carbon dioxide (CO2) emissions from Power Industry (Energy) (Mt CO2e) 4.073930e-05   164
#                                        People using at least basic sanitation services, urban (% of urban population) 3.958969e-05   165
#                                                            Communications, computer, etc. (% of service exports, BoP) 3.949571e-05   166
#                                                                            School enrollment, primary, male (% gross) 3.942634e-05   167
#                                                    Methane (CH4) emissions from Fugitive Emissions (Energy) (Mt CO2e) 3.932923e-05   168
#                                                                   GOAL 10: Reduced Inequality (5 year moving average) 3.930728e-05   169
#                                                  Nitrous oxide (N2O) emissions from Power Industry (Energy) (Mt CO2e) 3.920291e-05   170
#                                           Vulnerable employment, total (% of total employment) (modeled ILO estimate) 3.882807e-05   171
#                                         Wage and salaried workers, male (% of male employment) (modeled ILO estimate) 3.880812e-05   172
#                                                                                 Current health expenditure (% of GDP) 3.860214e-05   173
#                         Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate) 3.840059e-05   174
#                  Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age) 3.782233e-05   175
#                                                                         GDP per person employed (constant 2021 PPP $) 3.705287e-05   176
#                                                                                       Cereal production (metric tons) 3.700360e-05   177
#                                                 Employment to population ratio, 15+, total (%) (modeled ILO estimate) 3.669462e-05   178
#                                                      Exports of goods, services and primary income (BoP, current US$) 3.655856e-05   179
#     Share of youth not in education, employment or training, male (% of male youth population) (modeled ILO estimate) 3.598044e-05   180
#                                                                                              Mineral rents (% of GDP) 3.580609e-05   181
#                                                                          Population ages 0-14 (% of total population) 3.572263e-05   182
#                                          Employment to population ratio, ages 15-24, total (%) (modeled ILO estimate) 3.543694e-05   183
#                                                                     Inflation, GDP deflator: linked series (annual %) 3.523629e-05   184
#                           Labor force participation rate, male (% of male population ages 15+) (modeled ILO estimate) 3.480800e-05   185
#                                                    International tourism, expenditures for travel items (current US$) 3.424248e-05   186
#                                               GOAL 12: Responsible Consumption and Production (5 year moving average) 3.421688e-05   187
#                                Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate) 3.410994e-05   188
#                                                                         GDP per capita, PPP (current international $) 3.390255e-05   189
#                                             Carbon dioxide (CO2) emissions from Fugitive Emissions (Energy) (Mt CO2e) 3.316398e-05   190
#                                           Employment to population ratio, ages 15-24, male (%) (modeled ILO estimate) 3.307029e-05   191
#                                                                  Refugee population by country or territory of asylum 3.267075e-05   192
#                                                                  Access to electricity, rural (% of rural population) 3.252422e-05   193
#                                            Total greenhouse gas emissions per capita excluding LULUCF (t CO2e/capita) 3.233086e-05   194
#                                                                                          Natural gas rents (% of GDP) 3.188685e-05   195
#                                                                                Compulsory education, duration (years) 3.120774e-05   196
#                                         Computer, communications and other services (% of commercial service imports) 3.108031e-05   197
#                                                                               Access to electricity (% of population) 3.034605e-05   198
#                                                                 Domestic credit to private sector by banks (% of GDP) 3.030693e-05   199
#                                                                                             Number of neonatal deaths 3.027684e-05   200
#                                                                               Fuel imports (% of merchandise imports) 2.956581e-05   201
#                            Carbon dioxide (CO2) net fluxes from LULUCF - Total excluding non-tropical fires (Mt CO2e) 2.922376e-05   202
#                                                                              GDP, PPP (constant 2021 international $) 2.908349e-05   203
#                                                                                Preprimary education, duration (years) 2.865415e-05   204
#                     Labor force participation rate, female (% of female population ages 15-64) (modeled ILO estimate) 2.830199e-05   205
#                                                                                               Number of infant deaths 2.823791e-05   206
#       Total alcohol consumption per capita, male (liters of pure alcohol, projected estimates, male 15+ years of age) 2.813114e-05   207
#                                                                     Population ages 0-14, male (% of male population) 2.780761e-05   208
#                                                                                             Primary education, pupils 2.722806e-05   209
#                                     Access to clean fuels and technologies for cooking, rural (% of rural population) 2.712600e-05   210
#                                                                    Nitrous oxide (N2O) emissions from Waste (Mt CO2e) 2.701856e-05   211
#                                                     Self-employed, male (% of male employment) (modeled ILO estimate) 2.690166e-05   212
#                                                   GOAL 11: Sustainable Cities and Communities (5 year moving average) 2.650938e-05   213
#                                                                      Monetary Sector credit to private sector (% GDP) 2.644394e-05   214
#                                                            Communications, computer, etc. (% of service imports, BoP) 2.637221e-05   215
#                                      Labor force participation rate for ages 15-24, female (%) (modeled ILO estimate) 2.627425e-05   216
#                                                                                                  Oil rents (% of GDP) 2.597623e-05   217
#                                                   Carbon dioxide (CO2) net fluxes from LULUCF - Forest Land (Mt CO2e) 2.579326e-05   218
#                                                                                                 GDP growth (annual %) 2.507191e-05   219
#                                                                         GOAL 15: Life on Land (5 year moving average) 2.444075e-05   220
#                                                        Methane (CH4) emissions from Power Industry (Energy) (Mt CO2e) 2.408742e-05   221
#                                                                    Methane (CH4) emissions from Agriculture (Mt CO2e) 2.406684e-05   222
#                                        Labor force participation rate for ages 15-24, male (%) (modeled ILO estimate) 2.341403e-05   223
#                                                                                                      Rural population 2.298070e-05   224
#                                                                               Crop production index (2014-2016 = 100) 2.269027e-05   225
#                                                                                     Number of deaths ages 20-24 years 2.252571e-05   226
#                                                                               Fuel exports (% of merchandise exports) 2.205599e-05   227
#                                                       Nitrous oxide (N2O) emissions from Transport (Energy) (Mt CO2e) 2.201577e-05   228
#                                                                                          Population ages 0-14, female 2.147213e-05   229
#                                                 Methane (CH4) emissions from Industrial Combustion (Energy) (Mt CO2e) 2.127824e-05   230
#                                            Carbon dioxide (CO2) emissions excluding LULUCF per capita (t CO2e/capita) 2.087275e-05   231
#                                                              Nitrous oxide (N2O) emissions from Agriculture (Mt CO2e) 2.057590e-05   232
#                                       Wage and salaried workers, total (% of total employment) (modeled ILO estimate) 2.039015e-05   233
#                                     Access to clean fuels and technologies for cooking, urban (% of urban population) 2.024783e-05   234
#                                     Wage and salaried workers, female (% of female employment) (modeled ILO estimate) 2.023070e-05   235
#                                             Vulnerable employment, male (% of male employment) (modeled ILO estimate) 1.936347e-05   236
#                                                             Total greenhouse gas emissions including LULUCF (Mt CO2e) 1.905315e-05   237
#                                                                                    GDP, PPP (current international $) 1.840643e-05   238
#                                                   Self-employed, total (% of total employment) (modeled ILO estimate) 1.765705e-05   239
#                                                  Access to clean fuels and technologies for cooking (% of population) 1.746146e-05   240
#                                                                                                 Coal rents (% of GDP) 1.744994e-05   241
#                                                                                       Number of deaths ages 5-9 years 1.731447e-05   242
#                                                      Nitrous oxide (N2O) emissions (total) excluding LULUCF (Mt CO2e) 1.707759e-05   243
#                                                 Carbon dioxide (CO2) net fluxes from LULUCF - Deforestation (Mt CO2e) 1.575099e-05   244
#                                                                                                     GNI (current US$) 1.560551e-05   245
#                                           Nitrous oxide (N2O) emissions from Industrial Combustion (Energy) (Mt CO2e) 1.523671e-05   246
#                                                                          Methane (CH4) emissions from Waste (Mt CO2e) 1.449464e-05   247
#                                                      Carbon dioxide (CO2) emissions from Transport (Energy) (Mt CO2e) 1.435212e-05   248
#                                                       Carbon dioxide (CO2) emissions from Building (Energy) (Mt CO2e) 1.423334e-05   249
#                                                                            GOAL 1: No Poverty (5 year moving average) 1.418113e-05   250
#                                                                                           Population ages 0-14, total 1.417314e-05   251
#                                                                                                     GDP (current US$) 1.388472e-05   252
#                                                                                                      Urban population 1.367616e-05   253
#                                          Carbon dioxide (CO2) emissions from Industrial Combustion (Energy) (Mt CO2e) 1.294304e-05   254
#                                                                                     Number of deaths ages 10-14 years 1.266085e-05   255
#                                                                         Adjusted savings: energy depletion (% of GNI) 1.227422e-05   256
#                                                                                               GDP (constant 2015 US$) 1.222577e-05   257
#                                                             Total greenhouse gas emissions excluding LULUCF (Mt CO2e) 1.215351e-05   258
#                                                                                    GNI, PPP (current international $) 1.090660e-05   259
#                                                                                     Number of deaths ages 15-19 years 1.086223e-05   260
#                                                            Methane (CH4) emissions (total) excluding LULUCF (Mt CO2e) 1.077772e-05   261
#                                                                                                    Labor force, total 1.025106e-05   262
#                                                     Carbon dioxide (CO2) emissions (total) excluding LULUCF (Mt CO2e) 9.297752e-06   263
#                                                  General government final consumption expenditure (constant 2015 US$) 8.387857e-06   264
#                                                                     Final consumption expenditure (constant 2015 US$) 7.390810e-06   265
#                                                          Health/Demographic survey (Availability score over 10 years) 7.253037e-06   266
#                                                    Household Survey on income, etc (Availability score over 10 years) 5.576918e-06   267
#                                                                 Labor Force Survey (Availability score over 10 years) 5.032130e-06   268
#                                                                                       GNI, Atlas method (current US$) 4.308594e-06   269
#                                                                       GOAL 13: Climate Action (5 year moving average) 3.744321e-06   270
#                                                                                     Region_Middle East & North Africa 3.547553e-06   271
#                                                                                      Income Group_Lower middle income 3.456900e-06   272
#                                                                                             Region_Sub-Saharan Africa 1.943777e-06   273
#                                                                                            Region_East Asia & Pacific 1.353514e-06   274
#                                                                                          Region_Europe & Central Asia 4.425499e-07   275
#                                                                                      Income Group_Upper middle income 3.830333e-07   276
#                                                                                               Income Group_Low income 1.150313e-07   277
#                                                                                              Income Group_High income 2.593071e-08   278
#                                                                                                  Region_North America 2.108867e-08   279
#                                                                                                     Region_South Asia 6.476529e-09   280

# %%
#run only 1 subgroup of features at a time
file = 'Field Mapping List.csv'
df2 = pd.read_csv(os.path.join(folder_loc, file))
print(df2['Indicator Category'].unique())
# Out:
# ['Environmental' 'Health' 'Socioeconomic']

# %%
feats_all = df.columns.tolist()
cols_to_exclude_except_enviro = list(set(df2[df2['Indicator Category'] != 'Environmental']['Field Name'].tolist() + cols_to_exclude))
cols_to_exclude_except_health = list(set(df2[df2['Indicator Category'] != 'Health']['Field Name'].tolist() + cols_to_exclude))
cols_to_exclude_except_socio = list(set(df2[df2['Indicator Category'] != 'Socioeconomic']['Field Name'].tolist() + cols_to_exclude))
print(f"{len(feats_all)} total features")
print(f"{len(feats_all) - len(cols_to_exclude_except_enviro)} environmental features")
print(f"{len(feats_all) - len(cols_to_exclude_except_health)} health features")
print(f"{len(feats_all) - len(cols_to_exclude_except_socio)} socioeconomic features")

print(cols_to_exclude_except_enviro)
print(cols_to_exclude_except_health)
print(cols_to_exclude_except_socio)
# Out:
# 286 total features
# 80 environmental features
# 73 health features
# 127 socioeconomic features
# ['School enrollment, primary (% gross)', 'GDP, PPP (constant 2021 international $)', 'Wage and salaried workers, male (% of male employment) (modeled ILO estimate)', 'GOAL 10: Reduced Inequality (5 year moving average)', 'Population ages 0-14, total', 'Labor force participation rate, total (% of total population ages 15-64) (modeled ILO estimate)', 'Probability of dying among children ages 5-9 years (per 1,000)', 'Travel services (% of commercial service imports)', 'Prevalence of overweight (modeled estimate, % of children under 5)', 'Life expectancy at birth, total (years)', 'GDP (constant 2015 US$)', 'GDP per capita growth (annual %)', 'Refugee population by country or territory of asylum', 'Labor force, total', 'Labor Force Survey (Availability score over 10 years)', 'Birth rate, crude (per 1,000 people)', 'Communications, computer, etc. (% of service imports, BoP)', 'International tourism, expenditures for travel items (current US$)', 'Insurance and financial services (% of commercial service imports)', 'Income Group_Upper middle income', 'GOAL 11: Sustainable Cities and Communities (5 year moving average)', 'Employment to population ratio, 15+, total (%) (modeled ILO estimate)', 'Insurance and financial services (% of commercial service exports)', 'Fuel imports (% of merchandise imports)', 'Travel services (% of commercial service exports)', 'Adolescent fertility rate (births per 1,000 women ages 15-19)', 'Mortality rate, under-5 (per 1,000 live births)', 'Incidence of tuberculosis (per 100,000 people)', 'Population ages 0-14, female (% of female population)', 'Region_South Asia', 'CountryShortName', 'GOAL 16: Peace and Justice Strong Institutions (5 year moving average)', 'Transport services (% of commercial service imports)', 'School enrollment, primary, male (% gross)', 'Region_East Asia & Pacific', 'Ratio of female to male labor force participation rate (%) (modeled ILO estimate)', 'Refugee population by country or territory of origin', 'Final consumption expenditure (constant 2015 US$)', 'Region_North America', 'Employment to population ratio, ages 15-24, total (%) (modeled ILO estimate)', 'Vulnerable employment, total (% of total employment) (modeled ILO estimate)', 'Self-employed, male (% of male employment) (modeled ILO estimate)', 'Total alcohol consumption per capita, female (liters of pure alcohol, projected estimates, female 15+ years of age)', 'People using at least basic sanitation services, rural (% of rural population)', 'Mortality rate, neonatal (per 1,000 live births)', 'Domestic general government health expenditure (% of GDP)', 'Region_Middle East & North Africa', 'Region_Sub-Saharan Africa', 'Fuel exports (% of merchandise exports)', 'Unemployment, female (% of female labor force) (modeled ILO estimate)', 'Health/Demographic survey (Availability score over 10 years)', 'GOAL 1: No Poverty (5 year moving average)', 'Number of maternal deaths', 'Claims on central government, etc. (% GDP)', 'Rural population (% of total population)', 'Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)', 'Mortality rate, under-5, female (per 1,000 live births)', 'Number of deaths ages 20-24 years', 'Labor force participation rate for ages 15-24, male (%) (modeled ILO estimate)', 'Probability of dying among adolescents ages 15-19 years (per 1,000)', 'Wage and salaried workers, total (% of total employment) (modeled ILO estimate)', 'GDP (current US$)', 'People using at least basic drinking water services (% of population)', 'Mortality rate, infant, male (per 1,000 live births)', 'Broad money (% of GDP)', 'Inflation, GDP deflator (annual %)', 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)', 'GDP per capita (constant 2015 US$)', 'GDP per capita, PPP (constant 2021 international $)', 'Ores and metals imports (% of merchandise imports)', 'Mortality rate, infant, female (per 1,000 live births)', 'International tourism, receipts for ...
# ['School enrollment, primary (% gross)', 'GDP, PPP (constant 2021 international $)', 'Wage and salaried workers, male (% of male employment) (modeled ILO estimate)', 'GOAL 10: Reduced Inequality (5 year moving average)', 'Labor force participation rate, total (% of total population ages 15-64) (modeled ILO estimate)', 'Methane (CH4) emissions (total) excluding LULUCF (Mt CO2e)', 'Forest area (sq. km)', 'Travel services (% of commercial service imports)', 'Methane (CH4) emissions from Fugitive Emissions (Energy) (Mt CO2e)', 'Carbon dioxide (CO2) net fluxes from LULUCF - Total excluding non-tropical fires (Mt CO2e)', 'GDP (constant 2015 US$)', 'GDP per capita growth (annual %)', 'Refugee population by country or territory of asylum', 'Labor force, total', 'Life expectancy at birth, total (years)', 'Labor Force Survey (Availability score over 10 years)', 'Communications, computer, etc. (% of service imports, BoP)', 'International tourism, expenditures for travel items (current US$)', 'Insurance and financial services (% of commercial service imports)', 'Income Group_Upper middle income', 'GOAL 11: Sustainable Cities and Communities (5 year moving average)', 'Carbon dioxide (CO2) emissions from Industrial Processes (Mt CO2e)', 'Employment to population ratio, 15+, total (%) (modeled ILO estimate)', 'Insurance and financial services (% of commercial service exports)', 'Fluorinated greenhouse gases (F-gases) emissions from Industrial Processes (Mt CO2e)', 'Fuel imports (% of merchandise imports)', 'Travel services (% of commercial service exports)', 'Natural gas rents (% of GDP)', 'Carbon dioxide (CO2) net fluxes from LULUCF - Forest Land (Mt CO2e)', 'Capture fisheries production (metric tons)', 'Access to clean fuels and technologies for cooking, rural (% of rural population)', 'GOAL 16: Peace and Justice Strong Institutions (5 year moving average)', 'CountryShortName', 'Region_South Asia', 'Transport services (% of commercial service imports)', 'School enrollment, primary, male (% gross)', 'Region_East Asia & Pacific', 'Ratio of female to male labor force participation rate (%) (modeled ILO estimate)', 'Refugee population by country or territory of origin', 'Cereal production (metric tons)', 'Nitrous oxide (N2O) emissions (total) excluding LULUCF (Mt CO2e)', 'Final consumption expenditure (constant 2015 US$)', 'Region_North America', 'Employment to population ratio, ages 15-24, total (%) (modeled ILO estimate)', 'Vulnerable employment, total (% of total employment) (modeled ILO estimate)', 'Carbon dioxide (CO2) emissions from Building (Energy) (Mt CO2e)', 'Self-employed, male (% of male employment) (modeled ILO estimate)', 'Access to clean fuels and technologies for cooking (% of population)', 'Carbon dioxide (CO2) net fluxes from LULUCF - Deforestation (Mt CO2e)', 'Region_Middle East & North Africa', 'Region_Sub-Saharan Africa', 'Fuel exports (% of merchandise exports)', 'Unemployment, female (% of female labor force) (modeled ILO estimate)', 'Carbon dioxide (CO2) emissions from Power Industry (Energy) (Mt CO2e)', 'Rural population', 'Carbon intensity of GDP (kg CO2e per 2021 PPP $)', 'GOAL 1: No Poverty (5 year moving average)', 'Renewable internal freshwater resources per capita (cubic meters)', 'Claims on central government, etc. (% GDP)', 'Rural population (% of total population)', 'Labor force participation rate for ages 15-24, male (%) (modeled ILO estimate)', 'Wage and salaried workers, total (% of total employment) (modeled ILO estimate)', 'GDP (current US$)', 'Broad money (% of GDP)', 'Inflation, GDP deflator (annual %)', 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)', 'GDP per capita (constant 2015 US$)', 'GDP per capita, PPP (constant 2021 international $)', 'Ores and metals imports (% of merchandise imports)', 'International tourism, receipts for travel items (current US$)', 'Employment to population ratio, ages 15-24, female (%) (modeled ILO estimate)', 'Total fisher ...
# ['Population ages 0-14, total', 'Methane (CH4) emissions (total) excluding LULUCF (Mt CO2e)', 'Forest area (sq. km)', 'Probability of dying among children ages 5-9 years (per 1,000)', 'Prevalence of overweight (modeled estimate, % of children under 5)', 'Methane (CH4) emissions from Fugitive Emissions (Energy) (Mt CO2e)', 'Carbon dioxide (CO2) net fluxes from LULUCF - Total excluding non-tropical fires (Mt CO2e)', 'Life expectancy at birth, total (years)', 'Birth rate, crude (per 1,000 people)', 'Carbon dioxide (CO2) emissions from Industrial Processes (Mt CO2e)', 'Fluorinated greenhouse gases (F-gases) emissions from Industrial Processes (Mt CO2e)', 'Natural gas rents (% of GDP)', 'Carbon dioxide (CO2) net fluxes from LULUCF - Forest Land (Mt CO2e)', 'Capture fisheries production (metric tons)', 'Access to clean fuels and technologies for cooking, rural (% of rural population)', 'Adolescent fertility rate (births per 1,000 women ages 15-19)', 'Mortality rate, under-5 (per 1,000 live births)', 'Incidence of tuberculosis (per 100,000 people)', 'Population ages 0-14, female (% of female population)', 'CountryShortName', 'Cereal production (metric tons)', 'Nitrous oxide (N2O) emissions (total) excluding LULUCF (Mt CO2e)', 'Carbon dioxide (CO2) emissions from Building (Energy) (Mt CO2e)', 'Access to clean fuels and technologies for cooking (% of population)', 'Total alcohol consumption per capita, female (liters of pure alcohol, projected estimates, female 15+ years of age)', 'People using at least basic sanitation services, rural (% of rural population)', 'Carbon dioxide (CO2) net fluxes from LULUCF - Deforestation (Mt CO2e)', 'Mortality rate, neonatal (per 1,000 live births)', 'Domestic general government health expenditure (% of GDP)', 'Health/Demographic survey (Availability score over 10 years)', 'Carbon dioxide (CO2) emissions from Power Industry (Energy) (Mt CO2e)', 'Rural population', 'Carbon intensity of GDP (kg CO2e per 2021 PPP $)', 'Renewable internal freshwater resources per capita (cubic meters)', 'Number of maternal deaths', 'Rural population (% of total population)', 'Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)', 'Mortality rate, under-5, female (per 1,000 live births)', 'Number of deaths ages 20-24 years', 'Probability of dying among adolescents ages 15-19 years (per 1,000)', 'People using at least basic drinking water services (% of population)', 'Mortality rate, infant, male (per 1,000 live births)', 'Mortality rate, infant, female (per 1,000 live births)', 'Total fisheries production (metric tons)', 'Urban population', 'Methane (CH4) emissions (total) excluding LULUCF (% change from 1990)', 'Total greenhouse gas emissions excluding LULUCF (% change from 1990)', 'Methane (CH4) emissions from Transport (Energy) (Mt CO2e)', 'Water productivity, total (constant 2015 US$ GDP per cubic meter of total freshwater withdrawal)', 'Number of neonatal deaths', 'Permanent cropland (% of land area)', 'Methane (CH4) emissions from Power Industry (Energy) (Mt CO2e)', 'Current health expenditure per capita (current US$)', 'Number of under-five deaths', 'Crop production index (2014-2016 = 100)', 'Livestock production index (2014-2016 = 100)', 'Methane (CH4) emissions from Agriculture (Mt CO2e)', 'Number of deaths ages 10-14 years', 'Total alcohol consumption per capita, male (liters of pure alcohol, projected estimates, male 15+ years of age)', 'Energy intensity level of primary energy (MJ/$2017 PPP GDP)', 'Population density (people per sq. km of land area)', 'Nitrous oxide (N2O) emissions (total) excluding LULUCF (% change from 1990)', 'Methane (CH4) emissions from Industrial Combustion (Energy) (Mt CO2e)', 'Population ages 15-64 (% of total population)', 'Prevalence of anemia among non-pregnant women (% of women ages 15-49)', 'Immunization, DPT (% of children ages 12-23 months)', 'Prevalence of undernourishment (% of population)', 'Mineral rents (% of GDP)', 'Fertilizer  ...

# %% [markdown]
# ## Environmental Features

# %%
#just the environmental features
bagging_features(cols_to_exclude_except_enviro)
# Out:
# Average MAE: 0.7016
# Average MSE: 1.2443
# Average Training R²: 0.9961
# Average Validation R²: 0.9820
#
# Sorted Feature Importance:
#                                                                                          Feature  Importance  Rank
#                                                          Access to electricity (% of population)    0.657766     1
#                             Access to clean fuels and technologies for cooking (% of population)    0.081420     2
#                                             Access to electricity, urban (% of urban population)    0.035695     3
#                Access to clean fuels and technologies for cooking, urban (% of urban population)    0.023296     4
#                                                                Arable land (hectares per person)    0.019422     5
# Water productivity, total (constant 2015 US$ GDP per cubic meter of total freshwater withdrawal)    0.012072     6
#                                   Carbon intensity of GDP (kg CO2e per constant 2021 US$ of GDP)    0.011928     7
#                                                               Agricultural land (% of land area)    0.009689     8
#                                                       Capture fisheries production (metric tons)    0.007699     9
#                     Carbon dioxide (CO2) emissions (total) excluding LULUCF (% change from 1990)    0.007228    10
#                                             Access to electricity, rural (% of rural population)    0.007106    11
#                                                              Permanent cropland (% of land area)    0.006427    12
#                       Carbon dioxide (CO2) emissions excluding LULUCF per capita (t CO2e/capita)    0.005896    13
#                               Methane (CH4) emissions from Fugitive Emissions (Energy) (Mt CO2e)    0.004893    14
#                             Total greenhouse gas emissions excluding LULUCF (% change from 1990)    0.004698    15
#                                    Fertilizer consumption (kilograms per hectare of arable land)    0.004413    16
#                                                             Aquaculture production (metric tons)    0.004045    17
#                                                         Urban population (% of total population)    0.003889    18
#                                                               Rural population growth (annual %)    0.003634    19
#                               Renewable energy consumption (% of total final energy consumption)    0.003050    20
#                                  Nitrous oxide (N2O) emissions from Transport (Energy) (Mt CO2e)    0.002938    21
#                                                                                 Urban population    0.002896    22
#                              Carbon dioxide (CO2) net fluxes from LULUCF - Forest Land (Mt CO2e)    0.002872    23
#                                                                             Forest area (sq. km)    0.002780    24
#                      Nitrous oxide (N2O) emissions (total) excluding LULUCF (% change from 1990)    0.002662    25
#                            Renewable internal freshwater resources, total (billion cubic meters)    0.002627    26
#                                              Population density (people per sq. km of land area)    0.002602    27
#                             Nitrous oxide (N2O) emissions from Power Industry (Energy) (Mt CO2e)    0.002538    28
#                         Nitrous oxide (N2O) emissions from Fugitive Emissions (Energy) (Mt CO2e)    0.002435    29
#                                                         Total fisheries production (metric tons)    0.002406    30
#                                   Methane (CH4) emissions from Power Industry (Energy) (Mt CO2e)    0.002397    31
#                                                                     Arable land (% of land area)    0.002275    32
#       Carbon dioxide (CO2) net fluxes from LULUCF - Total excluding non-tropical fires (Mt CO2e)    0.002176    33
#                                      Energy intensity level of primary energy (MJ/$2017 PPP GDP)    0.002159    34
#                                                          Food production index (2014-2016 = 100)    0.002075    35
#                                Renewable internal freshwater resources per capita (cubic meters)    0.002039    36
#                                                               Urban population growth (annual %)    0.002039    37
#                                                     Livestock production index (2014-2016 = 100)    0.001980    38
#                            Carbon dioxide (CO2) net fluxes from LULUCF - Deforestation (Mt CO2e)    0.001891    39
#                                                                          Forest rents (% of GDP)    0.001854    40
#                           PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)    0.001835    41
#                            Carbon dioxide (CO2) emissions from Power Industry (Energy) (Mt CO2e)    0.001795    42
#                                                          Crop production index (2014-2016 = 100)    0.001733    43
#                                         Methane (CH4) emissions from Building (Energy) (Mt CO2e)    0.001664    44
#                            Methane (CH4) emissions from Industrial Combustion (Energy) (Mt CO2e)    0.001610    45
#                                Nitrous oxide (N2O) emissions from Industrial Processes (Mt CO2e)    0.001603    46
#                                                         Total natural resources rents (% of GDP)    0.001537    47
#             Fluorinated greenhouse gases (F-gases) emissions from Industrial Processes (Mt CO2e)    0.001506    48
#                                                     Methane (CH4) emissions from Waste (Mt CO2e)    0.001455    49
#                                                                     Forest area (% of land area)    0.001388    50
#                            Methane (CH4) emissions (total) excluding LULUCF (% change from 1990)    0.001315    51
#                        Carbon dioxide (CO2) emissions from Fugitive Emissions (Energy) (Mt CO2e)    0.001277    52
#                                   Nitrous oxide (N2O) emissions from Building (Energy) (Mt CO2e)    0.001182    53
#                                                                  Cereal production (metric tons)    0.001161    54
#                       Total greenhouse gas emissions per capita excluding LULUCF (t CO2e/capita)    0.001145    55
#                                               Nitrous oxide (N2O) emissions from Waste (Mt CO2e)    0.001106    56
#                                        Total greenhouse gas emissions including LULUCF (Mt CO2e)    0.000932    57
#                               Carbon dioxide (CO2) emissions from Industrial Processes (Mt CO2e)    0.000930    58
#                                                 Carbon intensity of GDP (kg CO2e per 2021 PPP $)    0.000904    59
#                      Nitrous oxide (N2O) emissions from Industrial Combustion (Energy) (Mt CO2e)    0.000835    60
#                                                                                 Rural population    0.000816    61
#                                                                             Oil rents (% of GDP)    0.000761    62
#                                  Carbon dioxide (CO2) emissions from Building (Energy) (Mt CO2e)    0.000759    63
#                                                                         Mineral rents (% of GDP)    0.000758    64
#                Access to clean fuels and technologies for cooking, rural (% of rural population)    0.000752    65
#                                Carbon dioxide (CO2) emissions (total) excluding LULUCF (Mt CO2e)    0.000722    66
#                                                                               Land area (sq. km)    0.000694    67
#                                                          Land under cereal production (hectares)    0.000681    68
#                                                                            Coal rents (% of GDP)    0.000661    69
#                     Carbon dioxide (CO2) emissions from Industrial Combustion (Energy) (Mt CO2e)    0.000608    70
#                                                                     Natural gas rents (% of GDP)    0.000549    71
#                                                  GOAL 13: Climate Action (5 year moving average)    0.000531    72
#                                        Methane (CH4) emissions from Transport (Energy) (Mt CO2e)    0.000432    73
#                                 Nitrous oxide (N2O) emissions (total) excluding LULUCF (Mt CO2e)    0.000422    74
#                                                                            Surface area (sq. km)    0.000380    75
#                                         Nitrous oxide (N2O) emissions from Agriculture (Mt CO2e)    0.000361    76
#                                               Methane (CH4) emissions from Agriculture (Mt CO2e)    0.000359    77
#                                       Methane (CH4) emissions (total) excluding LULUCF (Mt CO2e)    0.000350    78
#                                 Carbon dioxide (CO2) emissions from Transport (Energy) (Mt CO2e)    0.000325    79
#                                        Total greenhouse gas emissions excluding LULUCF (Mt CO2e)    0.000261    80

# %%
#also exclude high correlation environmental features from correlation_to_all_within_group_lister.ipynb
addl_cols_to_exclude = [
    'Total greenhouse gas emissions including LULUCF (Mt CO2e)',
    'Carbon dioxide (CO2) emissions (total) excluding LULUCF (Mt CO2e)',
    'Cereal production (metric tons)',
    'Fluorinated greenhouse gases (F-gases) emissions from Industrial Processes (Mt CO2e)',
    'Methane (CH4) emissions (total) excluding LULUCF (Mt CO2e)',
    'Carbon dioxide (CO2) emissions from Industrial Combustion (Energy) (Mt CO2e)',
    'Carbon dioxide (CO2) emissions from Power Industry (Energy) (Mt CO2e)',
    'Nitrous oxide (N2O) emissions (total) excluding LULUCF (Mt CO2e)',
    'Carbon dioxide (CO2) emissions from Building (Energy) (Mt CO2e)',
    'Carbon dioxide (CO2) emissions from Fugitive Emissions (Energy) (Mt CO2e)',
    'Land under cereal production (hectares)',
    'Methane (CH4) emissions from Waste (Mt CO2e)',
    'Methane (CH4) emissions from Industrial Combustion (Energy) (Mt CO2e)',
    'Methane (CH4) emissions from Agriculture (Mt CO2e)',
    'Carbon dioxide (CO2) emissions from Industrial Processes (Mt CO2e)',
    'Nitrous oxide (N2O) emissions from Industrial Combustion (Energy) (Mt CO2e)',
    'Nitrous oxide (N2O) emissions from Agriculture (Mt CO2e)',
    'Aquaculture production (metric tons)',
    'Total fisheries production (metric tons)',
    'Nitrous oxide (N2O) emissions from Power Industry (Energy) (Mt CO2e)',
    'Forest area (sq. km)',
    'Nitrous oxide (N2O) emissions from Waste (Mt CO2e)',
    'Nitrous oxide (N2O) emissions from Building (Energy) (Mt CO2e)',
    'Access to clean fuels and technologies for cooking (% of population)',
    'Methane (CH4) emissions from Power Industry (Energy) (Mt CO2e)',
    'Methane (CH4) emissions from Fugitive Emissions (Energy) (Mt CO2e)',
    'Carbon dioxide (CO2) emissions from Transport (Energy) (Mt CO2e)',
    'Methane (CH4) emissions from Transport (Energy) (Mt CO2e)',
    'Land area (sq. km)',
    'Carbon dioxide (CO2) emissions excluding LULUCF per capita (t CO2e/capita)',
    'Nitrous oxide (N2O) emissions from Industrial Processes (Mt CO2e)',
    'Methane (CH4) emissions from Building (Energy) (Mt CO2e)',
    'Access to electricity (% of population)',
    'Rural population (% of total population)',
    'Total greenhouse gas emissions excluding LULUCF (Mt CO2e)',
    'Access to electricity, rural (% of rural population)'  
]
new_cols_to_exclude_except_enviro = list(set(cols_to_exclude_except_enviro + addl_cols_to_exclude))
bagging_features(new_cols_to_exclude_except_enviro)
# Out:
# Average MAE: 0.7317
# Average MSE: 1.4512
# Average Training R²: 0.9958
# Average Validation R²: 0.9792
#
# Sorted Feature Importance:
#                                                                                          Feature  Importance  Rank
#                                             Access to electricity, urban (% of urban population)    0.648290     1
#                Access to clean fuels and technologies for cooking, urban (% of urban population)    0.100169     2
#                                                                Arable land (hectares per person)    0.049122     3
#                Access to clean fuels and technologies for cooking, rural (% of rural population)    0.024997     4
#                                   Carbon intensity of GDP (kg CO2e per constant 2021 US$ of GDP)    0.017862     5
# Water productivity, total (constant 2015 US$ GDP per cubic meter of total freshwater withdrawal)    0.016500     6
#                                    Fertilizer consumption (kilograms per hectare of arable land)    0.016085     7
#                                                       Capture fisheries production (metric tons)    0.012118     8
#                                  Nitrous oxide (N2O) emissions from Transport (Energy) (Mt CO2e)    0.006567     9
#                     Carbon dioxide (CO2) emissions (total) excluding LULUCF (% change from 1990)    0.006279    10
#                         Nitrous oxide (N2O) emissions from Fugitive Emissions (Energy) (Mt CO2e)    0.006206    11
#                       Total greenhouse gas emissions per capita excluding LULUCF (t CO2e/capita)    0.005873    12
#                                                         Urban population (% of total population)    0.005561    13
#                             Total greenhouse gas emissions excluding LULUCF (% change from 1990)    0.005036    14
#                                                               Urban population growth (annual %)    0.004456    15
#       Carbon dioxide (CO2) net fluxes from LULUCF - Total excluding non-tropical fires (Mt CO2e)    0.004122    16
#                            Carbon dioxide (CO2) net fluxes from LULUCF - Deforestation (Mt CO2e)    0.003662    17
#                                                              Permanent cropland (% of land area)    0.003582    18
#                                Renewable internal freshwater resources per capita (cubic meters)    0.003453    19
#                                                     Livestock production index (2014-2016 = 100)    0.003173    20
#                                                               Agricultural land (% of land area)    0.003138    21
#                                                                          Forest rents (% of GDP)    0.003116    22
#                                              Population density (people per sq. km of land area)    0.003101    23
#                               Renewable energy consumption (% of total final energy consumption)    0.003094    24
#                                                                     Arable land (% of land area)    0.003083    25
#                           PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)    0.002942    26
#                                                 Carbon intensity of GDP (kg CO2e per 2021 PPP $)    0.002713    27
#                            Renewable internal freshwater resources, total (billion cubic meters)    0.002694    28
#                                                                                 Rural population    0.002691    29
#                                                                            Surface area (sq. km)    0.002613    30
#                                      Energy intensity level of primary energy (MJ/$2017 PPP GDP)    0.002599    31
#                      Nitrous oxide (N2O) emissions (total) excluding LULUCF (% change from 1990)    0.002575    32
#                                                          Crop production index (2014-2016 = 100)    0.002547    33
#                              Carbon dioxide (CO2) net fluxes from LULUCF - Forest Land (Mt CO2e)    0.002541    34
#                                                               Rural population growth (annual %)    0.002493    35
#                                                                     Forest area (% of land area)    0.002259    36
#                                                          Food production index (2014-2016 = 100)    0.002110    37
#                            Methane (CH4) emissions (total) excluding LULUCF (% change from 1990)    0.001978    38
#                                                                                 Urban population    0.001940    39
#                                                         Total natural resources rents (% of GDP)    0.001799    40
#                                                                             Oil rents (% of GDP)    0.001554    41
#                                                                         Mineral rents (% of GDP)    0.001013    42
#                                                                     Natural gas rents (% of GDP)    0.000935    43
#                                                                            Coal rents (% of GDP)    0.000799    44
#                                                  GOAL 13: Climate Action (5 year moving average)    0.000558    45

# %% [markdown]
# ## Health Features

# %%
#just the health features
bagging_features(cols_to_exclude_except_health)
# Out:
# Average MAE: 0.3807
# Average MSE: 0.3399
# Average Training R²: 0.9990
# Average Validation R²: 0.9951
#
# Sorted Feature Importance:
#                                                                                                             Feature  Importance  Rank
#                                                               Mortality rate, under-5, male (per 1,000 live births)    0.372460     1
#                                                             Mortality rate, adult, female (per 1,000 female adults)    0.331131     2
#                                                                     Mortality rate, under-5 (per 1,000 live births)    0.111142     3
#                                                                                Death rate, crude (per 1,000 people)    0.087879     4
#                                                             Mortality rate, under-5, female (per 1,000 live births)    0.055580     5
#                                                        Domestic private health expenditure per capita (current US$)    0.010846     6
#                                                                 Mortality rate, adult, male (per 1,000 male adults)    0.009769     7
#                                                                 Current health expenditure per capita (current US$)    0.003010     8
#                                                      Probability of dying among children ages 5-9 years (per 1,000)    0.000741     9
#                                                                      Mortality rate, infant (per 1,000 live births)    0.000726    10
#                                             Domestic general government health expenditure per capita (current US$)    0.000704    11
#                                                                      Incidence of tuberculosis (per 100,000 people)    0.000672    12
#                                               People using at least basic drinking water services (% of population)    0.000609    13
#                                                                    Mortality rate, neonatal (per 1,000 live births)    0.000584    14
#                                                                  Out-of-pocket expenditure per capita (current US$)    0.000569    15
#                                                Current health expenditure per capita, PPP (current international $)    0.000568    16
#                                                 Probability of dying among adolescents ages 10-14 years (per 1,000)    0.000509    17
#                            Domestic general government health expenditure per capita, PPP (current international $)    0.000495    18
#                                      People using at least basic sanitation services, rural (% of rural population)    0.000485    19
#                                      People using at least basic sanitation services, urban (% of urban population)    0.000465    20
#                                  People using at least basic drinking water services, urban (% of urban population)    0.000461    21
#                                                         Out-of-pocket expenditure (% of current health expenditure)    0.000459    22
#                                                 Probability of dying among adolescents ages 15-19 years (per 1,000)    0.000426    23
#                                                                Mortality rate, infant, male (per 1,000 live births)    0.000425    24
#                                                   People using at least basic sanitation services (% of population)    0.000421    25
#                                                                                 Lifetime risk of maternal death (%)    0.000415    26
#                                                       Probability of dying among youth ages 20-24 years (per 1,000)    0.000402    27
#                                       Domestic private health expenditure per capita, PPP (current international $)    0.000391    28
#                                                  Prevalence of overweight (modeled estimate, % of children under 5)    0.000367    29
#                                                                       Prevalence of anemia among pregnant women (%)    0.000327    30
#                                                              Mortality rate, infant, female (per 1,000 live births)    0.000313    31
#                                                                                Birth rate, crude (per 1,000 people)    0.000299    32
#                                                       Adolescent fertility rate (births per 1,000 women ages 15-19)    0.000281    33
#                                                              Population ages 15-19, female (% of female population)    0.000277    34
#                                    Prevalence of stunting, height for age (modeled estimate, % of children under 5)    0.000274    35
#                                                 Out-of-pocket expenditure per capita, PPP (current international $)    0.000255    36
#                                                                       Population ages 15-64 (% of total population)    0.000244    37
#                                                              Population ages 10-14, female (% of female population)    0.000233    38
#                                                Prevalence of anemia among children (% of children ages 6-59 months)    0.000227    39
#                                                                     Tuberculosis case detection rate (%, all forms)    0.000221    40
#                                    Domestic general government health expenditure (% of current health expenditure)    0.000216    41
#                                                                                           Number of maternal deaths    0.000210    42
#                                                                 People practicing open defecation (% of population)    0.000209    43
#                                                                 Immunization, DPT (% of children ages 12-23 months)    0.000198    44
#                                                      Lifetime risk of maternal death (1 in: rate varies by country)    0.000188    45
#                                               Prevalence of anemia among non-pregnant women (% of women ages 15-49)    0.000182    46
#                                                                               Current health expenditure (% of GDP)    0.000171    47
#                                                           Domestic general government health expenditure (% of GDP)    0.000170    48
#                                                Maternal mortality ratio (modeled estimate, per 100,000 live births)    0.000169    49
#                                                                    Prevalence of undernourishment (% of population)    0.000162    50
#                                                                  Population ages 15-19, male (% of male population)    0.000158    51
#                                                               Population ages 0-14, female (% of female population)    0.000156    52
#                                                                Tuberculosis treatment success rate (% of new cases)    0.000152    53
# Total alcohol consumption per capita, female (liters of pure alcohol, projected estimates, female 15+ years of age)    0.000150    54
#                                                                  Population ages 10-14, male (% of male population)    0.000150    55
#                                        Prevalence of anemia among women of reproductive age (% of women ages 15-49)    0.000149    56
#                                                                        Population ages 0-14 (% of total population)    0.000142    57
#                                                                   Population ages 0-14, male (% of male population)    0.000126    58
#                Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)    0.000123    59
#                                                                                     Number of deaths ages 5-9 years    0.000121    60
#                                               Domestic private health expenditure (% of current health expenditure)    0.000117    61
#                                                                                           Number of neonatal deaths    0.000113    62
#                                                                                   Number of deaths ages 10-14 years    0.000096    63
#                                                             Immunization, measles (% of children ages 12-23 months)    0.000095    64
#                                                                                   Number of deaths ages 20-24 years    0.000094    65
#                                                                                          Population ages 0-14, male    0.000083    66
#                                                                                             Number of infant deaths    0.000078    67
#     Total alcohol consumption per capita, male (liters of pure alcohol, projected estimates, male 15+ years of age)    0.000075    68
#                                                                                   Number of deaths ages 15-19 years    0.000072    69
#                                                                                        Population ages 0-14, female    0.000062    70
#                                                                                         Number of under-five deaths    0.000060    71
#                                                                                         Population ages 0-14, total    0.000050    72
#                                                        Health/Demographic survey (Availability score over 10 years)    0.000039    73

# %%
#also exclude high correlation health features from correlation_to_all_within_group_lister.ipynb
addl_cols_to_exclude = [
    'Life expectancy at birth, female (years)',
    'Number of deaths ages 15-19 years',
    'Mortality rate, infant (per 1,000 live births)',
    'Life expectancy at birth, total (years)',
    'Number of deaths ages 10-14 years',
    'Mortality rate, infant, female (per 1,000 live births)',
    'Number of deaths ages 20-24 years',
    'Prevalence of anemia among children (% of children ages 6-59 months)',
    'Mortality rate, infant, male (per 1,000 live births)',
    'Population ages 0-14 (% of total population)',
    'Mortality rate, under-5 (per 1,000 live births)',
    'Birth rate, crude (per 1,000 people)',
    'Population ages 0-14, female (% of female population)',
    'Mortality rate, neonatal (per 1,000 live births)',
    'Mortality rate, under-5, female (per 1,000 live births)',
    'Life expectancy at birth, male (years)',
    'Number of deaths ages 5-9 years',
    'Current health expenditure per capita (current US$)',
    'Out-of-pocket expenditure per capita (current US$)',
    'Population ages 0-14, male (% of male population)',
    'Population ages 10-14, female (% of female population)',
    'Population ages 0-14, female',
    'Population ages 10-14, male (% of male population)',
    'Prevalence of anemia among non-pregnant women (% of women ages 15-49)',
    'Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)',
    'People using at least basic sanitation services, rural (% of rural population)',
    'Number of infant deaths',
    'Current health expenditure per capita, PPP (current international $)',
    'Mortality rate, under-5, male (per 1,000 live births)',
    'Maternal mortality ratio (modeled estimate, per 100,000 live births)',
    'Out-of-pocket expenditure (% of current health expenditure)',
    'Population ages 15-19, female (% of female population)',
    'Probability of dying among adolescents ages 15-19 years (per 1,000)',
    'Probability of dying among adolescents ages 10-14 years (per 1,000)',
    'Prevalence of anemia among pregnant women (%)',
    'Domestic general government health expenditure per capita (current US$)',
    'Domestic private health expenditure per capita (current US$)',
    'Lifetime risk of maternal death (%)',
    'Immunization, DPT (% of children ages 12-23 months)',
    'People using at least basic drinking water services, urban (% of urban population)',
    'Population ages 0-14, male',
    'Mortality rate, adult, female (per 1,000 female adults)',
    'Number of maternal deaths',
    'People using at least basic sanitation services, urban (% of urban population)',
    'Number of neonatal deaths',
    'Total alcohol consumption per capita, female (liters of pure alcohol, projected estimates, female 15+ years of age)'    
]
new_cols_to_exclude_except_health = list(set(cols_to_exclude_except_health + addl_cols_to_exclude))
bagging_features(new_cols_to_exclude_except_health)
# Out:
# Average MAE: 0.4412
# Average MSE: 0.4660
# Average Training R²: 0.9986
# Average Validation R²: 0.9933
#
# Sorted Feature Importance:
#                                                                                                         Feature  Importance  Rank
#                                                  Probability of dying among children ages 5-9 years (per 1,000)    0.694992     1
#                                                             Mortality rate, adult, male (per 1,000 male adults)    0.164198     2
#                                                                            Death rate, crude (per 1,000 people)    0.103017     3
#                        Domestic general government health expenditure per capita, PPP (current international $)    0.005794     4
#                                           People using at least basic drinking water services (% of population)    0.003814     5
#                                                  Lifetime risk of maternal death (1 in: rate varies by country)    0.003174     6
#                                               People using at least basic sanitation services (% of population)    0.003140     7
#                                   Domestic private health expenditure per capita, PPP (current international $)    0.002691     8
#                                    Prevalence of anemia among women of reproductive age (% of women ages 15-49)    0.001813     9
#                                                                  Incidence of tuberculosis (per 100,000 people)    0.001770    10
#                                                                   Population ages 15-64 (% of total population)    0.001698    11
#                                                   Probability of dying among youth ages 20-24 years (per 1,000)    0.001582    12
#                                                              Population ages 15-19, male (% of male population)    0.001516    13
#                                             Out-of-pocket expenditure per capita, PPP (current international $)    0.001364    14
# Total alcohol consumption per capita, male (liters of pure alcohol, projected estimates, male 15+ years of age)    0.001250    15
#                                                   Adolescent fertility rate (births per 1,000 women ages 15-19)    0.001068    16
#                                Prevalence of stunting, height for age (modeled estimate, % of children under 5)    0.001027    17
#                                                                                     Number of under-five deaths    0.000725    18
#                                                             People practicing open defecation (% of population)    0.000607    19
#                                                                Prevalence of undernourishment (% of population)    0.000591    20
#                                                                                     Population ages 0-14, total    0.000588    21
#                                                       Domestic general government health expenditure (% of GDP)    0.000545    22
#                                              Prevalence of overweight (modeled estimate, % of children under 5)    0.000517    23
#                                                         Immunization, measles (% of children ages 12-23 months)    0.000489    24
#                                                                 Tuberculosis case detection rate (%, all forms)    0.000398    25
#                                                                           Current health expenditure (% of GDP)    0.000393    26
#                                Domestic general government health expenditure (% of current health expenditure)    0.000389    27
#                                           Domestic private health expenditure (% of current health expenditure)    0.000359    28
#                                                            Tuberculosis treatment success rate (% of new cases)    0.000358    29
#                                                    Health/Demographic survey (Availability score over 10 years)    0.000133    30

# %% [markdown]
# ## Socioeconomic Features

# %%
#just the socioeconomic features
bagging_features(cols_to_exclude_except_socio)
# Out:
# Average MAE: 0.8604
# Average MSE: 1.8540
# Average Training R²: 0.9949
# Average Validation R²: 0.9734
#
# Sorted Feature Importance:
#                                                                                                               Feature   Importance  Rank
#                                                                                             Region_Sub-Saharan Africa 5.888169e-01     1
#                                                                                    GDP per capita (constant 2015 US$) 1.365193e-01     2
#                                                                         Commercial bank branches (per 100,000 adults) 3.762669e-02     3
#                                                                            GNI per capita, Atlas method (current US$) 2.930651e-02     4
#                                                                 Adjusted net national income per capita (current US$) 2.387673e-02     5
#                                                                                           Pillar 1 - Data Use - Score 1.880629e-02     6
#                                                                  Refugee population by country or territory of origin 1.230392e-02     7
#                                                                                          GDP per capita (current US$) 1.099979e-02     8
#                                                                      Monetary Sector credit to private sector (% GDP) 1.037090e-02     9
#                                                                 Domestic credit to private sector by banks (% of GDP) 7.467645e-03    10
#                                                                                                Broad money (% of GDP) 7.306080e-03    11
#                     Labor force participation rate, female (% of female population ages 15-64) (modeled ILO estimate) 4.432095e-03    12
#                                                                          Labor force, female (% of total labor force) 4.361809e-03    13
#                                                        International tourism, receipts for travel items (current US$) 3.689118e-03    14
#                                                                    Adjusted savings: education expenditure (% of GNI) 3.192519e-03    15
#                                     Wage and salaried workers, female (% of female employment) (modeled ILO estimate) 3.188314e-03    16
#                       Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate) 3.124200e-03    17
#                                                                   GDP per capita, PPP (constant 2021 international $) 3.063182e-03    18
#                                                                         GDP per person employed (constant 2021 PPP $) 3.059034e-03    19
#                         Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate) 2.509287e-03    20
#                                                                    Ores and metals imports (% of merchandise imports) 2.454118e-03    21
#                                                 Self-employed, female (% of female employment) (modeled ILO estimate) 2.451732e-03    22
#                                                                                Compulsory education, duration (years) 2.377180e-03    23
#                                    Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate) 2.365564e-03    24
#                                                                         Adjusted savings: energy depletion (% of GNI) 2.188113e-03    25
#                                                                                                         Net migration 2.086414e-03    26
#                                                                     Travel services (% of commercial service imports) 2.065685e-03    27
#                                                                  Transport services (% of commercial service imports) 2.033665e-03    28
#                                                                          Domestic credit to private sector (% of GDP) 2.014873e-03    29
#                                                                  Transport services (% of commercial service exports) 1.953946e-03    30
#                                                     Self-employed, male (% of male employment) (modeled ILO estimate) 1.832761e-03    31
#                                                                  Official exchange rate (LCU per US$, period average) 1.755835e-03    32
#                                                                  Refugee population by country or territory of asylum 1.645934e-03    33
#                                                                               Fuel exports (% of merchandise exports) 1.558570e-03    34
#                                                                    Adjusted savings: carbon dioxide damage (% of GNI) 1.423701e-03    35
#                                     Ratio of female to male labor force participation rate (%) (modeled ILO estimate) 1.387190e-03    36
#                                                    Insurance and financial services (% of commercial service imports) 1.363068e-03    37
#                                         Wage and salaried workers, male (% of male employment) (modeled ILO estimate) 1.354121e-03    38
#                                                                                             Primary education, pupils 1.306957e-03    39
#                                                    Insurance and financial services (% of commercial service exports) 1.240393e-03    40
#                                                                 Automated teller machines (ATMs) (per 100,000 adults) 1.224630e-03    41
#                                                                            Claims on central government, etc. (% GDP) 1.211927e-03    42
#                                                                     External balance on goods and services (% of GDP) 1.174965e-03    43
#                                         Computer, communications and other services (% of commercial service exports) 1.174240e-03    44
#                                                                                      Pillar 3 - Data Products - Score 1.165205e-03    45
#                                                                            GOAL 1: No Poverty (5 year moving average) 1.159356e-03    46
#                                        Agriculture, forestry, and fishing, value added per worker (constant 2015 US$) 1.143256e-03    47
#                                                            Agriculture, forestry, and fishing, value added (% of GDP) 1.098852e-03    48
#                         Labor force participation rate, male (% of male population ages 15-64) (modeled ILO estimate) 1.092853e-03    49
#                                                         Proportion of seats held by women in national parliaments (%) 1.077959e-03    50
#                                                                  Women Business and the Law Index Score (scale 1-100) 1.066765e-03    51
#                                                                                  Import unit value index (2015 = 100) 1.064677e-03    52
#                                                                             International tourism, number of arrivals 1.049274e-03    53
#                                       Wage and salaried workers, total (% of total employment) (modeled ILO estimate) 1.040169e-03    54
# Share of youth not in education, employment or training, female (% of female youth population) (modeled ILO estimate) 1.040158e-03    55
#                                                                              Exports of goods and services (% of GDP) 1.036528e-03    56
#     Share of youth not in education, employment or training, male (% of male youth population) (modeled ILO estimate) 1.012651e-03    57
#         Share of youth not in education, employment or training, total (% of youth population) (modeled ILO estimate) 9.866338e-04    58
#                                                Employment to population ratio, 15+, female (%) (modeled ILO estimate) 9.823444e-04    59
#                                                     Unemployment, male (% of male labor force) (modeled ILO estimate) 9.679090e-04    60
#                                                 Employment to population ratio, 15+, total (%) (modeled ILO estimate) 8.972334e-04    61
#                                                      Exports of goods, services and primary income (BoP, current US$) 7.857195e-04    62
#                                         Vulnerable employment, female (% of female employment) (modeled ILO estimate) 7.653718e-04    63
#                                                                                                    Labor force, total 7.602582e-04    64
#                                                    International tourism, expenditures for travel items (current US$) 7.380679e-04    65
#                                        Labor force participation rate for ages 15-24, male (%) (modeled ILO estimate) 7.284529e-04    66
#                                                                                Preprimary education, duration (years) 7.229002e-04    67
#                                           Vulnerable employment, total (% of total employment) (modeled ILO estimate) 7.088815e-04    68
#                                                   Self-employed, total (% of total employment) (modeled ILO estimate) 6.889129e-04    69
#                                                                         GNI per capita, PPP (current international $) 6.885596e-04    70
#                                                                                  Export unit value index (2015 = 100) 6.615232e-04    71
#                                                                     Travel services (% of commercial service exports) 6.330719e-04    72
#                                                                                               GDP (constant 2015 US$) 5.995385e-04    73
#                                                            Communications, computer, etc. (% of service exports, BoP) 5.971994e-04    74
#                                                                              GDP, PPP (constant 2021 international $) 5.939559e-04    75
#                                          Employment to population ratio, ages 15-24, total (%) (modeled ILO estimate) 5.883274e-04    76
#                                                                                    GNI, PPP (current international $) 5.823770e-04    77
#                                           Employment to population ratio, ages 15-24, male (%) (modeled ILO estimate) 5.804022e-04    78
#                                                                          School enrollment, primary, female (% gross) 5.682822e-04    79
#                                             Vulnerable employment, male (% of male employment) (modeled ILO estimate) 5.512785e-04    80
#                                       Labor force participation rate for ages 15-24, total (%) (modeled ILO estimate) 5.453951e-04    81
#                                                  Employment to population ratio, 15+, male (%) (modeled ILO estimate) 5.359774e-04    82
#                                Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate) 5.312687e-04    83
#                                                     GOAL 17: Partnerships to achieve the Goal (5 year moving average) 5.278227e-04    84
#                                                                                                 GDP growth (annual %) 5.266369e-04    85
#                                                                            School enrollment, primary, male (% gross) 5.117895e-04    86
#                       Labor force participation rate, total (% of total population ages 15-64) (modeled ILO estimate) 4.860222e-04    87
#                                                                       Final consumption expenditure (annual % growth) 4.810946e-04    88
#                                      Labor force participation rate for ages 15-24, female (%) (modeled ILO estimate) 4.519279e-04    89
#                                                                               Fuel imports (% of merchandise imports) 4.475546e-04    90
#                                                                                      GDP per capita growth (annual %) 4.462970e-04    91
#                                                                     Inflation, GDP deflator: linked series (annual %) 4.379211e-04    92
#                                                                                  School enrollment, primary (% gross) 4.369085e-04    93
#                                                 Unemployment, female (% of female labor force) (modeled ILO estimate) 4.276685e-04    94
#                                         Employment to population ratio, ages 15-24, female (%) (modeled ILO estimate) 4.268078e-04    95
#                                                                                    Inflation, GDP deflator (annual %) 4.260870e-04    96
#                                  Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate) 4.155738e-04    97
#                                                  General government final consumption expenditure (constant 2015 US$) 4.055325e-04    98
#                                                                         GDP per capita, PPP (current international $) 3.996777e-04    99
#                                                            Communications, computer, etc. (% of service imports, BoP) 3.936800e-04   100
#                                                                                    GDP, PPP (current international $) 3.714714e-04   101
#                                         Computer, communications and other services (% of commercial service imports) 3.620280e-04   102
#                           Labor force participation rate, male (% of male population ages 15+) (modeled ILO estimate) 3.585224e-04   103
#                                                   GOAL 11: Sustainable Cities and Communities (5 year moving average) 3.545056e-04   104
#                                                                            Adjusted net national income (current US$) 3.232167e-04   105
#                                                                     Final consumption expenditure (constant 2015 US$) 3.143951e-04   106
#                                                                                       GNI, Atlas method (current US$) 2.830750e-04   107
#                                                                   GOAL 10: Reduced Inequality (5 year moving average) 2.779654e-04   108
#                                                GOAL 16: Peace and Justice Strong Institutions (5 year moving average) 2.717183e-04   109
#                                               GOAL 12: Responsible Consumption and Production (5 year moving average) 2.643977e-04   110
#                                                   Unemployment, total (% of total labor force) (modeled ILO estimate) 2.564074e-04   111
#                                                                 Labor Force Survey (Availability score over 10 years) 2.253864e-04   112
#                                                                         GOAL 15: Life on Land (5 year moving average) 1.900855e-04   113
#                                                    General government final consumption expenditure (annual % growth) 1.596309e-04   114
#                                                                                                     GDP (current US$) 1.509116e-04   115
#                                                    Household Survey on income, etc (Availability score over 10 years) 1.140570e-04   116
#                                                                                                     GNI (current US$) 1.056827e-04   117
#                                                                                      Region_Latin America & Caribbean 6.115571e-05   118
#                                                                                      Income Group_Lower middle income 5.524227e-05   119
#                                                                                                     Region_South Asia 4.240603e-05   120
#                                                                                            Region_East Asia & Pacific 4.111852e-05   121
#                                                                                          Region_Europe & Central Asia 2.376247e-05   122
#                                                                                      Income Group_Upper middle income 2.093791e-05   123
#                                                                                     Region_Middle East & North Africa 1.243468e-05   124
#                                                                                               Income Group_Low income 4.653718e-06   125
#                                                                                              Income Group_High income 2.388671e-06   126
#                                                                                                  Region_North America 7.980280e-10   127

# %%
#also exclude high correlation socioeconomic features from correlation_to_all_within_group_lister.ipynb
addl_cols_to_exclude = [
    'General government final consumption expenditure (constant 2015 US$)',
    'Self-employed, female (% of female employment) (modeled ILO estimate)',
    'Self-employed, male (% of male employment) (modeled ILO estimate)',
    'Adjusted net national income (current US$)',
    'Final consumption expenditure (constant 2015 US$)',
    'Self-employed, total (% of total employment) (modeled ILO estimate)',
    'GDP, PPP (constant 2021 international $)',
    'GDP per capita, PPP (constant 2021 international $)',
    'GNI, PPP (current international $)',
    'Vulnerable employment, female (% of female employment) (modeled ILO estimate)',
    'Adjusted net national income per capita (current US$)',
    'GDP, PPP (current international $)',
    'Vulnerable employment, male (% of male employment) (modeled ILO estimate)',
    'Exports of goods, services and primary income (BoP, current US$)',
    'GDP per capita (constant 2015 US$)',
    'Unemployment, male (% of male labor force) (modeled ILO estimate)',
    'Unemployment, female (% of female labor force) (modeled ILO estimate)',
    'Vulnerable employment, total (% of total employment) (modeled ILO estimate)',
    'GDP (constant 2015 US$)',
    'GNI, Atlas method (current US$)',
    'Employment to population ratio, 15+, female (%) (modeled ILO estimate)',
    'Unemployment, total (% of total labor force) (modeled ILO estimate)',
    'Domestic credit to private sector (% of GDP)',
    'GNI per capita, PPP (current international $)',
    'GDP per capita, PPP (current international $)',
    'Employment to population ratio, ages 15-24, male (%) (modeled ILO estimate)',
    'Employment to population ratio, ages 15-24, female (%) (modeled ILO estimate)',
    'Wage and salaried workers, female (% of female employment) (modeled ILO estimate)',
    'School enrollment, primary, female (% gross)',
    'Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate)',
    'Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate)',
    'School enrollment, primary, male (% gross)',
    'Share of youth not in education, employment or training, female (% of female youth population) (modeled ILO estimate)',
    'Communications, computer, etc. (% of service exports, BoP)',
    'Communications, computer, etc. (% of service imports, BoP)',
    'Labor force participation rate for ages 15-24, female (%) (modeled ILO estimate)',
    'Primary education, pupils',
    'Monetary Sector credit to private sector (% GDP)',
    'Labor force, female (% of total labor force)',
    'Labor force participation rate, female (% of female population ages 15-64) (modeled ILO estimate)',
    'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)',
    'Labor force participation rate for ages 15-24, male (%) (modeled ILO estimate)',
    'Inflation, GDP deflator (annual %)',
    'GNI per capita, Atlas method (current US$)',
    'GNI (current US$)',
    'GDP growth (annual %)',
    'Employment to population ratio, ages 15-24, total (%) (modeled ILO estimate)',
    'Employment to population ratio, 15+, total (%) (modeled ILO estimate)',
    'Employment to population ratio, 15+, male (%) (modeled ILO estimate)',
    'Wage and salaried workers, male (% of male employment) (modeled ILO estimate)'   
]
new_cols_to_exclude_except_socio = list(set(cols_to_exclude_except_socio + addl_cols_to_exclude))
bagging_features(new_cols_to_exclude_except_socio)
# Out:
# Average MAE: 0.8967
# Average MSE: 1.9826
# Average Training R²: 0.9941
# Average Validation R²: 0.9716
#
# Sorted Feature Importance:
#                                                                                                           Feature   Importance  Rank
#                                                                                         Region_Sub-Saharan Africa 5.888169e-01     1
#                                                                                      GDP per capita (current US$) 2.002121e-01     2
#                                                                     Commercial bank branches (per 100,000 adults) 3.981752e-02     3
#                                                                                       Pillar 1 - Data Use - Score 1.906746e-02     4
#                                                             Domestic credit to private sector by banks (% of GDP) 1.563907e-02     5
#                                                              Refugee population by country or territory of origin 1.280820e-02     6
#                                   Wage and salaried workers, total (% of total employment) (modeled ILO estimate) 9.133182e-03     7
#                                                                                            Broad money (% of GDP) 7.869147e-03     8
#                                                    International tourism, receipts for travel items (current US$) 6.893422e-03     9
#                     Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate) 6.431559e-03    10
#                                                                Adjusted savings: education expenditure (% of GNI) 5.383507e-03    11
#                   Labor force participation rate, total (% of total population ages 15-64) (modeled ILO estimate) 4.359970e-03    12
#                              Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate) 3.746211e-03    13
#                                                                     GDP per person employed (constant 2021 PPP $) 3.597705e-03    14
#                                 Ratio of female to male labor force participation rate (%) (modeled ILO estimate) 3.360612e-03    15
#                                                                     Adjusted savings: energy depletion (% of GNI) 3.275466e-03    16
#                                                                           Fuel exports (% of merchandise exports) 3.081131e-03    17
#                                                                Adjusted savings: carbon dioxide damage (% of GNI) 2.946433e-03    18
#                                                                 Travel services (% of commercial service imports) 2.790369e-03    19
#                                                                                                Labor force, total 2.673097e-03    20
#                                                              Transport services (% of commercial service exports) 2.474392e-03    21
#                                                              Official exchange rate (LCU per US$, period average) 2.458515e-03    22
#                                                              Transport services (% of commercial service imports) 2.376170e-03    23
#                                                                        Claims on central government, etc. (% GDP) 1.975506e-03    24
#                                                                Ores and metals imports (% of merchandise imports) 1.952167e-03    25
#                                                                                                     Net migration 1.905703e-03    26
#                                    Agriculture, forestry, and fishing, value added per worker (constant 2015 US$) 1.904776e-03    27
#                                                Insurance and financial services (% of commercial service imports) 1.894398e-03    28
#                                                        Agriculture, forestry, and fishing, value added (% of GDP) 1.839146e-03    29
#     Share of youth not in education, employment or training, total (% of youth population) (modeled ILO estimate) 1.827187e-03    30
#                                                              Refugee population by country or territory of asylum 1.716320e-03    31
#                                                                              Import unit value index (2015 = 100) 1.602595e-03    32
#                                                Insurance and financial services (% of commercial service exports) 1.586184e-03    33
#                                                International tourism, expenditures for travel items (current US$) 1.556924e-03    34
#                                   Labor force participation rate for ages 15-24, total (%) (modeled ILO estimate) 1.487808e-03    35
#                                                     Proportion of seats held by women in national parliaments (%) 1.449763e-03    36
#                                                                                  Pillar 3 - Data Products - Score 1.440010e-03    37
#                                                                          Exports of goods and services (% of GDP) 1.352178e-03    38
#                                                                 Travel services (% of commercial service exports) 1.214323e-03    39
#                                                                        GOAL 1: No Poverty (5 year moving average) 1.213958e-03    40
#                                                                   Final consumption expenditure (annual % growth) 1.206986e-03    41
#                                                                         International tourism, number of arrivals 1.184037e-03    42
# Share of youth not in education, employment or training, male (% of male youth population) (modeled ILO estimate) 1.180689e-03    43
#                                                                                                 GDP (current US$) 1.178656e-03    44
#                                     Computer, communications and other services (% of commercial service exports) 1.128068e-03    45
#                                                                              School enrollment, primary (% gross) 1.123563e-03    46
#                                                                              Export unit value index (2015 = 100) 1.115215e-03    47
#                       Labor force participation rate, male (% of male population ages 15+) (modeled ILO estimate) 1.059037e-03    48
#                                                                            Compulsory education, duration (years) 1.051896e-03    49
#                                                                 External balance on goods and services (% of GDP) 1.046670e-03    50
#                                                                 Inflation, GDP deflator: linked series (annual %) 1.044716e-03    51
#                                                             Automated teller machines (ATMs) (per 100,000 adults) 9.977484e-04    52
#                                                 GOAL 17: Partnerships to achieve the Goal (5 year moving average) 9.807269e-04    53
#                     Labor force participation rate, male (% of male population ages 15-64) (modeled ILO estimate) 9.574193e-04    54
#                                                                           Fuel imports (% of merchandise imports) 9.565636e-04    55
#                                                              Women Business and the Law Index Score (scale 1-100) 9.348310e-04    56
#                                     Computer, communications and other services (% of commercial service imports) 8.722081e-04    57
#                                                                            Preprimary education, duration (years) 7.720136e-04    58
#                                                                                  GDP per capita growth (annual %) 6.992117e-04    59
#                                               GOAL 11: Sustainable Cities and Communities (5 year moving average) 5.664159e-04    60
#                                            GOAL 16: Peace and Justice Strong Institutions (5 year moving average) 3.928373e-04    61
#                                           GOAL 12: Responsible Consumption and Production (5 year moving average) 3.792605e-04    62
#                                                             Labor Force Survey (Availability score over 10 years) 3.586104e-04    63
#                                                General government final consumption expenditure (annual % growth) 3.510619e-04    64
#                                                                     GOAL 15: Life on Land (5 year moving average) 2.601163e-04    65
#                                                               GOAL 10: Reduced Inequality (5 year moving average) 2.501957e-04    66
#                                                Household Survey on income, etc (Availability score over 10 years) 2.319627e-04    67
#                                                                                        Region_East Asia & Pacific 1.281230e-04    68
#                                                                                  Region_Latin America & Caribbean 1.136338e-04    69
#                                                                                  Income Group_Lower middle income 8.764166e-05    70
#                                                                                          Income Group_High income 6.720974e-05    71
#                                                                                      Region_Europe & Central Asia 6.211638e-05    72
#                                                                                  Income Group_Upper middle income 5.403213e-05    73
#                                                                                                 Region_South Asia 3.679908e-05    74
#                                                                                           Income Group_Low income 2.962402e-05    75
#                                                                                 Region_Middle East & North Africa 9.017617e-06    76
#                                                                                              Region_North America 2.780517e-09    77
