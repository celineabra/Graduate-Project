# %%
import pandas as pd
import os 

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', None)
pd.set_option('display.expand_frame_repr', False)

# %%
import numpy as np
from sklearn.model_selection import KFold
from sklearn.impute import KNNImputer
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from lightgbm import LGBMRegressor
import re

# %%
folder_loc = 'F:/class/BANA 698/week 8'


file_list = [f for f in os.listdir(folder_loc) if os.path.isfile(os.path.join(folder_loc, f))]
for file in file_list:
    print(file)

# %%
file = 'Group1DatasetRaw.onehotted.csv'
df = pd.read_csv(os.path.join(folder_loc, file))

# %%
#for col in sorted(df.columns): print(col)

# %%
#remove special chars and spaces from feature names bc lightgbm can't handle them
df.columns = df.columns.str.replace('-', ' to ')
df.columns = df.columns.str.replace('=', 'equals')
df.columns = df.columns.str.replace('/', ' divided by ')
df.columns = df.columns.str.replace('%', 'percent', regex=False)
df.columns = df.columns.str.replace('$', 'dollar', regex=False)
df.columns = df.columns.str.replace('&', 'and')
df.columns = df.columns.str.replace(' ', '_')
df.columns = df.columns.str.replace(r'[^\w\s]', '', regex=True)
df.columns = df.columns.str.strip()

# %%
#for col in sorted(df.columns): print(col)

# %%
target = 'Life_expectancy_at_birth_total_years'

cols_to_exclude = [
    'Life_expectancy_at_birth_female_years',
    'Life_expectancy_at_birth_male_years',
    'Life_expectancy_at_birth_total_years',
    'CountryShortName',
    'Year',
    'Death_rate_crude_per_1000_people',
    'Lifetime_risk_of_maternal_death_1_in_rate_varies_by_country',
    'Lifetime_risk_of_maternal_death_percent',
    'Mortality_rate_adult_female_per_1000_female_adults',
    'Mortality_rate_adult_male_per_1000_male_adults',
    'Mortality_rate_infant_female_per_1000_live_births',
    'Mortality_rate_infant_male_per_1000_live_births',
    'Mortality_rate_infant_per_1000_live_births',
    'Mortality_rate_neonatal_per_1000_live_births',
    'Mortality_rate_under_to_5_female_per_1000_live_births',
    'Mortality_rate_under_to_5_male_per_1000_live_births',
    'Mortality_rate_under_to_5_per_1000_live_births',
    'Number_of_deaths_ages_10_to_14_years',
    'Number_of_deaths_ages_15_to_19_years',
    'Number_of_deaths_ages_20_to_24_years',
    'Number_of_deaths_ages_5_to_9_years',
    'Number_of_infant_deaths',
    'Number_of_maternal_deaths',
    'Number_of_neonatal_deaths',
    'Number_of_under_to_five_deaths',
    'Maternal_mortality_ratio_modeled_estimate_per_100000_live_births',
    'Probability_of_dying_among_adolescents_ages_10_to_14_years_per_1000',
    'Probability_of_dying_among_adolescents_ages_15_to_19_years_per_1000',
    'Probability_of_dying_among_children_ages_5_to_9_years_per_1000',
    'Probability_of_dying_among_youth_ages_20_to_24_years_per_1000'
]

# %%
lgbm_params = {
    'boosting_type': 'gbdt',
    'class_weight': None,
    'colsample_bytree': 1.0,
    'importance_type': 'split',
    'learning_rate': 0.1,
    'max_depth': -1,
    'min_child_samples': 20,
    'min_child_weight': 0.001,
    'min_split_gain': 0.0,
    'n_estimators': 100,
    'n_jobs': -1,
    'num_leaves': 31,
    'objective': None,
    'random_state': 1,
    'reg_alpha': 0.0,
    'reg_lambda': 0.0,
    'subsample': 1.0,
    'subsample_for_bin': 200000,
    'subsample_freq': 0,
    'verbose': 0
}
#got default parameters from running:
#model = LGBMRegressor()
#model.get_params()

# %%
def lgbm_features(cols_to_exclude = cols_to_exclude, target = target, df = df, kfold_random_state = 1, n_neighbors = 5):
    X = df.drop(columns = cols_to_exclude)
    y = df[target]

    imputer = KNNImputer(n_neighbors = n_neighbors)
    model = LGBMRegressor(**lgbm_params)

    cv = KFold(n_splits=5, shuffle=True, random_state = kfold_random_state)

    mae_scores = []
    mse_scores = []
    r2_scores = []
    feature_importance_list = []

    for train_idx, val_idx in cv.split(X):
        #train_idx will be a NumPy array containing the integer indices of the rows in the original DataFrame X (and y) that should be used as the training set for the current fold.
        #val_idx will be a NumPy array containing the integer indices of the rows in X (and y) that should be used as the validation (or test) set for the current fold.

        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]
        
        X_train_imputed = imputer.fit_transform(X_train)
        X_val_imputed = imputer.transform(X_val)
        
        X_train_imputed = pd.DataFrame(X_train_imputed, columns=X_train.columns)
        X_val_imputed = pd.DataFrame(X_val_imputed, columns=X_val.columns)
        
        model.fit(X_train_imputed, y_train)
        y_pred = model.predict(X_val_imputed)
        
        mae = mean_absolute_error(y_val, y_pred)
        mse = mean_squared_error(y_val, y_pred)
        r2 = r2_score(y_val, y_pred)        
        mae_scores.append(mae)
        mse_scores.append(mse)
        r2_scores.append(r2)
        
        feature_importance_list.append(model.feature_importances_)


    avg_mae = np.mean(mae_scores)
    avg_mse = np.mean(mse_scores)
    avg_r2 = np.mean(r2_scores)

    print(f'Average MAE: {avg_mae:.4f}')
    print(f'Average MSE: {avg_mse:.4f}')
    print(f'Average R²: {avg_r2:.4f}')

    avg_feature_importance = np.mean(feature_importance_list, axis=0)
    feature_importance_df = pd.DataFrame({
        'Feature': X.columns,
        'Importance': avg_feature_importance
    })
    feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False).reset_index(drop=True)
    feature_importance_df['Rank'] = feature_importance_df.index + 1
    feature_importance_df = feature_importance_df[['Feature', 'Importance', 'Rank']]

    print('\nSorted Feature Importance:')
    print(feature_importance_df.to_string(index=False))

# %%
lgbm_features()
# Out:
# Average MAE: 0.5289
# Average MSE: 0.7219
# Average R²: 0.9896
#
# Sorted Feature Importance:
#                                                                                                               Feature  Importance  Rank
#                                                                           Incidence_of_tuberculosis_per_100000_people        56.0     1
#                                                Insurance_and_financial_services_percent_of_commercial_service_imports        46.6     2
#                                                                  Prevalence_of_undernourishment_percent_of_population        45.4     3
#                                                                               Import_unit_value_index_2015_equals_100        45.0     4
#                                                                                      Birth_rate_crude_per_1000_people        44.4     5
#                                             Energy_intensity_level_of_primary_energy_MJ_divided_by_dollar2017_PPP_GDP        39.2     6
#                                                                   Final_consumption_expenditure_annual_percent_growth        37.0     7
#                                                                                       Arable_land_hectares_per_person        36.2     8
#                                                         Adolescent_fertility_rate_births_per_1000_women_ages_15_to_19        34.8     9
#                                                 People_using_at_least_basic_sanitation_services_percent_of_population        34.6    10
#                                                                                Pillar_3__to__Data_Products__to__Score        33.0    11
#                                                                       Labor_force_female_percent_of_total_labor_force        31.8    12
#                                                             Immunization_DPT_percent_of_children_ages_12_to_23_months        31.4    13
#                                                                                     Pillar_1__to__Data_Use__to__Score        30.6    14
#                                                                               Permanent_cropland_percent_of_land_area        30.4    15
#                                                                    Livestock_production_index_2014_to_2016_equals_100        29.0    16
#                                                        GOAL_17_Partnerships_to_achieve_the_Goal_5_year_moving_average        29.0    17
#                                                                         Crop_production_index_2014_to_2016_equals_100        28.8    18
#                                                                 Travel_services_percent_of_commercial_service_imports        28.8    19
#                                           Prevalence_of_anemia_among_children_percent_of_children_ages_6_to_59_months        28.4    20
#                                                                               Export_unit_value_index_2015_equals_100        28.0    21
#                                                          Population_ages_15_to_19_female_percent_of_female_population        27.8    22
#                                                                    Tuberculosis_case_detection_rate_percent_all_forms        25.4    23
#                                                                                 Inflation_GDP_deflator_annual_percent        24.6    24
#                                                              Transport_services_percent_of_commercial_service_imports        24.4    25
#                                                              Population_ages_15_to_19_male_percent_of_male_population        24.4    26
#                                                                                            Broad_money_percent_of_GDP        24.0    27
#                                                                                Urban_population_growth_annual_percent        23.6    28
#                                                                                  GDP_per_capita_growth_annual_percent        23.0    29
#                                                                         Food_production_index_2014_to_2016_equals_100        23.0    30
#                                          Carbon_dioxide_CO2_emissions_total_excluding_LULUCF_percent_change_from_1990        22.8    31
#                                    Prevalence_of_stunting_height_for_age_modeled_estimate_percent_of_children_under_5        22.6    32
#                                              Total_greenhouse_gas_emissions_excluding_LULUCF_percent_change_from_1990        22.4    33
#                                                                 Travel_services_percent_of_commercial_service_exports        22.2    34
#                                           Nitrous_oxide_N2O_emissions_total_excluding_LULUCF_percent_change_from_1990        21.4    35
#                                                                Official_exchange_rate_LCU_per_USdollar_period_average        21.4    36
#                                                              Transport_services_percent_of_commercial_service_exports        21.2    37
#                                                  GOAL_12_Responsible_Consumption_and_Production_5_year_moving_average        21.2    38
#                                                                      GOAL_10_Reduced_Inequality_5_year_moving_average        21.0    39
#                                                                           Access_to_electricity_percent_of_population        20.8    40
#                                     People_using_at_least_basic_sanitation_services_urban_percent_of_urban_population        20.8    41
#                                                    Renewable_internal_freshwater_resources_total_billion_cubic_meters        20.6    42
#                                                              Tuberculosis_treatment_success_rate_percent_of_new_cases        19.6    43
#                                                                                Agricultural_land_percent_of_land_area        19.6    44
#                                                                                             GDP_growth_annual_percent        19.0    45
#                                                                          Claims_on_central_government_etc_percent_GDP        19.0    46
#                                                 Methane_CH4_emissions_total_excluding_LULUCF_percent_change_from_1990        18.8    47
#                                                               People_practicing_open_defecation_percent_of_population        18.8    48
#                                                                  Refugee_population_by_country_or_territory_of_asylum        18.6    49
#                                                                              Capture_fisheries_production_metric_tons        18.4    50
#                                                         Domestic_general_government_health_expenditure_percent_of_GDP        18.2    51
#                                                              Population_ages_10_to_14_male_percent_of_male_population        18.2    52
#                    Water_productivity_total_constant_2015_USdollar_GDP_per_cubic_meter_of_total_freshwater_withdrawal        18.0    53
#                                                                          Total_natural_resources_rents_percent_of_GDP        17.6    54
#                                                Insurance_and_financial_services_percent_of_commercial_service_exports        17.4    55
#                                                                           Fuel_imports_percent_of_merchandise_imports        17.4    56
#                                                                  Refugee_population_by_country_or_territory_of_origin        17.2    57
#                                                                Current_health_expenditure_per_capita_current_USdollar        17.2    58
#                                                               Access_to_electricity_urban_percent_of_urban_population        17.2    59
#                                                   GOAL_16_Peace_and_Justice_Strong_Institutions_5_year_moving_average        17.0    60
#                                                                                Total_fisheries_production_metric_tons        16.8    61
#                                                 Prevalence_of_overweight_modeled_estimate_percent_of_children_under_5        16.8    62
#                                                     Proportion_of_seats_held_by_women_in_national_parliaments_percent        16.6    63
#                                        Agriculture_forestry_and_fishing_value_added_per_worker_constant_2015_USdollar        16.4    64
#                                                                                Rural_population_growth_annual_percent        16.4    65
#                                                                                    Aquaculture_production_metric_tons        16.4    66
#                                                                                          Mineral_rents_percent_of_GDP        16.4    67
#                                                 Out_to_of_to_pocket_expenditure_percent_of_current_health_expenditure        16.4    68
#                                                                 Adjusted_savings_carbon_dioxide_damage_percent_of_GNI        16.2    69
#                                                    Carbon_dioxide_CO2_net_fluxes_from_LULUCF__to__Forest_Land_Mt_CO2e        16.0    70
#                                                                                                         Net_migration        15.8    71
#                                      Computer_communications_and_other_services_percent_of_commercial_service_exports        15.8    72
#                                                            Communications_computer_etc_percent_of_service_exports_BoP        15.8    73
#                                                                                      Arable_land_percent_of_land_area        15.6    74
#                                                                          Exports_of_goods_and_services_percent_of_GDP        15.6    75
#                                                                  Monetary_Sector_credit_to_private_sector_percent_GDP        15.6    76
#                                       Prevalence_of_anemia_among_non_to_pregnant_women_percent_of_women_ages_15_to_49        15.4    77
#                                                                        School_enrollment_primary_female_percent_gross        15.2    78
#                                                       Renewable_internal_freshwater_resources_per_capita_cubic_meters        15.2    79
#                                                                 Adjusted_savings_education_expenditure_percent_of_GNI        15.0    80
#                                                General_government_final_consumption_expenditure_annual_percent_growth        15.0    81
#                                                                      Population_density_people_per_sq_km_of_land_area        14.8    82
#                                                                             Current_health_expenditure_percent_of_GDP        14.4    83
#                                             People_using_at_least_basic_drinking_water_services_percent_of_population        14.2    84
#                                                      GOAL_11_Sustainable_Cities_and_Communities_5_year_moving_average        14.2    85
#                                                Current_health_expenditure_per_capita_PPP_current_international_dollar        14.0    86
#                                 People_using_at_least_basic_drinking_water_services_urban_percent_of_urban_population        14.0    87
#                                                                      Domestic_credit_to_private_sector_percent_of_GDP        13.6    88
#                                                                                      Forest_area_percent_of_land_area        13.0    89
#                                                                                   Compulsory_education_duration_years        12.8    90
#                                                                                          Region_Sub_to_Saharan_Africa        12.6    91
#                                                                 External_balance_on_goods_and_services_percent_of_GDP        12.4    92
#                                                                              International_tourism_number_of_arrivals        12.2    93
#                                Unemployment_youth_male_percent_of_male_labor_force_ages_15_to_24_modeled_ILO_estimate        12.2    94
#                                                      International_tourism_receipts_for_travel_items_current_USdollar        12.0    95
#                                                                          School_enrollment_primary_male_percent_gross        12.0    96
#                                                   Employment_to_population_ratio_15_male_percent_modeled_ILO_estimate        12.0    97
#                                     People_using_at_least_basic_sanitation_services_rural_percent_of_rural_population        12.0    98
#                                                                     Prevalence_of_anemia_among_pregnant_women_percent        11.8    99
#                                                Renewable_energy_consumption_percent_of_total_final_energy_consumption        11.8   100
#                                                                Ores_and_metals_imports_percent_of_merchandise_imports        11.8   101
#                                                  Carbon_dioxide_CO2_net_fluxes_from_LULUCF__to__Deforestation_Mt_CO2e        11.8   102
#                              Unemployment_youth_total_percent_of_total_labor_force_ages_15_to_24_modeled_ILO_estimate        11.4   103
#                                                           Fertilizer_consumption_kilograms_per_hectare_of_arable_land        11.2   104
#                                                                               School_enrollment_primary_percent_gross        11.2   105
#                                                                            Commercial_bank_branches_per_100000_adults        11.2   106
#                                           Out_to_of_to_pocket_expenditure_per_capita_PPP_current_international_dollar        11.0   107
#                                                                      Adjusted_savings_energy_depletion_percent_of_GNI        11.0   108
#                                                            Communications_computer_etc_percent_of_service_imports_BoP        11.0   109
#                                                                   Carbon_intensity_of_GDP_kg_CO2e_per_2021_PPP_dollar        11.0   110
#                                  Domestic_general_government_health_expenditure_percent_of_current_health_expenditure        10.4   111
#                                                                                                     Forest_area_sq_km        10.4   112
#                                                                          Rural_population_percent_of_total_population        10.4   113
#                                                         Immunization_measles_percent_of_children_ages_12_to_23_months        10.4   114
#                                                Unemployment_female_percent_of_female_labor_force_modeled_ILO_estimate        10.2   115
#                                                                    Methane_CH4_emissions_from_Building_Energy_Mt_CO2e        10.2   116
#                                                                           Fuel_exports_percent_of_merchandise_exports        10.2   117
#                                                     Carbon_intensity_of_GDP_kg_CO2e_per_constant_2021_USdollar_of_GDP        10.0   118
#                                      Computer_communications_and_other_services_percent_of_commercial_service_imports        10.0   119
#                                                    Nitrous_oxide_N2O_emissions_from_Fugitive_Emissions_Energy_Mt_CO2e         9.6   120
#                                                                      Automated_teller_machines_ATMs_per_100000_adults         9.6   121
#                                                  Unemployment_total_percent_of_total_labor_force_modeled_ILO_estimate         9.6   122
#                                                       Domestic_private_health_expenditure_per_capita_current_USdollar         9.4   123
#             Total_alcohol_consumption_per_capita_male_liters_of_pure_alcohol_projected_estimates_male_15_years_of_age         9.4   124
#                          Carbon_dioxide_CO2_net_fluxes_from_LULUCF__to__Total_excluding_non_to_tropical_fires_Mt_CO2e         9.2   125
#                                                               Population_ages_0_to_14_male_percent_of_male_population         9.2   126
#                                                                                           Forest_rents_percent_of_GDP         9.0   127
#                                    Labor_force_participation_rate_for_ages_15_to_24_male_percent_modeled_ILO_estimate         9.0   128
#                                                             Domestic_credit_to_private_sector_by_banks_percent_of_GDP         9.0   129
#                     Labor_force_participation_rate_male_percent_of_male_population_ages_15_to_64_modeled_ILO_estimate         9.0   130
#                                            Domestic_general_government_health_expenditure_per_capita_current_USdollar         8.8   131
#                                                                        Nitrous_oxide_N2O_emissions_from_Waste_Mt_CO2e         8.8   132
#                            Domestic_general_government_health_expenditure_per_capita_PPP_current_international_dollar         8.6   133
#                                             Domestic_private_health_expenditure_percent_of_current_health_expenditure         8.6   134
#         Share_of_youth_not_in_education_employment_or_training_total_percent_of_youth_population_modeled_ILO_estimate         8.6   135
#                                                           Out_to_of_to_pocket_expenditure_per_capita_current_USdollar         8.4   136
#                                                                   Inflation_GDP_deflator_linked_series_annual_percent         8.4   137
#                                                                  Population_ages_15_to_64_percent_of_total_population         8.4   138
#                       Total_alcohol_consumption_per_capita_liters_of_pure_alcohol_projected_estimates_15_years_of_age         8.2   139
#                                   Prevalence_of_anemia_among_women_of_reproductive_age_percent_of_women_ages_15_to_49         8.0   140
#     Share_of_youth_not_in_education_employment_or_training_male_percent_of_male_youth_population_modeled_ILO_estimate         8.0   141
#                                                                                              Oil_rents_percent_of_GDP         7.8   142
#                                     Carbon_dioxide_CO2_emissions_excluding_LULUCF_per_capita_t_CO2e_divided_by_capita         7.6   143
#                                                                            GOAL_15_Life_on_Land_5_year_moving_average         7.6   144
#                                                                 Women_Business_and_the_Law_Index_Score_scale_1_to_100         7.6   145
#                                                    PM25_air_pollution_mean_annual_exposure_micrograms_per_cubic_meter         7.4   146
#                                                          Population_ages_10_to_14_female_percent_of_female_population         7.4   147
#                                       Domestic_private_health_expenditure_per_capita_PPP_current_international_dollar         7.4   148
#                           Labor_force_participation_rate_male_percent_of_male_population_ages_15_modeled_ILO_estimate         7.4   149
#                                                  Employment_to_population_ratio_15_total_percent_modeled_ILO_estimate         7.2   150
#                                  Labor_force_participation_rate_for_ages_15_to_24_female_percent_modeled_ILO_estimate         7.2   151
#                                                           Agriculture_forestry_and_fishing_value_added_percent_of_GDP         7.0   152
#                   Labor_force_participation_rate_total_percent_of_total_population_ages_15_to_64_modeled_ILO_estimate         6.8   153
#                                                                               GOAL_1_No_Poverty_5_year_moving_average         6.8   154
#                                            Vulnerable_employment_male_percent_of_male_employment_modeled_ILO_estimate         6.8   155
# Share_of_youth_not_in_education_employment_or_training_female_percent_of_female_youth_population_modeled_ILO_estimate         6.8   156
#                                                                                             Coal_rents_percent_of_GDP         6.8   157
#                                                              Methane_CH4_emissions_from_Power_Industry_Energy_Mt_CO2e         6.8   158
#                                        Employment_to_population_ratio_ages_15_to_24_male_percent_modeled_ILO_estimate         6.6   159
#                                                          Methane_CH4_emissions_from_Fugitive_Emissions_Energy_Mt_CO2e         6.6   160
#                                      Employment_to_population_ratio_ages_15_to_24_female_percent_modeled_ILO_estimate         6.6   161
#                                                                          Urban_population_percent_of_total_population         6.4   162
#                                                        Nitrous_oxide_N2O_emissions_from_Power_Industry_Energy_Mt_CO2e         6.4   163
#                                                               Access_to_electricity_rural_percent_of_rural_population         6.2   164
#                                                                                                       Land_area_sq_km         6.2   165
#                                                  International_tourism_expenditures_for_travel_items_current_USdollar         6.2   166
#                 Labor_force_participation_rate_female_percent_of_female_population_ages_15_to_64_modeled_ILO_estimate         6.2   167
#                                                                          GNI_per_capita_Atlas_method_current_USdollar         6.0   168
#                                                           Population_ages_0_to_14_female_percent_of_female_population         6.0   169
#                            Unemployment_youth_female_percent_of_female_labor_force_ages_15_to_24_modeled_ILO_estimate         6.0   170
#                                                                   Population_ages_0_to_14_percent_of_total_population         6.0   171
#                                   Total_greenhouse_gas_emissions_per_capita_excluding_LULUCF_t_CO2e_divided_by_capita         6.0   172
#                                                              Nitrous_oxide_N2O_emissions_from_Building_Energy_Mt_CO2e         5.8   173
#                                                 Employment_to_population_ratio_15_female_percent_modeled_ILO_estimate         5.8   174
#                                                    Unemployment_male_percent_of_male_labor_force_modeled_ILO_estimate         5.8   175
#                                   Fluorinated_greenhouse_gases_F_to_gases_emissions_from_Industrial_Processes_Mt_CO2e         5.8   176
#         Total_alcohol_consumption_per_capita_female_liters_of_pure_alcohol_projected_estimates_female_15_years_of_age         5.6   177
#                                                         Nitrous_oxide_N2O_emissions_from_Industrial_Processes_Mt_CO2e         5.6   178
#                                                                                 GDP_per_capita_constant_2015_USdollar         5.6   179
#                                                 Self_to_employed_male_percent_of_male_employment_modeled_ILO_estimate         5.4   180
#                                                                                      Natural_gas_rents_percent_of_GDP         5.2   181
#                                       Employment_to_population_ratio_ages_15_to_24_total_percent_modeled_ILO_estimate         5.0   182
#                                                                       GNI_per_capita_PPP_current_international_dollar         4.8   183
#                                                       Methane_CH4_emissions_from_Industrial_Combustion_Energy_Mt_CO2e         4.8   184
#                                   Labor_force_participation_rate_for_ages_15_to_24_total_percent_modeled_ILO_estimate         4.8   185
#                       Labor_force_participation_rate_female_percent_of_female_population_ages_15_modeled_ILO_estimate         4.8   186
#                                                                                              Primary_education_pupils         4.8   187
#                                                                                   Preprimary_education_duration_years         4.6   188
#                                  Access_to_clean_fuels_and_technologies_for_cooking_urban_percent_of_urban_population         4.6   189
#                                                                              Methane_CH4_emissions_from_Waste_Mt_CO2e         4.6   190
#                         Labor_force_participation_rate_total_percent_of_total_population_ages_15_modeled_ILO_estimate         4.6   191
#                                             Self_to_employed_female_percent_of_female_employment_modeled_ILO_estimate         4.4   192
#                                        Vulnerable_employment_female_percent_of_female_employment_modeled_ILO_estimate         4.4   193
#                                                                          GOAL_13_Climate_Action_5_year_moving_average         4.4   194
#                                                                   Methane_CH4_emissions_from_Transport_Energy_Mt_CO2e         4.4   195
#                                                 Health_divided_by_Demographic_survey_Availability_score_over_10_years         4.4   196
#                                                               Total_greenhouse_gas_emissions_including_LULUCF_Mt_CO2e         4.2   197
#                                                                                         Cereal_production_metric_tons         4.2   198
#                                                 Nitrous_oxide_N2O_emissions_from_Industrial_Combustion_Energy_Mt_CO2e         4.2   199
#                                                     Exports_of_goods_services_and_primary_income_BoP_current_USdollar         4.0   200
#                                   Ratio_of_female_to_male_labor_force_participation_rate_percent_modeled_ILO_estimate         4.0   201
#                                                                                 Land_under_cereal_production_hectares         4.0   202
#                                                                      GDP_per_person_employed_constant_2021_PPP_dollar         4.0   203
#                                                       Carbon_dioxide_CO2_emissions_from_Power_Industry_Energy_Mt_CO2e         4.0   204
#                                                   Carbon_dioxide_CO2_emissions_from_Fugitive_Emissions_Energy_Mt_CO2e         4.0   205
#                                                                                                      Rural_population         4.0   206
#                                                                        Methane_CH4_emissions_from_Agriculture_Mt_CO2e         3.8   207
#                                  Access_to_clean_fuels_and_technologies_for_cooking_rural_percent_of_rural_population         3.8   208
#                                                            Nitrous_oxide_N2O_emissions_total_excluding_LULUCF_Mt_CO2e         3.6   209
#                                                             Nitrous_oxide_N2O_emissions_from_Transport_Energy_Mt_CO2e         3.6   210
#                                                             Carbon_dioxide_CO2_emissions_from_Building_Energy_Mt_CO2e         3.6   211
#                                                                       GDP_per_capita_PPP_current_international_dollar         3.4   212
#                                                Carbon_dioxide_CO2_emissions_from_Industrial_Combustion_Energy_Mt_CO2e         3.4   213
#                                              Access_to_clean_fuels_and_technologies_for_cooking_percent_of_population         3.4   214
#                                               Self_to_employed_total_percent_of_total_employment_modeled_ILO_estimate         3.2   215
#                                    Wage_and_salaried_workers_female_percent_of_female_employment_modeled_ILO_estimate         3.2   216
#                                                              Adjusted_net_national_income_per_capita_current_USdollar         3.0   217
#                                          Vulnerable_employment_total_percent_of_total_employment_modeled_ILO_estimate         3.0   218
#                                                            Carbon_dioxide_CO2_emissions_from_Transport_Energy_Mt_CO2e         3.0   219
#                                                                 GDP_per_capita_PPP_constant_2021_international_dollar         2.8   220
#                                                                                     GNI_Atlas_method_current_USdollar         2.8   221
#                                      Wage_and_salaried_workers_total_percent_of_total_employment_modeled_ILO_estimate         2.6   222
#                                                                                  GNI_PPP_current_international_dollar         2.6   223
#                                        Wage_and_salaried_workers_male_percent_of_male_employment_modeled_ILO_estimate         2.6   224
#                                                                  Final_consumption_expenditure_constant_2015_USdollar         2.6   225
#                                                                                                      Urban_population         2.6   226
#                                                           Carbon_dioxide_CO2_emissions_total_excluding_LULUCF_Mt_CO2e         2.4   227
#                                                        Carbon_dioxide_CO2_emissions_from_Industrial_Processes_Mt_CO2e         2.4   228
#                                                                                                     Labor_force_total         2.4   229
#                                               General_government_final_consumption_expenditure_constant_2015_USdollar         2.4   230
#                                                                   Labor_Force_Survey_Availability_score_over_10_years         2.2   231
#                                                                                                    Surface_area_sq_km         2.0   232
#                                                                  Nitrous_oxide_N2O_emissions_from_Agriculture_Mt_CO2e         2.0   233
#                                                                  Methane_CH4_emissions_total_excluding_LULUCF_Mt_CO2e         2.0   234
#                                                                                       GDP_per_capita_current_USdollar         1.8   235
#                                                                                  GDP_PPP_current_international_dollar         1.6   236
#                                                                         Adjusted_net_national_income_current_USdollar         1.6   237
#                                                                                                  GDP_current_USdollar         1.6   238
#                                                                            GDP_PPP_constant_2021_international_dollar         1.4   239
#                                                               Total_greenhouse_gas_emissions_excluding_LULUCF_Mt_CO2e         1.4   240
#                                                                                            GDP_constant_2015_USdollar         1.2   241
#                                                       Household_Survey_on_income_etc_Availability_score_over_10_years         1.2   242
#                                                                                        Population_ages_0_to_14_female         1.0   243
#                                                                                          Population_ages_0_to_14_male         0.6   244
#                                                                                          Region_East_Asia_and_Pacific         0.6   245
#                                                                                               Income_Group_Low_income         0.4   246
#                                                                                         Population_ages_0_to_14_total         0.2   247
#                                                                                        Region_Europe_and_Central_Asia         0.2   248
#                                                                                                  GNI_current_USdollar         0.2   249
#                                                                                    Region_Latin_America_and_Caribbean         0.0   250
#                                                                                   Region_Middle_East_and_North_Africa         0.0   251
#                                                                                                  Region_North_America         0.0   252
#                                                                                                     Region_South_Asia         0.0   253
#                                                                                              Income_Group_High_income         0.0   254
#                                                                                      Income_Group_Lower_middle_income         0.0   255
#                                                                                      Income_Group_Upper_middle_income         0.0   256
