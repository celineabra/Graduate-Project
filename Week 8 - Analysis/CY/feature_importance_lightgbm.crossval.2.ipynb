# %%
import pandas as pd
import os

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', None)
pd.set_option('display.expand_frame_repr', False)

# %%
import numpy as np
from sklearn.model_selection import KFold
from sklearn.impute import KNNImputer
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from lightgbm import LGBMRegressor
import re

# %%
folder_loc = 'F:/class/BANA 698/week 8'

file_list = [f for f in os.listdir(folder_loc) if os.path.isfile(os.path.join(folder_loc, f))]
for file in file_list:
    print(file)
# Out:
# #week 8 - y.lnk
# basic_stats_Group1DatasetCleaned.knn.standarddeviation.csv
# basic_stats_Group1DatasetRaw.onehotted.csv
# basic_stats_Group1Dataset_LCU_removed(except_exchange_rate).income.groups.regions.onehotted.csv
# correlations.all.csv
# correlations.all.to.life_expectancy_total.csv
# Group1DatasetCleaned.knn.standarddeviation.csv
# Group1DatasetRaw.csv
# Group1DatasetRaw.onehotted.csv
# Group1Dataset_LCU_removed(except_exchange_rate).income.groups.regions.csv
# Group1Dataset_LCU_removed(except_exchange_rate).income.groups.regions.onehotted.20percent.nans.dropped.csv
# Group1Dataset_LCU_removed(except_exchange_rate).income.groups.regions.onehotted.csv
# ImputationAndStandardize.ipynb
# README.md

# %%
file = 'Group1DatasetRaw.onehotted.csv'
df = pd.read_csv(os.path.join(folder_loc, file))

# %%
#for col in sorted(df.columns): print(col)

# %%
target = 'Life expectancy at birth, total (years)'

cols_to_exclude = [
    'Life expectancy at birth, total (years)',
    'Life expectancy at birth, female (years)',
    'Life expectancy at birth, male (years)',
    'CountryShortName',
    'Year'
]

# %%
#function to remove special chars and spaces from feature names bc lightgbm can't handle them
def clean_col_name(col_name):
    col_name = col_name.replace('-', ' to ')
    col_name = col_name.replace('=', 'equals')
    col_name = col_name.replace('/', ' divided by ')
    col_name = col_name.replace('%', 'percent')
    col_name = col_name.replace('$', 'dollars')
    col_name = col_name.replace('&', 'and')
    col_name = col_name.replace(' ', '_')
    col_name = re.sub(r'[^\w\s]', '', col_name)
    col_name = col_name.strip()
    return col_name

# %%
target = clean_col_name(target)
cols_to_exclude = [clean_col_name(col) for col in cols_to_exclude]
df.columns = df.columns.map(clean_col_name)

# %%
#print(target)

# %%
#for col in cols_to_exclude: print(col)

# %%
#for col in sorted(df.columns): print(col)

# %%
lgbm_params = {
    'boosting_type': 'gbdt',
    'class_weight': None,
    'colsample_bytree': 1.0,
    'importance_type': 'split',
    'learning_rate': 0.1,
    'max_depth': -1,
    'min_child_samples': 20,
    'min_child_weight': 0.001,
    'min_split_gain': 0.0,
    'n_estimators': 100,
    'n_jobs': -1,
    'num_leaves': 31,
    'objective': None,
    'random_state': 1,
    'reg_alpha': 0.0,
    'reg_lambda': 0.0,
    'subsample': 1.0,
    'subsample_for_bin': 200000,
    'subsample_freq': 0,
    'verbose': 0
}
#got default parameters from running:
#model = LGBMRegressor()
#model.get_params()

# %%
def lgbm_features(cols_to_exclude = cols_to_exclude, target = target, df = df, kfold_random_state = 1, n_neighbors = 5):
    X = df.drop(columns = cols_to_exclude)
    y = df[target]

    imputer = KNNImputer(n_neighbors = n_neighbors)
    model = LGBMRegressor(**lgbm_params)

    cv = KFold(n_splits=5, shuffle=True, random_state = kfold_random_state)

    mae_scores = []
    mse_scores = []
    r2_scores = []
    feature_importance_list = []

    for train_idx, val_idx in cv.split(X):
        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]
        
        X_train_imputed = imputer.fit_transform(X_train)
        X_val_imputed = imputer.transform(X_val)
        
        X_train_imputed = pd.DataFrame(X_train_imputed, columns=X_train.columns)
        X_val_imputed = pd.DataFrame(X_val_imputed, columns=X_val.columns)
        
        model.fit(X_train_imputed, y_train)
        y_pred = model.predict(X_val_imputed)
        
        mae = mean_absolute_error(y_val, y_pred)
        mse = mean_squared_error(y_val, y_pred)
        r2 = r2_score(y_val, y_pred)        
        mae_scores.append(mae)
        mse_scores.append(mse)
        r2_scores.append(r2)
        
        feature_importance_list.append(model.feature_importances_)


    avg_mae = np.mean(mae_scores)
    avg_mse = np.mean(mse_scores)
    avg_r2 = np.mean(r2_scores)

    print(f'Average MAE: {avg_mae:.4f}')
    print(f'Average MSE: {avg_mse:.4f}')
    print(f'Average R²: {avg_r2:.4f}')

    avg_feature_importance = np.mean(feature_importance_list, axis=0)
    feature_importance_df = pd.DataFrame({
        'Feature': X.columns,
        'Importance': avg_feature_importance
    })
    feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False).reset_index(drop=True)
    feature_importance_df['Rank'] = feature_importance_df.index + 1
    feature_importance_df = feature_importance_df[['Feature', 'Importance', 'Rank']]

    print('\nSorted Average Feature Importance:')
    print(feature_importance_df.to_string(index=False))

# %%
#first run, with all features
lgbm_features()
# Out:
# Average MAE: 0.2811
# Average MSE: 0.1954
# Average R²: 0.9972
#
# Sorted Average Feature Importance:
#                                                                                                               Feature  Importance  Rank
#                                                                    Mortality_rate_adult_female_per_1000_female_adults       205.4     1
#                                                                                      Death_rate_crude_per_1000_people       194.0     2
#                                                                        Mortality_rate_adult_male_per_1000_male_adults       153.2     3
#                                                          Population_ages_15_to_19_female_percent_of_female_population        35.0     4
#                                                                   Mortality_rate_under_to_5_male_per_1000_live_births        33.2     5
#                                                                               Import_unit_value_index_2015_equals_100        29.8     6
#                                                                   Final_consumption_expenditure_annual_percent_growth        29.2     7
#                                                                  Refugee_population_by_country_or_territory_of_origin        25.6     8
#                                                        Probability_of_dying_among_children_ages_5_to_9_years_per_1000        24.0     9
#                                                                    Livestock_production_index_2014_to_2016_equals_100        24.0    10
#                                                                          Mortality_rate_neonatal_per_1000_live_births        24.0    11
#                                                                         Crop_production_index_2014_to_2016_equals_100        22.8    12
#                                                                           Incidence_of_tuberculosis_per_100000_people        22.0    13
#                                                                 Travel_services_percent_of_commercial_service_imports        20.8    14
#                                                                               Export_unit_value_index_2015_equals_100        20.6    15
#                                                                                Pillar_3__to__Data_Products__to__Score        20.0    16
#                                                                          Claims_on_central_government_etc_percent_GDP        20.0    17
#                                                              Transport_services_percent_of_commercial_service_exports        19.6    18
#                                                                 Mortality_rate_under_to_5_female_per_1000_live_births        19.4    19
#                                                               Official_exchange_rate_LCU_per_USdollars_period_average        19.2    20
#                                                Insurance_and_financial_services_percent_of_commercial_service_exports        18.8    21
#                                                                          School_enrollment_primary_male_percent_gross        18.4    22
#                                                                                 Inflation_GDP_deflator_annual_percent        18.2    23
#                                                                                  GDP_per_capita_growth_annual_percent        18.2    24
#                                                              Tuberculosis_treatment_success_rate_percent_of_new_cases        18.2    25
#                                                     Proportion_of_seats_held_by_women_in_national_parliaments_percent        17.8    26
#                                                                                             GDP_growth_annual_percent        17.8    27
#                                                      Domestic_private_health_expenditure_per_capita_current_USdollars        17.8    28
#                                                               Current_health_expenditure_per_capita_current_USdollars        17.2    29
#                                                   GOAL_16_Peace_and_Justice_Strong_Institutions_5_year_moving_average        17.0    30
#                                    Prevalence_of_stunting_height_for_age_modeled_estimate_percent_of_children_under_5        17.0    31
#                                                                                     Pillar_1__to__Data_Use__to__Score        16.8    32
#                                                General_government_final_consumption_expenditure_annual_percent_growth        16.8    33
#                                                                                      Birth_rate_crude_per_1000_people        16.8    34
#                                                                      GOAL_10_Reduced_Inequality_5_year_moving_average        16.6    35
#                                                                                       Arable_land_hectares_per_person        16.6    36
#                                                       Renewable_internal_freshwater_resources_per_capita_cubic_meters        16.6    37
#                                                         Domestic_general_government_health_expenditure_percent_of_GDP        16.4    38
#                                                 Methane_CH4_emissions_total_excluding_LULUCF_percent_change_from_1990        16.4    39
#                                                                        Mortality_rate_under_to_5_per_1000_live_births        16.4    40
#                                                                  Population_ages_15_to_64_percent_of_total_population        16.4    41
#                                                              Transport_services_percent_of_commercial_service_imports        16.4    42
#                                                                          Exports_of_goods_and_services_percent_of_GDP        16.4    43
#                                  Domestic_general_government_health_expenditure_percent_of_current_health_expenditure        16.2    44
#                                                        GOAL_17_Partnerships_to_achieve_the_Goal_5_year_moving_average        16.2    45
#                                                                           Fuel_imports_percent_of_merchandise_imports        16.0    46
#                                                              Population_ages_15_to_19_male_percent_of_male_population        15.8    47
#                                                                                Urban_population_growth_annual_percent        15.8    48
#                                                                                Total_fisheries_production_metric_tons        15.6    49
#                                                                 Travel_services_percent_of_commercial_service_exports        15.6    50
#                                                                                GDP_per_capita_constant_2015_USdollars        15.0    51
#                                                                                Rural_population_growth_annual_percent        14.8    52
#                                                                                      Forest_area_percent_of_land_area        14.8    53
#                                                                                            Broad_money_percent_of_GDP        14.6    54
#                                                                         Food_production_index_2014_to_2016_equals_100        14.6    55
#                                                         Adolescent_fertility_rate_births_per_1000_women_ages_15_to_19        14.4    56
#                                                    PM25_air_pollution_mean_annual_exposure_micrograms_per_cubic_meter        14.2    57
#                                                     International_tourism_receipts_for_travel_items_current_USdollars        14.2    58
#                                       Agriculture_forestry_and_fishing_value_added_per_worker_constant_2015_USdollars        14.0    59
#                     Labor_force_participation_rate_male_percent_of_male_population_ages_15_to_64_modeled_ILO_estimate        14.0    60
#                                                                                                         Net_migration        13.8    61
#                                                                 External_balance_on_goods_and_services_percent_of_GDP        13.8    62
#                                                                     Mortality_rate_infant_female_per_1000_live_births        13.6    63
#                                                                      Domestic_credit_to_private_sector_percent_of_GDP        13.4    64
#                                                                 Adjusted_savings_carbon_dioxide_damage_percent_of_GNI        13.2    65
#                                                  GOAL_12_Responsible_Consumption_and_Production_5_year_moving_average        13.2    66
#                                                               People_practicing_open_defecation_percent_of_population        13.2    67
#                                                                                   Compulsory_education_duration_years        13.0    68
#                                                                               School_enrollment_primary_percent_gross        13.0    69
#                                Unemployment_youth_male_percent_of_male_labor_force_ages_15_to_24_modeled_ILO_estimate        13.0    70
#                                                    Carbon_intensity_of_GDP_kg_CO2e_per_constant_2021_USdollars_of_GDP        12.8    71
#                                                                                      Arable_land_percent_of_land_area        12.8    72
#                                                                            Commercial_bank_branches_per_100000_adults        12.8    73
#                                                                               Permanent_cropland_percent_of_land_area        12.6    74
#                                           Nitrous_oxide_N2O_emissions_total_excluding_LULUCF_percent_change_from_1990        12.4    75
#                                                   Probability_of_dying_among_adolescents_ages_15_to_19_years_per_1000        12.2    76
#                                          Carbon_dioxide_CO2_emissions_total_excluding_LULUCF_percent_change_from_1990        12.2    77
#                                                                                Agricultural_land_percent_of_land_area        12.0    78
#                                                                  Refugee_population_by_country_or_territory_of_asylum        12.0    79
#                                                                        School_enrollment_primary_female_percent_gross        12.0    80
#                                    Labor_force_participation_rate_for_ages_15_to_24_male_percent_modeled_ILO_estimate        11.8    81
#                                                            Communications_computer_etc_percent_of_service_exports_BoP        11.8    82
#                                                   Employment_to_population_ratio_15_male_percent_modeled_ILO_estimate        11.6    83
#                                                                 Adjusted_savings_education_expenditure_percent_of_GNI        11.6    84
#                                                 Employment_to_population_ratio_15_female_percent_modeled_ILO_estimate        11.4    85
#                                                         Probability_of_dying_among_youth_ages_20_to_24_years_per_1000        11.2    86
#                                            Energy_intensity_level_of_primary_energy_MJ_divided_by_dollars2017_PPP_GDP        11.2    87
#                                                          Population_ages_10_to_14_female_percent_of_female_population        11.2    88
#                                                                      Automated_teller_machines_ATMs_per_100000_adults        11.2    89
#                                                    Carbon_dioxide_CO2_net_fluxes_from_LULUCF__to__Forest_Land_Mt_CO2e        11.0    90
#                                                                          Total_natural_resources_rents_percent_of_GDP        11.0    91
#                                       Prevalence_of_anemia_among_non_to_pregnant_women_percent_of_women_ages_15_to_49        11.0    92
#                                                                  Carbon_intensity_of_GDP_kg_CO2e_per_2021_PPP_dollars        11.0    93
#                                      Domestic_private_health_expenditure_per_capita_PPP_current_international_dollars        10.8    94
#                          Carbon_dioxide_CO2_net_fluxes_from_LULUCF__to__Total_excluding_non_to_tropical_fires_Mt_CO2e        10.8    95
#                                                                               Lifetime_risk_of_maternal_death_percent        10.8    96
#                                   Ratio_of_female_to_male_labor_force_participation_rate_percent_modeled_ILO_estimate        10.8    97
#                                                                              International_tourism_number_of_arrivals        10.8    98
#                                                                           Fuel_exports_percent_of_merchandise_exports        10.8    99
#                                                                          Rural_population_percent_of_total_population        10.6   100
#                                                             Immunization_DPT_percent_of_children_ages_12_to_23_months        10.6   101
#                                                 Out_to_of_to_pocket_expenditure_percent_of_current_health_expenditure        10.4   102
#                                                            Communications_computer_etc_percent_of_service_imports_BoP        10.4   103
#                              Unemployment_youth_total_percent_of_total_labor_force_ages_15_to_24_modeled_ILO_estimate        10.2   104
#                                                              Population_ages_10_to_14_male_percent_of_male_population        10.2   105
#                                                                            Mortality_rate_infant_per_1000_live_births        10.0   106
#                                                                       Labor_force_female_percent_of_total_labor_force        10.0   107
#                                              Total_greenhouse_gas_emissions_excluding_LULUCF_percent_change_from_1990        10.0   108
#                                                 International_tourism_expenditures_for_travel_items_current_USdollars         9.8   109
#                                             People_using_at_least_basic_drinking_water_services_percent_of_population         9.8   110
#                                                Unemployment_female_percent_of_female_labor_force_modeled_ILO_estimate         9.6   111
#                                           Prevalence_of_anemia_among_children_percent_of_children_ages_6_to_59_months         9.6   112
#                                                      Maternal_mortality_ratio_modeled_estimate_per_100000_live_births         9.6   113
#         Share_of_youth_not_in_education_employment_or_training_total_percent_of_youth_population_modeled_ILO_estimate         9.4   114
#                                                                                           Forest_rents_percent_of_GDP         9.4   115
#                                                                      Adjusted_savings_energy_depletion_percent_of_GNI         9.4   116
#                                      Computer_communications_and_other_services_percent_of_commercial_service_exports         9.4   117
#                                                                             Current_health_expenditure_percent_of_GDP         9.4   118
#                                                Insurance_and_financial_services_percent_of_commercial_service_imports         9.4   119
#                                                                    Methane_CH4_emissions_from_Building_Energy_Mt_CO2e         9.4   120
#                                                                              Capture_fisheries_production_metric_tons         9.2   121
#                                                                Ores_and_metals_imports_percent_of_merchandise_imports         9.2   122
#                   Labor_force_participation_rate_total_percent_of_total_population_ages_15_to_64_modeled_ILO_estimate         9.2   123
#                           Labor_force_participation_rate_male_percent_of_male_population_ages_15_modeled_ILO_estimate         9.0   124
#     Share_of_youth_not_in_education_employment_or_training_male_percent_of_male_youth_population_modeled_ILO_estimate         9.0   125
#                                      Employment_to_population_ratio_ages_15_to_24_female_percent_modeled_ILO_estimate         9.0   126
#                                                                                    Aquaculture_production_metric_tons         8.8   127
#                                                 Self_to_employed_male_percent_of_male_employment_modeled_ILO_estimate         8.8   128
#                                                                       Mortality_rate_infant_male_per_1000_live_births         8.8   129
# Share_of_youth_not_in_education_employment_or_training_female_percent_of_female_youth_population_modeled_ILO_estimate         8.8   130
#                                                                 Women_Business_and_the_Law_Index_Score_scale_1_to_100         8.6   131
#                                                Renewable_energy_consumption_percent_of_total_final_energy_consumption         8.4   132
#                                                                   Inflation_GDP_deflator_linked_series_annual_percent         8.4   133
#                                                 Prevalence_of_overweight_modeled_estimate_percent_of_children_under_5         8.4   134
#                                                           Population_ages_0_to_14_female_percent_of_female_population         8.4   135
#                                                    Unemployment_male_percent_of_male_labor_force_modeled_ILO_estimate         8.2   136
#                                   Labor_force_participation_rate_for_ages_15_to_24_total_percent_modeled_ILO_estimate         8.2   137
#                                     People_using_at_least_basic_sanitation_services_rural_percent_of_rural_population         8.2   138
#                                                 People_using_at_least_basic_sanitation_services_percent_of_population         8.2   139
#                                             Domestic_private_health_expenditure_percent_of_current_health_expenditure         8.2   140
#                                                                    Tuberculosis_case_detection_rate_percent_all_forms         8.0   141
#                                          Out_to_of_to_pocket_expenditure_per_capita_PPP_current_international_dollars         8.0   142
#                   Water_productivity_total_constant_2015_USdollars_GDP_per_cubic_meter_of_total_freshwater_withdrawal         8.0   143
#                                     People_using_at_least_basic_sanitation_services_urban_percent_of_urban_population         7.8   144
#                                 People_using_at_least_basic_drinking_water_services_urban_percent_of_urban_population         7.8   145
#                                                           Fertilizer_consumption_kilograms_per_hectare_of_arable_land         7.8   146
#                                                    Renewable_internal_freshwater_resources_total_billion_cubic_meters         7.6   147
#                                      Computer_communications_and_other_services_percent_of_commercial_service_imports         7.6   148
#                                                          Out_to_of_to_pocket_expenditure_per_capita_current_USdollars         7.6   149
#                                                      GOAL_11_Sustainable_Cities_and_Communities_5_year_moving_average         7.6   150
#                                             Self_to_employed_female_percent_of_female_employment_modeled_ILO_estimate         7.4   151
#                                                  Carbon_dioxide_CO2_net_fluxes_from_LULUCF__to__Deforestation_Mt_CO2e         7.4   152
#                       Total_alcohol_consumption_per_capita_liters_of_pure_alcohol_projected_estimates_15_years_of_age         7.2   153
#                                                                     Prevalence_of_anemia_among_pregnant_women_percent         7.2   154
#                                       Employment_to_population_ratio_ages_15_to_24_total_percent_modeled_ILO_estimate         7.2   155
#                                        Employment_to_population_ratio_ages_15_to_24_male_percent_modeled_ILO_estimate         7.0   156
#                                                                  Prevalence_of_undernourishment_percent_of_population         6.8   157
#                                                                                                      Urban_population         6.8   158
#                                                               Access_to_electricity_rural_percent_of_rural_population         6.8   159
#                                                                           Access_to_electricity_percent_of_population         6.8   160
#                                                                                          Mineral_rents_percent_of_GDP         6.8   161
#                                        Vulnerable_employment_female_percent_of_female_employment_modeled_ILO_estimate         6.6   162
#                                                    Nitrous_oxide_N2O_emissions_from_Fugitive_Emissions_Energy_Mt_CO2e         6.6   163
#                                                  Employment_to_population_ratio_15_total_percent_modeled_ILO_estimate         6.4   164
#                                                                                         Cereal_production_metric_tons         6.4   165
#                                                   Probability_of_dying_among_adolescents_ages_10_to_14_years_per_1000         6.4   166
#                                                           Agriculture_forestry_and_fishing_value_added_percent_of_GDP         6.4   167
#                                   Fluorinated_greenhouse_gases_F_to_gases_emissions_from_Industrial_Processes_Mt_CO2e         6.2   168
#                                               Current_health_expenditure_per_capita_PPP_current_international_dollars         6.2   169
#                                                        Nitrous_oxide_N2O_emissions_from_Power_Industry_Energy_Mt_CO2e         6.0   170
#                         Labor_force_participation_rate_total_percent_of_total_population_ages_15_modeled_ILO_estimate         6.0   171
#                                                  Unemployment_total_percent_of_total_labor_force_modeled_ILO_estimate         5.8   172
#                                               Self_to_employed_total_percent_of_total_employment_modeled_ILO_estimate         5.6   173
#                                                                  Monetary_Sector_credit_to_private_sector_percent_GDP         5.6   174
#                                                           Lifetime_risk_of_maternal_death_1_in_rate_varies_by_country         5.6   175
#                                                              Nitrous_oxide_N2O_emissions_from_Building_Energy_Mt_CO2e         5.6   176
#                            Unemployment_youth_female_percent_of_female_labor_force_ages_15_to_24_modeled_ILO_estimate         5.6   177
#                                   Total_greenhouse_gas_emissions_per_capita_excluding_LULUCF_t_CO2e_divided_by_capita         5.6   178
#                                                                                              Oil_rents_percent_of_GDP         5.6   179
#                           Domestic_general_government_health_expenditure_per_capita_PPP_current_international_dollars         5.4   180
#                       Labor_force_participation_rate_female_percent_of_female_population_ages_15_modeled_ILO_estimate         5.4   181
#                                                                                                       Land_area_sq_km         5.2   182
#                                                                          Urban_population_percent_of_total_population         5.2   183
#                                           Domestic_general_government_health_expenditure_per_capita_current_USdollars         5.2   184
#         Total_alcohol_consumption_per_capita_female_liters_of_pure_alcohol_projected_estimates_female_15_years_of_age         5.2   185
#                                                       Carbon_dioxide_CO2_emissions_from_Power_Industry_Energy_Mt_CO2e         5.2   186
#                                                                      Population_density_people_per_sq_km_of_land_area         5.0   187
#                                                                            GOAL_15_Life_on_Land_5_year_moving_average         5.0   188
#                                                         Immunization_measles_percent_of_children_ages_12_to_23_months         4.8   189
#                                  Labor_force_participation_rate_for_ages_15_to_24_female_percent_modeled_ILO_estimate         4.6   190
#                                                                                      Natural_gas_rents_percent_of_GDP         4.6   191
#                                                                                             Number_of_maternal_deaths         4.6   192
#                                                          Methane_CH4_emissions_from_Fugitive_Emissions_Energy_Mt_CO2e         4.6   193
#                 Labor_force_participation_rate_female_percent_of_female_population_ages_15_to_64_modeled_ILO_estimate         4.4   194
#                                                              Methane_CH4_emissions_from_Power_Industry_Energy_Mt_CO2e         4.4   195
#                                                         Nitrous_oxide_N2O_emissions_from_Industrial_Processes_Mt_CO2e         4.4   196
#             Total_alcohol_consumption_per_capita_male_liters_of_pure_alcohol_projected_estimates_male_15_years_of_age         4.4   197
#                                                                                    Region_Latin_America_and_Caribbean         4.4   198
#                                   Prevalence_of_anemia_among_women_of_reproductive_age_percent_of_women_ages_15_to_49         4.2   199
#                                            Vulnerable_employment_male_percent_of_male_employment_modeled_ILO_estimate         4.2   200
#                                                    Exports_of_goods_services_and_primary_income_BoP_current_USdollars         4.2   201
#                                                             Carbon_dioxide_CO2_emissions_from_Building_Energy_Mt_CO2e         4.2   202
#                                                                     GDP_per_person_employed_constant_2021_PPP_dollars         4.2   203
#                                                                                             Coal_rents_percent_of_GDP         4.0   204
#                                                                      GNI_per_capita_PPP_current_international_dollars         4.0   205
#                                                                   Population_ages_0_to_14_percent_of_total_population         3.8   206
#                                                                         GNI_per_capita_Atlas_method_current_USdollars         3.8   207
#                                  Access_to_clean_fuels_and_technologies_for_cooking_urban_percent_of_urban_population         3.8   208
#                                                       Methane_CH4_emissions_from_Industrial_Combustion_Energy_Mt_CO2e         3.8   209
#                                                                                              Primary_education_pupils         3.8   210
#                                                                  Nitrous_oxide_N2O_emissions_from_Agriculture_Mt_CO2e         3.6   211
#                                                                                             Number_of_neonatal_deaths         3.6   212
#                                                                        Methane_CH4_emissions_from_Agriculture_Mt_CO2e         3.6   213
#                                                               Population_ages_0_to_14_male_percent_of_male_population         3.6   214
#                                                                              Methane_CH4_emissions_from_Waste_Mt_CO2e         3.6   215
#                                                               Access_to_electricity_urban_percent_of_urban_population         3.4   216
#                                                                                 Land_under_cereal_production_hectares         3.4   217
#                                                                                               Number_of_infant_deaths         3.4   218
#                                                               Total_greenhouse_gas_emissions_including_LULUCF_Mt_CO2e         3.2   219
#                                                                                  Number_of_deaths_ages_20_to_24_years         3.2   220
#                                                                                                     Forest_area_sq_km         3.0   221
#                                                   Carbon_dioxide_CO2_emissions_from_Fugitive_Emissions_Energy_Mt_CO2e         3.0   222
#                                                                                    Number_of_deaths_ages_5_to_9_years         3.0   223
#                                      Wage_and_salaried_workers_total_percent_of_total_employment_modeled_ILO_estimate         3.0   224
#                                                                        Nitrous_oxide_N2O_emissions_from_Waste_Mt_CO2e         3.0   225
#                                        Wage_and_salaried_workers_male_percent_of_male_employment_modeled_ILO_estimate         2.8   226
#                                                                                   Preprimary_education_duration_years         2.8   227
#                                                Carbon_dioxide_CO2_emissions_from_Industrial_Combustion_Energy_Mt_CO2e         2.8   228
#                                                                   Methane_CH4_emissions_from_Transport_Energy_Mt_CO2e         2.8   229
#                                                                                        Population_ages_0_to_14_female         2.8   230
#                                                            Carbon_dioxide_CO2_emissions_from_Transport_Energy_Mt_CO2e         2.6   231
#                                                 Health_divided_by_Demographic_survey_Availability_score_over_10_years         2.6   232
#                                                             Nitrous_oxide_N2O_emissions_from_Transport_Energy_Mt_CO2e         2.6   233
#                                              Access_to_clean_fuels_and_technologies_for_cooking_percent_of_population         2.6   234
#                                  Access_to_clean_fuels_and_technologies_for_cooking_rural_percent_of_rural_population         2.6   235
#                                              General_government_final_consumption_expenditure_constant_2015_USdollars         2.4   236
#                                                                  Methane_CH4_emissions_total_excluding_LULUCF_Mt_CO2e         2.4   237
#                                                                               GOAL_1_No_Poverty_5_year_moving_average         2.4   238
#                                                        Carbon_dioxide_CO2_emissions_from_Industrial_Processes_Mt_CO2e         2.4   239
#                                                                                 GNI_PPP_current_international_dollars         2.4   240
#                                                                          GOAL_13_Climate_Action_5_year_moving_average         2.2   241
#                                                                                  Number_of_deaths_ages_15_to_19_years         2.2   242
#                                     Carbon_dioxide_CO2_emissions_excluding_LULUCF_per_capita_t_CO2e_divided_by_capita         2.2   243
#                                                             Adjusted_net_national_income_per_capita_current_USdollars         2.0   244
#                                                                                  Number_of_deaths_ages_10_to_14_years         2.0   245
#                                          Vulnerable_employment_total_percent_of_total_employment_modeled_ILO_estimate         2.0   246
#                                                                 Final_consumption_expenditure_constant_2015_USdollars         1.8   247
#                                                                                                      Rural_population         1.8   248
#                                                 Nitrous_oxide_N2O_emissions_from_Industrial_Combustion_Energy_Mt_CO2e         1.8   249
#                                                            Nitrous_oxide_N2O_emissions_total_excluding_LULUCF_Mt_CO2e         1.8   250
#                                                                                    GNI_Atlas_method_current_USdollars         1.8   251
#                                                                        Adjusted_net_national_income_current_USdollars         1.8   252
#                                                             Domestic_credit_to_private_sector_by_banks_percent_of_GDP         1.8   253
#                                                                                      GDP_per_capita_current_USdollars         1.8   254
#                                                                GDP_per_capita_PPP_constant_2021_international_dollars         1.6   255
#                                                                                           GDP_constant_2015_USdollars         1.6   256
#                                                                      GDP_per_capita_PPP_current_international_dollars         1.6   257
#                                                                                        Number_of_under_to_five_deaths         1.6   258
#                                                           Carbon_dioxide_CO2_emissions_total_excluding_LULUCF_Mt_CO2e         1.6   259
#                                                                           GDP_PPP_constant_2021_international_dollars         1.4   260
#                                    Wage_and_salaried_workers_female_percent_of_female_employment_modeled_ILO_estimate         1.2   261
#                                                                                                     Labor_force_total         1.2   262
#                                                                                                    Surface_area_sq_km         1.2   263
#                                                                                          Population_ages_0_to_14_male         1.2   264
#                                                               Total_greenhouse_gas_emissions_excluding_LULUCF_Mt_CO2e         1.0   265
#                                                                                        Region_Europe_and_Central_Asia         0.8   266
#                                                                                                 GNI_current_USdollars         0.8   267
#                                                       Household_Survey_on_income_etc_Availability_score_over_10_years         0.8   268
#                                                                                 GDP_PPP_current_international_dollars         0.6   269
#                                                                                      Income_Group_Lower_middle_income         0.6   270
#                                                                                                 GDP_current_USdollars         0.6   271
#                                                                   Labor_Force_Survey_Availability_score_over_10_years         0.4   272
#                                                                                         Population_ages_0_to_14_total         0.2   273
#                                                                                   Region_Middle_East_and_North_Africa         0.0   274
#                                                                                                  Region_North_America         0.0   275
#                                                                                                     Region_South_Asia         0.0   276
#                                                                                          Region_Sub_to_Saharan_Africa         0.0   277
#                                                                                              Income_Group_High_income         0.0   278
#                                                                                               Income_Group_Low_income         0.0   279
#                                                                                          Region_East_Asia_and_Pacific         0.0   280
#                                                                                      Income_Group_Upper_middle_income         0.0   281

# %%
mortality_cols_to_exclude = [
    'Death rate, crude (per 1,000 people)',
    'Lifetime risk of maternal death (%)',
    'Lifetime risk of maternal death (1 in: rate varies by country)',
    'Maternal mortality ratio (modeled estimate, per 100,000 live births)',
    'Number of maternal deaths',
    'Number of deaths ages 5-9 years',
    'Number of under-five deaths',
    'Number of infant deaths',
    'Number of deaths ages 10-14 years',
    'Number of neonatal deaths',
    'Number of deaths ages 15-19 years',
    'Number of deaths ages 20-24 years',
    'Mortality rate, adult, female (per 1,000 female adults)',
    'Mortality rate, infant, male (per 1,000 live births)',
    'Mortality rate, infant (per 1,000 live births)',
    'Mortality rate, adult, male (per 1,000 male adults)',
    'Mortality rate, infant, female (per 1,000 live births)',
    'Mortality rate, under-5, male (per 1,000 live births)',
    'Mortality rate, under-5 (per 1,000 live births)',
    'Mortality rate, under-5, female (per 1,000 live births)',
    'Mortality rate, neonatal (per 1,000 live births)',
    'Probability of dying among youth ages 20-24 years (per 1,000)',
    'Probability of dying among adolescents ages 15-19 years (per 1,000)',
    'Probability of dying among children ages 5-9 years (per 1,000)',
    'Probability of dying among adolescents ages 10-14 years (per 1,000)'   
]
mortality_cols_to_exclude = [clean_col_name(col) for col in mortality_cols_to_exclude]

# %%
#second run, but dropping redundant features
addl_cols_to_exclude = [
    #features in column "Feature_1" from correlation_to_all_lister.ipynb
    'Total greenhouse gas emissions including LULUCF (Mt CO2e)',
    'GDP, PPP (constant 2021 international $)',
    'General government final consumption expenditure (constant 2015 US$)',
    'GNI, PPP (current international $)',
    'Carbon dioxide (CO2) emissions (total) excluding LULUCF (Mt CO2e)',
    'GDP, PPP (current international $)',
    'Cereal production (metric tons)',
    'Methane (CH4) emissions (total) excluding LULUCF (Mt CO2e)',
    'Life expectancy at birth, female (years)',
    'Adjusted net national income (current US$)',
    'Fluorinated greenhouse gases (F-gases) emissions from Industrial Processes (Mt CO2e)',
    'Primary education, pupils',
    'Final consumption expenditure (constant 2015 US$)',
    'Adjusted net national income per capita (current US$)',
    'Number of deaths ages 15-19 years',
    'Self-employed, female (% of female employment) (modeled ILO estimate)',
    'Nitrous oxide (N2O) emissions (total) excluding LULUCF (Mt CO2e)',
    'Self-employed, male (% of male employment) (modeled ILO estimate)',
    'Mortality rate, infant (per 1,000 live births)',
    'GDP (constant 2015 US$)',
    'Life expectancy at birth, total (years)',
    'Carbon dioxide (CO2) emissions from Power Industry (Energy) (Mt CO2e)',
    'Carbon dioxide (CO2) emissions from Industrial Combustion (Energy) (Mt CO2e)',
    'Land under cereal production (hectares)',
    'GDP per capita, PPP (constant 2021 international $)',
    'Methane (CH4) emissions from Industrial Combustion (Energy) (Mt CO2e)',
    'Self-employed, total (% of total employment) (modeled ILO estimate)',
    'Carbon dioxide (CO2) emissions from Fugitive Emissions (Energy) (Mt CO2e)',
    'Carbon dioxide (CO2) emissions from Building (Energy) (Mt CO2e)',
    'Number of deaths ages 10-14 years',
    'Methane (CH4) emissions from Agriculture (Mt CO2e)',
    'Number of deaths ages 20-24 years',
    'GNI, Atlas method (current US$)',
    'Prevalence of anemia among children (% of children ages 6-59 months)',
    'Nitrous oxide (N2O) emissions from Industrial Combustion (Energy) (Mt CO2e)',
    'Rural population',
    'Nitrous oxide (N2O) emissions from Agriculture (Mt CO2e)',
    'GNI per capita, Atlas method (current US$)',
    'Methane (CH4) emissions from Waste (Mt CO2e)',
    'Mortality rate, infant, female (per 1,000 live births)',
    'Mortality rate, infant, male (per 1,000 live births)',
    'Vulnerable employment, female (% of female employment) (modeled ILO estimate)',
    'Nitrous oxide (N2O) emissions from Power Industry (Energy) (Mt CO2e)',
    'GNI (current US$)',
    'GDP per capita (current US$)',
    'GDP per capita (constant 2015 US$)',
    'Population ages 0-14 (% of total population)',
    'Vulnerable employment, male (% of male employment) (modeled ILO estimate)',
    'Carbon dioxide (CO2) emissions from Industrial Processes (Mt CO2e)',
    'Birth rate, crude (per 1,000 people)',
    'Mortality rate, under-5 (per 1,000 live births)',
    'Access to electricity (% of population)',
    'Life expectancy at birth, male (years)',
    'Mortality rate, neonatal (per 1,000 live births)',
    'Nitrous oxide (N2O) emissions from Building (Energy) (Mt CO2e)',
    'Number of deaths ages 5-9 years',
    'Nitrous oxide (N2O) emissions from Waste (Mt CO2e)',
    'Exports of goods, services and primary income (BoP, current US$)',
    'Access to electricity, rural (% of rural population)',
    'Aquaculture production (metric tons)',
    'Vulnerable employment, total (% of total employment) (modeled ILO estimate)',
    'Current health expenditure per capita (current US$)',
    'Population ages 0-14, female (% of female population)',
    'Total fisheries production (metric tons)',
    'Mortality rate, under-5, female (per 1,000 live births)',
    'GDP (current US$)',
    'Unemployment, male (% of male labor force) (modeled ILO estimate)',
    'Unemployment, female (% of female labor force) (modeled ILO estimate)',
    'Out-of-pocket expenditure per capita (current US$)',
    'People using at least basic sanitation services, rural (% of rural population)',
    'Number of infant deaths',
    'Population ages 0-14, male',
    'Population ages 0-14, male (% of male population)',
    'School enrollment, primary, female (% gross)',
    'Population ages 10-14, female (% of female population)',
    'Population ages 10-14, male (% of male population)',
    'Mortality rate, under-5, male (per 1,000 live births)',
    'Population ages 0-14, female',
    'Access to clean fuels and technologies for cooking (% of population)',
    'Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)',
    'GDP per capita, PPP (current international $)',
    'Employment to population ratio, ages 15-24, female (%) (modeled ILO estimate)',
    'Domestic credit to private sector (% of GDP)',
    'Employment to population ratio, ages 15-24, male (%) (modeled ILO estimate)',
    'Methane (CH4) emissions from Power Industry (Energy) (Mt CO2e)',
    'Unemployment, total (% of total labor force) (modeled ILO estimate)',
    'Current health expenditure per capita, PPP (current international $)',
    'Forest area (sq. km)',
    'GNI per capita, PPP (current international $)',
    'Employment to population ratio, 15+, female (%) (modeled ILO estimate)',
    'Carbon dioxide (CO2) emissions from Transport (Energy) (Mt CO2e)',
    'Wage and salaried workers, female (% of female employment) (modeled ILO estimate)',
    'Prevalence of anemia among non-pregnant women (% of women ages 15-49)',
    'Maternal mortality ratio (modeled estimate, per 100,000 live births)',
    'Methane (CH4) emissions from Building (Energy) (Mt CO2e)',
    'Methane (CH4) emissions from Fugitive Emissions (Energy) (Mt CO2e)',
    'Prevalence of anemia among pregnant women (%)',
    'Urban population',
    'School enrollment, primary, male (% gross)',
    'Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate)',
    'Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate)',
    'Probability of dying among adolescents ages 10-14 years (per 1,000)',
    'Rural population (% of total population)',
    'Total greenhouse gas emissions excluding LULUCF (Mt CO2e)',
    'Total alcohol consumption per capita, female (liters of pure alcohol, projected estimates, female 15+ years of age)',
    'Share of youth not in education, employment or training, female (% of female youth population) (modeled ILO estimate)',
    'Probability of dying among adolescents ages 15-19 years (per 1,000)',
    'Methane (CH4) emissions from Transport (Energy) (Mt CO2e)',
    'Population ages 15-19, female (% of female population)',
    'People using at least basic sanitation services, urban (% of urban population)',
    'Carbon dioxide (CO2) emissions excluding LULUCF per capita (t CO2e/capita)',
    'Communications, computer, etc. (% of service exports, BoP)',
    'Communications, computer, etc. (% of service imports, BoP)',
    'Domestic general government health expenditure per capita (current US$)',
    'Domestic private health expenditure per capita (current US$)',
    'Employment to population ratio, 15+, male (%) (modeled ILO estimate)',
    'Employment to population ratio, 15+, total (%) (modeled ILO estimate)',
    'Employment to population ratio, ages 15-24, total (%) (modeled ILO estimate)',
    'GDP growth (annual %)',
    'Immunization, DPT (% of children ages 12-23 months)',
    'Inflation, GDP deflator (annual %)',
    'Labor force participation rate for ages 15-24, female (%) (modeled ILO estimate)',
    'Labor force participation rate for ages 15-24, male (%) (modeled ILO estimate)',
    'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)',
    'Labor force participation rate, female (% of female population ages 15-64) (modeled ILO estimate)',
    'Labor force, female (% of total labor force)',
    'Land area (sq. km)',
    'Lifetime risk of maternal death (%)',
    'Monetary Sector credit to private sector (% GDP)',
    'Mortality rate, adult, female (per 1,000 female adults)',
    'Nitrous oxide (N2O) emissions from Industrial Processes (Mt CO2e)',
    'Number of maternal deaths',
    'Number of neonatal deaths',
    'Out-of-pocket expenditure (% of current health expenditure)',
    'People using at least basic drinking water services, urban (% of urban population)',
    'Wage and salaried workers, male (% of male employment) (modeled ILO estimate)'
]
addl_cols_to_exclude = [clean_col_name(col) for col in addl_cols_to_exclude]
new_cols_to_exclude = cols_to_exclude + mortality_cols_to_exclude + addl_cols_to_exclude
new_cols_to_exclude = list(set(new_cols_to_exclude))
lgbm_features(new_cols_to_exclude)
# Out:
# Average MAE: 0.5654
# Average MSE: 0.8252
# Average R²: 0.9881
#
# Sorted Average Feature Importance:
#                                                                                                           Feature  Importance  Rank
#                                                     Adolescent_fertility_rate_births_per_1000_women_ages_15_to_19        67.0     1
#                                             People_using_at_least_basic_sanitation_services_percent_of_population        54.2     2
#                                                                       Incidence_of_tuberculosis_per_100000_people        52.0     3
#                                                                           Import_unit_value_index_2015_equals_100        51.2     4
#                                                                Tuberculosis_case_detection_rate_percent_all_forms        45.0     5
#                                            Insurance_and_financial_services_percent_of_commercial_service_imports        43.8     6
#                                                                            Pillar_3__to__Data_Products__to__Score        43.2     7
#                                                              Prevalence_of_undernourishment_percent_of_population        41.6     8
#                                                             Travel_services_percent_of_commercial_service_imports        41.6     9
#                                                                                   Arable_land_hectares_per_person        41.6    10
#                                                               Inflation_GDP_deflator_linked_series_annual_percent        41.6    11
#                                                           Access_to_electricity_urban_percent_of_urban_population        40.8    12
#                                                                              GDP_per_capita_growth_annual_percent        40.2    13
#                                        Energy_intensity_level_of_primary_energy_MJ_divided_by_dollars2017_PPP_GDP        37.8    14
#                       Domestic_general_government_health_expenditure_per_capita_PPP_current_international_dollars        35.6    15
#                                                               Final_consumption_expenditure_annual_percent_growth        35.4    16
#                                                                Livestock_production_index_2014_to_2016_equals_100        35.2    17
#                                                                                 Pillar_1__to__Data_Use__to__Score        34.6    18
#                               Prevalence_of_anemia_among_women_of_reproductive_age_percent_of_women_ages_15_to_49        33.8    19
#                                                         Domestic_credit_to_private_sector_by_banks_percent_of_GDP        32.6    20
#                                                                           Permanent_cropland_percent_of_land_area        32.4    21
#                                                       Fertilizer_consumption_kilograms_per_hectare_of_arable_land        32.2    22
#                                          Total_greenhouse_gas_emissions_excluding_LULUCF_percent_change_from_1990        32.0    23
#                                                              Refugee_population_by_country_or_territory_of_asylum        31.6    24
#                                Prevalence_of_stunting_height_for_age_modeled_estimate_percent_of_children_under_5        30.8    25
#                                                             Adjusted_savings_education_expenditure_percent_of_GNI        30.6    26
#                                                                                        Broad_money_percent_of_GDP        30.2    27
#                                                                            Agricultural_land_percent_of_land_area        30.0    28
#                                                          Population_ages_15_to_19_male_percent_of_male_population        30.0    29
#                                                             Travel_services_percent_of_commercial_service_exports        29.4    30
#                                                          Transport_services_percent_of_commercial_service_imports        29.4    31
#                                                              Refugee_population_by_country_or_territory_of_origin        29.0    32
#                                                                           School_enrollment_primary_percent_gross        28.8    33
#                                             Prevalence_of_overweight_modeled_estimate_percent_of_children_under_5        28.2    34
#                                                                      Claims_on_central_government_etc_percent_GDP        28.0    35
#                                                 International_tourism_receipts_for_travel_items_current_USdollars        27.8    36
#                                                           Official_exchange_rate_LCU_per_USdollars_period_average        27.6    37
#                                                          Transport_services_percent_of_commercial_service_exports        27.6    38
#                                                    GOAL_17_Partnerships_to_achieve_the_Goal_5_year_moving_average        27.4    39
#                                                                     Crop_production_index_2014_to_2016_equals_100        27.4    40
#                                                                          Capture_fisheries_production_metric_tons        27.2    41
#                                                                     Food_production_index_2014_to_2016_equals_100        27.0    42
#                                                                                  Arable_land_percent_of_land_area        26.8    43
#                                                                      Total_natural_resources_rents_percent_of_GDP        26.6    44
#                                                                           Export_unit_value_index_2015_equals_100        26.6    45
#                                                Renewable_internal_freshwater_resources_total_billion_cubic_meters        26.4    46
#         Total_alcohol_consumption_per_capita_male_liters_of_pure_alcohol_projected_estimates_male_15_years_of_age        26.0    47
#                                      Carbon_dioxide_CO2_emissions_total_excluding_LULUCF_percent_change_from_1990        26.0    48
#                          Unemployment_youth_total_percent_of_total_labor_force_ages_15_to_24_modeled_ILO_estimate        25.4    49
#                                             Methane_CH4_emissions_total_excluding_LULUCF_percent_change_from_1990        24.8    50
#                                       Nitrous_oxide_N2O_emissions_total_excluding_LULUCF_percent_change_from_1990        24.8    51
#                                                 Proportion_of_seats_held_by_women_in_national_parliaments_percent        24.4    52
#                                               GOAL_16_Peace_and_Justice_Strong_Institutions_5_year_moving_average        24.4    53
#                                            Insurance_and_financial_services_percent_of_commercial_service_exports        24.2    54
#                                                              Population_ages_15_to_64_percent_of_total_population        24.2    55
#                                                                            Rural_population_growth_annual_percent        23.8    56
#                                                                            Urban_population_growth_annual_percent        23.6    57
#               Water_productivity_total_constant_2015_USdollars_GDP_per_cubic_meter_of_total_freshwater_withdrawal        23.4    58
#                                              GOAL_12_Responsible_Consumption_and_Production_5_year_moving_average        23.2    59
#                                                             Adjusted_savings_carbon_dioxide_damage_percent_of_GNI        23.2    60
#                                                     Immunization_measles_percent_of_children_ages_12_to_23_months        23.0    61
#                                                Carbon_intensity_of_GDP_kg_CO2e_per_constant_2021_USdollars_of_GDP        22.8    62
#                                                                                                     Net_migration        22.6    63
#                                                           People_practicing_open_defecation_percent_of_population        22.4    64
#                                                          Tuberculosis_treatment_success_rate_percent_of_new_cases        21.8    65
#                                                                  GOAL_10_Reduced_Inequality_5_year_moving_average        21.4    66
#                                  Computer_communications_and_other_services_percent_of_commercial_service_exports        21.2    67
#                                         People_using_at_least_basic_drinking_water_services_percent_of_population        21.2    68
#                                                                         Current_health_expenditure_percent_of_GDP        21.0    69
#                                   Agriculture_forestry_and_fishing_value_added_per_worker_constant_2015_USdollars        20.8    70
#                                  Wage_and_salaried_workers_total_percent_of_total_employment_modeled_ILO_estimate        20.8    71
#                                                                  Population_density_people_per_sq_km_of_land_area        20.0    72
#                 Labor_force_participation_rate_male_percent_of_male_population_ages_15_to_64_modeled_ILO_estimate        20.0    73
#                                                   Renewable_internal_freshwater_resources_per_capita_cubic_meters        19.8    74
#                                                             External_balance_on_goods_and_services_percent_of_GDP        19.2    75
#                                                     Domestic_general_government_health_expenditure_percent_of_GDP        19.2    76
#                                                                      Exports_of_goods_and_services_percent_of_GDP        19.0    77
#                                                Carbon_dioxide_CO2_net_fluxes_from_LULUCF__to__Forest_Land_Mt_CO2e        18.8    78
#                                                Nitrous_oxide_N2O_emissions_from_Fugitive_Emissions_Energy_Mt_CO2e        18.8    79
#                               Labor_force_participation_rate_for_ages_15_to_24_total_percent_modeled_ILO_estimate        18.4    80
#                                                                       Fuel_imports_percent_of_merchandise_imports        18.2    81
#                                                                       Fuel_exports_percent_of_merchandise_exports        17.8    82
#                                                                      Urban_population_percent_of_total_population        17.8    83
#                                                                 GDP_per_person_employed_constant_2021_PPP_dollars        17.0    84
#                                  Domestic_private_health_expenditure_per_capita_PPP_current_international_dollars        17.0    85
#               Labor_force_participation_rate_total_percent_of_total_population_ages_15_to_64_modeled_ILO_estimate        16.6    86
#                                            General_government_final_consumption_expenditure_annual_percent_growth        16.6    87
#                              Domestic_general_government_health_expenditure_percent_of_current_health_expenditure        16.6    88
#                                                              Carbon_intensity_of_GDP_kg_CO2e_per_2021_PPP_dollars        16.4    89
#                                      Out_to_of_to_pocket_expenditure_per_capita_PPP_current_international_dollars        16.4    90
#                                                                        Commercial_bank_branches_per_100000_adults        16.2    91
#                                                                               Compulsory_education_duration_years        16.2    92
#                                              Carbon_dioxide_CO2_net_fluxes_from_LULUCF__to__Deforestation_Mt_CO2e        16.0    93
#                                                            Ores_and_metals_imports_percent_of_merchandise_imports        15.6    94
#                                                                                  Forest_area_percent_of_land_area        15.0    95
#                                                                  Adjusted_savings_energy_depletion_percent_of_GNI        14.8    96
#                                                  GOAL_11_Sustainable_Cities_and_Communities_5_year_moving_average        14.6    97
#                                                PM25_air_pollution_mean_annual_exposure_micrograms_per_cubic_meter        14.4    98
#                       Labor_force_participation_rate_male_percent_of_male_population_ages_15_modeled_ILO_estimate        14.4    99
#                                             International_tourism_expenditures_for_travel_items_current_USdollars        14.4   100
#                                  Computer_communications_and_other_services_percent_of_commercial_service_imports        14.2   101
#                                                                                      Mineral_rents_percent_of_GDP        14.0   102
#                                                                          International_tourism_number_of_arrivals        14.0   103
#                                                       Agriculture_forestry_and_fishing_value_added_percent_of_GDP        13.8   104
#                                                                  Automated_teller_machines_ATMs_per_100000_adults        13.8   105
# Share_of_youth_not_in_education_employment_or_training_male_percent_of_male_youth_population_modeled_ILO_estimate        13.8   106
#                      Carbon_dioxide_CO2_net_fluxes_from_LULUCF__to__Total_excluding_non_to_tropical_fires_Mt_CO2e        13.4   107
#                               Ratio_of_female_to_male_labor_force_participation_rate_percent_modeled_ILO_estimate        13.2   108
#                                            Renewable_energy_consumption_percent_of_total_final_energy_consumption        12.8   109
#                                                                                      Region_Sub_to_Saharan_Africa        12.4   110
#                     Labor_force_participation_rate_total_percent_of_total_population_ages_15_modeled_ILO_estimate        12.4   111
#                                                                                       Forest_rents_percent_of_GDP        12.2   112
#                                         Domestic_private_health_expenditure_percent_of_current_health_expenditure        11.6   113
#                                                                           GOAL_1_No_Poverty_5_year_moving_average        11.6   114
#                                                                                         Coal_rents_percent_of_GDP        11.4   115
#     Share_of_youth_not_in_education_employment_or_training_total_percent_of_youth_population_modeled_ILO_estimate        11.4   116
#                                                             Women_Business_and_the_Law_Index_Score_scale_1_to_100        11.0   117
#                               Total_greenhouse_gas_emissions_per_capita_excluding_LULUCF_t_CO2e_divided_by_capita        10.0   118
#                                                                                                 Labor_force_total        10.0   119
#                                                                                                Surface_area_sq_km         9.8   120
#                                                         Nitrous_oxide_N2O_emissions_from_Transport_Energy_Mt_CO2e         9.8   121
#                                                                                          Oil_rents_percent_of_GDP         9.4   122
#                                                                                  Natural_gas_rents_percent_of_GDP         9.4   123
#                              Access_to_clean_fuels_and_technologies_for_cooking_urban_percent_of_urban_population         7.6   124
#                              Access_to_clean_fuels_and_technologies_for_cooking_rural_percent_of_rural_population         7.4   125
#                                             Health_divided_by_Demographic_survey_Availability_score_over_10_years         6.6   126
#                                                                               Preprimary_education_duration_years         5.6   127
#                                                                      GOAL_13_Climate_Action_5_year_moving_average         5.2   128
#                                                                        GOAL_15_Life_on_Land_5_year_moving_average         4.8   129
#                                                                                     Population_ages_0_to_14_total         4.4   130
#                                                               Labor_Force_Survey_Availability_score_over_10_years         4.0   131
#                                                   Household_Survey_on_income_etc_Availability_score_over_10_years         1.6   132
#                                                                                      Region_East_Asia_and_Pacific         1.0   133
#                                                                                  Income_Group_Lower_middle_income         0.6   134
#                                                                                  Income_Group_Upper_middle_income         0.4   135
#                                                                                    Region_Europe_and_Central_Asia         0.0   136
#                                                                                Region_Latin_America_and_Caribbean         0.0   137
#                                                                               Region_Middle_East_and_North_Africa         0.0   138
#                                                                                              Region_North_America         0.0   139
#                                                                                                 Region_South_Asia         0.0   140
#                                                                                          Income_Group_High_income         0.0   141
#                                                                                           Income_Group_Low_income         0.0   142

# %%
#third run, but dropping different redundant features
addl_cols_to_exclude = [
    #features in column "Feature_2" from correlation_to_all_lister.ipynb
    'Total greenhouse gas emissions excluding LULUCF (Mt CO2e)',
    'Nitrous oxide (N2O) emissions from Waste (Mt CO2e)',
    'Urban population',
    'Labor force, total',
    'Nitrous oxide (N2O) emissions from Transport (Energy) (Mt CO2e)',
    'Methane (CH4) emissions from Power Industry (Energy) (Mt CO2e)',
    'Carbon dioxide (CO2) emissions from Power Industry (Energy) (Mt CO2e)',
    'Carbon dioxide (CO2) emissions from Building (Energy) (Mt CO2e)',
    'GDP (current US$)',
    'GNI (current US$)',
    'Mortality rate, under-5, male (per 1,000 live births)',
    'Nitrous oxide (N2O) emissions from Power Industry (Energy) (Mt CO2e)',
    'GNI, Atlas method (current US$)',
    'Nitrous oxide (N2O) emissions from Agriculture (Mt CO2e)',
    'Nitrous oxide (N2O) emissions (total) excluding LULUCF (Mt CO2e)',
    'Wage and salaried workers, total (% of total employment) (modeled ILO estimate)',
    'Carbon dioxide (CO2) emissions from Transport (Energy) (Mt CO2e)',
    'Nitrous oxide (N2O) emissions from Building (Energy) (Mt CO2e)',
    'Nitrous oxide (N2O) emissions from Industrial Combustion (Energy) (Mt CO2e)',
    'Mortality rate, under-5 (per 1,000 live births)',
    'Carbon dioxide (CO2) emissions (total) excluding LULUCF (Mt CO2e)',
    'Wage and salaried workers, male (% of male employment) (modeled ILO estimate)',
    'Wage and salaried workers, female (% of female employment) (modeled ILO estimate)',
    'Methane (CH4) emissions from Waste (Mt CO2e)',
    'GDP (constant 2015 US$)',
    'Domestic general government health expenditure per capita, PPP (current international $)',
    'Mortality rate, under-5, female (per 1,000 live births)',
    'Population ages 0-14, total',
    'Probability of dying among children ages 5-9 years (per 1,000)',
    'Number of under-five deaths',
    'Number of neonatal deaths',
    'Population ages 0-14, male',
    'Vulnerable employment, total (% of total employment) (modeled ILO estimate)',
    'Carbon dioxide (CO2) emissions from Industrial Processes (Mt CO2e)',
    'Mortality rate, infant, male (per 1,000 live births)',
    'Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate)',
    'GDP per capita (current US$)',
    'Cereal production (metric tons)',
    'Current health expenditure per capita (current US$)',
    'Methane (CH4) emissions from Fugitive Emissions (Energy) (Mt CO2e)',
    'Domestic general government health expenditure per capita (current US$)',
    'Methane (CH4) emissions (total) excluding LULUCF (Mt CO2e)',
    'Mortality rate, neonatal (per 1,000 live births)',
    'Methane (CH4) emissions from Industrial Combustion (Energy) (Mt CO2e)',
    'GDP per person employed (constant 2021 PPP $)',
    'Number of deaths ages 20-24 years',
    'Population ages 10-14, female (% of female population)',
    'Vulnerable employment, male (% of male employment) (modeled ILO estimate)',
    'Carbon dioxide (CO2) emissions from Industrial Combustion (Energy) (Mt CO2e)',
    'Current health expenditure per capita, PPP (current international $)',
    'Total greenhouse gas emissions including LULUCF (Mt CO2e)',
    'Fluorinated greenhouse gases (F-gases) emissions from Industrial Processes (Mt CO2e)',
    'Population ages 10-14, male (% of male population)',
    'GDP, PPP (current international $)',
    'Population ages 0-14, female',
    'People using at least basic sanitation services (% of population)',
    'Number of infant deaths',
    'Mortality rate, adult, male (per 1,000 male adults)',
    'Number of deaths ages 5-9 years',
    'Prevalence of anemia among women of reproductive age (% of women ages 15-49)',
    'Population ages 0-14, male (% of male population)',
    'Probability of dying among adolescents ages 10-14 years (per 1,000)',
    'Vulnerable employment, female (% of female employment) (modeled ILO estimate)',
    'Mortality rate, infant, female (per 1,000 live births)',
    'Mortality rate, infant (per 1,000 live births)',
    'Mortality rate, adult, female (per 1,000 female adults)',
    'GDP, PPP (constant 2021 international $)',
    'GNI per capita, Atlas method (current US$)',
    'Labor force participation rate for ages 15-24, total (%) (modeled ILO estimate)',
    'GNI, PPP (current international $)',
    'Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate)',
    'Population ages 15-19, male (% of male population)',
    'People using at least basic sanitation services, urban (% of urban population)',
    'Population ages 0-14, female (% of female population)',
    'Adjusted net national income (current US$)',
    'Carbon dioxide (CO2) emissions from Fugitive Emissions (Energy) (Mt CO2e)',
    'Domestic credit to private sector by banks (% of GDP)',
    'GDP per capita, PPP (current international $)',
    'Prevalence of anemia among pregnant women (%)',
    'Unemployment, total (% of total labor force) (modeled ILO estimate)',
    'GDP per capita (constant 2015 US$)',
    'People using at least basic drinking water services (% of population)',
    'School enrollment, primary (% gross)',
    'Self-employed, total (% of total employment) (modeled ILO estimate)',
    'Surface area (sq. km)',
    'Total alcohol consumption per capita, male (liters of pure alcohol, projected estimates, male 15+ years of age)',
    'Employment to population ratio, ages 15-24, total (%) (modeled ILO estimate)',
    'Population ages 15-19, female (% of female population)',
    'Labor force participation rate, female (% of female population ages 15-64) (modeled ILO estimate)',
    'Land under cereal production (hectares)',
    'Methane (CH4) emissions from Transport (Energy) (Mt CO2e)',
    'Nitrous oxide (N2O) emissions from Industrial Processes (Mt CO2e)',
    'Life expectancy at birth, total (years)',
    'Out-of-pocket expenditure per capita, PPP (current international $)',
    'Total alcohol consumption per capita, female (liters of pure alcohol, projected estimates, female 15+ years of age)',
    'Life expectancy at birth, male (years)',
    'Total fisheries production (metric tons)',
    'Domestic private health expenditure per capita, PPP (current international $)',
    'Domestic private health expenditure (% of current health expenditure)',
    'Total greenhouse gas emissions per capita excluding LULUCF (t CO2e/capita)',
    'Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate)',
    'Land area (sq. km)',
    'Maternal mortality ratio (modeled estimate, per 100,000 live births)',
    'Methane (CH4) emissions from Agriculture (Mt CO2e)',
    'Computer, communications and other services (% of commercial service imports)',
    'Urban population (% of total population)',
    'Computer, communications and other services (% of commercial service exports)',
    'Monetary Sector credit to private sector (% GDP)',
    'Access to electricity, urban (% of urban population)',
    'Access to electricity (% of population)',
    'Share of youth not in education, employment or training, total (% of youth population) (modeled ILO estimate)',
    'School enrollment, primary, male (% gross)',
    'Self-employed, male (% of male employment) (modeled ILO estimate)',
    'GDP per capita growth (annual %)',
    'Inflation, GDP deflator: linked series (annual %)',
    'Population ages 0-14 (% of total population)',
    'GNI per capita, PPP (current international $)',
    'Labor force participation rate for ages 15-24, female (%) (modeled ILO estimate)',
    'Labor force participation rate for ages 15-24, male (%) (modeled ILO estimate)',
    'Number of deaths ages 15-19 years',
    'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)',
    'GDP per capita, PPP (constant 2021 international $)',
    'Access to clean fuels and technologies for cooking, urban (% of urban population)',
    'Immunization, measles (% of children ages 12-23 months)',
    'Prevalence of anemia among non-pregnant women (% of women ages 15-49)',
    'Labor force participation rate, male (% of male population ages 15+) (modeled ILO estimate)',
    'Final consumption expenditure (constant 2015 US$)',
    'Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate)',
    'Probability of dying among youth ages 20-24 years (per 1,000)',
    'Ratio of female to male labor force participation rate (%) (modeled ILO estimate)',
    'Rural population',
    'Labor force participation rate, total (% of total population ages 15-64) (modeled ILO estimate)',
    'Access to clean fuels and technologies for cooking, rural (% of rural population)'
]
addl_cols_to_exclude = [clean_col_name(col) for col in addl_cols_to_exclude]
new_cols_to_exclude = cols_to_exclude + mortality_cols_to_exclude + addl_cols_to_exclude
new_cols_to_exclude = list(set(new_cols_to_exclude))
lgbm_features(new_cols_to_exclude)
# Out:
# Average MAE: 0.5546
# Average MSE: 0.7768
# Average R²: 0.9888
#
# Sorted Average Feature Importance:
#                                                                                                               Feature  Importance  Rank
#                                                                           Incidence_of_tuberculosis_per_100000_people        72.2     1
#                                                                                      Birth_rate_crude_per_1000_people        65.8     2
#                                                                               Import_unit_value_index_2015_equals_100        50.8     3
#                                                         Adolescent_fertility_rate_births_per_1000_women_ages_15_to_19        50.4     4
#                                                                                       Arable_land_hectares_per_person        48.0     5
#                                                                                     Pillar_1__to__Data_Use__to__Score        46.4     6
#                                                                  Prevalence_of_undernourishment_percent_of_population        46.4     7
#                                                                                Pillar_3__to__Data_Products__to__Score        45.6     8
#                                                Insurance_and_financial_services_percent_of_commercial_service_imports        45.0     9
#                                           Prevalence_of_anemia_among_children_percent_of_children_ages_6_to_59_months        41.0    10
#                                                                   Final_consumption_expenditure_annual_percent_growth        38.8    11
#                                                                       Labor_force_female_percent_of_total_labor_force        38.0    12
#                                                                                             GDP_growth_annual_percent        38.0    13
#                                                                    Livestock_production_index_2014_to_2016_equals_100        37.8    14
#                                                                 Travel_services_percent_of_commercial_service_imports        37.6    15
#                                            Energy_intensity_level_of_primary_energy_MJ_divided_by_dollars2017_PPP_GDP        35.2    16
#                                                                          Rural_population_percent_of_total_population        33.0    17
#                                                                    Tuberculosis_case_detection_rate_percent_all_forms        32.4    18
#                                                 Methane_CH4_emissions_total_excluding_LULUCF_percent_change_from_1990        31.6    19
#                                                             Immunization_DPT_percent_of_children_ages_12_to_23_months        31.4    20
#                                                                  Refugee_population_by_country_or_territory_of_asylum        31.2    21
#                                                      Domestic_private_health_expenditure_per_capita_current_USdollars        30.6    22
#                                     People_using_at_least_basic_sanitation_services_rural_percent_of_rural_population        30.6    23
#                                    Prevalence_of_stunting_height_for_age_modeled_estimate_percent_of_children_under_5        30.4    24
#                                                        GOAL_17_Partnerships_to_achieve_the_Goal_5_year_moving_average        30.2    25
#                                                    Renewable_internal_freshwater_resources_total_billion_cubic_meters        29.6    26
#                                                                          Claims_on_central_government_etc_percent_GDP        28.6    27
#                                                 Out_to_of_to_pocket_expenditure_percent_of_current_health_expenditure        28.6    28
#                                                                                 Inflation_GDP_deflator_annual_percent        28.6    29
#                                                              Transport_services_percent_of_commercial_service_imports        28.4    30
#                                          Carbon_dioxide_CO2_emissions_total_excluding_LULUCF_percent_change_from_1990        28.0    31
#                                                                               Export_unit_value_index_2015_equals_100        27.6    32
#                                                               Official_exchange_rate_LCU_per_USdollars_period_average        27.4    33
#                                                                  Refugee_population_by_country_or_territory_of_origin        27.2    34
#                                                                                            Broad_money_percent_of_GDP        27.0    35
#                                                                                Rural_population_growth_annual_percent        27.0    36
#                                                                               Permanent_cropland_percent_of_land_area        26.8    37
#                     Labor_force_participation_rate_male_percent_of_male_population_ages_15_to_64_modeled_ILO_estimate        26.2    38
#                                                                                Agricultural_land_percent_of_land_area        26.0    39
#                                              Total_greenhouse_gas_emissions_excluding_LULUCF_percent_change_from_1990        25.8    40
#                                                   GOAL_16_Peace_and_Justice_Strong_Institutions_5_year_moving_average        25.4    41
#                                                                         Crop_production_index_2014_to_2016_equals_100        25.4    42
#                                                               People_practicing_open_defecation_percent_of_population        25.0    43
#                                                                 Travel_services_percent_of_commercial_service_exports        25.0    44
#                                                                      Domestic_credit_to_private_sector_percent_of_GDP        24.8    45
#                                                                        School_enrollment_primary_female_percent_gross        24.8    46
#                                                                Ores_and_metals_imports_percent_of_merchandise_imports        24.8    47
#                                                              Tuberculosis_treatment_success_rate_percent_of_new_cases        24.8    48
#                                                                         Food_production_index_2014_to_2016_equals_100        24.4    49
#                                                              Transport_services_percent_of_commercial_service_exports        24.4    50
#                                                     Proportion_of_seats_held_by_women_in_national_parliaments_percent        24.0    51
#                                                                                Urban_population_growth_annual_percent        24.0    52
#                                  Domestic_general_government_health_expenditure_percent_of_current_health_expenditure        24.0    53
#                                                          Out_to_of_to_pocket_expenditure_per_capita_current_USdollars        23.0    54
#                       Total_alcohol_consumption_per_capita_liters_of_pure_alcohol_projected_estimates_15_years_of_age        23.0    55
#                                                Unemployment_female_percent_of_female_labor_force_modeled_ILO_estimate        23.0    56
#                                       Agriculture_forestry_and_fishing_value_added_per_worker_constant_2015_USdollars        22.8    57
#                                           Nitrous_oxide_N2O_emissions_total_excluding_LULUCF_percent_change_from_1990        22.8    58
#                   Water_productivity_total_constant_2015_USdollars_GDP_per_cubic_meter_of_total_freshwater_withdrawal        22.2    59
#                                                                 Adjusted_savings_carbon_dioxide_damage_percent_of_GNI        22.0    60
#                                                                                                         Net_migration        22.0    61
#                                                         Domestic_general_government_health_expenditure_percent_of_GDP        21.6    62
#                                                       Renewable_internal_freshwater_resources_per_capita_cubic_meters        21.6    63
#                                                            Communications_computer_etc_percent_of_service_exports_BoP        21.4    64
#                                                    Carbon_dioxide_CO2_net_fluxes_from_LULUCF__to__Forest_Land_Mt_CO2e        21.2    65
#                                                                            Commercial_bank_branches_per_100000_adults        21.2    66
#                                                                                      Arable_land_percent_of_land_area        21.0    67
#                                                   Employment_to_population_ratio_15_male_percent_modeled_ILO_estimate        20.8    68
#                                                               Access_to_electricity_rural_percent_of_rural_population        20.6    69
#                                                                                    Aquaculture_production_metric_tons        20.6    70
#                                                                              Capture_fisheries_production_metric_tons        20.6    71
#                                                General_government_final_consumption_expenditure_annual_percent_growth        20.4    72
#                                                    Nitrous_oxide_N2O_emissions_from_Fugitive_Emissions_Energy_Mt_CO2e        20.2    73
#                                                 Prevalence_of_overweight_modeled_estimate_percent_of_children_under_5        19.8    74
#                                                Insurance_and_financial_services_percent_of_commercial_service_exports        19.8    75
#                                                                                   Compulsory_education_duration_years        19.4    76
#                                                                 External_balance_on_goods_and_services_percent_of_GDP        19.0    77
#                                                Renewable_energy_consumption_percent_of_total_final_energy_consumption        19.0    78
#                                                                 Adjusted_savings_education_expenditure_percent_of_GNI        18.8    79
#                                                  GOAL_12_Responsible_Consumption_and_Production_5_year_moving_average        18.8    80
#                                 People_using_at_least_basic_drinking_water_services_urban_percent_of_urban_population        18.8    81
#                                                                      Population_density_people_per_sq_km_of_land_area        18.6    82
#                                                     International_tourism_receipts_for_travel_items_current_USdollars        18.2    83
#                                                                    Methane_CH4_emissions_from_Building_Energy_Mt_CO2e        17.8    84
#                                                                              International_tourism_number_of_arrivals        17.6    85
#                                                                          Total_natural_resources_rents_percent_of_GDP        17.6    86
#                                                                           Fuel_imports_percent_of_merchandise_imports        17.4    87
#                                                                      GOAL_10_Reduced_Inequality_5_year_moving_average        17.2    88
#                                                    Carbon_intensity_of_GDP_kg_CO2e_per_constant_2021_USdollars_of_GDP        17.2    89
#                                                                                                     Forest_area_sq_km        17.0    90
#                                                           Fertilizer_consumption_kilograms_per_hectare_of_arable_land        16.8    91
#                                                    Unemployment_male_percent_of_male_labor_force_modeled_ILO_estimate        16.4    92
#                                                                  Population_ages_15_to_64_percent_of_total_population        16.2    93
#                                                                                           Forest_rents_percent_of_GDP        16.2    94
#                                                            Communications_computer_etc_percent_of_service_imports_BoP        16.0    95
#                                                                      Automated_teller_machines_ATMs_per_100000_adults        15.8    96
#     Share_of_youth_not_in_education_employment_or_training_male_percent_of_male_youth_population_modeled_ILO_estimate        15.6    97
#                                                                                          Region_Sub_to_Saharan_Africa        15.2    98
#                                                             Adjusted_net_national_income_per_capita_current_USdollars        15.0    99
#                                                                             Current_health_expenditure_percent_of_GDP        15.0   100
#                                                 International_tourism_expenditures_for_travel_items_current_USdollars        14.6   101
#                                                                      Adjusted_savings_energy_depletion_percent_of_GNI        14.0   102
#                                                                          Exports_of_goods_and_services_percent_of_GDP        13.8   103
#                                                           Agriculture_forestry_and_fishing_value_added_percent_of_GDP        13.8   104
#                                                                  Carbon_intensity_of_GDP_kg_CO2e_per_2021_PPP_dollars        13.6   105
#                                                  Employment_to_population_ratio_15_total_percent_modeled_ILO_estimate        13.4   106
#                                                  Carbon_dioxide_CO2_net_fluxes_from_LULUCF__to__Deforestation_Mt_CO2e        13.2   107
#                                                      GOAL_11_Sustainable_Cities_and_Communities_5_year_moving_average        13.2   108
# Share_of_youth_not_in_education_employment_or_training_female_percent_of_female_youth_population_modeled_ILO_estimate        13.0   109
#                                                    PM25_air_pollution_mean_annual_exposure_micrograms_per_cubic_meter        12.8   110
#                                                                               GOAL_1_No_Poverty_5_year_moving_average        12.6   111
#                                                 Employment_to_population_ratio_15_female_percent_modeled_ILO_estimate        12.6   112
#                                        Employment_to_population_ratio_ages_15_to_24_male_percent_modeled_ILO_estimate        12.4   113
#                          Carbon_dioxide_CO2_net_fluxes_from_LULUCF__to__Total_excluding_non_to_tropical_fires_Mt_CO2e        12.2   114
#                                                                                          Mineral_rents_percent_of_GDP        11.6   115
#                                             Self_to_employed_female_percent_of_female_employment_modeled_ILO_estimate        11.2   116
#                                                                                      Forest_area_percent_of_land_area        10.8   117
#                                                                                              Primary_education_pupils        10.0   118
#                                                                 Women_Business_and_the_Law_Index_Score_scale_1_to_100         9.8   119
#                                      Employment_to_population_ratio_ages_15_to_24_female_percent_modeled_ILO_estimate         9.8   120
#                                                                                             Coal_rents_percent_of_GDP         9.4   121
#                                              General_government_final_consumption_expenditure_constant_2015_USdollars         9.2   122
#                                                    Exports_of_goods_services_and_primary_income_BoP_current_USdollars         9.2   123
#                                                                                              Oil_rents_percent_of_GDP         8.8   124
#                                                                                      Natural_gas_rents_percent_of_GDP         8.0   125
#                                                                           Fuel_exports_percent_of_merchandise_exports         8.0   126
#                                     Carbon_dioxide_CO2_emissions_excluding_LULUCF_per_capita_t_CO2e_divided_by_capita         7.6   127
#                                                                                   Preprimary_education_duration_years         6.0   128
#                                                                            GOAL_15_Life_on_Land_5_year_moving_average         5.8   129
#                                              Access_to_clean_fuels_and_technologies_for_cooking_percent_of_population         5.8   130
#                                                 Health_divided_by_Demographic_survey_Availability_score_over_10_years         5.0   131
#                                                                   Labor_Force_Survey_Availability_score_over_10_years         4.0   132
#                                                                          GOAL_13_Climate_Action_5_year_moving_average         3.2   133
#                                                                                    Region_Latin_America_and_Caribbean         3.0   134
#                                                       Household_Survey_on_income_etc_Availability_score_over_10_years         1.6   135
#                                                                                          Region_East_Asia_and_Pacific         0.8   136
#                                                                                               Income_Group_Low_income         0.8   137
#                                                                                      Income_Group_Upper_middle_income         0.6   138
#                                                                                      Income_Group_Lower_middle_income         0.4   139
#                                                                                   Region_Middle_East_and_North_Africa         0.2   140
#                                                                                        Region_Europe_and_Central_Asia         0.0   141
#                                                                                                  Region_North_America         0.0   142
#                                                                                                     Region_South_Asia         0.0   143
#                                                                                              Income_Group_High_income         0.0   144
