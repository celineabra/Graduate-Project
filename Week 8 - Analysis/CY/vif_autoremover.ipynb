# %%
#this automates removal of the highest vif feature from the dataset until a vif threshold is achieved
#makes a list of the features that were dropped for having too high vif
import pandas as pd
import os

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', None)
pd.set_option('display.expand_frame_repr', False)
pd.options.display.float_format = '{:,.2f}'.format

# %%
import time
from sklearn.impute import KNNImputer
from statsmodels.stats.outliers_influence import variance_inflation_factor
pd.options.display.float_format = '{:,.2e}'.format

# %%
folder_loc = 'F:/class/BANA 698/week 8'


file_list = [f for f in os.listdir(folder_loc) if os.path.isfile(os.path.join(folder_loc, f))]
#for file in file_list: print(file)

# %%
file = 'Group1DatasetRaw.onehotted.csv'
df = pd.read_csv(os.path.join(folder_loc, file))

# %%
cols_to_exclude = [
    #target and directly related
    'Life expectancy at birth, total (years)',
    'Life expectancy at birth, female (years)',
    'Life expectancy at birth, male (years)',
    'CountryShortName',
    'Year',
    #perfect correlate determined by correlation_to_all_lister.ipynb
    'Rural population (% of total population)'
]

# %%
def vif_loop(df, vif_threshold = 10):
    #presumes dataset has no nans and no numerics
    print("Count: Time Elapsed: VIF Score: Feature Removed")
    excluded_features = []
    count = 1
    while True:
        start_time = time.time() 
        X = df.drop(columns = excluded_features)
        vif_data = pd.DataFrame()
        vif_data['Feature'] = X.columns
        vif_data['VIF'] = [
            variance_inflation_factor(X.values, i)
            for i in range(X.shape[1])
        ]
        vif_data.sort_values('VIF', ascending=False, inplace=True)
        
        highest_vif_row = vif_data.iloc[0]
        max_vif = float(highest_vif_row['VIF'])
        if max_vif < vif_threshold:
            break
        
        feature_to_remove = highest_vif_row['Feature']  
        end_time = time.time() 
        elapsed = end_time - start_time 
        print(f"#{count}: {elapsed:.2f}s: {max_vif:,.2f}: {feature_to_remove}")
        count += 1

        excluded_features.append(feature_to_remove)

    print(f"\nList of Features with High VIFs:")
    print("highVIFS = [")
    for feature in excluded_features:
        print(f"    '{feature}',")    
    print("]")

    print(f"\nRemaining Features and VIFs:")
    print(vif_data.to_string(index=False, float_format="{:,.2f}".format))
    
    return excluded_features

# %%
#drop any non-numeric columns first
df_imputed = df.drop(columns='CountryShortName')

#impute the rest of the dataset
imputer = KNNImputer()
df_imputed = pd.DataFrame(imputer.fit_transform(df_imputed), columns=df_imputed.columns, index=df_imputed.index)

#drop the target, non-numeric features, and any perfectly negative correlating features
df_imputed.drop(columns = cols_to_exclude, errors = 'ignore', inplace=True)

addl_cols_to_exclude = vif_loop(df_imputed, 5)
# Out:
# Count: Time Elapsed: VIF Score: Feature Removed
# #1: 31.09s: 4,503,599,627,370,496.00: Population ages 0-14, total
# #2: 30.33s: 468,119,649.86: Self-employed, female (% of female employment) (modeled ILO estimate)
# #3: 25.52s: 188,022,245.02: Total greenhouse gas emissions excluding LULUCF (Mt CO2e)
# #4: 27.11s: 77,845,512.52: Nitrous oxide (N2O) emissions (total) excluding LULUCF (Mt CO2e)
# #5: 28.08s: 101,495,943.58: Self-employed, male (% of male employment) (modeled ILO estimate)
# #6: 24.17s: 33,957,036.65: Methane (CH4) emissions (total) excluding LULUCF (Mt CO2e)
# #7: 24.65s: 10,078,483.80: Carbon dioxide (CO2) emissions (total) excluding LULUCF (Mt CO2e)
# #8: 27.49s: 871,551.05: Mortality rate, under-5 (per 1,000 live births)
# #9: 28.87s: 610,805.28: Employment to population ratio, ages 15-24, total (%) (modeled ILO estimate)
# #10: 26.52s: 478,382.47: Current health expenditure per capita (current US$)
# #11: 23.64s: 381,508.41: Mortality rate, infant (per 1,000 live births)
# #12: 23.29s: 222,160.18: Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate)
# #13: 23.62s: 139,393.53: GDP, PPP (current international $)
# #14: 22.18s: 88,563.29: Employment to population ratio, 15+, total (%) (modeled ILO estimate)
# #15: 22.53s: 84,191.66: Wage and salaried workers, total (% of total employment) (modeled ILO estimate)
# #16: 23.54s: 78,022.66: Population ages 0-14, male
# #17: 22.39s: 77,658.61: Population ages 0-14 (% of total population)
# #18: 24.90s: 69,652.84: Total fisheries production (metric tons)
# #19: 21.90s: 39,369.32: Prevalence of anemia among women of reproductive age (% of women ages 15-49)
# #20: 22.62s: 38,092.86: Current health expenditure per capita, PPP (current international $)
# #21: 19.29s: 36,819.82: GNI (current US$)
# #22: 20.57s: 17,108.70: Share of youth not in education, employment or training, total (% of youth population) (modeled ILO estimate)
# #23: 25.72s: 12,838.67: Region_Europe & Central Asia
# #24: 28.47s: 11,666.41: Mortality rate, under-5, male (per 1,000 live births)
# #25: 23.36s: 10,991.21: Number of infant deaths
# #26: 21.80s: 10,569.49: Total natural resources rents (% of GDP)
# #27: 23.92s: 7,819.11: Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)
# #28: 23.75s: 7,743.60: GDP (constant 2015 US$)
# #29: 20.18s: 7,709.03: Domestic credit to private sector by banks (% of GDP)
# #30: 20.05s: 7,415.81: Vulnerable employment, total (% of total employment) (modeled ILO estimate)
# #31: 20.88s: 7,100.92: Employment to population ratio, 15+, male (%) (modeled ILO estimate)
# #32: 20.84s: 6,070.72: GDP (current US$)
# #33: 19.49s: 5,098.94: Labor force, total
# #34: 25.48s: 5,058.97: Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)
# #35: 22.61s: 5,017.76: Labor force participation rate for ages 15-24, total (%) (modeled ILO estimate)
# #36: 17.94s: 4,588.79: Population ages 0-14, female (% of female population)
# #37: 17.56s: 2,445.87: Self-employed, total (% of total employment) (modeled ILO estimate)
# #38: 17.05s: 2,243.97: Labor force participation rate, female (% of female population ages 15-64) (modeled ILO estimate)
# #39: 16.12s: 2,189.50: Population ages 0-14, female
# #40: 17.75s: 2,017.96: Nitrous oxide (N2O) emissions from Industrial Combustion (Energy) (Mt CO2e)
# #41: 18.39s: 1,805.08: Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate)
# #42: 17.21s: 1,594.77: GDP, PPP (constant 2021 international $)
# #43: 14.43s: 1,577.13: GNI, Atlas method (current US$)
# #44: 19.82s: 1,503.94: Number of deaths ages 10-14 years
# #45: 15.96s: 1,493.33: Wage and salaried workers, female (% of female employment) (modeled ILO estimate)
# #46: 14.95s: 1,416.96: School enrollment, primary (% gross)
# #47: 14.61s: 1,303.46: Mortality rate, infant, female (per 1,000 live births)
# #48: 14.20s: 1,204.10: Carbon dioxide (CO2) emissions from Industrial Processes (Mt CO2e)
# #49: 14.21s: 1,064.27: Nitrous oxide (N2O) emissions from Waste (Mt CO2e)
# #50: 13.98s: 946.63: Surface area (sq. km)
# #51: 13.90s: 931.43: GDP per capita, PPP (current international $)
# #52: 13.60s: 897.89: Employment to population ratio, ages 15-24, female (%) (modeled ILO estimate)
# #53: 13.58s: 797.93: Population ages 10-14, male (% of male population)
# #54: 13.26s: 791.00: Number of under-five deaths
# #55: 13.17s: 737.38: Carbon dioxide (CO2) emissions from Transport (Energy) (Mt CO2e)
# #56: 16.12s: 645.18: Carbon dioxide (CO2) emissions from Power Industry (Energy) (Mt CO2e)
# #57: 15.33s: 609.97: Unemployment, total (% of total labor force) (modeled ILO estimate)
# #58: 14.36s: 606.60: Number of deaths ages 15-19 years
# #59: 12.76s: 577.20: Urban population
# #60: 12.61s: 576.32: Final consumption expenditure (constant 2015 US$)
# #61: 12.59s: 491.60: Access to clean fuels and technologies for cooking (% of population)
# #62: 12.27s: 466.51: Total greenhouse gas emissions including LULUCF (Mt CO2e)
# #63: 12.25s: 433.86: Labor force participation rate, total (% of total population ages 15-64) (modeled ILO estimate)
# #64: 12.07s: 398.43: GDP per capita, PPP (constant 2021 international $)
# #65: 17.87s: 384.60: Population ages 0-14, male (% of male population)
# #66: 12.84s: 367.47: Domestic private health expenditure per capita, PPP (current international $)
# #67: 12.92s: 360.88: Nitrous oxide (N2O) emissions from Agriculture (Mt CO2e)
# #68: 11.98s: 347.42: GNI, PPP (current international $)
# #69: 11.84s: 295.94: Rural population
# #70: 11.75s: 260.34: Employment to population ratio, ages 15-24, male (%) (modeled ILO estimate)
# #71: 11.76s: 248.49: Carbon dioxide (CO2) emissions from Industrial Combustion (Energy) (Mt CO2e)
# #72: 12.21s: 237.60: Mortality rate, infant, male (per 1,000 live births)
# #73: 11.25s: 232.82: Ratio of female to male labor force participation rate (%) (modeled ILO estimate)
# #74: 11.40s: 211.45: GNI per capita, Atlas method (current US$)
# #75: 11.38s: 203.47: Cereal production (metric tons)
# #76: 10.78s: 187.34: Domestic general government health expenditure per capita (current US$)
# #77: 10.77s: 177.44: Total alcohol consumption per capita, female (liters of pure alcohol, projected estimates, female 15+ years of age)
# #78: 11.27s: 169.87: Labor force participation rate, male (% of male population ages 15+) (modeled ILO estimate)
# #79: 11.15s: 164.95: Methane (CH4) emissions from Agriculture (Mt CO2e)
# #80: 10.22s: 160.03: Population ages 15-19, female (% of female population)
# #81: 10.22s: 158.74: GDP growth (annual %)
# #82: 10.11s: 157.24: Vulnerable employment, male (% of male employment) (modeled ILO estimate)
# #83: 10.19s: 153.98: Maternal mortality ratio (modeled estimate, per 100,000 live births)
# #84: 10.16s: 150.96: Transport services (% of commercial service imports)
# #85: 9.94s: 147.14: Nitrous oxide (N2O) emissions from Building (Energy) (Mt CO2e)
# #86: 9.41s: 140.76: GDP per capita (current US$)
# #87: 9.32s: 133.97: Number of deaths ages 20-24 years
# #88: 9.87s: 127.55: Nitrous oxide (N2O) emissions from Transport (Energy) (Mt CO2e)
# #89: 9.84s: 124.87: Fluorinated greenhouse gases (F-gases) emissions from Industrial Processes (Mt CO2e)
# #90: 9.65s: 124.61: Income Group_High income
# #91: 9.32s: 116.14: People using at least basic sanitation services (% of population)
# #92: 9.39s: 99.45: Carbon dioxide (CO2) emissions excluding LULUCF per capita (t CO2e/capita)
# #93: 9.04s: 95.71: Out-of-pocket expenditure per capita (current US$)
# #94: 8.94s: 93.63: Carbon dioxide (CO2) emissions from Building (Energy) (Mt CO2e)
# #95: 8.70s: 90.99: GDP per capita (constant 2015 US$)
# #96: 8.56s: 85.65: Forest area (sq. km)
# #97: 10.15s: 80.70: Land under cereal production (hectares)
# #98: 8.83s: 78.01: Adjusted net national income (current US$)
# #99: 9.18s: 76.84: Number of deaths ages 5-9 years
# #100: 8.63s: 75.31: Computer, communications and other services (% of commercial service exports)
# #101: 8.14s: 71.28: Mortality rate, under-5, female (per 1,000 live births)
# #102: 8.08s: 68.90: Methane (CH4) emissions from Waste (Mt CO2e)
# #103: 9.82s: 64.25: Domestic general government health expenditure (% of GDP)
# #104: 8.21s: 62.72: Carbon dioxide (CO2) emissions from Fugitive Emissions (Energy) (Mt CO2e)
# #105: 8.36s: 60.70: Employment to population ratio, 15+, female (%) (modeled ILO estimate)
# #106: 8.26s: 57.51: Prevalence of anemia among pregnant women (%)
# #107: 7.65s: 54.38: Access to electricity (% of population)
# #108: 7.93s: 53.23: Nitrous oxide (N2O) emissions from Power Industry (Energy) (Mt CO2e)
# #109: 8.26s: 51.37: Vulnerable employment, female (% of female employment) (modeled ILO estimate)
# #110: 7.49s: 48.97: Mortality rate, adult, female (per 1,000 female adults)
# #111: 7.71s: 45.34: Birth rate, crude (per 1,000 people)
# #112: 7.02s: 41.43: Methane (CH4) emissions from Building (Energy) (Mt CO2e)
# #113: 6.83s: 40.97: Methane (CH4) emissions from Fugitive Emissions (Energy) (Mt CO2e)
# #114: 6.68s: 39.47: Population ages 10-14, female (% of female population)
# #115: 6.74s: 39.19: Probability of dying among children ages 5-9 years (per 1,000)
# #116: 6.68s: 35.91: GNI per capita, PPP (current international $)
# #117: 6.50s: 35.31: Monetary Sector credit to private sector (% GDP)
# #118: 6.84s: 34.68: Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate)
# #119: 6.44s: 34.39: Methane (CH4) emissions from Power Industry (Energy) (Mt CO2e)
# #120: 6.42s: 32.51: Probability of dying among youth ages 20-24 years (per 1,000)
# #121: 6.25s: 30.76: GDP per person employed (constant 2021 PPP $)
# #122: 6.16s: 29.99: Domestic private health expenditure (% of current health expenditure)
# #123: 6.01s: 29.06: Methane (CH4) emissions from Industrial Combustion (Energy) (Mt CO2e)
# #124: 5.71s: 27.83: Prevalence of anemia among children (% of children ages 6-59 months)
# #125: 5.92s: 27.74: Unemployment, female (% of female labor force) (modeled ILO estimate)
# #126: 6.38s: 26.75: Computer, communications and other services (% of commercial service imports)
# #127: 7.03s: 25.53: People using at least basic drinking water services (% of population)
# #128: 5.73s: 24.82: Exports of goods, services and primary income (BoP, current US$)
# #129: 5.60s: 24.22: Domestic general government health expenditure per capita, PPP (current international $)
# #130: 6.47s: 23.95: People using at least basic sanitation services, urban (% of urban population)
# #131: 6.41s: 23.23: Labor force participation rate for ages 15-24, female (%) (modeled ILO estimate)
# #132: 7.18s: 20.89: Access to clean fuels and technologies for cooking, rural (% of rural population)
# #133: 6.90s: 19.06: Region_Sub-Saharan Africa
# #134: 6.22s: 18.56: Land area (sq. km)
# #135: 5.76s: 18.25: Mortality rate, neonatal (per 1,000 live births)
# #136: 5.70s: 17.97: Travel services (% of commercial service exports)
# #137: 5.68s: 16.64: General government final consumption expenditure (constant 2015 US$)
# #138: 5.43s: 1,051.22: People using at least basic drinking water services, urban (% of urban population)
# #139: 5.41s: 1,149.60: School enrollment, primary, male (% gross)
# #140: 5.21s: 833.44: Population ages 15-64 (% of total population)
# #141: 5.08s: 507.11: Labor force participation rate, male (% of male population ages 15-64) (modeled ILO estimate)
# #142: 5.15s: 464.53: Food production index (2014-2016 = 100)
# #143: 4.92s: 407.54: Immunization, DPT (% of children ages 12-23 months)
# #144: 4.71s: 346.34: Pillar 3 - Data Products - Score
# #145: 4.63s: 250.66: Labor force, female (% of total labor force)
# #146: 4.63s: 237.45: Access to electricity, urban (% of urban population)
# #147: 4.56s: 170.24: Population ages 15-19, male (% of male population)
# #148: 4.52s: 136.70: Import unit value index (2015 = 100)
# #149: 4.82s: 124.93: Immunization, measles (% of children ages 12-23 months)
# #150: 4.62s: 122.49: GOAL 15: Life on Land (5 year moving average)
# #151: 4.52s: 117.01: School enrollment, primary, female (% gross)
# #152: 4.78s: 112.49: Women Business and the Law Index Score (scale 1-100)
# #153: 4.62s: 91.99: Wage and salaried workers, male (% of male employment) (modeled ILO estimate)
# #154: 4.54s: 73.67: Domestic general government health expenditure (% of current health expenditure)
# #155: 4.48s: 70.77: People using at least basic sanitation services, rural (% of rural population)
# #156: 4.39s: 68.45: Tuberculosis case detection rate (%, all forms)
# #157: 4.30s: 60.40: Access to clean fuels and technologies for cooking, urban (% of urban population)
# #158: 4.31s: 53.84: Death rate, crude (per 1,000 people)
# #159: 4.08s: 52.94: Livestock production index (2014-2016 = 100)
# #160: 3.89s: 52.28: Urban population (% of total population)
# #161: 3.88s: 48.12: Tuberculosis treatment success rate (% of new cases)
# #162: 3.83s: 47.38: Export unit value index (2015 = 100)
# #163: 3.73s: 45.48: GOAL 17: Partnerships to achieve the Goal (5 year moving average)
# #164: 3.74s: 42.37: Labor force participation rate for ages 15-24, male (%) (modeled ILO estimate)
# #165: 3.66s: 40.96: Mortality rate, adult, male (per 1,000 male adults)
# #166: 3.55s: 39.65: Access to electricity, rural (% of rural population)
# #167: 3.57s: 36.98: Crop production index (2014-2016 = 100)
# #168: 3.42s: 36.71: Compulsory education, duration (years)
# #169: 3.26s: 31.27: Carbon intensity of GDP (kg CO2e per 2021 PPP $)
# #170: 3.22s: 29.49: Share of youth not in education, employment or training, female (% of female youth population) (modeled ILO estimate)
# #171: 3.17s: 29.21: Prevalence of anemia among non-pregnant women (% of women ages 15-49)
# #172: 3.38s: 28.47: GOAL 1: No Poverty (5 year moving average)
# #173: 3.29s: 27.49: Current health expenditure (% of GDP)
# #174: 3.81s: 25.78: GOAL 10: Reduced Inequality (5 year moving average)
# #175: 3.65s: 25.42: Probability of dying among adolescents ages 15-19 years (per 1,000)
# #176: 4.10s: 23.53: Household Survey on income, etc (Availability score over 10 years)
# #177: 6.59s: 21.29: Adolescent fertility rate (births per 1,000 women ages 15-19)
# #178: 2.72s: 21.06: Renewable energy consumption (% of total final energy consumption)
# #179: 2.60s: 20.27: Agricultural land (% of land area)
# #180: 3.24s: 18.88: GOAL 16: Peace and Justice Strong Institutions (5 year moving average)
# #181: 3.17s: 18.16: Out-of-pocket expenditure per capita, PPP (current international $)
# #182: 2.59s: 17.61: Inflation, GDP deflator: linked series (annual %)
# #183: 4.47s: 16.69: Pillar 1 - Data Use - Score
# #184: 2.91s: 16.21: Unemployment, male (% of male labor force) (modeled ILO estimate)
# #185: 2.84s: 16.02: Adjusted savings: education expenditure (% of GNI)
# #186: 2.57s: 15.58: PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)
# #187: 2.12s: 15.31: Carbon intensity of GDP (kg CO2e per constant 2021 US$ of GDP)
# #188: 1.88s: 14.98: Communications, computer, etc. (% of service imports, BoP)
# #189: 1.98s: 14.81: Adjusted net national income per capita (current US$)
# #190: 1.91s: 14.42: Prevalence of stunting, height for age (modeled estimate, % of children under 5)
# #191: 1.79s: 14.10: Agriculture, forestry, and fishing, value added (% of GDP)
# #192: 1.63s: 13.47: Energy intensity level of primary energy (MJ/$2017 PPP GDP)
# #193: 1.67s: 13.24: Broad money (% of GDP)
# #194: 1.69s: 12.55: Nitrous oxide (N2O) emissions from Industrial Processes (Mt CO2e)
# #195: 1.69s: 11.85: GOAL 11: Sustainable Cities and Communities (5 year moving average)
# #196: 1.52s: 11.61: Preprimary education, duration (years)
# #197: 1.69s: 11.33: Share of youth not in education, employment or training, male (% of male youth population) (modeled ILO estimate)
# #198: 1.49s: 10.82: Carbon dioxide (CO2) net fluxes from LULUCF - Forest Land (Mt CO2e)
# #199: 1.60s: 10.41: Exports of goods and services (% of GDP)
# #200: 1.39s: 10.23: Income Group_Lower middle income
# #201: 1.31s: 9.99: Probability of dying among adolescents ages 10-14 years (per 1,000)
# #202: 1.36s: 9.79: Aquaculture production (metric tons)
# #203: 2.20s: 9.06: Domestic credit to private sector (% of GDP)
# #204: 1.46s: 8.84: Out-of-pocket expenditure (% of current health expenditure)
# #205: 1.16s: 8.65: Number of neonatal deaths
# #206: 1.26s: 8.63: Health/Demographic survey (Availability score over 10 years)
# #207: 1.24s: 8.33: Total alcohol consumption per capita, male (liters of pure alcohol, projected estimates, male 15+ years of age)
# #208: 1.05s: 8.00: Oil rents (% of GDP)
# #209: 1.01s: 7.73: Methane (CH4) emissions from Transport (Energy) (Mt CO2e)
# #210: 1.06s: 7.53: Prevalence of overweight (modeled estimate, % of children under 5)
# #211: 1.09s: 7.15: International tourism, receipts for travel items (current US$)
# #212: 0.95s: 6.79: Urban population growth (annual %)
# #213: 0.98s: 6.73: Total greenhouse gas emissions excluding LULUCF (% change from 1990)
# #214: 1.01s: 6.60: Proportion of seats held by women in national parliaments (%)
# #215: 0.88s: 6.23: Total greenhouse gas emissions per capita excluding LULUCF (t CO2e/capita)
# #216: 0.90s: 6.18: Forest area (% of land area)
# #217: 0.91s: 6.16: GOAL 12: Responsible Consumption and Production (5 year moving average)
# #218: 0.92s: 5.94: Labor Force Survey (Availability score over 10 years)
# #219: 1.09s: 5.78: Lifetime risk of maternal death (%)
# #220: 0.80s: 5.57: Automated teller machines (ATMs) (per 100,000 adults)
# #221: 0.79s: 5.35: Nitrous oxide (N2O) emissions from Fugitive Emissions (Energy) (Mt CO2e)
# #222: 0.71s: 5.32: Fuel imports (% of merchandise imports)
# #223: 0.69s: 5.29: Communications, computer, etc. (% of service exports, BoP)
#
# List of Features with High VIFs:
# highVIFS = [
#     'Population ages 0-14, total',
#     'Self-employed, female (% of female employment) (modeled ILO estimate)',
#     'Total greenhouse gas emissions excluding LULUCF (Mt CO2e)',
#     'Nitrous oxide (N2O) emissions (total) excluding LULUCF (Mt CO2e)',
#     'Self-employed, male (% of male employment) (modeled ILO estimate)',
#     'Methane (CH4) emissions (total) excluding LULUCF (Mt CO2e)',
#     'Carbon dioxide (CO2) emissions (total) excluding LULUCF (Mt CO2e)',
#     'Mortality rate, under-5 (per 1,000 live births)',
#     'Employment to population ratio, ages 15-24, total (%) (modeled ILO estimate)',
#     'Current health expenditure per capita (current US$)',
#     'Mortality rate, infant (per 1,000 live births)',
#     'Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate)',
#     'GDP, PPP (current international $)',
#     'Employment to population ratio, 15+, total (%) (modeled ILO estimate)',
#     'Wage and salaried workers, total (% of total employment) (modeled ILO estimate)',
#     'Population ages 0-14, male',
#     'Population ages 0-14 (% of total population)',
#     'Total fisheries production (metric tons)',
#     'Prevalence of anemia among women of reproductive age (% of women ages 15-49)',
#     'Current health expenditure per capita, PPP (current international $)',
#     'GNI (current US$)',
#     'Share of youth not in education, employment or training, total (% of youth population) (modeled ILO estimate)',
#     'Region_Europe & Central Asia',
#     'Mortality rate, under-5, male (per 1,000 live births)',
#     'Number of infant deaths',
#     'Total natural resources rents (% of GDP)',
#     'Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)',
#     'GDP (constant 2015 US$)',
#     'Domestic credit to private sector by banks (% of GDP)',
#     'Vulnerable employment, total (% of total employment) (modeled ILO estimate)',
#     'Employment to population ratio, 15+, male (%) (modeled ILO estimate)',
#     'GDP (current US$)',
#     'Labor force, total',
#     'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)',
#     'Labor force participation rate for ages 15-24, total (%) (modeled ILO estimate)',
#     'Population ages 0-14, female (% of female population)',
#     'Self-employed, total (% of total employment) (modeled ILO estimate)',
#     'Labor force participation rate, female (% of female population ages 15-64) (modeled ILO estimate)',
#     'Population ages 0-14, female',
#     'Nitrous oxide (N2O) emissions from Industrial Combustion (Energy) (Mt CO2e)',
#     'Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate)',
#     'GDP, PPP (constant 2021 international $)',
#     'GNI, Atlas method (current US$)',
#     'Number of deaths ages 10-14 years',
#     'Wage and salaried workers, female (% of female employment) (modeled ILO estimate)',
#     'School enrollment, primary (% gross)',
#     'Mortality rate, infant, female (per 1,000 live births)',
#     'Carbon dioxide (CO2) emissions from Industrial Processes (Mt CO2e)',
#     'Nitrous oxide (N2O) emissions from Waste (Mt CO2e)',
#     'Surface area (sq. km)',
#     'GDP per capita, PPP (current international $)',
#     'Employment to population ratio, ages 15-24, female (%) (modeled ILO estimate)',
#     'Population ages 10-14, male (% of male population)',
#     'Number of under-five deaths',
#     'Carbon dioxide (CO2) emissions from Transport (Energy) (Mt CO2e)',
#     'Carbon dioxide (CO2) emissions from Power Industry (Energy) (Mt CO2e)',
#     'Unemployment, total (% of total labor force) (modeled ILO estimate)',
#     'Number of deaths ages 15-19 years',
#     'Urban population',
#     'Final consumption expenditure (constant 2015 US$)',
#     'Access to clean fuels and technologies for cooking (% of population)',
#     'Total greenhouse gas emissions including LULUCF (Mt CO2e)',
#     'Labor force participation rate, total (% of total population ages 15-64) (modeled ILO estimate)',
#     'GDP per capita, PPP (constant 2021 international $)',
#     'Population ages 0-14, male (% of male population)',
#     'Domestic private health expenditure per capita, PPP (current international $)',
#     'Nitrous oxide (N2O) emissions from Agriculture (Mt CO2e)',
#     'GNI, PPP (current international $)',
#     'Rural population',
#     'Employment to population ratio, ages 15-24, male (%) (modeled ILO estimate)',
#     'Carbon dioxide (CO2) emissions from Industrial Combustion (Energy) (Mt CO2e)',
#     'Mortality rate, infant, male (per 1,000 live births)',
#     'Ratio of female to male labor force participation rate (%) (modeled ILO estimate)',
#     'GNI per capita, Atlas method (current US$)',
#     'Cereal production (metric tons)',
#     'Domestic general government health expenditure per capita (current US$)',
#     'Total alcohol consumption per capita, female (liters of pure alcohol, projected estimates, female 15+ years of age)',
#     'Labor force participation rate, male (% of male population ages 15+) (modeled ILO estimate)',
#     'Methane (CH4) emissions from Agriculture (Mt CO2e)',
#     'Population ages 15-19, female (% of female population)',
#     'GDP growth (annual %)',
#     'Vulnerable employment, male (% of male employment) (modeled ILO estimate)',
#     'Maternal mortality ratio (modeled estimate, per 100,000 live births)',
#     'Transport services (% of commercial service imports)',
#     'Nitrous oxide (N2O) emissions from Building (Energy) (Mt CO2e)',
#     'GDP per capita (current US$)',
#     'Number of deaths ages 20-24 years',
#     'Nitrous oxide (N2O) emissions from Transport (Energy) (Mt CO2e)',
#     'Fluorinated greenhouse gases (F-gases) emissions from Industrial Processes (Mt CO2e)',
#     'Income Group_High income',
#     'People using at least basic sanitation services (% of population)',
#     'Carbon dioxide (CO2) emissions excluding LULUCF per capita (t CO2e/capita)',
#     'Out-of-pocket expenditure per capita (current US$)',
#     'Carbon dioxide (CO2) emissions from Building (Energy) (Mt CO2e)',
#     'GDP per capita (constant 2015 US$)',
#     'Forest area (sq. km)',
#     'Land under cereal production (hectares)',
#     'Adjusted net national income (current US$)',
#     'Number of deaths ages 5-9 years',
#     'Computer, communications and other services (% of commercial service exports)',
#     'Mortality rate, under-5, female (per 1,000 live births)',
#     'Methane (CH4) emissions from Waste (Mt CO2e)',
#     'Domestic general government health expenditure (% of GDP)',
#     'Carbon dioxide (CO2) emissions from Fugitive Emissions (Energy) (Mt CO2e)',
#     'Employment to population ratio, 15+, female (%) (modeled ILO estimate)',
#     'Prevalence of anemia among pregnant women (%)',
#     'Access to electricity (% of population)',
#     'Nitrous oxide (N2O) emissions from Power Industry (Energy) (Mt CO2e)',
#     'Vulnerable employment, female (% of female employment) (modeled ILO estimate)',
#     'Mortality rate, adult, female (per 1,000 female adults)',
#     'Birth rate, crude (per 1,000 people)',
#     'Methane (CH4) emissions from Building (Energy) (Mt CO2e)',
#     'Methane (CH4) emissions from Fugitive Emissions (Energy) (Mt CO2e)',
#     'Population ages 10-14, female (% of female population)',
#     'Probability of dying among children ages 5-9 years (per 1,000)',
#     'GNI per capita, PPP (current international $)',
#     'Monetary Sector credit to private sector (% GDP)',
#     'Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate)',
#     'Methane (CH4) emissions from Power Industry (Energy) (Mt CO2e)',
#     'Probability of dying among youth ages 20-24 years (per 1,000)',
#     'GDP per person employed (constant 2021 PPP $)',
#     'Domestic private health expenditure (% of current health expenditure)',
#     'Methane (CH4) emissions from Industrial Combustion (Energy) (Mt CO2e)',
#     'Prevalence of anemia among children (% of children ages 6-59 months)',
#     'Unemployment, female (% of female labor force) (modeled ILO estimate)',
#     'Computer, communications and other services (% of commercial service imports)',
#     'People using at least basic drinking water services (% of population)',
#     'Exports of goods, services and primary income (BoP, current US$)',
#     'Domestic general government health expenditure per capita, PPP (current international $)',
#     'People using at least basic sanitation services, urban (% of urban population)',
#     'Labor force participation rate for ages 15-24, female (%) (modeled ILO estimate)',
#     'Access to clean fuels and technologies for cooking, rural (% of rural population)',
#     'Region_Sub-Saharan Africa',
#     'Land area (sq. km)',
#     'Mortality rate, neonatal (per 1,000 live births)',
#     'Travel services (% of commercial service exports)',
#     'General government final consumption expenditure (constant 2015 US$)',
#     'People using at least basic drinking water services, urban (% of urban population)',
#     'School enrollment, primary, male (% gross)',
#     'Population ages 15-64 (% of total population)',
#     'Labor force participation rate, male (% of male population ages 15-64) (modeled ILO estimate)',
#     'Food production index (2014-2016 = 100)',
#     'Immunization, DPT (% of children ages 12-23 months)',
#     'Pillar 3 - Data Products - Score',
#     'Labor force, female (% of total labor force)',
#     'Access to electricity, urban (% of urban population)',
#     'Population ages 15-19, male (% of male population)',
#     'Import unit value index (2015 = 100)',
#     'Immunization, measles (% of children ages 12-23 months)',
#     'GOAL 15: Life on Land (5 year moving average)',
#     'School enrollment, primary, female (% gross)',
#     'Women Business and the Law Index Score (scale 1-100)',
#     'Wage and salaried workers, male (% of male employment) (modeled ILO estimate)',
#     'Domestic general government health expenditure (% of current health expenditure)',
#     'People using at least basic sanitation services, rural (% of rural population)',
#     'Tuberculosis case detection rate (%, all forms)',
#     'Access to clean fuels and technologies for cooking, urban (% of urban population)',
#     'Death rate, crude (per 1,000 people)',
#     'Livestock production index (2014-2016 = 100)',
#     'Urban population (% of total population)',
#     'Tuberculosis treatment success rate (% of new cases)',
#     'Export unit value index (2015 = 100)',
#     'GOAL 17: Partnerships to achieve the Goal (5 year moving average)',
#     'Labor force participation rate for ages 15-24, male (%) (modeled ILO estimate)',
#     'Mortality rate, adult, male (per 1,000 male adults)',
#     'Access to electricity, rural (% of rural population)',
#     'Crop production index (2014-2016 = 100)',
#     'Compulsory education, duration (years)',
#     'Carbon intensity of GDP (kg CO2e per 2021 PPP $)',
#     'Share of youth not in education, employment or training, female (% of female youth population) (modeled ILO estimate)',
#     'Prevalence of anemia among non-pregnant women (% of women ages 15-49)',
#     'GOAL 1: No Poverty (5 year moving average)',
#     'Current health expenditure (% of GDP)',
#     'GOAL 10: Reduced Inequality (5 year moving average)',
#     'Probability of dying among adolescents ages 15-19 years (per 1,000)',
#     'Household Survey on income, etc (Availability score over 10 years)',
#     'Adolescent fertility rate (births per 1,000 women ages 15-19)',
#     'Renewable energy consumption (% of total final energy consumption)',
#     'Agricultural land (% of land area)',
#     'GOAL 16: Peace and Justice Strong Institutions (5 year moving average)',
#     'Out-of-pocket expenditure per capita, PPP (current international $)',
#     'Inflation, GDP deflator: linked series (annual %)',
#     'Pillar 1 - Data Use - Score',
#     'Unemployment, male (% of male labor force) (modeled ILO estimate)',
#     'Adjusted savings: education expenditure (% of GNI)',
#     'PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)',
#     'Carbon intensity of GDP (kg CO2e per constant 2021 US$ of GDP)',
#     'Communications, computer, etc. (% of service imports, BoP)',
#     'Adjusted net national income per capita (current US$)',
#     'Prevalence of stunting, height for age (modeled estimate, % of children under 5)',
#     'Agriculture, forestry, and fishing, value added (% of GDP)',
#     'Energy intensity level of primary energy (MJ/$2017 PPP GDP)',
#     'Broad money (% of GDP)',
#     'Nitrous oxide (N2O) emissions from Industrial Processes (Mt CO2e)',
#     'GOAL 11: Sustainable Cities and Communities (5 year moving average)',
#     'Preprimary education, duration (years)',
#     'Share of youth not in education, employment or training, male (% of male youth population) (modeled ILO estimate)',
#     'Carbon dioxide (CO2) net fluxes from LULUCF - Forest Land (Mt CO2e)',
#     'Exports of goods and services (% of GDP)',
#     'Income Group_Lower middle income',
#     'Probability of dying among adolescents ages 10-14 years (per 1,000)',
#     'Aquaculture production (metric tons)',
#     'Domestic credit to private sector (% of GDP)',
#     'Out-of-pocket expenditure (% of current health expenditure)',
#     'Number of neonatal deaths',
#     'Health/Demographic survey (Availability score over 10 years)',
#     'Total alcohol consumption per capita, male (liters of pure alcohol, projected estimates, male 15+ years of age)',
#     'Oil rents (% of GDP)',
#     'Methane (CH4) emissions from Transport (Energy) (Mt CO2e)',
#     'Prevalence of overweight (modeled estimate, % of children under 5)',
#     'International tourism, receipts for travel items (current US$)',
#     'Urban population growth (annual %)',
#     'Total greenhouse gas emissions excluding LULUCF (% change from 1990)',
#     'Proportion of seats held by women in national parliaments (%)',
#     'Total greenhouse gas emissions per capita excluding LULUCF (t CO2e/capita)',
#     'Forest area (% of land area)',
#     'GOAL 12: Responsible Consumption and Production (5 year moving average)',
#     'Labor Force Survey (Availability score over 10 years)',
#     'Lifetime risk of maternal death (%)',
#     'Automated teller machines (ATMs) (per 100,000 adults)',
#     'Nitrous oxide (N2O) emissions from Fugitive Emissions (Energy) (Mt CO2e)',
#     'Fuel imports (% of merchandise imports)',
#     'Communications, computer, etc. (% of service exports, BoP)',
# ]
#
# Remaining Features and VIFs:
#                                                                                          Feature  VIF
#                                                 Prevalence of undernourishment (% of population) 4.95
#                               Insurance and financial services (% of commercial service imports) 4.91
#                                                          Fuel exports (% of merchandise exports) 4.87
#                                                       Capture fisheries production (metric tons) 4.80
#                                               Adjusted savings: carbon dioxide damage (% of GNI) 4.54
#                            Carbon dioxide (CO2) net fluxes from LULUCF - Deforestation (Mt CO2e) 4.52
#                                                Travel services (% of commercial service imports) 4.39
#                                                    Adjusted savings: energy depletion (% of GNI) 4.38
#                                                                     Natural gas rents (% of GDP) 4.27
#           Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate) 4.26
#                                                                     Arable land (% of land area) 4.20
#                                                    Commercial bank branches (per 100,000 adults) 4.20
#                            Renewable internal freshwater resources, total (billion cubic meters) 4.18
#                                                                        Primary education, pupils 4.11
#                            Methane (CH4) emissions (total) excluding LULUCF (% change from 1990) 4.02
#       Carbon dioxide (CO2) net fluxes from LULUCF - Total excluding non-tropical fires (Mt CO2e) 4.02
#                     Carbon dioxide (CO2) emissions (total) excluding LULUCF (% change from 1990) 3.85
#                                             Transport services (% of commercial service exports) 3.82
#                      Nitrous oxide (N2O) emissions (total) excluding LULUCF (% change from 1990) 3.66
#                               Insurance and financial services (% of commercial service exports) 3.66
#                                                                Arable land (hectares per person) 3.60
#                                                  GOAL 13: Climate Action (5 year moving average) 3.50
#                               International tourism, expenditures for travel items (current US$) 3.23
#                                               Ores and metals imports (% of merchandise imports) 3.21
#                                                                          Income Group_Low income 2.99
#                                                                          Forest rents (% of GDP) 2.93
#                                     Domestic private health expenditure per capita (current US$) 2.83
#                                                   Incidence of tuberculosis (per 100,000 people) 2.75
#                                   Lifetime risk of maternal death (1 in: rate varies by country) 2.70
#                                                  Final consumption expenditure (annual % growth) 2.70
#                                              People practicing open defecation (% of population) 2.56
#                                                        International tourism, number of arrivals 2.52
#                                                External balance on goods and services (% of GDP) 2.51
#                                                                 Region_Latin America & Caribbean 2.46
# Water productivity, total (constant 2015 US$ GDP per cubic meter of total freshwater withdrawal) 2.42
#                   Agriculture, forestry, and fishing, value added per worker (constant 2015 US$) 2.37
#                                                                Region_Middle East & North Africa 2.36
#                                                                 Income Group_Upper middle income 2.31
#                                                                       Region_East Asia & Pacific 2.17
#                                                                             Region_North America 2.14
#                                                              Permanent cropland (% of land area) 2.13
#                                                                        Number of maternal deaths 2.09
#                                    Fertilizer consumption (kilograms per hectare of arable land) 1.93
#                                                                                Region_South Asia 1.93
#                                                               Rural population growth (annual %) 1.89
#                                                                                    Net migration 1.77
#                                                                 GDP per capita growth (annual %) 1.75
#                                              Population density (people per sq. km of land area) 1.64
#                                                       Claims on central government, etc. (% GDP) 1.62
#                                Renewable internal freshwater resources per capita (cubic meters) 1.55
#                                                                         Mineral rents (% of GDP) 1.51
#                                             Refugee population by country or territory of asylum 1.50
#                               General government final consumption expenditure (annual % growth) 1.42
#                                             Refugee population by country or territory of origin 1.39
#                                             Official exchange rate (LCU per US$, period average) 1.39
#                                                               Inflation, GDP deflator (annual %) 1.29
#                                                                            Coal rents (% of GDP) 1.16
