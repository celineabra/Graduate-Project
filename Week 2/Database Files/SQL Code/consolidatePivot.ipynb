# %%
import pandas as pd
import sqlite3

conn = sqlite3.connect('D:\GitHub Repos\culminating-project-group-1\Week 2\Database Files\BANA698GROUP1.db.db')
df = pd.read_sql_query('SELECT "CountryShortName", Year, "IndicatorName", Value FROM AllRecords', conn)

pivot_df = df.pivot_table(index=["CountryShortName", "Year"], columns="IndicatorName", values="Value", aggfunc='max')
print(pivot_df)

pivot_df.to_csv('Group1Data.csv')
# Out:
# IndicatorName                       ARI treatment (% of children under 5 taken to a health provider)  \
# CountryShortName            Year
# Afghanistan                 2021.0                                                NaN
#                             2022.0                                                NaN
#                             2023.0                                                NaN
# Africa Eastern and Southern 2021.0                                                NaN
#                             2022.0                                                NaN
# ...                                                                               ...
# Zambia                      2022.0                                                NaN
#                             2023.0                                                NaN
# Zimbabwe                    2021.0                                                NaN
#                             2022.0                                                NaN
#                             2023.0                                                NaN
#
# IndicatorName                       Access to clean fuels and technologies for cooking  (% of population)  \
# CountryShortName            Year
# Afghanistan                 2021.0                                          34.900000
#                             2022.0                                          36.100000
#                             2023.0                                                NaN
# Africa Eastern and Southern 2021.0                                          21.372164
#                             2022.0                                          22.100884
# ...                                                                               ...
# Zambia                      2022.0                                           9.000000
#                             2023.0                                                NaN
# Zimbabwe                    2021.0                                          30.500000
#                             2022.0                                          30.800000
#                             2023.0                                                NaN
#
# IndicatorName                       Access to clean fuels and technologies for cooking, rural (% of rural population)  \
# CountryShortName            Year
# Afghanistan                 2021.0                                          17.400000
#                             2022.0                                          18.500000
#                             2023.0                                                NaN
# Africa Eastern and Southern 2021.0                                           9.097176
#                             2022.0                                           9.473374
# ...                                                                               ...
# Zambia                      2022.0                                           2.200000
#                             2023.0                                                NaN
# Zimbabwe                    2021.0                                           7.100000
#                             2022.0                                           7.200000
#                             2023.0                                                NaN
#
# IndicatorName                       Access to clean fuels and technologies for cooking, urban (% of urban population)  \
# CountryShortName            Year
# Afghanistan                 2021.0                                          84.500000
#                             2022.0                                          85.000000
#                             2023.0                                                NaN
# Africa Eastern and Southern 2021.0                                          40.687817
#                             2022.0                                          41.211606
# ...                                                                               ...
# Zambia                      2022.0                                          16.600000
#                             2023.0                                                NaN
# Zimbabwe                    2021.0                                          78.400000
#                             2022.0                                          78.200000
#                             2023.0                                                NaN
#
# IndicatorName                       Access to electricity (% of population)  \
# CountryShortName            Year
# Afghanistan                 2021.0                                97.700000
#                             2022.0                                85.300000
#                             2023.0                                      NaN
# Africa Eastern and Southern 2021.0                                48.127211
#                             2022.0                                48.742043
# ...                                                                     ...
# Zambia                      2022.0                                47.800000
#                             2023.0                                      NaN
# Zimbabwe                    2021.0                                49.000000
#                             2022.0                                50.100000
#                             2023.0                                      NaN
#
# IndicatorName                       Access to electricity, rural (% of rural population)  \
# CountryShortName            Year
# Afghanistan                 2021.0                                          97.100000
#                             2022.0                                          81.700000
#                             2023.0                                                NaN
# Africa Eastern and Southern 2021.0                                          32.809138
#                             2022.0                                          33.760782
# ...                                                                               ...
# Zambia                      2022.0                                          14.500000
#                             2023.0                                                NaN
# Zimbabwe                    2021.0                                          31.600000
#                             2022.0                                          33.700000
#                             2023.0                                                NaN
#
# IndicatorName                       Access to electricity, urban (% of urban population)  \
# CountryShortName            Year
# Afghanistan                 2021.0                                          99.500000
#                             2022.0                                          95.900000
#                             2023.0                                                NaN
# Africa Eastern and Southern 2021.0                                          75.483124
#                             2022.0                                          75.847809
# ...                                                                               ...
# Zambia                      2022.0                                          87.000000
#                             2023.0                                                NaN
# Zimbabwe                    2021.0                                          85.300000
#                             2022.0                                          89.000000
#                             2023.0                                                NaN
#
# IndicatorName                       Account ownership at a financial institution or with a mobile-money-service provider (% of population ages 15+)  \
# CountryShortName            Year
# Afghanistan                 2021.0                                               9.65
#                             2022.0                                                NaN
#                             2023.0                                                NaN
# Africa Eastern and Southern 2021.0                                                NaN
#                             2022.0                                                NaN
# ...                                                                               ...
# Zambia                      2022.0                                                NaN
#                             2023.0                                                NaN
# Zimbabwe                    2021.0                                              59.75
#                             2022.0                                                NaN
#                             2023.0                                                NaN
#
# IndicatorName                       Account ownership at a financial institution or with a mobile-money-service provider, female (% of population ages 15+)  \
# CountryShortName            Year
# Afghanistan                 2021.0                                               4.70
#                             2022.0                                                NaN
#                             2023.0                                                NaN
# Africa Eastern and Southern 2021.0                                                NaN
#                             2022.0                                                NaN
# ...                                                                               ...
# Zambia                      2022.0                                                NaN
#                             2023.0                                                NaN
# Zimbabwe                    2021.0                                              53.98
#                             2022.0                                                NaN
#                             2023.0                                                NaN
#
# IndicatorName                       Account ownership at a financial institution or with a mobile-money-service provider, male (% of population ages 15+)  \
# CountryShortName            Year
# Afghanistan                 2021.0                                              14.79
#                             2022.0                                                NaN
#                             2023.0                                                NaN
# Africa Eastern and Southern 2021.0                                                NaN
#                             2022.0                                                NaN
# ...                                                                               ...
# Zambia                      2022.0                                                NaN
#                             2023.0                                                NaN
# Zimbabwe                    2021.0                                              65.86
#                             2022.0                                                NaN
#                             2023.0                                                NaN
#
# IndicatorName                       ...  \
# CountryShortName            Year    ...
# Afghanistan                 2021.0  ...
#                             2022.0  ...
#                             2023.0  ...
# Africa Eastern and Southern 2021.0  ...
#                             2022.0  ...
# ...                                 ...
# Zambia                      2022.0  ...
#                             2023.0  ...
# Zimbabwe                    2021.0  ...
#                             2022.0  ...
#                             2023.0  ...
#
# IndicatorName                       Women who believe a husband is justified in beating his wife (any of five reasons) (%)  \
# CountryShortName            Year
# Afghanistan                 2021.0                                                NaN
#                             2022.0                                                NaN
#                             2023.0                                                NaN
# Africa Eastern and Southern 2021.0                                                NaN
#                             2022.0                                                NaN
# ...                                                                               ...
# Zambia                      2022.0                                                NaN
#                             2023.0                                                NaN
# Zimbabwe                    2021.0                                                NaN
#                             2022.0                                                NaN
#                             2023.0                                                NaN
#
# IndicatorName                       Women who believe a husband is justified in beating his wife when she argues with him (%)  \
# CountryShortName            Year
# Afghanistan                 2021.0                                                NaN
#                             2022.0                                                NaN
#                             2023.0                                                NaN
# Africa Eastern and Southern 2021.0                                                NaN
#                             2022.0                                                NaN
# ...                                                                               ...
# Zambia                      2022.0                                                NaN
#                             2023.0                                                NaN
# Zimbabwe                    2021.0                                                NaN
#                             2022.0                                                NaN
#                             2023.0                                                NaN
#
# IndicatorName                       Women who believe a husband is justified in beating his wife when she burns the food (%)  \
# CountryShortName            Year
# Afghanistan                 2021.0                                                NaN
#                             2022.0                                                NaN
#                             2023.0                                                NaN
# Africa Eastern and Southern 2021.0                                                NaN
#                             2022.0                                                NaN
# ...                                                                               ...
# Zambia                      2022.0                                                NaN
#                             2023.0                                                NaN
# Zimbabwe                    2021.0                                                NaN
#                             2022.0                                                NaN
#                             2023.0                                                NaN
#
# IndicatorName                       Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# CountryShortName            Year
# Afghanistan                 2021.0                                                NaN
#                             2022.0                                                NaN
#                             2023.0                                                NaN
# Africa Eastern and Southern 2021.0                                                NaN
#                             2022.0                                                NaN
# ...                                                                               ...
# Zambia                      2022.0                                                NaN
#                             2023.0                                                NaN
# Zimbabwe                    2021.0                                                NaN
#                             2022.0                                                NaN
#                             2023.0                                                NaN
#
# IndicatorName                       Women who believe a husband is justified in beating his wife when she neglects the children (%)  \
# CountryShortName            Year
# Afghanistan                 2021.0                                                NaN
#                             2022.0                                                NaN
#                             2023.0                                                NaN
# Africa Eastern and Southern 2021.0                                                NaN
#                             2022.0                                                NaN
# ...                                                                               ...
# Zambia                      2022.0                                                NaN
#                             2023.0                                                NaN
# Zimbabwe                    2021.0                                                NaN
#                             2022.0                                                NaN
#                             2023.0                                                NaN
#
# IndicatorName                       Women who believe a husband is justified in beating his wife when she refuses sex with him (%)  \
# CountryShortName            Year
# Afghanistan                 2021.0                                                NaN
#                             2022.0                                                NaN
#                             2023.0                                                NaN
# Africa Eastern and Southern 2021.0                                                NaN
#                             2022.0                                                NaN
# ...                                                                               ...
# Zambia                      2022.0                                                NaN
#                             2023.0                                                NaN
# Zimbabwe                    2021.0                                                NaN
#                             2022.0                                                NaN
#                             2023.0                                                NaN
#
# IndicatorName                       Women who were first married by age 15 (% of women ages 20-24)  \
# CountryShortName            Year
# Afghanistan                 2021.0                                                NaN
#                             2022.0                                                NaN
#                             2023.0                                                9.6
# Africa Eastern and Southern 2021.0                                                NaN
#                             2022.0                                                NaN
# ...                                                                               ...
# Zambia                      2022.0                                                NaN
#                             2023.0                                                NaN
# Zimbabwe                    2021.0                                                NaN
#                             2022.0                                                NaN
#                             2023.0                                                NaN
#
# IndicatorName                       Women who were first married by age 18 (% of women ages 20-24)  \
# CountryShortName            Year
# Afghanistan                 2021.0                                                NaN
#                             2022.0                                                NaN
#                             2023.0                                               28.7
# Africa Eastern and Southern 2021.0                                                NaN
#                             2022.0                                                NaN
# ...                                                                               ...
# Zambia                      2022.0                                                NaN
#                             2023.0                                                NaN
# Zimbabwe                    2021.0                                                NaN
#                             2022.0                                                NaN
#                             2023.0                                                NaN
#
# IndicatorName                       Women's share of population ages 15+ living with HIV (%)  \
# CountryShortName            Year
# Afghanistan                 2021.0                                          29.231041
#                             2022.0                                          29.313433
#                             2023.0                                                NaN
# Africa Eastern and Southern 2021.0                                          62.568564
#                             2022.0                                          62.815034
# ...                                                                               ...
# Zambia                      2022.0                                          62.643319
#                             2023.0                                                NaN
# Zimbabwe                    2021.0                                          60.693180
#                             2022.0                                          60.825294
#                             2023.0                                                NaN
#
# IndicatorName                       Young people (ages 15-24) newly infected with HIV
# CountryShortName            Year
# Afghanistan                 2021.0                                              500.0
#                             2022.0                                              500.0
#                             2023.0                                                NaN
# Africa Eastern and Southern 2021.0                                                NaN
#                             2022.0                                                NaN
# ...                                                                               ...
# Zambia                      2022.0                                            12000.0
#                             2023.0                                                NaN
# Zimbabwe                    2021.0                                             5200.0
#                             2022.0                                             4900.0
#                             2023.0                                                NaN
#
# [795 rows x 1511 columns]
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[1], line 10
#       7 pivot_df = df.pivot_table(index=["CountryShortName", "Year"], columns="IndicatorName", values="Value", aggfunc='max')
#       8 print(pivot_df)
# ---> 10 pivot_df.to_csv('Group1Data.csv')
#
# File c:\Users\joshu\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\joshu\anaconda3\Lib\site-packages\pandas\core\generic.py:3720, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3709 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3711 formatter = DataFrameFormatter(
#    3712     frame=df,
#    3713     header=header,
#    (...)
#    3717     decimal=decimal,
#    3718 )
# -> 3720 return DataFrameRenderer(formatter).to_csv(
#    3721     path_or_buf,
#    3722     lineterminator=lineterminator,
#    3723     sep=sep,
#    3724     encoding=encoding,
#    3725     errors=errors,
#    3726     compression=compression,
#    3727     quoting=quoting,
#    3728     columns=columns,
#    3729     index_label=index_label,
#    3730     mode=mode,
#    3731     chunksize=chunksize,
#    3732     quotechar=quotechar,
#    3733     date_format=date_format,
#    3734     doublequote=doublequote,
#    3735     escapechar=escapechar,
#    3736     storage_options=storage_options,
#    3737 )
#
# File c:\Users\joshu\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\joshu\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1189, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1168     created_buffer = False
#    1170 csv_formatter = CSVFormatter(
#    1171     path_or_buf=path_or_buf,
#    1172     lineterminator=lineterminator,
#    (...)
#    1187     formatter=self.fmt,
#    1188 )
# -> 1189 csv_formatter.save()
#    1191 if created_buffer:
#    1192     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\joshu\anaconda3\Lib\site-packages\pandas\io\formats\csvs.py:241, in CSVFormatter.save(self)
#     237 """
#     238 Create the writer & save.
#     239 """
#     240 # apply compression and byte/text conversion
# --> 241 with get_handle(
#     242     self.filepath_or_buffer,
#     243     self.mode,
#     244     encoding=self.encoding,
#     245     errors=self.errors,
#     246     compression=self.compression,
#     247     storage_options=self.storage_options,
#     248 ) as handles:
#     249
#     250     # Note: self.encoding is irrelevant here
#     251     self.writer = csvlib.writer(
#     252         handles.handle,
#     253         lineterminator=self.lineterminator,
#    (...)
#     258         quotechar=self.quotechar,
#     259     )
#     261     self._save()
#
# File c:\Users\joshu\anaconda3\Lib\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: 'Group1Data.csv'
