# %%
import pandas as pd
import numpy as np
import glob
import os

# Columns to drop
DROP_COLS = ["Country Name", "Series Name"]

# Look for all .xlsx files in the same directory
xlsx_files = glob.glob("*.xlsx")

for xlsx_file in xlsx_files:
    print(f"\n=== Processing {xlsx_file} ===")
    df = pd.read_excel(xlsx_file, sheet_name="Data")
    print("Initial columns:", df.columns.tolist())

    # 1. Drop unwanted columns if they exist
    for col in DROP_COLS:
        if col in df.columns:
            df.drop(columns=[col], inplace=True)
    print("Columns after dropping:", df.columns.tolist())

    # (Optional) Replace ".." with NaN if your data uses that for missing values
    # df.replace("..", np.nan, inplace=True)

    # 2. Identify columns that look like "2021Q1 [YR2021Q1]", etc.
    #    We assume they contain "YR" in the name.
    quarter_cols = [c for c in df.columns if "YR" in c]
    print("Detected quarter columns:", quarter_cols)

    # If no quarter columns found, skip this file
    if not quarter_cols:
        print("No quarter columns found. Skipping this file.")
        continue

    # 3. Melt (unpivot) these quarterly columns into rows
    try:
        df = df.melt(
            id_vars=["Country Code", "Series Code"],  # columns to keep
            value_vars=quarter_cols,
            var_name="Quarter",  # e.g. "2021Q1 [YR2021Q1]"
            value_name="Value"
        )
    except KeyError as e:
        print("ERROR in melt:", e)
        print("Check that 'Country Code' and 'Series Code' exist in df.columns.")
        continue

    print("Columns after melt:", df.columns.tolist())
    print("Sample data after melt:\n", df.head())

    # 4. Extract the 4-digit year from strings like "2021Q1 [YR2021Q1]"
    df["Year"] = df["Quarter"].str.extract(r"(\d{4})").astype(float).dropna().astype(int)

    # 5. Ensure "Value" is numeric (this fixes the aggregation issue)
    df["Value"] = pd.to_numeric(df["Value"], errors="coerce")

    # 6. Group by (Country Code, Series Code, Year) and compute the average of "Value"
    df = df.groupby(["Country Code", "Series Code", "Year"], as_index=False).agg({"Value": "mean"})
    print("Columns after groupby:", df.columns.tolist())
    print("Sample data after groupby:\n", df.head())

    # 7. Drop any rows where "Value" is NaN
    df.dropna(subset=["Value"], inplace=True)

    if df.empty:
        print("No data after dropping NaN values in 'Value'. Skipping reorder/save.")
        continue

    # 8. Reorder columns (only if they exist)
    needed_cols = ["Country Code", "Series Code", "Year", "Value"]
    missing_cols = [col for col in needed_cols if col not in df.columns]
    if missing_cols:
        print(f"ERROR: Missing columns in final DataFrame: {missing_cols}")
        continue

    df = df[needed_cols]

    # 9. Save to CSV (same base name as the original XLSX)
    out_csv = os.path.splitext(xlsx_file)[0] + ".csv"
    df.to_csv(out_csv, index=False)
    print(f"Saved to '{out_csv}'")
# Out:
# === Processing Budgetary Central Gov.(% of GDP) Data - P_Data_Extract_From_Quarterly_Public_Sector_Debt.xlsx ===
# Initial columns: ['Country Name', 'Country Code', 'Series Name', 'Series Code', '2012Q2 [YR2012Q2]', '2012Q3 [YR2012Q3]', '2012Q4 [YR2012Q4]', '2013Q1 [YR2013Q1]', '2013Q2 [YR2013Q2]', '2013Q3 [YR2013Q3]', '2013Q4 [YR2013Q4]', '2014Q1 [YR2014Q1]', '2014Q2 [YR2014Q2]', '2014Q3 [YR2014Q3]', '2014Q4 [YR2014Q4]', '2015Q1 [YR2015Q1]', '2015Q2 [YR2015Q2]', '2015Q3 [YR2015Q3]', '2015Q4 [YR2015Q4]', '2016Q1 [YR2016Q1]', '2016Q2 [YR2016Q2]', '2016Q3 [YR2016Q3]', '2016Q4 [YR2016Q4]', '2017Q1 [YR2017Q1]', '2017Q2 [YR2017Q2]', '2017Q3 [YR2017Q3]', '2017Q4 [YR2017Q4]', '2018Q1 [YR2018Q1]', '2018Q2 [YR2018Q2]', '2018Q3 [YR2018Q3]', '2018Q4 [YR2018Q4]', '2019Q1 [YR2019Q1]', '2019Q2 [YR2019Q2]', '2019Q3 [YR2019Q3]', '2019Q4 [YR2019Q4]', '2020Q1 [YR2020Q1]', '2020Q2 [YR2020Q2]', '2020Q3 [YR2020Q3]', '2020Q4 [YR2020Q4]', '2021Q1 [YR2021Q1]', '2021Q2 [YR2021Q2]', '2021Q3 [YR2021Q3]', '2021Q4 [YR2021Q4]', '2022Q1 [YR2022Q1]', '2022Q2 [YR2022Q2]', '2022Q3 [YR2022Q3]', '2022Q4 [YR2022Q4]', '2023Q1 [YR2023Q1]', '2023Q2 [YR2023Q2]', '2023Q3 [YR2023Q3]', '2023Q4 [YR2023Q4]', '2024Q1 [YR2024Q1]', '2024Q2 [YR2024Q2]', '2024Q3 [YR2024Q3]']
# Columns after dropping: ['Country Code', 'Series Code', '2012Q2 [YR2012Q2]', '2012Q3 [YR2012Q3]', '2012Q4 [YR2012Q4]', '2013Q1 [YR2013Q1]', '2013Q2 [YR2013Q2]', '2013Q3 [YR2013Q3]', '2013Q4 [YR2013Q4]', '2014Q1 [YR2014Q1]', '2014Q2 [YR2014Q2]', '2014Q3 [YR2014Q3]', '2014Q4 [YR2014Q4]', '2015Q1 [YR2015Q1]', '2015Q2 [YR2015Q2]', '2015Q3 [YR2015Q3]', '2015Q4 [YR2015Q4]', '2016Q1 [YR2016Q1]', '2016Q2 [YR2016Q2]', '2016Q3 [YR2016Q3]', '2016Q4 [YR2016Q4]', '2017Q1 [YR2017Q1]', '2017Q2 [YR2017Q2]', '2017Q3 [YR2017Q3]', '2017Q4 [YR2017Q4]', '2018Q1 [YR2018Q1]', '2018Q2 [YR2018Q2]', '2018Q3 [YR2018Q3]', '2018Q4 [YR2018Q4]', '2019Q1 [YR2019Q1]', '2019Q2 [YR2019Q2]', '2019Q3 [YR2019Q3]', '2019Q4 [YR2019Q4]', '2020Q1 [YR2020Q1]', '2020Q2 [YR2020Q2]', '2020Q3 [YR2020Q3]', '2020Q4 [YR2020Q4]', '2021Q1 [YR2021Q1]', '2021Q2 [YR2021Q2]', '2021Q3 [YR2021Q3]', '2021Q4 [YR2021Q4]', '2022Q1 [YR2022Q1]', '2022Q2 [YR2022Q2]', '2022Q3 [YR2022Q3]', '2022Q4 [YR2022Q4]', '2023Q1 [YR2023Q1]', '2023Q2 [YR2023Q2]', '2023Q3 [YR2023Q3]', '2023Q4 [YR2023Q4]', '2024Q1 [YR2024Q1]', '2024Q2 [YR2024Q2]', '2024Q3 [YR2024Q3]']
# Detected quarter columns: ['2012Q2 [YR2012Q2]', '2012Q3 [YR2012Q3]', '2012Q4 [YR2012Q4]', '2013Q1 [YR2013Q1]', '2013Q2 [YR2013Q2]', '2013Q3 [YR2013Q3]', '2013Q4 [YR2013Q4]', '2014Q1 [YR2014Q1]', '2014Q2 [YR2014Q2]', '2014Q3 [YR2014Q3]', '2014Q4 [YR2014Q4]', '2015Q1 [YR2015Q1]', '2015Q2 [YR2015Q2]', '2015Q3 [YR2015Q3]', '2015Q4 [YR2015Q4]', '2016Q1 [YR2016Q1]', '2016Q2 [YR2016Q2]', '2016Q3 [YR2016Q3]', '2016Q4 [YR2016Q4]', '2017Q1 [YR2017Q1]', '2017Q2 [YR2017Q2]', '2017Q3 [YR2017Q3]', '2017Q4 [YR2017Q4]', '2018Q1 [YR2018Q1]', '2018Q2 [YR2018Q2]', '2018Q3 [YR2018Q3]', '2018Q4 [YR2018Q4]', '2019Q1 [YR2019Q1]', '2019Q2 [YR2019Q2]', '2019Q3 [YR2019Q3]', '2019Q4 [YR2019Q4]', '2020Q1 [YR2020Q1]', '2020Q2 [YR2020Q2]', '2020Q3 [YR2020Q3]', '2020Q4 [YR2020Q4]', '2021Q1 [YR2021Q1]', '2021Q2 [YR2021Q2]', '2021Q3 [YR2021Q3]', '2021Q4 [YR2021Q4]', '2022Q1 [YR2022Q1]', '2022Q2 [YR2022Q2]', '2022Q3 [YR2022Q3]', '2022Q4 [YR2022Q4]', '2023Q1 [YR2023Q1]', '2023Q2 [YR2023Q2]', '2023Q3 [YR2023Q3]', '2023Q4 [YR2023Q4]', '2024Q1 [YR2024Q1]', '2024Q2 [YR2024Q2]', '2024Q3 [YR2024Q3]']
# Columns after melt: ['Country Code', 'Series Code', 'Quarter', 'Value']
# Sample data after melt:
#    Country Code           Series Code            Quarter Value
# 0          ALB  DP.DOD.DECD.CR.BC.Z1  2012Q2 [YR2012Q2]    ..
# 1          ALB  DP.DOD.DECN.CR.BC.Z1  2012Q2 [YR2012Q2]    ..
# 2          ALB  DP.DOD.DECX.CR.BC.Z1  2012Q2 [YR2012Q2]    ..
# 3          ALB  DP.DOD.DECF.CR.BC.Z1  2012Q2 [YR2012Q2]    ..
# 4          ALB  DP.DOD.DECT.CR.BC.Z1  2012Q2 [YR2012Q2]    ..
# Columns after groupby: ['Country Code', 'Series Code', 'Year', 'Value']
# Sample data after groupby:
#    Country Code           Series Code  Year  Value
# 0          ALB  DP.DOD.DECD.CR.BC.Z1  2012    NaN
# 1          ALB  DP.DOD.DECD.CR.BC.Z1  2013    NaN
# 2          ALB  DP.DOD.DECD.CR.BC.Z1  2014    NaN
# 3          ALB  DP.DOD.DECD.CR.BC.Z1  2015    NaN
# 4          ALB  DP.DOD.DECD.CR.BC.Z1  2016    NaN
# Saved to 'Budgetary Central Gov.(% of GDP) Data - P_Data_Extract_From_Quarterly_Public_Sector_Debt.csv'
#
# === Processing Central Gov.(% of GDP) Data - P_Data_Extract_From_Quarterly_Public_Sector_Debt.xlsx ===
# Initial columns: ['Country Name', 'Country Code', 'Series Name', 'Series Code', '2012Q2 [YR2012Q2]', '2012Q3 [YR2012Q3]', '2012Q4 [YR2012Q4]', '2013Q1 [YR2013Q1]', '2013Q2 [YR2013Q2]', '2013Q3 [YR2013Q3]', '2013Q4 [YR2013Q4]', '2014Q1 [YR2014Q1]', '2014Q2 [YR2014Q2]', '2014Q3 [YR2014Q3]', '2014Q4 [YR2014Q4]', '2015Q1 [YR2015Q1]', '2015Q2 [YR2015Q2]', '2015Q3 [YR2015Q3]', '2015Q4 [YR2015Q4]', '2016Q1 [YR2016Q1]', '2016Q2 [YR2016Q2]', '2016Q3 [YR2016Q3]', '2016Q4 [YR2016Q4]', '2017Q1 [YR2017Q1]', '2017Q2 [YR2017Q2]', '2017Q3 [YR2017Q3]', '2017Q4 [YR2017Q4]', '2018Q1 [YR2018Q1]', '2018Q2 [YR2018Q2]', '2018Q3 [YR2018Q3]', '2018Q4 [YR2018Q4]', '2019Q1 [YR2019Q1]', '2019Q2 [YR2019Q2]', '2019Q3 [YR2019Q3]', '2019Q4 [YR2019Q4]', '2020Q1 [YR2020Q1]', '2020Q2 [YR2020Q2]', '2020Q3 [YR2020Q3]', '2020Q4 [YR2020Q4]', '2021Q1 [YR2021Q1]', '2021Q2 [YR2021Q2]', '2021Q3 [YR2021Q3]', '2021Q4 [YR2021Q4]', '2022Q1 [YR2022Q1]', '2022Q2 [YR2022Q2]', '2022Q3 [YR2022Q3]', '2022Q4 [YR2022Q4]', '2023Q1 [YR2023Q1]', '2023Q2 [YR2023Q2]', '2023Q3 [YR2023Q3]', '2023Q4 [YR2023Q4]', '2024Q1 [YR2024Q1]', '2024Q2 [YR2024Q2]', '2024Q3 [YR2024Q3]']
# Columns after dropping: ['Country Code', 'Series Code', '2012Q2 [YR2012Q2]', '2012Q3 [YR2012Q3]', '2012Q4 [YR2012Q4]', '2013Q1 [YR2013Q1]', '2013Q2 [YR2013Q2]', '2013Q3 [YR2013Q3]', '2013Q4 [YR2013Q4]', '2014Q1 [YR2014Q1]', '2014Q2 [YR2014Q2]', '2014Q3 [YR2014Q3]', '2014Q4 [YR2014Q4]', '2015Q1 [YR2015Q1]', '2015Q2 [YR2015Q2]', '2015Q3 [YR2015Q3]', '2015Q4 [YR2015Q4]', '2016Q1 [YR2016Q1]', '2016Q2 [YR2016Q2]', '2016Q3 [YR2016Q3]', '2016Q4 [YR2016Q4]', '2017Q1 [YR2017Q1]', '2017Q2 [YR2017Q2]', '2017Q3 [YR2017Q3]', '2017Q4 [YR2017Q4]', '2018Q1 [YR2018Q1]', '2018Q2 [YR2018Q2]', '2018Q3 [YR2018Q3]', '2018Q4 [YR2018Q4]', '2019Q1 [YR2019Q1]', '2019Q2 [YR2019Q2]', '2019Q3 [YR2019Q3]', '2019Q4 [YR2019Q4]', '2020Q1 [YR2020Q1]', '2020Q2 [YR2020Q2]', '2020Q3 [YR2020Q3]', '2020Q4 [YR2020Q4]', '2021Q1 [YR2021Q1]', '2021Q2 [YR2021Q2]', '2021Q3 [YR2021Q3]', '2021Q4 [YR2021Q4]', '2022Q1 [YR2022Q1]', '2022Q2 [YR2022Q2]', '2022Q3 [YR2022Q3]', '2022Q4 [YR2022Q4]', '2023Q1 [YR2023Q1]', '2023Q2 [YR2023Q2]', '2023Q3 [YR2023Q3]', '2023Q4 [YR2023Q4]', '2024Q1 [YR2024Q1]', '2024Q2 [YR2024Q2]', '2024Q3 [YR2024Q3]']
# Detected quarter columns: ['2012Q2 [YR2012Q2]', '2012Q3 [YR2012Q3]', '2012Q4 [YR2012Q4]', '2013Q1 [YR2013Q1]', '2013Q2 [YR2013Q2]', '2013Q3 [YR2013Q3]', '2013Q4 [YR2013Q4]', '2014Q1 [YR2014Q1]', '2014Q2 [YR2014Q2]', '2014Q3 [YR2014Q3]', '2014Q4 [YR2014Q4]', '2015Q1 [YR2015Q1]', '2015Q2 [YR2015Q2]', '2015Q3 [YR2015Q3]', '2015Q4 [YR2015Q4]', '2016Q1 [YR2016Q1]', '2016Q2 [YR2016Q2]', '2016Q3 [YR2016Q3]', '2016Q4 [YR2016Q4]', '2017Q1 [YR2017Q1]', '2017Q2 [YR2017Q2]', '2017Q3 [YR2017Q3]', '2017Q4 [YR2017Q4]', '2018Q1 [YR2018Q1]', '2018Q2 [YR2018Q2]', '2018Q3 [YR2018Q3]', '2018Q4 [YR2018Q4]', '2019Q1 [YR2019Q1]', '2019Q2 [YR2019Q2]', '2019Q3 [YR2019Q3]', '2019Q4 [YR2019Q4]', '2020Q1 [YR2020Q1]', '2020Q2 [YR2020Q2]', '2020Q3 [YR2020Q3]', '2020Q4 [YR2020Q4]', '2021Q1 [YR2021Q1]', '2021Q2 [YR2021Q2]', '2021Q3 [YR2021Q3]', '2021Q4 [YR2021Q4]', '2022Q1 [YR2022Q1]', '2022Q2 [YR2022Q2]', '2022Q3 [YR2022Q3]', '2022Q4 [YR2022Q4]', '2023Q1 [YR2023Q1]', '2023Q2 [YR2023Q2]', '2023Q3 [YR2023Q3]', '2023Q4 [YR2023Q4]', '2024Q1 [YR2024Q1]', '2024Q2 [YR2024Q2]', '2024Q3 [YR2024Q3]']
# Columns after melt: ['Country Code', 'Series Code', 'Quarter', 'Value']
# Sample data after melt:
#    Country Code           Series Code            Quarter      Value
# 0          ALB  DP.DOD.DECD.CR.CG.Z1  2012Q2 [YR2012Q2]  34.284583
# 1          ALB  DP.DOD.DECN.CR.CG.Z1  2012Q2 [YR2012Q2]  33.527553
# 2          ALB  DP.DOD.DECX.CR.CG.Z1  2012Q2 [YR2012Q2]  22.654331
# 3          ALB  DP.DOD.DECF.CR.CG.Z1  2012Q2 [YR2012Q2]  23.411361
# 4          ALB  DP.DOD.DECT.CR.CG.Z1  2012Q2 [YR2012Q2]  56.938914
# Columns after groupby: ['Country Code', 'Series Code', 'Year', 'Value']
# Sample data after groupby:
#    Country Code           Series Code  Year      Value
# 0          ALB  DP.DOD.DECD.CR.CG.Z1  2012  34.538899
# 1          ALB  DP.DOD.DECD.CR.CG.Z1  2013  36.678676
# 2          ALB  DP.DOD.DECD.CR.CG.Z1  2014  39.178708
# 3          ALB  DP.DOD.DECD.CR.CG.Z1  2015  40.071870
# 4          ALB  DP.DOD.DECD.CR.CG.Z1  2016  38.127073
# Saved to 'Central Gov.(% of GDP) Data - P_Data_Extract_From_Quarterly_Public_Sector_Debt.csv'
#
# === Processing Financial Public Corp.(% of GDP) Data - P_Data_Extract_From_Quarterly_Public_Sector_Debt.xlsx ===
# Initial columns: ['Country Name', 'Country Code', 'Series Name', 'Series Code', '2012Q2 [YR2012Q2]', '2012Q3 [YR2012Q3]', '2012Q4 [YR2012Q4]', '2013Q1 [YR2013Q1]', '2013Q2 [YR2013Q2]', '2013Q3 [YR2013Q3]', '2013Q4 [YR2013Q4]', '2014Q1 [YR2014Q1]', '2014Q2 [YR2014Q2]', '2014Q3 [YR2014Q3]', '2014Q4 [YR2014Q4]', '2015Q1 [YR2015Q1]', '2015Q2 [YR2015Q2]', '2015Q3 [YR2015Q3]', '2015Q4 [YR2015Q4]', '2016Q1 [YR2016Q1]', '2016Q2 [YR2016Q2]', '2016Q3 [YR2016Q3]', '2016Q4 [YR2016Q4]', '2017Q1 [YR2017Q1]', '2017Q2 [YR2017Q2]', '2017Q3 [YR2017Q3]', '2017Q4 [YR2017Q4]', '2018Q1 [YR2018Q1]', '2018Q2 [YR2018Q2]', '2018Q3 [YR2018Q3]', '2018Q4 [YR2018Q4]', '2019Q1 [YR2019Q1]', '2019Q2 [YR2019Q2]', '2019Q3 [YR2019Q3]', '2019Q4 [YR2019Q4]', '2020Q1 [YR2020Q1]', '2020Q2 [YR2020Q2]', '2020Q3 [YR2020Q3]', '2020Q4 [YR2020Q4]', '2021Q1 [YR2021Q1]', '2021Q2 [YR2021Q2]', '2021Q3 [YR2021Q3]', '2021Q4 [YR2021Q4]', '2022Q1 [YR2022Q1]', '2022Q2 [YR2022Q2]', '2022Q3 [YR2022Q3]', '2022Q4 [YR2022Q4]', '2023Q1 [YR2023Q1]', '2023Q2 [YR2023Q2]', '2023Q3 [YR2023Q3]', '2023Q4 [YR2023Q4]', '2024Q1 [YR2024Q1]', '2024Q2 [YR2024Q2]', '2024Q3 [YR2024Q3]']
# Columns after dropping: ['Country Code', 'Series Code', '2012Q2 [YR2012Q2]', '2012Q3 [YR2012Q3]', '2012Q4 [YR2012Q4]', '2013Q1 [YR2013Q1]', '2013Q2 [YR2013Q2]', '2013Q3 [YR2013Q3]', '2013Q4 [YR2013Q4]', '2014Q1 [YR2014Q1]', '2014Q2 [YR2014Q2]', '2014Q3 [YR2014Q3]', '2014Q4 [YR2014Q4]', '2015Q1 [YR2015Q1]', '2015Q2 [YR2015Q2]', '2015Q3 [YR2015Q3]', '2015Q4 [YR2015Q4]', '2016Q1 [YR2016Q1]', '2016Q2 [YR2016Q2]', '2016Q3 [YR2016Q3]', '2016Q4 [YR2016Q4]', '2017Q1 [YR2017Q1]', '2017Q2 [YR2017Q2]', '2017Q3 [YR2017Q3]', '2017Q4 [YR2017Q4]', '2018Q1 [YR2018Q1]', '2018Q2 [YR2018Q2]', '2018Q3 [YR2018Q3]', '2018Q4 [YR2018Q4]', '2019Q1 [YR2019Q1]', '2019Q2 [YR2019Q2]', '2019Q3 [YR2019Q3]', '2019Q4 [YR2019Q4]', '2020Q1 [YR2020Q1]', '2020Q2 [YR2020Q2]', '2020Q3 [YR2020Q3]', '2020Q4 [YR2020Q4]', '2021Q1 [YR2021Q1]', '2021Q2 [YR2021Q2]', '2021Q3 [YR2021Q3]', '2021Q4 [YR2021Q4]', '2022Q1 [YR2022Q1]', '2022Q2 [YR2022Q2]', '2022Q3 [YR2022Q3]', '2022Q4 [YR2022Q4]', '2023Q1 [YR2023Q1]', '2023Q2 [YR2023Q2]', '2023Q3 [YR2023Q3]', '2023Q4 [YR2023Q4]', '2024Q1 [YR2024Q1]', '2024Q2 [YR2024Q2]', '2024Q3 [YR2024Q3]']
# Detected quarter columns: ['2012Q2 [YR2012Q2]', '2012Q3 [YR2012Q3]', '2012Q4 [YR2012Q4]', '2013Q1 [YR2013Q1]', '2013Q2 [YR2013Q2]', '2013Q3 [YR2013Q3]', '2013Q4 [YR2013Q4]', '2014Q1 [YR2014Q1]', '2014Q2 [YR2014Q2]', '2014Q3 [YR2014Q3]', '2014Q4 [YR2014Q4]', '2015Q1 [YR2015Q1]', '2015Q2 [YR2015Q2]', '2015Q3 [YR2015Q3]', '2015Q4 [YR2015Q4]', '2016Q1 [YR2016Q1]', '2016Q2 [YR2016Q2]', '2016Q3 [YR2016Q3]', '2016Q4 [YR2016Q4]', '2017Q1 [YR2017Q1]', '2017Q2 [YR2017Q2]', '2017Q3 [YR2017Q3]', '2017Q4 [YR2017Q4]', '2018Q1 [YR2018Q1]', '2018Q2 [YR2018Q2]', '2018Q3 [YR2018Q3]', '2018Q4 [YR2018Q4]', '2019Q1 [YR2019Q1]', '2019Q2 [YR2019Q2]', '2019Q3 [YR2019Q3]', '2019Q4 [YR2019Q4]', '2020Q1 [YR2020Q1]', '2020Q2 [YR2020Q2]', '2020Q3 [YR2020Q3]', '2020Q4 [YR2020Q4]', '2021Q1 [YR2021Q1]', '2021Q2 [YR2021Q2]', '2021Q3 [YR2021Q3]', '2021Q4 [YR2021Q4]', '2022Q1 [YR2022Q1]', '2022Q2 [YR2022Q2]', '2022Q3 [YR2022Q3]', '2022Q4 [YR2022Q4]', '2023Q1 [YR2023Q1]', '2023Q2 [YR2023Q2]', '2023Q3 [YR2023Q3]', '2023Q4 [YR2023Q4]', '2024Q1 [YR2024Q1]', '2024Q2 [YR2024Q2]', '2024Q3 [YR2024Q3]']
# Columns after melt: ['Country Code', 'Series Code', 'Quarter', 'Value']
# Sample data after melt:
#    Country Code           Series Code            Quarter    Value
# 0          ALB  DP.DOD.DECD.CR.FC.Z1  2012Q2 [YR2012Q2]       ..
# 1          ALB  DP.DOD.DECN.CR.FC.Z1  2012Q2 [YR2012Q2]       ..
# 2          ALB  DP.DOD.DECX.CR.FC.Z1  2012Q2 [YR2012Q2]  1.00698
# 3          ALB  DP.DOD.DECF.CR.FC.Z1  2012Q2 [YR2012Q2]  1.00698
# 4          ALB  DP.DOD.DECT.CR.FC.Z1  2012Q2 [YR2012Q2]  1.00698
# Columns after groupby: ['Country Code', 'Series Code', 'Year', 'Value']
# Sample data after groupby:
#    Country Code           Series Code  Year      Value
# 0          ALB  DP.DOD.DECD.CR.FC.Z1  2012        NaN
# 1          ALB  DP.DOD.DECD.CR.FC.Z1  2013        NaN
# 2          ALB  DP.DOD.DECD.CR.FC.Z1  2014  24.991127
# 3          ALB  DP.DOD.DECD.CR.FC.Z1  2015  27.866345
# 4          ALB  DP.DOD.DECD.CR.FC.Z1  2016  28.316450
# Saved to 'Financial Public Corp.(% of GDP) Data - P_Data_Extract_From_Quarterly_Public_Sector_Debt.csv'
#
# === Processing General Gov.(% of GDP) Data - P_Data_Extract_From_Quarterly_Public_Sector_Debt.xlsx ===
# Initial columns: ['Country Name', 'Country Code', 'Series Name', 'Series Code', '2012Q2 [YR2012Q2]', '2012Q3 [YR2012Q3]', '2012Q4 [YR2012Q4]', '2013Q1 [YR2013Q1]', '2013Q2 [YR2013Q2]', '2013Q3 [YR2013Q3]', '2013Q4 [YR2013Q4]', '2014Q1 [YR2014Q1]', '2014Q2 [YR2014Q2]', '2014Q3 [YR2014Q3]', '2014Q4 [YR2014Q4]', '2015Q1 [YR2015Q1]', '2015Q2 [YR2015Q2]', '2015Q3 [YR2015Q3]', '2015Q4 [YR2015Q4]', '2016Q1 [YR2016Q1]', '2016Q2 [YR2016Q2]', '2016Q3 [YR2016Q3]', '2016Q4 [YR2016Q4]', '2017Q1 [YR2017Q1]', '2017Q2 [YR2017Q2]', '2017Q3 [YR2017Q3]', '2017Q4 [YR2017Q4]', '2018Q1 [YR2018Q1]', '2018Q2 [YR2018Q2]', '2018Q3 [YR2018Q3]', '2018Q4 [YR2018Q4]', '2019Q1 [YR2019Q1]', '2019Q2 [YR2019Q2]', '2019Q3 [YR2019Q3]', '2019Q4 [YR2019Q4]', '2020Q1 [YR2020Q1]', '2020Q2 [YR2020Q2]', '2020Q3 [YR2020Q3]', '2020Q4 [YR2020Q4]', '2021Q1 [YR2021Q1]', '2021Q2 [YR2021Q2]', '2021Q3 [YR2021Q3]', '2021Q4 [YR2021Q4]', '2022Q1 [YR2022Q1]', '2022Q2 [YR2022Q2]', '2022Q3 [YR2022Q3]', '2022Q4 [YR2022Q4]', '2023Q1 [YR2023Q1]', '2023Q2 [YR2023Q2]', '2023Q3 [YR2023Q3]', '2023Q4 [YR2023Q4]', '2024Q1 [YR2024Q1]', '2024Q2 [YR2024Q2]', '2024Q3 [YR2024Q3]']
# Columns after dropping: ['Country Code', 'Series Code', '2012Q2 [YR2012Q2]', '2012Q3 [YR2012Q3]', '2012Q4 [YR2012Q4]', '2013Q1 [YR2013Q1]', '2013Q2 [YR2013Q2]', '2013Q3 [YR2013Q3]', '2013Q4 [YR2013Q4]', '2014Q1 [YR2014Q1]', '2014Q2 [YR2014Q2]', '2014Q3 [YR2014Q3]', '2014Q4 [YR2014Q4]', '2015Q1 [YR2015Q1]', '2015Q2 [YR2015Q2]', '2015Q3 [YR2015Q3]', '2015Q4 [YR2015Q4]', '2016Q1 [YR2016Q1]', '2016Q2 [YR2016Q2]', '2016Q3 [YR2016Q3]', '2016Q4 [YR2016Q4]', '2017Q1 [YR2017Q1]', '2017Q2 [YR2017Q2]', '2017Q3 [YR2017Q3]', '2017Q4 [YR2017Q4]', '2018Q1 [YR2018Q1]', '2018Q2 [YR2018Q2]', '2018Q3 [YR2018Q3]', '2018Q4 [YR2018Q4]', '2019Q1 [YR2019Q1]', '2019Q2 [YR2019Q2]', '2019Q3 [YR2019Q3]', '2019Q4 [YR2019Q4]', '2020Q1 [YR2020Q1]', '2020Q2 [YR2020Q2]', '2020Q3 [YR2020Q3]', '2020Q4 [YR2020Q4]', '2021Q1 [YR2021Q1]', '2021Q2 [YR2021Q2]', '2021Q3 [YR2021Q3]', '2021Q4 [YR2021Q4]', '2022Q1 [YR2022Q1]', '2022Q2 [YR2022Q2]', '2022Q3 [YR2022Q3]', '2022Q4 [YR2022Q4]', '2023Q1 [YR2023Q1]', '2023Q2 [YR2023Q2]', '2023Q3 [YR2023Q3]', '2023Q4 [YR2023Q4]', '2024Q1 [YR2024Q1]', '2024Q2 [YR2024Q2]', '2024Q3 [YR2024Q3]']
# Detected quarter columns: ['2012Q2 [YR2012Q2]', '2012Q3 [YR2012Q3]', '2012Q4 [YR2012Q4]', '2013Q1 [YR2013Q1]', '2013Q2 [YR2013Q2]', '2013Q3 [YR2013Q3]', '2013Q4 [YR2013Q4]', '2014Q1 [YR2014Q1]', '2014Q2 [YR2014Q2]', '2014Q3 [YR2014Q3]', '2014Q4 [YR2014Q4]', '2015Q1 [YR2015Q1]', '2015Q2 [YR2015Q2]', '2015Q3 [YR2015Q3]', '2015Q4 [YR2015Q4]', '2016Q1 [YR2016Q1]', '2016Q2 [YR2016Q2]', '2016Q3 [YR2016Q3]', '2016Q4 [YR2016Q4]', '2017Q1 [YR2017Q1]', '2017Q2 [YR2017Q2]', '2017Q3 [YR2017Q3]', '2017Q4 [YR2017Q4]', '2018Q1 [YR2018Q1]', '2018Q2 [YR2018Q2]', '2018Q3 [YR2018Q3]', '2018Q4 [YR2018Q4]', '2019Q1 [YR2019Q1]', '2019Q2 [YR2019Q2]', '2019Q3 [YR2019Q3]', '2019Q4 [YR2019Q4]', '2020Q1 [YR2020Q1]', '2020Q2 [YR2020Q2]', '2020Q3 [YR2020Q3]', '2020Q4 [YR2020Q4]', '2021Q1 [YR2021Q1]', '2021Q2 [YR2021Q2]', '2021Q3 [YR2021Q3]', '2021Q4 [YR2021Q4]', '2022Q1 [YR2022Q1]', '2022Q2 [YR2022Q2]', '2022Q3 [YR2022Q3]', '2022Q4 [YR2022Q4]', '2023Q1 [YR2023Q1]', '2023Q2 [YR2023Q2]', '2023Q3 [YR2023Q3]', '2023Q4 [YR2023Q4]', '2024Q1 [YR2024Q1]', '2024Q2 [YR2024Q2]', '2024Q3 [YR2024Q3]']
# Columns after melt: ['Country Code', 'Series Code', 'Quarter', 'Value']
# Sample data after melt:
#    Country Code           Series Code            Quarter      Value
# 0          ALB  DP.DOD.DECD.CR.GG.Z1  2012Q2 [YR2012Q2]  34.284583
# 1          ALB  DP.DOD.DECN.CR.GG.Z1  2012Q2 [YR2012Q2]  33.527553
# 2          ALB  DP.DOD.DECX.CR.GG.Z1  2012Q2 [YR2012Q2]  22.654331
# 3          ALB  DP.DOD.DECF.CR.GG.Z1  2012Q2 [YR2012Q2]  23.411361
# 4          ALB  DP.DOD.DECT.CR.GG.Z1  2012Q2 [YR2012Q2]  56.938914
# Columns after groupby: ['Country Code', 'Series Code', 'Year', 'Value']
# Sample data after groupby:
#    Country Code           Series Code  Year      Value
# 0          ALB  DP.DOD.DECD.CR.GG.Z1  2012  34.538899
# 1          ALB  DP.DOD.DECD.CR.GG.Z1  2013  36.678676
# 2          ALB  DP.DOD.DECD.CR.GG.Z1  2014  37.371365
# 3          ALB  DP.DOD.DECD.CR.GG.Z1  2015  37.974313
# 4          ALB  DP.DOD.DECD.CR.GG.Z1  2016  35.847041
# Saved to 'General Gov.(% of GDP) Data - P_Data_Extract_From_Quarterly_Public_Sector_Debt.csv'
#
# === Processing Nonfinancial Public Corp.(% of GDP) Data - P_Data_Extract_From_Quarterly_Public_Sector_Debt.xlsx ===
# Initial columns: ['Country Name', 'Country Code', 'Series Name', 'Series Code', '2012Q2 [YR2012Q2]', '2012Q3 [YR2012Q3]', '2012Q4 [YR2012Q4]', '2013Q1 [YR2013Q1]', '2013Q2 [YR2013Q2]', '2013Q3 [YR2013Q3]', '2013Q4 [YR2013Q4]', '2014Q1 [YR2014Q1]', '2014Q2 [YR2014Q2]', '2014Q3 [YR2014Q3]', '2014Q4 [YR2014Q4]', '2015Q1 [YR2015Q1]', '2015Q2 [YR2015Q2]', '2015Q3 [YR2015Q3]', '2015Q4 [YR2015Q4]', '2016Q1 [YR2016Q1]', '2016Q2 [YR2016Q2]', '2016Q3 [YR2016Q3]', '2016Q4 [YR2016Q4]', '2017Q1 [YR2017Q1]', '2017Q2 [YR2017Q2]', '2017Q3 [YR2017Q3]', '2017Q4 [YR2017Q4]', '2018Q1 [YR2018Q1]', '2018Q2 [YR2018Q2]', '2018Q3 [YR2018Q3]', '2018Q4 [YR2018Q4]', '2019Q1 [YR2019Q1]', '2019Q2 [YR2019Q2]', '2019Q3 [YR2019Q3]', '2019Q4 [YR2019Q4]', '2020Q1 [YR2020Q1]', '2020Q2 [YR2020Q2]', '2020Q3 [YR2020Q3]', '2020Q4 [YR2020Q4]', '2021Q1 [YR2021Q1]', '2021Q2 [YR2021Q2]', '2021Q3 [YR2021Q3]', '2021Q4 [YR2021Q4]', '2022Q1 [YR2022Q1]', '2022Q2 [YR2022Q2]', '2022Q3 [YR2022Q3]', '2022Q4 [YR2022Q4]', '2023Q1 [YR2023Q1]', '2023Q2 [YR2023Q2]', '2023Q3 [YR2023Q3]', '2023Q4 [YR2023Q4]', '2024Q1 [YR2024Q1]', '2024Q2 [YR2024Q2]', '2024Q3 [YR2024Q3]']
# Columns after dropping: ['Country Code', 'Series Code', '2012Q2 [YR2012Q2]', '2012Q3 [YR2012Q3]', '2012Q4 [YR2012Q4]', '2013Q1 [YR2013Q1]', '2013Q2 [YR2013Q2]', '2013Q3 [YR2013Q3]', '2013Q4 [YR2013Q4]', '2014Q1 [YR2014Q1]', '2014Q2 [YR2014Q2]', '2014Q3 [YR2014Q3]', '2014Q4 [YR2014Q4]', '2015Q1 [YR2015Q1]', '2015Q2 [YR2015Q2]', '2015Q3 [YR2015Q3]', '2015Q4 [YR2015Q4]', '2016Q1 [YR2016Q1]', '2016Q2 [YR2016Q2]', '2016Q3 [YR2016Q3]', '2016Q4 [YR2016Q4]', '2017Q1 [YR2017Q1]', '2017Q2 [YR2017Q2]', '2017Q3 [YR2017Q3]', '2017Q4 [YR2017Q4]', '2018Q1 [YR2018Q1]', '2018Q2 [YR2018Q2]', '2018Q3 [YR2018Q3]', '2018Q4 [YR2018Q4]', '2019Q1 [YR2019Q1]', '2019Q2 [YR2019Q2]', '2019Q3 [YR2019Q3]', '2019Q4 [YR2019Q4]', '2020Q1 [YR2020Q1]', '2020Q2 [YR2020Q2]', '2020Q3 [YR2020Q3]', '2020Q4 [YR2020Q4]', '2021Q1 [YR2021Q1]', '2021Q2 [YR2021Q2]', '2021Q3 [YR2021Q3]', '2021Q4 [YR2021Q4]', '2022Q1 [YR2022Q1]', '2022Q2 [YR2022Q2]', '2022Q3 [YR2022Q3]', '2022Q4 [YR2022Q4]', '2023Q1 [YR2023Q1]', '2023Q2 [YR2023Q2]', '2023Q3 [YR2023Q3]', '2023Q4 [YR2023Q4]', '2024Q1 [YR2024Q1]', '2024Q2 [YR2024Q2]', '2024Q3 [YR2024Q3]']
# Detected quarter columns: ['2012Q2 [YR2012Q2]', '2012Q3 [YR2012Q3]', '2012Q4 [YR2012Q4]', '2013Q1 [YR2013Q1]', '2013Q2 [YR2013Q2]', '2013Q3 [YR2013Q3]', '2013Q4 [YR2013Q4]', '2014Q1 [YR2014Q1]', '2014Q2 [YR2014Q2]', '2014Q3 [YR2014Q3]', '2014Q4 [YR2014Q4]', '2015Q1 [YR2015Q1]', '2015Q2 [YR2015Q2]', '2015Q3 [YR2015Q3]', '2015Q4 [YR2015Q4]', '2016Q1 [YR2016Q1]', '2016Q2 [YR2016Q2]', '2016Q3 [YR2016Q3]', '2016Q4 [YR2016Q4]', '2017Q1 [YR2017Q1]', '2017Q2 [YR2017Q2]', '2017Q3 [YR2017Q3]', '2017Q4 [YR2017Q4]', '2018Q1 [YR2018Q1]', '2018Q2 [YR2018Q2]', '2018Q3 [YR2018Q3]', '2018Q4 [YR2018Q4]', '2019Q1 [YR2019Q1]', '2019Q2 [YR2019Q2]', '2019Q3 [YR2019Q3]', '2019Q4 [YR2019Q4]', '2020Q1 [YR2020Q1]', '2020Q2 [YR2020Q2]', '2020Q3 [YR2020Q3]', '2020Q4 [YR2020Q4]', '2021Q1 [YR2021Q1]', '2021Q2 [YR2021Q2]', '2021Q3 [YR2021Q3]', '2021Q4 [YR2021Q4]', '2022Q1 [YR2022Q1]', '2022Q2 [YR2022Q2]', '2022Q3 [YR2022Q3]', '2022Q4 [YR2022Q4]', '2023Q1 [YR2023Q1]', '2023Q2 [YR2023Q2]', '2023Q3 [YR2023Q3]', '2023Q4 [YR2023Q4]', '2024Q1 [YR2024Q1]', '2024Q2 [YR2024Q2]', '2024Q3 [YR2024Q3]']
# Columns after melt: ['Country Code', 'Series Code', 'Quarter', 'Value']
# Sample data after melt:
#    Country Code           Series Code            Quarter Value
# 0          ALB  DP.DOD.DECD.CR.NF.Z1  2012Q2 [YR2012Q2]    ..
# 1          ALB  DP.DOD.DECN.CR.NF.Z1  2012Q2 [YR2012Q2]    ..
# 2          ALB  DP.DOD.DECX.CR.NF.Z1  2012Q2 [YR2012Q2]    ..
# 3          ALB  DP.DOD.DECF.CR.NF.Z1  2012Q2 [YR2012Q2]    ..
# 4          ALB  DP.DOD.DECT.CR.NF.Z1  2012Q2 [YR2012Q2]    ..
# Columns after groupby: ['Country Code', 'Series Code', 'Year', 'Value']
# Sample data after groupby:
#    Country Code           Series Code  Year  Value
# 0          ALB  DP.DOD.DECD.CR.NF.Z1  2012    NaN
# 1          ALB  DP.DOD.DECD.CR.NF.Z1  2013    NaN
# 2          ALB  DP.DOD.DECD.CR.NF.Z1  2014    NaN
# 3          ALB  DP.DOD.DECD.CR.NF.Z1  2015    NaN
# 4          ALB  DP.DOD.DECD.CR.NF.Z1  2016    NaN
# Saved to 'Nonfinancial Public Corp.(% of GDP) Data - P_Data_Extract_From_Quarterly_Public_Sector_Debt.csv'
#
# === Processing Total Public Sector, (US$) Data - P_Data_Extract_From_Quarterly_Public_Sector_Debt.xlsx ===
# Initial columns: ['Country Name', 'Country Code', 'Series Name', 'Series Code', '2012Q2 [YR2012Q2]', '2012Q3 [YR2012Q3]', '2012Q4 [YR2012Q4]', '2013Q1 [YR2013Q1]', '2013Q2 [YR2013Q2]', '2013Q3 [YR2013Q3]', '2013Q4 [YR2013Q4]', '2014Q1 [YR2014Q1]', '2014Q2 [YR2014Q2]', '2014Q3 [YR2014Q3]', '2014Q4 [YR2014Q4]', '2015Q1 [YR2015Q1]', '2015Q2 [YR2015Q2]', '2015Q3 [YR2015Q3]', '2015Q4 [YR2015Q4]', '2016Q1 [YR2016Q1]', '2016Q2 [YR2016Q2]', '2016Q3 [YR2016Q3]', '2016Q4 [YR2016Q4]', '2017Q1 [YR2017Q1]', '2017Q2 [YR2017Q2]', '2017Q3 [YR2017Q3]', '2017Q4 [YR2017Q4]', '2018Q1 [YR2018Q1]', '2018Q2 [YR2018Q2]', '2018Q3 [YR2018Q3]', '2018Q4 [YR2018Q4]', '2019Q1 [YR2019Q1]', '2019Q2 [YR2019Q2]', '2019Q3 [YR2019Q3]', '2019Q4 [YR2019Q4]', '2020Q1 [YR2020Q1]', '2020Q2 [YR2020Q2]', '2020Q3 [YR2020Q3]', '2020Q4 [YR2020Q4]', '2021Q1 [YR2021Q1]', '2021Q2 [YR2021Q2]', '2021Q3 [YR2021Q3]', '2021Q4 [YR2021Q4]', '2022Q1 [YR2022Q1]', '2022Q2 [YR2022Q2]', '2022Q3 [YR2022Q3]', '2022Q4 [YR2022Q4]', '2023Q1 [YR2023Q1]', '2023Q2 [YR2023Q2]', '2023Q3 [YR2023Q3]', '2023Q4 [YR2023Q4]', '2024Q1 [YR2024Q1]', '2024Q2 [YR2024Q2]', '2024Q3 [YR2024Q3]']
# Columns after dropping: ['Country Code', 'Series Code', '2012Q2 [YR2012Q2]', '2012Q3 [YR2012Q3]', '2012Q4 [YR2012Q4]', '2013Q1 [YR2013Q1]', '2013Q2 [YR2013Q2]', '2013Q3 [YR2013Q3]', '2013Q4 [YR2013Q4]', '2014Q1 [YR2014Q1]', '2014Q2 [YR2014Q2]', '2014Q3 [YR2014Q3]', '2014Q4 [YR2014Q4]', '2015Q1 [YR2015Q1]', '2015Q2 [YR2015Q2]', '2015Q3 [YR2015Q3]', '2015Q4 [YR2015Q4]', '2016Q1 [YR2016Q1]', '2016Q2 [YR2016Q2]', '2016Q3 [YR2016Q3]', '2016Q4 [YR2016Q4]', '2017Q1 [YR2017Q1]', '2017Q2 [YR2017Q2]', '2017Q3 [YR2017Q3]', '2017Q4 [YR2017Q4]', '2018Q1 [YR2018Q1]', '2018Q2 [YR2018Q2]', '2018Q3 [YR2018Q3]', '2018Q4 [YR2018Q4]', '2019Q1 [YR2019Q1]', '2019Q2 [YR2019Q2]', '2019Q3 [YR2019Q3]', '2019Q4 [YR2019Q4]', '2020Q1 [YR2020Q1]', '2020Q2 [YR2020Q2]', '2020Q3 [YR2020Q3]', '2020Q4 [YR2020Q4]', '2021Q1 [YR2021Q1]', '2021Q2 [YR2021Q2]', '2021Q3 [YR2021Q3]', '2021Q4 [YR2021Q4]', '2022Q1 [YR2022Q1]', '2022Q2 [YR2022Q2]', '2022Q3 [YR2022Q3]', '2022Q4 [YR2022Q4]', '2023Q1 [YR2023Q1]', '2023Q2 [YR2023Q2]', '2023Q3 [YR2023Q3]', '2023Q4 [YR2023Q4]', '2024Q1 [YR2024Q1]', '2024Q2 [YR2024Q2]', '2024Q3 [YR2024Q3]']
# Detected quarter columns: ['2012Q2 [YR2012Q2]', '2012Q3 [YR2012Q3]', '2012Q4 [YR2012Q4]', '2013Q1 [YR2013Q1]', '2013Q2 [YR2013Q2]', '2013Q3 [YR2013Q3]', '2013Q4 [YR2013Q4]', '2014Q1 [YR2014Q1]', '2014Q2 [YR2014Q2]', '2014Q3 [YR2014Q3]', '2014Q4 [YR2014Q4]', '2015Q1 [YR2015Q1]', '2015Q2 [YR2015Q2]', '2015Q3 [YR2015Q3]', '2015Q4 [YR2015Q4]', '2016Q1 [YR2016Q1]', '2016Q2 [YR2016Q2]', '2016Q3 [YR2016Q3]', '2016Q4 [YR2016Q4]', '2017Q1 [YR2017Q1]', '2017Q2 [YR2017Q2]', '2017Q3 [YR2017Q3]', '2017Q4 [YR2017Q4]', '2018Q1 [YR2018Q1]', '2018Q2 [YR2018Q2]', '2018Q3 [YR2018Q3]', '2018Q4 [YR2018Q4]', '2019Q1 [YR2019Q1]', '2019Q2 [YR2019Q2]', '2019Q3 [YR2019Q3]', '2019Q4 [YR2019Q4]', '2020Q1 [YR2020Q1]', '2020Q2 [YR2020Q2]', '2020Q3 [YR2020Q3]', '2020Q4 [YR2020Q4]', '2021Q1 [YR2021Q1]', '2021Q2 [YR2021Q2]', '2021Q3 [YR2021Q3]', '2021Q4 [YR2021Q4]', '2022Q1 [YR2022Q1]', '2022Q2 [YR2022Q2]', '2022Q3 [YR2022Q3]', '2022Q4 [YR2022Q4]', '2023Q1 [YR2023Q1]', '2023Q2 [YR2023Q2]', '2023Q3 [YR2023Q3]', '2023Q4 [YR2023Q4]', '2024Q1 [YR2024Q1]', '2024Q2 [YR2024Q2]', '2024Q3 [YR2024Q3]']
# Columns after melt: ['Country Code', 'Series Code', 'Quarter', 'Value']
# Sample data after melt:
#    Country Code           Series Code            Quarter             Value
# 0          ALB  DP.DOD.DECD.CR.PS.CD  2012Q2 [YR2012Q2]  4126806730.99356
# 1          ALB  DP.DOD.DECN.CR.PS.CD  2012Q2 [YR2012Q2]     4035683625.54
# 2          ALB  DP.DOD.DECX.CR.PS.CD  2012Q2 [YR2012Q2]  2848092298.02379
# 3          ALB  DP.DOD.DECF.CR.PS.CD  2012Q2 [YR2012Q2]  2939215403.47735
# 4          ALB  DP.DOD.DECT.CR.PS.CD  2012Q2 [YR2012Q2]  6974899029.01734
# Columns after groupby: ['Country Code', 'Series Code', 'Year', 'Value']
# Sample data after groupby:
#    Country Code           Series Code  Year         Value
# 0          ALB  DP.DOD.DECD.CR.PS.CD  2012  4.435497e+09
# 1          ALB  DP.DOD.DECD.CR.PS.CD  2013  6.830870e+09
# 2          ALB  DP.DOD.DECD.CR.PS.CD  2014  7.406541e+09
# 3          ALB  DP.DOD.DECD.CR.PS.CD  2015  6.895552e+09
# 4          ALB  DP.DOD.DECD.CR.PS.CD  2016  7.060373e+09
# Saved to 'Total Public Sector, (US$) Data - P_Data_Extract_From_Quarterly_Public_Sector_Debt.csv'
