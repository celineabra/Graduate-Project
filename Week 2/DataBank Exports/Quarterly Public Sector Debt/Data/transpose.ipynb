# %%
import pandas as pd
import numpy as np
import glob
import os

# Columns to drop
DROP_COLS = ["Country Name", "Series Name"]

# Look for all .xlsx files in the same directory
xlsx_files = glob.glob("*.xlsx")

for xlsx_file in xlsx_files:
    print(f"\n=== Processing {xlsx_file} ===")
    df = pd.read_excel(xlsx_file, sheet_name="Data")
    print("Initial columns:", df.columns.tolist())

    # 1. Drop unwanted columns if they exist
    for col in DROP_COLS:
        if col in df.columns:
            df.drop(columns=[col], inplace=True)
    print("Columns after dropping:", df.columns.tolist())

    # (Optional) Replace ".." with NaN if your data uses that for missing values
    # df.replace("..", np.nan, inplace=True)

    # 2. Identify columns that look like "2021Q1 [YR2021Q1]", etc.
    #    We assume they contain "YR" in the name.
    quarter_cols = [c for c in df.columns if "YR" in c]
    print("Detected quarter columns:", quarter_cols)

    # If no quarter columns found, skip this file
    if not quarter_cols:
        print("No quarter columns found. Skipping this file.")
        continue

    # 3. Melt (unpivot) these quarterly columns into rows
    try:
        df = df.melt(
            id_vars=["Country Code", "Series Code"],  # columns to keep
            value_vars=quarter_cols,
            var_name="Quarter",  # e.g. "2021Q1 [YR2021Q1]"
            value_name="Value"
        )
    except KeyError as e:
        print("ERROR in melt:", e)
        print("Check that 'Country Code' and 'Series Code' exist in df.columns.")
        continue

    print("Columns after melt:", df.columns.tolist())
    print("Sample data after melt:\n", df.head())

    # 4. Extract the 4-digit year from strings like "2021Q1 [YR2021Q1]"
    df["Year"] = df["Quarter"].str.extract(r"(\d{4})").astype(float).dropna().astype(int)

    # 5. Ensure "Value" is numeric (this fixes the aggregation issue)
    df["Value"] = pd.to_numeric(df["Value"], errors="coerce")

    # 6. Group by (Country Code, Series Code, Year) and compute the average of "Value"
    df = df.groupby(["Country Code", "Series Code", "Year"], as_index=False).agg({"Value": "mean"})
    print("Columns after groupby:", df.columns.tolist())
    print("Sample data after groupby:\n", df.head())

    # 7. Drop any rows where "Value" is NaN
    df.dropna(subset=["Value"], inplace=True)

    if df.empty:
        print("No data after dropping NaN values in 'Value'. Skipping reorder/save.")
        continue

    # 8. Reorder columns (only if they exist)
    needed_cols = ["Country Code", "Series Code", "Year", "Value"]
    missing_cols = [col for col in needed_cols if col not in df.columns]
    if missing_cols:
        print(f"ERROR: Missing columns in final DataFrame: {missing_cols}")
        continue

    df = df[needed_cols]

    # 9. Save to CSV (same base name as the original XLSX)
    out_csv = os.path.splitext(xlsx_file)[0] + ".csv"
    df.to_csv(out_csv, index=False)
    print(f"Saved to '{out_csv}'")
# Out:
# === Processing Budgetary Central Gov.(% of GDP) Data - P_Data_Extract_From_Quarterly_Public_Sector_Debt.xlsx ===
# Initial columns: ['Country Name', 'Country Code', 'Series Name', 'Series Code', '2021Q1 [YR2021Q1]', '2021Q2 [YR2021Q2]', '2021Q3 [YR2021Q3]', '2021Q4 [YR2021Q4]', '2022Q1 [YR2022Q1]', '2022Q2 [YR2022Q2]', '2022Q3 [YR2022Q3]', '2022Q4 [YR2022Q4]', '2023Q1 [YR2023Q1]', '2023Q2 [YR2023Q2]', '2023Q3 [YR2023Q3]', '2023Q4 [YR2023Q4]']
# Columns after dropping: ['Country Code', 'Series Code', '2021Q1 [YR2021Q1]', '2021Q2 [YR2021Q2]', '2021Q3 [YR2021Q3]', '2021Q4 [YR2021Q4]', '2022Q1 [YR2022Q1]', '2022Q2 [YR2022Q2]', '2022Q3 [YR2022Q3]', '2022Q4 [YR2022Q4]', '2023Q1 [YR2023Q1]', '2023Q2 [YR2023Q2]', '2023Q3 [YR2023Q3]', '2023Q4 [YR2023Q4]']
# Detected quarter columns: ['2021Q1 [YR2021Q1]', '2021Q2 [YR2021Q2]', '2021Q3 [YR2021Q3]', '2021Q4 [YR2021Q4]', '2022Q1 [YR2022Q1]', '2022Q2 [YR2022Q2]', '2022Q3 [YR2022Q3]', '2022Q4 [YR2022Q4]', '2023Q1 [YR2023Q1]', '2023Q2 [YR2023Q2]', '2023Q3 [YR2023Q3]', '2023Q4 [YR2023Q4]']
# Columns after melt: ['Country Code', 'Series Code', 'Quarter', 'Value']
# Sample data after melt:
#    Country Code           Series Code            Quarter Value
# 0          ALB  DP.DOD.DECD.CR.BC.Z1  2021Q1 [YR2021Q1]    ..
# 1          ALB  DP.DOD.DECN.CR.BC.Z1  2021Q1 [YR2021Q1]    ..
# 2          ALB  DP.DOD.DECX.CR.BC.Z1  2021Q1 [YR2021Q1]    ..
# 3          ALB  DP.DOD.DECF.CR.BC.Z1  2021Q1 [YR2021Q1]    ..
# 4          ALB  DP.DOD.DECT.CR.BC.Z1  2021Q1 [YR2021Q1]    ..
# Columns after groupby: ['Country Code', 'Series Code', 'Year', 'Value']
# Sample data after groupby:
#    Country Code           Series Code  Year  Value
# 0          ALB  DP.DOD.DECD.CR.BC.Z1  2021    NaN
# 1          ALB  DP.DOD.DECD.CR.BC.Z1  2022    NaN
# 2          ALB  DP.DOD.DECD.CR.BC.Z1  2023    NaN
# 3          ALB  DP.DOD.DECF.CR.BC.Z1  2021    NaN
# 4          ALB  DP.DOD.DECF.CR.BC.Z1  2022    NaN
# Saved to 'Budgetary Central Gov.(% of GDP) Data - P_Data_Extract_From_Quarterly_Public_Sector_Debt.csv'
#
# === Processing Central Gov.(% of GDP) Data - P_Data_Extract_From_Quarterly_Public_Sector_Debt.xlsx ===
# Initial columns: ['Country Name', 'Country Code', 'Series Name', 'Series Code', '2021Q1 [YR2021Q1]', '2021Q2 [YR2021Q2]', '2021Q3 [YR2021Q3]', '2021Q4 [YR2021Q4]', '2022Q1 [YR2022Q1]', '2022Q2 [YR2022Q2]', '2022Q3 [YR2022Q3]', '2022Q4 [YR2022Q4]', '2023Q1 [YR2023Q1]', '2023Q2 [YR2023Q2]', '2023Q3 [YR2023Q3]', '2023Q4 [YR2023Q4]']
# Columns after dropping: ['Country Code', 'Series Code', '2021Q1 [YR2021Q1]', '2021Q2 [YR2021Q2]', '2021Q3 [YR2021Q3]', '2021Q4 [YR2021Q4]', '2022Q1 [YR2022Q1]', '2022Q2 [YR2022Q2]', '2022Q3 [YR2022Q3]', '2022Q4 [YR2022Q4]', '2023Q1 [YR2023Q1]', '2023Q2 [YR2023Q2]', '2023Q3 [YR2023Q3]', '2023Q4 [YR2023Q4]']
# Detected quarter columns: ['2021Q1 [YR2021Q1]', '2021Q2 [YR2021Q2]', '2021Q3 [YR2021Q3]', '2021Q4 [YR2021Q4]', '2022Q1 [YR2022Q1]', '2022Q2 [YR2022Q2]', '2022Q3 [YR2022Q3]', '2022Q4 [YR2022Q4]', '2023Q1 [YR2023Q1]', '2023Q2 [YR2023Q2]', '2023Q3 [YR2023Q3]', '2023Q4 [YR2023Q4]']
# Columns after melt: ['Country Code', 'Series Code', 'Quarter', 'Value']
# Sample data after melt:
#    Country Code           Series Code            Quarter      Value
# 0          ALB  DP.DOD.DECD.CR.CG.Z1  2021Q1 [YR2021Q1]  38.923696
# 1          ALB  DP.DOD.DECN.CR.CG.Z1  2021Q1 [YR2021Q1]  35.748197
# 2          ALB  DP.DOD.DECX.CR.CG.Z1  2021Q1 [YR2021Q1]  31.053842
# 3          ALB  DP.DOD.DECF.CR.CG.Z1  2021Q1 [YR2021Q1]   34.22934
# 4          ALB  DP.DOD.DECT.CR.CG.Z1  2021Q1 [YR2021Q1]  69.977538
# Columns after groupby: ['Country Code', 'Series Code', 'Year', 'Value']
# Sample data after groupby:
#    Country Code           Series Code  Year      Value
# 0          ALB  DP.DOD.DECD.CR.CG.Z1  2021  38.051008
# 1          ALB  DP.DOD.DECD.CR.CG.Z1  2022  35.807544
# 2          ALB  DP.DOD.DECD.CR.CG.Z1  2023  33.856196
# 3          ALB  DP.DOD.DECF.CR.CG.Z1  2021  33.104567
# 4          ALB  DP.DOD.DECF.CR.CG.Z1  2022  32.000788
# Saved to 'Central Gov.(% of GDP) Data - P_Data_Extract_From_Quarterly_Public_Sector_Debt.csv'
#
# === Processing Financial Public Corp.(% of GDP) Data - P_Data_Extract_From_Quarterly_Public_Sector_Debt.xlsx ===
# Initial columns: ['Country Name', 'Country Code', 'Series Name', 'Series Code', '2021Q1 [YR2021Q1]', '2021Q2 [YR2021Q2]', '2021Q3 [YR2021Q3]', '2021Q4 [YR2021Q4]', '2022Q1 [YR2022Q1]', '2022Q2 [YR2022Q2]', '2022Q3 [YR2022Q3]', '2022Q4 [YR2022Q4]', '2023Q1 [YR2023Q1]', '2023Q2 [YR2023Q2]', '2023Q3 [YR2023Q3]', '2023Q4 [YR2023Q4]']
# Columns after dropping: ['Country Code', 'Series Code', '2021Q1 [YR2021Q1]', '2021Q2 [YR2021Q2]', '2021Q3 [YR2021Q3]', '2021Q4 [YR2021Q4]', '2022Q1 [YR2022Q1]', '2022Q2 [YR2022Q2]', '2022Q3 [YR2022Q3]', '2022Q4 [YR2022Q4]', '2023Q1 [YR2023Q1]', '2023Q2 [YR2023Q2]', '2023Q3 [YR2023Q3]', '2023Q4 [YR2023Q4]']
# Detected quarter columns: ['2021Q1 [YR2021Q1]', '2021Q2 [YR2021Q2]', '2021Q3 [YR2021Q3]', '2021Q4 [YR2021Q4]', '2022Q1 [YR2022Q1]', '2022Q2 [YR2022Q2]', '2022Q3 [YR2022Q3]', '2022Q4 [YR2022Q4]', '2023Q1 [YR2023Q1]', '2023Q2 [YR2023Q2]', '2023Q3 [YR2023Q3]', '2023Q4 [YR2023Q4]']
# Columns after melt: ['Country Code', 'Series Code', 'Quarter', 'Value']
# Sample data after melt:
#    Country Code           Series Code            Quarter      Value
# 0          ALB  DP.DOD.DECD.CR.FC.Z1  2021Q1 [YR2021Q1]  34.621836
# 1          ALB  DP.DOD.DECN.CR.FC.Z1  2021Q1 [YR2021Q1]  26.453933
# 2          ALB  DP.DOD.DECX.CR.FC.Z1  2021Q1 [YR2021Q1]    0.40897
# 3          ALB  DP.DOD.DECF.CR.FC.Z1  2021Q1 [YR2021Q1]   8.576872
# 4          ALB  DP.DOD.DECT.CR.FC.Z1  2021Q1 [YR2021Q1]  35.030805
# Columns after groupby: ['Country Code', 'Series Code', 'Year', 'Value']
# Sample data after groupby:
#    Country Code           Series Code  Year      Value
# 0          ALB  DP.DOD.DECD.CR.FC.Z1  2021  33.832733
# 1          ALB  DP.DOD.DECD.CR.FC.Z1  2022  33.374976
# 2          ALB  DP.DOD.DECD.CR.FC.Z1  2023  31.965986
# 3          ALB  DP.DOD.DECF.CR.FC.Z1  2021   9.112806
# 4          ALB  DP.DOD.DECF.CR.FC.Z1  2022  10.827746
# Saved to 'Financial Public Corp.(% of GDP) Data - P_Data_Extract_From_Quarterly_Public_Sector_Debt.csv'
#
# === Processing General Gov.(% of GDP) Data - P_Data_Extract_From_Quarterly_Public_Sector_Debt.xlsx ===
# Initial columns: ['Country Name', 'Country Code', 'Series Name', 'Series Code', '2021Q1 [YR2021Q1]', '2021Q2 [YR2021Q2]', '2021Q3 [YR2021Q3]', '2021Q4 [YR2021Q4]', '2022Q1 [YR2022Q1]', '2022Q2 [YR2022Q2]', '2022Q3 [YR2022Q3]', '2022Q4 [YR2022Q4]', '2023Q1 [YR2023Q1]', '2023Q2 [YR2023Q2]', '2023Q3 [YR2023Q3]', '2023Q4 [YR2023Q4]']
# Columns after dropping: ['Country Code', 'Series Code', '2021Q1 [YR2021Q1]', '2021Q2 [YR2021Q2]', '2021Q3 [YR2021Q3]', '2021Q4 [YR2021Q4]', '2022Q1 [YR2022Q1]', '2022Q2 [YR2022Q2]', '2022Q3 [YR2022Q3]', '2022Q4 [YR2022Q4]', '2023Q1 [YR2023Q1]', '2023Q2 [YR2023Q2]', '2023Q3 [YR2023Q3]', '2023Q4 [YR2023Q4]']
# Detected quarter columns: ['2021Q1 [YR2021Q1]', '2021Q2 [YR2021Q2]', '2021Q3 [YR2021Q3]', '2021Q4 [YR2021Q4]', '2022Q1 [YR2022Q1]', '2022Q2 [YR2022Q2]', '2022Q3 [YR2022Q3]', '2022Q4 [YR2022Q4]', '2023Q1 [YR2023Q1]', '2023Q2 [YR2023Q2]', '2023Q3 [YR2023Q3]', '2023Q4 [YR2023Q4]']
# Columns after melt: ['Country Code', 'Series Code', 'Quarter', 'Value']
# Sample data after melt:
#    Country Code           Series Code            Quarter      Value
# 0          ALB  DP.DOD.DECD.CR.GG.Z1  2021Q1 [YR2021Q1]  38.221839
# 1          ALB  DP.DOD.DECN.CR.GG.Z1  2021Q1 [YR2021Q1]  35.046341
# 2          ALB  DP.DOD.DECX.CR.GG.Z1  2021Q1 [YR2021Q1]  31.053842
# 3          ALB  DP.DOD.DECF.CR.GG.Z1  2021Q1 [YR2021Q1]   34.22934
# 4          ALB  DP.DOD.DECT.CR.GG.Z1  2021Q1 [YR2021Q1]  69.275681
# Columns after groupby: ['Country Code', 'Series Code', 'Year', 'Value']
# Sample data after groupby:
#    Country Code           Series Code  Year      Value
# 0          ALB  DP.DOD.DECD.CR.GG.Z1  2021  37.336108
# 1          ALB  DP.DOD.DECD.CR.GG.Z1  2022  34.799446
# 2          ALB  DP.DOD.DECD.CR.GG.Z1  2023  32.912900
# 3          ALB  DP.DOD.DECF.CR.GG.Z1  2021  33.104567
# 4          ALB  DP.DOD.DECF.CR.GG.Z1  2022  32.000788
# Saved to 'General Gov.(% of GDP) Data - P_Data_Extract_From_Quarterly_Public_Sector_Debt.csv'
#
# === Processing Nonfinancial Public Corp.(% of GDP) Data - P_Data_Extract_From_Quarterly_Public_Sector_Debt.xlsx ===
# Initial columns: ['Country Name', 'Country Code', 'Series Name', 'Series Code', '2021Q1 [YR2021Q1]', '2021Q2 [YR2021Q2]', '2021Q3 [YR2021Q3]', '2021Q4 [YR2021Q4]', '2022Q1 [YR2022Q1]', '2022Q2 [YR2022Q2]', '2022Q3 [YR2022Q3]', '2022Q4 [YR2022Q4]', '2023Q1 [YR2023Q1]', '2023Q2 [YR2023Q2]', '2023Q3 [YR2023Q3]', '2023Q4 [YR2023Q4]']
# Columns after dropping: ['Country Code', 'Series Code', '2021Q1 [YR2021Q1]', '2021Q2 [YR2021Q2]', '2021Q3 [YR2021Q3]', '2021Q4 [YR2021Q4]', '2022Q1 [YR2022Q1]', '2022Q2 [YR2022Q2]', '2022Q3 [YR2022Q3]', '2022Q4 [YR2022Q4]', '2023Q1 [YR2023Q1]', '2023Q2 [YR2023Q2]', '2023Q3 [YR2023Q3]', '2023Q4 [YR2023Q4]']
# Detected quarter columns: ['2021Q1 [YR2021Q1]', '2021Q2 [YR2021Q2]', '2021Q3 [YR2021Q3]', '2021Q4 [YR2021Q4]', '2022Q1 [YR2022Q1]', '2022Q2 [YR2022Q2]', '2022Q3 [YR2022Q3]', '2022Q4 [YR2022Q4]', '2023Q1 [YR2023Q1]', '2023Q2 [YR2023Q2]', '2023Q3 [YR2023Q3]', '2023Q4 [YR2023Q4]']
# Columns after melt: ['Country Code', 'Series Code', 'Quarter', 'Value']
# Sample data after melt:
#    Country Code           Series Code            Quarter Value
# 0          ALB  DP.DOD.DECD.CR.NF.Z1  2021Q1 [YR2021Q1]    ..
# 1          ALB  DP.DOD.DECN.CR.NF.Z1  2021Q1 [YR2021Q1]    ..
# 2          ALB  DP.DOD.DECX.CR.NF.Z1  2021Q1 [YR2021Q1]    ..
# 3          ALB  DP.DOD.DECF.CR.NF.Z1  2021Q1 [YR2021Q1]    ..
# 4          ALB  DP.DOD.DECT.CR.NF.Z1  2021Q1 [YR2021Q1]    ..
# Columns after groupby: ['Country Code', 'Series Code', 'Year', 'Value']
# Sample data after groupby:
#    Country Code           Series Code  Year  Value
# 0          ALB  DP.DOD.DECD.CR.NF.Z1  2021    NaN
# 1          ALB  DP.DOD.DECD.CR.NF.Z1  2022    NaN
# 2          ALB  DP.DOD.DECD.CR.NF.Z1  2023    NaN
# 3          ALB  DP.DOD.DECF.CR.NF.Z1  2021    NaN
# 4          ALB  DP.DOD.DECF.CR.NF.Z1  2022    NaN
# Saved to 'Nonfinancial Public Corp.(% of GDP) Data - P_Data_Extract_From_Quarterly_Public_Sector_Debt.csv'
#
# === Processing Total Public Sector, (US$) Data - P_Data_Extract_From_Quarterly_Public_Sector_Debt.xlsx ===
# Initial columns: ['Country Name', 'Country Code', 'Series Name', 'Series Code', '2021Q1 [YR2021Q1]', '2021Q2 [YR2021Q2]', '2021Q3 [YR2021Q3]', '2021Q4 [YR2021Q4]', '2022Q1 [YR2022Q1]', '2022Q2 [YR2022Q2]', '2022Q3 [YR2022Q3]', '2022Q4 [YR2022Q4]', '2023Q1 [YR2023Q1]', '2023Q2 [YR2023Q2]', '2023Q3 [YR2023Q3]', '2023Q4 [YR2023Q4]']
# Columns after dropping: ['Country Code', 'Series Code', '2021Q1 [YR2021Q1]', '2021Q2 [YR2021Q2]', '2021Q3 [YR2021Q3]', '2021Q4 [YR2021Q4]', '2022Q1 [YR2022Q1]', '2022Q2 [YR2022Q2]', '2022Q3 [YR2022Q3]', '2022Q4 [YR2022Q4]', '2023Q1 [YR2023Q1]', '2023Q2 [YR2023Q2]', '2023Q3 [YR2023Q3]', '2023Q4 [YR2023Q4]']
# Detected quarter columns: ['2021Q1 [YR2021Q1]', '2021Q2 [YR2021Q2]', '2021Q3 [YR2021Q3]', '2021Q4 [YR2021Q4]', '2022Q1 [YR2022Q1]', '2022Q2 [YR2022Q2]', '2022Q3 [YR2022Q3]', '2022Q4 [YR2022Q4]', '2023Q1 [YR2023Q1]', '2023Q2 [YR2023Q2]', '2023Q3 [YR2023Q3]', '2023Q4 [YR2023Q4]']
# Columns after melt: ['Country Code', 'Series Code', 'Quarter', 'Value']
# Sample data after melt:
#    Country Code           Series Code            Quarter               Value
# 0          ALB  DP.DOD.DECD.CR.PS.CD  2021Q1 [YR2021Q1]  11171698787.809072
# 1          ALB  DP.DOD.DECN.CR.PS.CD  2021Q1 [YR2021Q1]   9345981024.429033
# 2          ALB  DP.DOD.DECX.CR.PS.CD  2021Q1 [YR2021Q1]   5063932166.474254
# 3          ALB  DP.DOD.DECF.CR.PS.CD  2021Q1 [YR2021Q1]   6889649929.854237
# 4          ALB  DP.DOD.DECT.CR.PS.CD  2021Q1 [YR2021Q1]  16235630954.283289
# Columns after groupby: ['Country Code', 'Series Code', 'Year', 'Value']
# Sample data after groupby:
#    Country Code           Series Code  Year         Value
# 0          ALB  DP.DOD.DECD.CR.PS.CD  2021  1.155376e+10
# 1          ALB  DP.DOD.DECD.CR.PS.CD  2022  1.180344e+10
# 2          ALB  DP.DOD.DECD.CR.PS.CD  2023  1.428776e+10
# 3          ALB  DP.DOD.DECF.CR.PS.CD  2021  7.202409e+09
# 4          ALB  DP.DOD.DECF.CR.PS.CD  2022  7.738228e+09
# Saved to 'Total Public Sector, (US$) Data - P_Data_Extract_From_Quarterly_Public_Sector_Debt.csv'
